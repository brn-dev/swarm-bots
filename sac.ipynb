# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.swarm_bot_env import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        if step % 100_000 == 0:
            save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=3, 
        hip_range=np.pi / 3.5,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, 256),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=256,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 249370
# env = <swarmbots.swarm_bot_env.SwarmBotEnv object at 0x000001CFBED9B550>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
# Starting Training
#
#
# step = 11000, num_env_steps = 11000, scores = -1.968 ± 0.13 (n=2), actor_loss = -37.641, critic_loss = 3.442, entropy_coef_loss = -5.894, entropy_coef = 0.740, action_stds = 0.847 ± 0.051, action_magnitude = 0.524 ± 0.289, num_gradient_steps = 1000, step_time = 11.80, total_time = 11.74
#
#
# step = 12000, num_env_steps = 12000, scores = -2.130 ± 0.20 (n=2), actor_loss = -55.528, critic_loss = 2.323, entropy_coef_loss = -11.935, entropy_coef = 0.549, action_stds = 0.893 ± 0.045, action_magnitude = 0.534 ± 0.289, num_gradient_steps = 2000, step_time = 7.16, total_time = 18.91
#
#
# step = 13000, num_env_steps = 13000, scores = -2.109 ± 0.24 (n=2), actor_loss = -66.975, critic_loss = 1.828, entropy_coef_loss = -17.933, entropy_coef = 0.406, action_stds = 0.899 ± 0.022, action_magnitude = 0.532 ± 0.287, num_gradient_steps = 3000, step_time = 7.13, total_time = 26.04
#
#
# step = 14000, num_env_steps = 14000, scores = -2.396 ± 0.01 (n=2), actor_loss = -73.543, critic_loss = 1.432, entropy_coef_loss = -23.813, entropy_coef = 0.301, action_stds = 0.913 ± 0.025, action_magnitude = 0.536 ± 0.290, num_gradient_steps = 4000, step_time = 7.30, total_time = 33.34
#
#
# step = 15000, num_env_steps = 15000, scores = -2.203 ± 0.05 (n=2), actor_loss = -76.943, critic_loss = 1.235, entropy_coef_loss = -29.424, entropy_coef = 0.223, action_stds = 0.904 ± 0.064, action_magnitude = 0.543 ± 0.289, num_gradient_steps = 5000, step_time = 7.01, total_time = 40.35
#
#
# step = 16000, num_env_steps = 16000, scores = -2.451 ± 0.24 (n=2), actor_loss = -78.052, critic_loss = 1.344, entropy_coef_loss = -34.352, entropy_coef = 0.166, action_stds = 0.891 ± 0.045, action_magnitude = 0.556 ± 0.290, num_gradient_steps = 6000, step_time = 7.12, total_time = 47.47
#
#
# step = 17000, num_env_steps = 17000, scores = -2.246 ± 0.17 (n=2), actor_loss = -77.139, critic_loss = 1.149, entropy_coef_loss = -38.323, entropy_coef = 0.124, action_stds = 0.909 ± 0.036, action_magnitude = 0.557 ± 0.292, num_gradient_steps = 7000, step_time = 7.23, total_time = 54.69
#
#
# step = 18000, num_env_steps = 18000, scores = -2.331 ± 0.04 (n=2), actor_loss = -76.481, critic_loss = 0.900, entropy_coef_loss = -42.540, entropy_coef = 0.092, action_stds = 0.879 ± 0.047, action_magnitude = 0.570 ± 0.295, num_gradient_steps = 8000, step_time = 7.18, total_time = 61.88
#
#
# step = 19000, num_env_steps = 19000, scores = -2.749 ± 0.10 (n=2), actor_loss = -74.622, critic_loss = 0.705, entropy_coef_loss = -45.813, entropy_coef = 0.069, action_stds = 0.933 ± 0.039, action_magnitude = 0.581 ± 0.295, num_gradient_steps = 9000, step_time = 7.19, total_time = 69.07
#
#
# step = 20000, num_env_steps = 20000, scores = -2.722 ± 0.03 (n=2), actor_loss = -71.858, critic_loss = 0.651, entropy_coef_loss = -47.282, entropy_coef = 0.052, action_stds = 0.788 ± 0.095, action_magnitude = 0.592 ± 0.296, num_gradient_steps = 10000, step_time = 7.18, total_time = 76.25
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 21000, num_env_steps = 21000, scores = -2.893 ± 0.16 (n=2), actor_loss = -69.704, critic_loss = 0.522, entropy_coef_loss = -50.410, entropy_coef = 0.039, action_stds = 0.901 ± 0.060, action_magnitude = 0.610 ± 0.297, num_gradient_steps = 11000, step_time = 7.20, total_time = 83.45
#
#
# step = 22000, num_env_steps = 22000, scores = -2.640 ± 0.27 (n=2), actor_loss = -66.535, critic_loss = 0.438, entropy_coef_loss = -51.372, entropy_coef = 0.029, action_stds = 0.826 ± 0.097, action_magnitude = 0.626 ± 0.296, num_gradient_steps = 12000, step_time = 7.07, total_time = 90.51
#
#
# step = 23000, num_env_steps = 23000, scores = -2.746 ± 0.11 (n=2), actor_loss = -63.828, critic_loss = 0.437, entropy_coef_loss = -52.583, entropy_coef = 0.022, action_stds = 0.844 ± 0.078, action_magnitude = 0.638 ± 0.299, num_gradient_steps = 13000, step_time = 7.09, total_time = 97.61
#
#
# step = 24000, num_env_steps = 24000, scores = -2.947 ± 0.04 (n=2), actor_loss = -60.751, critic_loss = 0.285, entropy_coef_loss = -47.939, entropy_coef = 0.017, action_stds = 0.839 ± 0.080, action_magnitude = 0.634 ± 0.298, num_gradient_steps = 14000, step_time = 7.11, total_time = 104.72
#
#
# step = 25000, num_env_steps = 25000, scores = -3.186 ± 0.08 (n=2), actor_loss = -58.424, critic_loss = 0.299, entropy_coef_loss = -44.928, entropy_coef = 0.013, action_stds = 0.822 ± 0.130, action_magnitude = 0.647 ± 0.299, num_gradient_steps = 15000, step_time = 7.11, total_time = 111.83
#
#
# step = 26000, num_env_steps = 26000, scores = -3.029 ± 0.05 (n=2), actor_loss = -55.472, critic_loss = 0.446, entropy_coef_loss = -41.065, entropy_coef = 0.010, action_stds = 0.692 ± 0.077, action_magnitude = 0.677 ± 0.298, num_gradient_steps = 16000, step_time = 7.21, total_time = 119.04
#
#
# step = 27000, num_env_steps = 27000, scores = -3.345 ± 0.06 (n=2), actor_loss = -53.235, critic_loss = 0.251, entropy_coef_loss = -37.947, entropy_coef = 0.008, action_stds = 0.755 ± 0.105, action_magnitude = 0.672 ± 0.300, num_gradient_steps = 17000, step_time = 7.25, total_time = 126.29
#
#
# step = 28000, num_env_steps = 28000, scores = -3.248 ± 0.13 (n=2), actor_loss = -50.101, critic_loss = 0.281, entropy_coef_loss = -34.985, entropy_coef = 0.006, action_stds = 0.813 ± 0.063, action_magnitude = 0.669 ± 0.301, num_gradient_steps = 18000, step_time = 7.32, total_time = 133.61
#
#
# step = 29000, num_env_steps = 29000, scores = -3.366 ± 0.02 (n=2), actor_loss = -47.968, critic_loss = 0.156, entropy_coef_loss = -35.584, entropy_coef = 0.005, action_stds = 0.720 ± 0.059, action_magnitude = 0.677 ± 0.299, num_gradient_steps = 19000, step_time = 7.17, total_time = 140.78
#
#
# step = 30000, num_env_steps = 30000, scores = -3.169 ± 0.01 (n=2), actor_loss = -45.683, critic_loss = 0.110, entropy_coef_loss = -22.911, entropy_coef = 0.004, action_stds = 0.711 ± 0.058, action_magnitude = 0.690 ± 0.297, num_gradient_steps = 20000, step_time = 7.13, total_time = 147.91
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 31000, num_env_steps = 31000, scores = -3.205 ± 0.23 (n=2), actor_loss = -43.557, critic_loss = 0.106, entropy_coef_loss = -20.032, entropy_coef = 0.003, action_stds = 0.691 ± 0.091, action_magnitude = 0.696 ± 0.297, num_gradient_steps = 21000, step_time = 7.17, total_time = 155.08
#
#
# step = 32000, num_env_steps = 32000, scores = -3.409 ± 0.07 (n=2), actor_loss = -41.279, critic_loss = 0.092, entropy_coef_loss = -15.854, entropy_coef = 0.002, action_stds = 0.636 ± 0.048, action_magnitude = 0.703 ± 0.296, num_gradient_steps = 22000, step_time = 7.20, total_time = 162.28
#
#
# step = 33000, num_env_steps = 33000, scores = -3.711 ± 0.15 (n=2), actor_loss = -39.307, critic_loss = 0.097, entropy_coef_loss = -4.447, entropy_coef = 0.002, action_stds = 0.581 ± 0.060, action_magnitude = 0.709 ± 0.296, num_gradient_steps = 23000, step_time = 7.17, total_time = 169.45
#
#
# step = 34000, num_env_steps = 34000, scores = -3.617 ± 0.07 (n=2), actor_loss = -37.417, critic_loss = 0.061, entropy_coef_loss = 2.654, entropy_coef = 0.002, action_stds = 0.716 ± 0.054, action_magnitude = 0.705 ± 0.296, num_gradient_steps = 24000, step_time = 7.13, total_time = 176.58
#
#
# step = 35000, num_env_steps = 35000, scores = -3.684 ± 0.05 (n=2), actor_loss = -35.664, critic_loss = 0.077, entropy_coef_loss = 0.467, entropy_coef = 0.002, action_stds = 0.604 ± 0.088, action_magnitude = 0.713 ± 0.296, num_gradient_steps = 25000, step_time = 7.10, total_time = 183.68
#
#
# step = 36000, num_env_steps = 36000, scores = -3.648 ± 0.14 (n=2), actor_loss = -33.638, critic_loss = 0.056, entropy_coef_loss = -10.516, entropy_coef = 0.001, action_stds = 0.576 ± 0.077, action_magnitude = 0.720 ± 0.292, num_gradient_steps = 26000, step_time = 7.10, total_time = 190.78
#
#
# step = 37000, num_env_steps = 37000, scores = -3.321 ± 0.00 (n=2), actor_loss = -32.067, critic_loss = 0.041, entropy_coef_loss = -7.840, entropy_coef = 0.001, action_stds = 0.640 ± 0.067, action_magnitude = 0.697 ± 0.297, num_gradient_steps = 27000, step_time = 7.07, total_time = 197.85
#
#
# step = 38000, num_env_steps = 38000, scores = -3.408 ± 0.04 (n=2), actor_loss = -30.619, critic_loss = 0.032, entropy_coef_loss = -5.231, entropy_coef = 0.001, action_stds = 0.604 ± 0.083, action_magnitude = 0.690 ± 0.298, num_gradient_steps = 28000, step_time = 7.16, total_time = 205.01
#
#
# step = 39000, num_env_steps = 39000, scores = -3.368 ± 0.03 (n=2), actor_loss = -28.982, critic_loss = 0.027, entropy_coef_loss = -7.127, entropy_coef = 0.001, action_stds = 0.550 ± 0.076, action_magnitude = 0.686 ± 0.298, num_gradient_steps = 29000, step_time = 7.08, total_time = 212.08
#
#
# step = 40000, num_env_steps = 40000, scores = -3.349 ± 0.35 (n=2), actor_loss = -27.661, critic_loss = 0.024, entropy_coef_loss = -5.216, entropy_coef = 0.001, action_stds = 0.558 ± 0.038, action_magnitude = 0.706 ± 0.296, num_gradient_steps = 30000, step_time = 7.10, total_time = 219.19
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 41000, num_env_steps = 41000, scores = -3.285 ± 0.14 (n=2), actor_loss = -26.150, critic_loss = 0.023, entropy_coef_loss = 13.298, entropy_coef = 0.001, action_stds = 0.554 ± 0.063, action_magnitude = 0.671 ± 0.300, num_gradient_steps = 31000, step_time = 7.18, total_time = 226.36
#
#
# step = 42000, num_env_steps = 42000, scores = -3.466 ± 0.00 (n=2), actor_loss = -25.028, critic_loss = 0.016, entropy_coef_loss = 0.790, entropy_coef = 0.001, action_stds = 0.623 ± 0.116, action_magnitude = 0.689 ± 0.299, num_gradient_steps = 32000, step_time = 7.33, total_time = 233.69
#
#
# step = 43000, num_env_steps = 43000, scores = -3.768 ± 0.30 (n=2), actor_loss = -23.660, critic_loss = 0.014, entropy_coef_loss = -2.842, entropy_coef = 0.001, action_stds = 0.521 ± 0.109, action_magnitude = 0.698 ± 0.298, num_gradient_steps = 33000, step_time = 7.21, total_time = 240.90
#
#
# step = 44000, num_env_steps = 44000, scores = -3.286 ± 0.09 (n=2), actor_loss = -22.478, critic_loss = 0.015, entropy_coef_loss = 2.039, entropy_coef = 0.001, action_stds = 0.526 ± 0.044, action_magnitude = 0.688 ± 0.296, num_gradient_steps = 34000, step_time = 7.21, total_time = 248.11
#
#
# step = 45000, num_env_steps = 45000, scores = -3.357 ± 0.12 (n=2), actor_loss = -21.463, critic_loss = 0.010, entropy_coef_loss = -7.673, entropy_coef = 0.001, action_stds = 0.554 ± 0.082, action_magnitude = 0.682 ± 0.300, num_gradient_steps = 35000, step_time = 7.18, total_time = 255.29
#
#
# step = 46000, num_env_steps = 46000, scores = -3.347 ± 0.21 (n=2), actor_loss = -20.365, critic_loss = 0.009, entropy_coef_loss = 6.449, entropy_coef = 0.000, action_stds = 0.519 ± 0.089, action_magnitude = 0.687 ± 0.302, num_gradient_steps = 36000, step_time = 7.20, total_time = 262.49
#
#
# step = 47000, num_env_steps = 47000, scores = -3.366 ± 0.02 (n=2), actor_loss = -19.314, critic_loss = 0.005, entropy_coef_loss = -3.765, entropy_coef = 0.000, action_stds = 0.504 ± 0.068, action_magnitude = 0.679 ± 0.299, num_gradient_steps = 37000, step_time = 7.21, total_time = 269.70
#
#
# step = 48000, num_env_steps = 48000, scores = -3.353 ± 0.05 (n=2), actor_loss = -18.290, critic_loss = 0.007, entropy_coef_loss = 6.525, entropy_coef = 0.000, action_stds = 0.500 ± 0.069, action_magnitude = 0.678 ± 0.298, num_gradient_steps = 38000, step_time = 7.10, total_time = 276.80
#
#
# step = 49000, num_env_steps = 49000, scores = -3.544 ± 0.00 (n=2), actor_loss = -17.337, critic_loss = 0.006, entropy_coef_loss = 3.717, entropy_coef = 0.000, action_stds = 0.605 ± 0.144, action_magnitude = 0.681 ± 0.298, num_gradient_steps = 39000, step_time = 7.10, total_time = 283.89
#
#
# step = 50000, num_env_steps = 50000, scores = -3.137 ± 0.12 (n=2), actor_loss = -16.479, critic_loss = 0.005, entropy_coef_loss = -10.019, entropy_coef = 0.000, action_stds = 0.482 ± 0.060, action_magnitude = 0.668 ± 0.300, num_gradient_steps = 40000, step_time = 7.15, total_time = 291.04
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 51000, num_env_steps = 51000, scores = -3.188 ± 0.09 (n=2), actor_loss = -15.688, critic_loss = 0.004, entropy_coef_loss = -18.912, entropy_coef = 0.000, action_stds = 0.486 ± 0.085, action_magnitude = 0.670 ± 0.302, num_gradient_steps = 41000, step_time = 7.45, total_time = 298.50
#
#
# step = 52000, num_env_steps = 52000, scores = -4.193 ± 0.13 (n=2), actor_loss = -14.925, critic_loss = 0.003, entropy_coef_loss = -9.040, entropy_coef = 0.000, action_stds = 0.526 ± 0.077, action_magnitude = 0.776 ± 0.282, num_gradient_steps = 42000, step_time = 7.10, total_time = 305.60
#
#
# step = 53000, num_env_steps = 53000, scores = -3.764 ± 0.39 (n=2), actor_loss = -14.174, critic_loss = 0.002, entropy_coef_loss = -7.164, entropy_coef = 0.000, action_stds = 0.578 ± 0.081, action_magnitude = 0.725 ± 0.296, num_gradient_steps = 43000, step_time = 6.99, total_time = 312.58
#
#
# step = 54000, num_env_steps = 54000, scores = -3.273 ± 0.08 (n=2), actor_loss = -13.417, critic_loss = 0.003, entropy_coef_loss = 3.278, entropy_coef = 0.000, action_stds = 0.500 ± 0.069, action_magnitude = 0.672 ± 0.297, num_gradient_steps = 44000, step_time = 7.12, total_time = 319.70
#
#
# step = 55000, num_env_steps = 55000, scores = -3.235 ± 0.17 (n=2), actor_loss = -12.726, critic_loss = 0.002, entropy_coef_loss = -3.350, entropy_coef = 0.000, action_stds = 0.494 ± 0.073, action_magnitude = 0.660 ± 0.303, num_gradient_steps = 45000, step_time = 6.96, total_time = 326.67
#
#
# step = 56000, num_env_steps = 56000, scores = -3.352 ± 0.03 (n=2), actor_loss = -12.063, critic_loss = 0.002, entropy_coef_loss = -13.976, entropy_coef = 0.000, action_stds = 0.467 ± 0.093, action_magnitude = 0.683 ± 0.298, num_gradient_steps = 46000, step_time = 6.98, total_time = 333.64
#
#
# step = 57000, num_env_steps = 57000, scores = -3.363 ± 0.06 (n=2), actor_loss = -11.462, critic_loss = 0.002, entropy_coef_loss = -1.633, entropy_coef = 0.000, action_stds = 0.497 ± 0.205, action_magnitude = 0.717 ± 0.297, num_gradient_steps = 47000, step_time = 6.85, total_time = 340.49
#
#
# step = 58000, num_env_steps = 58000, scores = -3.287 ± 0.36 (n=2), actor_loss = -10.871, critic_loss = 0.001, entropy_coef_loss = 6.619, entropy_coef = 0.000, action_stds = 0.448 ± 0.077, action_magnitude = 0.660 ± 0.300, num_gradient_steps = 48000, step_time = 6.87, total_time = 347.36
#
#
# step = 59000, num_env_steps = 59000, scores = -3.722 ± 0.39 (n=2), actor_loss = -10.338, critic_loss = 0.001, entropy_coef_loss = -1.265, entropy_coef = 0.000, action_stds = 0.472 ± 0.086, action_magnitude = 0.704 ± 0.301, num_gradient_steps = 49000, step_time = 6.85, total_time = 354.21
#
#
# step = 60000, num_env_steps = 60000, scores = -2.777 ± 0.04 (n=2), actor_loss = -9.799, critic_loss = 0.001, entropy_coef_loss = 11.109, entropy_coef = 0.000, action_stds = 0.449 ± 0.075, action_magnitude = 0.632 ± 0.301, num_gradient_steps = 50000, step_time = 6.76, total_time = 360.97
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 61000, num_env_steps = 61000, scores = -3.144 ± 0.24 (n=2), actor_loss = -9.301, critic_loss = 0.000, entropy_coef_loss = 0.876, entropy_coef = 0.000, action_stds = 0.502 ± 0.072, action_magnitude = 0.684 ± 0.301, num_gradient_steps = 51000, step_time = 6.88, total_time = 367.85
#
#
# step = 62000, num_env_steps = 62000, scores = -3.344 ± 0.31 (n=2), actor_loss = -8.852, critic_loss = 0.001, entropy_coef_loss = 0.614, entropy_coef = 0.000, action_stds = 0.458 ± 0.095, action_magnitude = 0.683 ± 0.302, num_gradient_steps = 52000, step_time = 6.78, total_time = 374.63
#
#
# step = 63000, num_env_steps = 63000, scores = -3.355 ± 0.37 (n=2), actor_loss = -8.341, critic_loss = 0.001, entropy_coef_loss = 6.927, entropy_coef = 0.000, action_stds = 0.403 ± 0.153, action_magnitude = 0.706 ± 0.297, num_gradient_steps = 53000, step_time = 7.03, total_time = 381.66
#
#
# step = 64000, num_env_steps = 64000, scores = -3.249 ± 0.03 (n=2), actor_loss = -7.917, critic_loss = 0.000, entropy_coef_loss = -6.005, entropy_coef = 0.000, action_stds = 0.389 ± 0.119, action_magnitude = 0.683 ± 0.301, num_gradient_steps = 54000, step_time = 6.74, total_time = 388.40
#
#
# step = 65000, num_env_steps = 65000, scores = -3.016 ± 0.21 (n=2), actor_loss = -7.508, critic_loss = 0.000, entropy_coef_loss = -20.730, entropy_coef = 0.000, action_stds = 0.346 ± 0.051, action_magnitude = 0.659 ± 0.304, num_gradient_steps = 55000, step_time = 6.89, total_time = 395.29
#
#
# step = 66000, num_env_steps = 66000, scores = -3.305 ± 0.58 (n=2), actor_loss = -7.130, critic_loss = 0.000, entropy_coef_loss = -10.063, entropy_coef = 0.000, action_stds = 0.399 ± 0.093, action_magnitude = 0.667 ± 0.299, num_gradient_steps = 56000, step_time = 6.77, total_time = 402.06
#
#
# step = 67000, num_env_steps = 67000, scores = -2.801 ± 0.08 (n=2), actor_loss = -6.760, critic_loss = 0.000, entropy_coef_loss = -11.155, entropy_coef = 0.000, action_stds = 0.366 ± 0.157, action_magnitude = 0.626 ± 0.302, num_gradient_steps = 57000, step_time = 6.94, total_time = 409.00
#
#
# step = 68000, num_env_steps = 68000, scores = -3.066 ± 0.27 (n=2), actor_loss = -6.406, critic_loss = 0.000, entropy_coef_loss = -15.242, entropy_coef = 0.000, action_stds = 0.319 ± 0.066, action_magnitude = 0.652 ± 0.302, num_gradient_steps = 58000, step_time = 6.86, total_time = 415.86
#
#
# step = 69000, num_env_steps = 69000, scores = -2.343 ± 0.02 (n=2), actor_loss = -6.066, critic_loss = 0.000, entropy_coef_loss = 3.814, entropy_coef = 0.000, action_stds = 0.358 ± 0.063, action_magnitude = 0.606 ± 0.298, num_gradient_steps = 59000, step_time = 6.85, total_time = 422.71
#
#
# step = 70000, num_env_steps = 70000, scores = -2.092 ± 0.29 (n=2), actor_loss = -5.762, critic_loss = 0.000, entropy_coef_loss = 3.338, entropy_coef = 0.000, action_stds = 0.325 ± 0.088, action_magnitude = 0.580 ± 0.305, num_gradient_steps = 60000, step_time = 6.80, total_time = 429.51
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 71000, num_env_steps = 71000, scores = -2.678 ± 0.05 (n=2), actor_loss = -5.460, critic_loss = 0.000, entropy_coef_loss = -7.355, entropy_coef = 0.000, action_stds = 0.280 ± 0.065, action_magnitude = 0.627 ± 0.297, num_gradient_steps = 61000, step_time = 6.85, total_time = 436.36
#
#
# step = 72000, num_env_steps = 72000, scores = -2.527 ± 0.16 (n=2), actor_loss = -5.191, critic_loss = 0.000, entropy_coef_loss = -3.014, entropy_coef = 0.000, action_stds = 0.278 ± 0.139, action_magnitude = 0.614 ± 0.295, num_gradient_steps = 62000, step_time = 6.98, total_time = 443.34
#
#
# step = 73000, num_env_steps = 73000, scores = -2.385 ± 0.57 (n=2), actor_loss = -4.899, critic_loss = 0.000, entropy_coef_loss = -5.391, entropy_coef = 0.000, action_stds = 0.243 ± 0.077, action_magnitude = 0.592 ± 0.304, num_gradient_steps = 63000, step_time = 6.89, total_time = 450.23
#
#
# step = 74000, num_env_steps = 74000, scores = -2.220 ± 0.13 (n=2), actor_loss = -4.648, critic_loss = 0.000, entropy_coef_loss = -4.209, entropy_coef = 0.000, action_stds = 0.287 ± 0.096, action_magnitude = 0.586 ± 0.300, num_gradient_steps = 64000, step_time = 6.92, total_time = 457.15
#
#
# step = 75000, num_env_steps = 75000, scores = -2.666 ± 0.12 (n=2), actor_loss = -4.406, critic_loss = 0.000, entropy_coef_loss = 4.425, entropy_coef = 0.000, action_stds = 0.326 ± 0.086, action_magnitude = 0.612 ± 0.304, num_gradient_steps = 65000, step_time = 6.74, total_time = 463.89
#
#
# step = 76000, num_env_steps = 76000, scores = -2.125 ± 0.05 (n=2), actor_loss = -4.175, critic_loss = 0.000, entropy_coef_loss = -0.699, entropy_coef = 0.000, action_stds = 0.280 ± 0.066, action_magnitude = 0.554 ± 0.303, num_gradient_steps = 66000, step_time = 6.87, total_time = 470.75
#
#
# step = 77000, num_env_steps = 77000, scores = -1.697 ± 0.25 (n=2), actor_loss = -3.965, critic_loss = 0.000, entropy_coef_loss = 8.766, entropy_coef = 0.000, action_stds = 0.278 ± 0.049, action_magnitude = 0.524 ± 0.291, num_gradient_steps = 67000, step_time = 6.77, total_time = 477.52
#
#
# step = 78000, num_env_steps = 78000, scores = -1.838 ± 0.10 (n=2), actor_loss = -3.760, critic_loss = 0.000, entropy_coef_loss = -0.561, entropy_coef = 0.000, action_stds = 0.249 ± 0.063, action_magnitude = 0.517 ± 0.291, num_gradient_steps = 68000, step_time = 6.81, total_time = 484.33
#
#
# step = 79000, num_env_steps = 79000, scores = -2.031 ± 0.05 (n=2), actor_loss = -3.557, critic_loss = 0.000, entropy_coef_loss = 3.325, entropy_coef = 0.000, action_stds = 0.201 ± 0.054, action_magnitude = 0.520 ± 0.301, num_gradient_steps = 69000, step_time = 6.77, total_time = 491.10
#
#
# step = 80000, num_env_steps = 80000, scores = -2.134 ± 0.02 (n=2), actor_loss = -3.386, critic_loss = 0.000, entropy_coef_loss = 5.474, entropy_coef = 0.000, action_stds = 0.279 ± 0.049, action_magnitude = 0.542 ± 0.299, num_gradient_steps = 70000, step_time = 6.86, total_time = 497.97
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 81000, num_env_steps = 81000, scores = -1.979 ± 0.17 (n=2), actor_loss = -3.214, critic_loss = 0.000, entropy_coef_loss = 0.692, entropy_coef = 0.000, action_stds = 0.248 ± 0.038, action_magnitude = 0.529 ± 0.296, num_gradient_steps = 71000, step_time = 6.88, total_time = 504.85
#
#
# step = 82000, num_env_steps = 82000, scores = -1.988 ± 0.14 (n=2), actor_loss = -3.042, critic_loss = 0.000, entropy_coef_loss = 1.467, entropy_coef = 0.000, action_stds = 0.242 ± 0.050, action_magnitude = 0.538 ± 0.289, num_gradient_steps = 72000, step_time = 6.82, total_time = 511.67
#
#
# step = 83000, num_env_steps = 83000, scores = -1.602 ± 0.29 (n=2), actor_loss = -2.889, critic_loss = 0.000, entropy_coef_loss = -6.092, entropy_coef = 0.000, action_stds = 0.248 ± 0.040, action_magnitude = 0.478 ± 0.294, num_gradient_steps = 73000, step_time = 6.81, total_time = 518.48
#
#
# step = 84000, num_env_steps = 84000, scores = -1.695 ± 0.05 (n=2), actor_loss = -2.739, critic_loss = 0.000, entropy_coef_loss = -7.517, entropy_coef = 0.000, action_stds = 0.231 ± 0.038, action_magnitude = 0.514 ± 0.296, num_gradient_steps = 74000, step_time = 6.74, total_time = 525.22
#
#
# step = 85000, num_env_steps = 85000, scores = -1.651 ± 0.05 (n=2), actor_loss = -2.595, critic_loss = 0.000, entropy_coef_loss = 6.114, entropy_coef = 0.000, action_stds = 0.298 ± 0.095, action_magnitude = 0.495 ± 0.295, num_gradient_steps = 75000, step_time = 6.93, total_time = 532.15
#
#
# step = 86000, num_env_steps = 86000, scores = -1.656 ± 0.11 (n=2), actor_loss = -2.460, critic_loss = 0.000, entropy_coef_loss = 2.196, entropy_coef = 0.000, action_stds = 0.229 ± 0.047, action_magnitude = 0.507 ± 0.283, num_gradient_steps = 76000, step_time = 7.02, total_time = 539.17
#
#
# step = 87000, num_env_steps = 87000, scores = -1.790 ± 0.00 (n=2), actor_loss = -2.325, critic_loss = 0.000, entropy_coef_loss = -2.133, entropy_coef = 0.000, action_stds = 0.240 ± 0.042, action_magnitude = 0.527 ± 0.292, num_gradient_steps = 77000, step_time = 6.87, total_time = 546.04
#
#
# step = 88000, num_env_steps = 88000, scores = -2.295 ± 0.64 (n=2), actor_loss = -2.210, critic_loss = 0.000, entropy_coef_loss = 1.478, entropy_coef = 0.000, action_stds = 0.202 ± 0.048, action_magnitude = 0.550 ± 0.309, num_gradient_steps = 78000, step_time = 6.84, total_time = 552.87
#
#
# step = 89000, num_env_steps = 89000, scores = -1.750 ± 0.40 (n=2), actor_loss = -2.090, critic_loss = 0.000, entropy_coef_loss = -1.113, entropy_coef = 0.000, action_stds = 0.220 ± 0.048, action_magnitude = 0.528 ± 0.305, num_gradient_steps = 79000, step_time = 6.94, total_time = 559.81
#
#
# step = 90000, num_env_steps = 90000, scores = -1.685 ± 0.08 (n=2), actor_loss = -1.985, critic_loss = 0.000, entropy_coef_loss = -0.234, entropy_coef = 0.000, action_stds = 0.229 ± 0.059, action_magnitude = 0.491 ± 0.290, num_gradient_steps = 80000, step_time = 6.82, total_time = 566.63
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 91000, num_env_steps = 91000, scores = -1.896 ± 0.01 (n=2), actor_loss = -1.878, critic_loss = 0.000, entropy_coef_loss = -8.031, entropy_coef = 0.000, action_stds = 0.260 ± 0.120, action_magnitude = 0.477 ± 0.310, num_gradient_steps = 81000, step_time = 7.24, total_time = 573.87
#
#
# step = 92000, num_env_steps = 92000, scores = -1.632 ± 0.22 (n=2), actor_loss = -1.779, critic_loss = 0.000, entropy_coef_loss = 6.492, entropy_coef = 0.000, action_stds = 0.190 ± 0.045, action_magnitude = 0.453 ± 0.286, num_gradient_steps = 82000, step_time = 6.88, total_time = 580.75
#
#
# step = 93000, num_env_steps = 93000, scores = -1.699 ± 0.12 (n=2), actor_loss = -1.680, critic_loss = 0.000, entropy_coef_loss = -8.710, entropy_coef = 0.000, action_stds = 0.219 ± 0.052, action_magnitude = 0.495 ± 0.295, num_gradient_steps = 83000, step_time = 6.82, total_time = 587.57
#
#
# step = 94000, num_env_steps = 94000, scores = -1.463 ± 0.15 (n=2), actor_loss = -1.586, critic_loss = 0.000, entropy_coef_loss = 2.335, entropy_coef = 0.000, action_stds = 0.222 ± 0.073, action_magnitude = 0.476 ± 0.295, num_gradient_steps = 84000, step_time = 6.84, total_time = 594.40
#
#
# step = 95000, num_env_steps = 95000, scores = -1.705 ± 0.13 (n=2), actor_loss = -1.497, critic_loss = 0.000, entropy_coef_loss = -0.826, entropy_coef = 0.000, action_stds = 0.268 ± 0.082, action_magnitude = 0.499 ± 0.285, num_gradient_steps = 85000, step_time = 6.77, total_time = 601.17
#
#
# step = 96000, num_env_steps = 96000, scores = -2.292 ± 0.20 (n=2), actor_loss = -1.419, critic_loss = 0.000, entropy_coef_loss = -6.984, entropy_coef = 0.000, action_stds = 0.271 ± 0.101, action_magnitude = 0.608 ± 0.307, num_gradient_steps = 86000, step_time = 6.93, total_time = 608.10
#
#
# step = 97000, num_env_steps = 97000, scores = -2.353 ± 0.37 (n=2), actor_loss = -1.341, critic_loss = 0.000, entropy_coef_loss = 5.007, entropy_coef = 0.000, action_stds = 0.295 ± 0.083, action_magnitude = 0.569 ± 0.311, num_gradient_steps = 87000, step_time = 6.89, total_time = 614.99
#
#
# step = 98000, num_env_steps = 98000, scores = -1.826 ± 0.03 (n=2), actor_loss = -1.266, critic_loss = 0.000, entropy_coef_loss = -1.306, entropy_coef = 0.000, action_stds = 0.257 ± 0.071, action_magnitude = 0.533 ± 0.310, num_gradient_steps = 88000, step_time = 6.89, total_time = 621.88
#
#
# step = 99000, num_env_steps = 99000, scores = -1.742 ± 0.13 (n=2), actor_loss = -1.197, critic_loss = 0.000, entropy_coef_loss = 1.044, entropy_coef = 0.000, action_stds = 0.274 ± 0.061, action_magnitude = 0.536 ± 0.301, num_gradient_steps = 89000, step_time = 6.78, total_time = 628.65
#
#
# step = 100000, num_env_steps = 100000, scores = -1.680 ± 0.07 (n=2), actor_loss = -1.127, critic_loss = 0.000, entropy_coef_loss = -0.297, entropy_coef = 0.000, action_stds = 0.237 ± 0.072, action_magnitude = 0.499 ± 0.309, num_gradient_steps = 90000, step_time = 6.92, total_time = 635.58
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 101000, num_env_steps = 101000, scores = -1.639 ± 0.09 (n=2), actor_loss = -1.062, critic_loss = 0.000, entropy_coef_loss = 1.937, entropy_coef = 0.000, action_stds = 0.300 ± 0.063, action_magnitude = 0.508 ± 0.296, num_gradient_steps = 91000, step_time = 6.88, total_time = 642.45
#
#
# step = 102000, num_env_steps = 102000, scores = -1.944 ± 0.24 (n=2), actor_loss = -1.008, critic_loss = 0.000, entropy_coef_loss = -1.150, entropy_coef = 0.000, action_stds = 0.265 ± 0.070, action_magnitude = 0.516 ± 0.300, num_gradient_steps = 92000, step_time = 7.12, total_time = 649.57
#
#
# step = 103000, num_env_steps = 103000, scores = -1.390 ± 0.06 (n=2), actor_loss = -0.948, critic_loss = 0.000, entropy_coef_loss = -5.997, entropy_coef = 0.000, action_stds = 0.248 ± 0.043, action_magnitude = 0.448 ± 0.278, num_gradient_steps = 93000, step_time = 6.79, total_time = 656.37
#
#
# step = 104000, num_env_steps = 104000, scores = -1.785 ± 0.29 (n=2), actor_loss = -0.899, critic_loss = 0.000, entropy_coef_loss = 6.031, entropy_coef = 0.000, action_stds = 0.287 ± 0.063, action_magnitude = 0.499 ± 0.286, num_gradient_steps = 94000, step_time = 6.97, total_time = 663.33
#
#
# step = 105000, num_env_steps = 105000, scores = -1.436 ± 0.04 (n=2), actor_loss = -0.851, critic_loss = 0.000, entropy_coef_loss = 9.457, entropy_coef = 0.000, action_stds = 0.246 ± 0.040, action_magnitude = 0.495 ± 0.290, num_gradient_steps = 95000, step_time = 6.94, total_time = 670.28
#
#
# step = 106000, num_env_steps = 106000, scores = -1.559 ± 0.14 (n=2), actor_loss = -0.810, critic_loss = 0.000, entropy_coef_loss = -0.165, entropy_coef = 0.000, action_stds = 0.272 ± 0.069, action_magnitude = 0.478 ± 0.285, num_gradient_steps = 96000, step_time = 6.83, total_time = 677.11
#
#
# step = 107000, num_env_steps = 107000, scores = -1.602 ± 0.23 (n=2), actor_loss = -0.762, critic_loss = 0.000, entropy_coef_loss = 3.319, entropy_coef = 0.000, action_stds = 0.279 ± 0.061, action_magnitude = 0.491 ± 0.294, num_gradient_steps = 97000, step_time = 6.90, total_time = 684.01
#
#
# step = 108000, num_env_steps = 108000, scores = -1.733 ± 0.11 (n=2), actor_loss = -0.721, critic_loss = 0.000, entropy_coef_loss = -4.221, entropy_coef = 0.000, action_stds = 0.303 ± 0.059, action_magnitude = 0.497 ± 0.300, num_gradient_steps = 98000, step_time = 6.76, total_time = 690.77
#
#
# step = 109000, num_env_steps = 109000, scores = -2.217 ± 0.77 (n=2), actor_loss = -0.682, critic_loss = 0.000, entropy_coef_loss = -0.563, entropy_coef = 0.000, action_stds = 0.298 ± 0.065, action_magnitude = 0.569 ± 0.303, num_gradient_steps = 99000, step_time = 6.80, total_time = 697.57
#
#
# step = 110000, num_env_steps = 110000, scores = -1.763 ± 0.11 (n=2), actor_loss = -0.643, critic_loss = 0.000, entropy_coef_loss = 2.876, entropy_coef = 0.000, action_stds = 0.221 ± 0.058, action_magnitude = 0.496 ± 0.292, num_gradient_steps = 100000, step_time = 6.74, total_time = 704.30
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 111000, num_env_steps = 111000, scores = -2.851 ± 0.12 (n=2), actor_loss = -0.609, critic_loss = 0.000, entropy_coef_loss = -4.424, entropy_coef = 0.000, action_stds = 0.265 ± 0.039, action_magnitude = 0.645 ± 0.312, num_gradient_steps = 101000, step_time = 6.83, total_time = 711.13
#
#
# step = 112000, num_env_steps = 112000, scores = -1.850 ± 0.18 (n=2), actor_loss = -0.570, critic_loss = 0.000, entropy_coef_loss = 2.734, entropy_coef = 0.000, action_stds = 0.264 ± 0.040, action_magnitude = 0.539 ± 0.302, num_gradient_steps = 102000, step_time = 6.79, total_time = 717.92
#
#
# step = 113000, num_env_steps = 113000, scores = -1.931 ± 0.05 (n=2), actor_loss = -0.544, critic_loss = 0.000, entropy_coef_loss = -0.075, entropy_coef = 0.000, action_stds = 0.311 ± 0.062, action_magnitude = 0.531 ± 0.299, num_gradient_steps = 103000, step_time = 6.78, total_time = 724.70
#
#
# step = 114000, num_env_steps = 114000, scores = -1.895 ± 0.49 (n=2), actor_loss = -0.512, critic_loss = 0.000, entropy_coef_loss = -1.137, entropy_coef = 0.000, action_stds = 0.233 ± 0.064, action_magnitude = 0.535 ± 0.300, num_gradient_steps = 104000, step_time = 6.96, total_time = 731.65
#
#
# step = 115000, num_env_steps = 115000, scores = -1.447 ± 0.07 (n=2), actor_loss = -0.485, critic_loss = 0.000, entropy_coef_loss = 8.822, entropy_coef = 0.000, action_stds = 0.228 ± 0.056, action_magnitude = 0.511 ± 0.297, num_gradient_steps = 105000, step_time = 6.92, total_time = 738.57
#
#
# step = 116000, num_env_steps = 116000, scores = -1.645 ± 0.00 (n=2), actor_loss = -0.456, critic_loss = 0.000, entropy_coef_loss = 1.052, entropy_coef = 0.000, action_stds = 0.306 ± 0.034, action_magnitude = 0.506 ± 0.296, num_gradient_steps = 106000, step_time = 6.87, total_time = 745.44
#
#
# step = 117000, num_env_steps = 117000, scores = -1.661 ± 0.08 (n=2), actor_loss = -0.432, critic_loss = 0.000, entropy_coef_loss = 0.912, entropy_coef = 0.000, action_stds = 0.250 ± 0.098, action_magnitude = 0.514 ± 0.298, num_gradient_steps = 107000, step_time = 6.92, total_time = 752.36
#
#
# step = 118000, num_env_steps = 118000, scores = -1.494 ± 0.09 (n=2), actor_loss = -0.402, critic_loss = 0.000, entropy_coef_loss = -0.332, entropy_coef = 0.000, action_stds = 0.280 ± 0.054, action_magnitude = 0.471 ± 0.290, num_gradient_steps = 108000, step_time = 6.85, total_time = 759.22
#
#
# step = 119000, num_env_steps = 119000, scores = -1.492 ± 0.17 (n=2), actor_loss = -0.376, critic_loss = 0.000, entropy_coef_loss = 1.002, entropy_coef = 0.000, action_stds = 0.240 ± 0.062, action_magnitude = 0.505 ± 0.292, num_gradient_steps = 109000, step_time = 6.83, total_time = 766.05
#
#
# step = 120000, num_env_steps = 120000, scores = -2.051 ± 0.26 (n=2), actor_loss = -0.354, critic_loss = 0.000, entropy_coef_loss = 0.115, entropy_coef = 0.000, action_stds = 0.287 ± 0.057, action_magnitude = 0.554 ± 0.313, num_gradient_steps = 110000, step_time = 6.98, total_time = 773.03
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 121000, num_env_steps = 121000, scores = -1.806 ± 0.01 (n=2), actor_loss = -0.329, critic_loss = 0.000, entropy_coef_loss = -0.141, entropy_coef = 0.000, action_stds = 0.258 ± 0.041, action_magnitude = 0.519 ± 0.299, num_gradient_steps = 111000, step_time = 6.77, total_time = 779.80
#
#
# step = 122000, num_env_steps = 122000, scores = -1.575 ± 0.09 (n=2), actor_loss = -0.312, critic_loss = 0.000, entropy_coef_loss = 4.453, entropy_coef = 0.000, action_stds = 0.353 ± 0.099, action_magnitude = 0.464 ± 0.268, num_gradient_steps = 112000, step_time = 6.89, total_time = 786.69
#
#
# step = 123000, num_env_steps = 123000, scores = -1.590 ± 0.26 (n=2), actor_loss = -0.306, critic_loss = 0.000, entropy_coef_loss = 6.641, entropy_coef = 0.000, action_stds = 0.296 ± 0.041, action_magnitude = 0.484 ± 0.289, num_gradient_steps = 113000, step_time = 6.93, total_time = 793.62
#
#
# step = 124000, num_env_steps = 124000, scores = -1.911 ± 0.11 (n=2), actor_loss = -0.298, critic_loss = 0.000, entropy_coef_loss = 6.710, entropy_coef = 0.000, action_stds = 0.369 ± 0.089, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 114000, step_time = 6.84, total_time = 800.46
#
#
# step = 125000, num_env_steps = 125000, scores = -1.959 ± 0.39 (n=2), actor_loss = -0.288, critic_loss = 0.000, entropy_coef_loss = -6.559, entropy_coef = 0.000, action_stds = 0.427 ± 0.062, action_magnitude = 0.533 ± 0.296, num_gradient_steps = 115000, step_time = 6.84, total_time = 807.30
#
#
# step = 126000, num_env_steps = 126000, scores = -3.224 ± 0.59 (n=2), actor_loss = -0.283, critic_loss = 0.000, entropy_coef_loss = -1.553, entropy_coef = 0.000, action_stds = 0.537 ± 0.359, action_magnitude = 0.699 ± 0.304, num_gradient_steps = 116000, step_time = 6.83, total_time = 814.13
#
#
# step = 127000, num_env_steps = 127000, scores = -2.584 ± 0.11 (n=2), actor_loss = -0.285, critic_loss = 0.000, entropy_coef_loss = 5.229, entropy_coef = 0.000, action_stds = 0.348 ± 0.065, action_magnitude = 0.612 ± 0.308, num_gradient_steps = 117000, step_time = 6.77, total_time = 820.89
#
#
# step = 128000, num_env_steps = 128000, scores = -2.048 ± 0.19 (n=2), actor_loss = -0.293, critic_loss = 0.000, entropy_coef_loss = -3.785, entropy_coef = 0.000, action_stds = 0.345 ± 0.051, action_magnitude = 0.540 ± 0.293, num_gradient_steps = 118000, step_time = 6.91, total_time = 827.80
#
#
# step = 129000, num_env_steps = 129000, scores = -2.058 ± 0.07 (n=2), actor_loss = -0.283, critic_loss = 0.000, entropy_coef_loss = 6.237, entropy_coef = 0.000, action_stds = 0.476 ± 0.091, action_magnitude = 0.561 ± 0.303, num_gradient_steps = 119000, step_time = 6.93, total_time = 834.72
#
#
# step = 130000, num_env_steps = 130000, scores = -2.048 ± 0.41 (n=2), actor_loss = -0.276, critic_loss = 0.000, entropy_coef_loss = -2.264, entropy_coef = 0.000, action_stds = 0.348 ± 0.094, action_magnitude = 0.587 ± 0.306, num_gradient_steps = 120000, step_time = 6.92, total_time = 841.65
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 131000, num_env_steps = 131000, scores = -2.477 ± 0.23 (n=2), actor_loss = -0.276, critic_loss = 0.000, entropy_coef_loss = 1.486, entropy_coef = 0.000, action_stds = 0.291 ± 0.104, action_magnitude = 0.620 ± 0.304, num_gradient_steps = 121000, step_time = 6.94, total_time = 848.59
#
#
# step = 132000, num_env_steps = 132000, scores = -2.325 ± 0.05 (n=2), actor_loss = -0.262, critic_loss = 0.000, entropy_coef_loss = -1.135, entropy_coef = 0.000, action_stds = 0.441 ± 0.079, action_magnitude = 0.623 ± 0.308, num_gradient_steps = 122000, step_time = 6.96, total_time = 855.55
#
#
# step = 133000, num_env_steps = 133000, scores = -2.444 ± 0.17 (n=2), actor_loss = -0.265, critic_loss = 0.000, entropy_coef_loss = 1.814, entropy_coef = 0.000, action_stds = 0.319 ± 0.079, action_magnitude = 0.622 ± 0.302, num_gradient_steps = 123000, step_time = 6.85, total_time = 862.40
#
#
# step = 134000, num_env_steps = 134000, scores = -3.053 ± 0.05 (n=2), actor_loss = -0.253, critic_loss = 0.000, entropy_coef_loss = -0.129, entropy_coef = 0.000, action_stds = 0.315 ± 0.097, action_magnitude = 0.683 ± 0.303, num_gradient_steps = 124000, step_time = 6.77, total_time = 869.17
#
#
# step = 135000, num_env_steps = 135000, scores = -2.557 ± 0.15 (n=2), actor_loss = -0.237, critic_loss = 0.000, entropy_coef_loss = -2.337, entropy_coef = 0.000, action_stds = 0.345 ± 0.061, action_magnitude = 0.628 ± 0.310, num_gradient_steps = 125000, step_time = 6.84, total_time = 876.01
#
#
# step = 136000, num_env_steps = 136000, scores = -2.378 ± 0.05 (n=2), actor_loss = -0.225, critic_loss = 0.000, entropy_coef_loss = 0.285, entropy_coef = 0.000, action_stds = 0.307 ± 0.062, action_magnitude = 0.598 ± 0.306, num_gradient_steps = 126000, step_time = 6.80, total_time = 882.81
#
#
# step = 137000, num_env_steps = 137000, scores = -2.102 ± 0.15 (n=2), actor_loss = -0.220, critic_loss = 0.000, entropy_coef_loss = -2.017, entropy_coef = 0.000, action_stds = 0.361 ± 0.115, action_magnitude = 0.549 ± 0.295, num_gradient_steps = 127000, step_time = 6.84, total_time = 889.65
#
#
# step = 138000, num_env_steps = 138000, scores = -1.847 ± 0.13 (n=2), actor_loss = -0.206, critic_loss = 0.000, entropy_coef_loss = -1.876, entropy_coef = 0.000, action_stds = 0.317 ± 0.063, action_magnitude = 0.506 ± 0.300, num_gradient_steps = 128000, step_time = 6.88, total_time = 896.53
#
#
# step = 139000, num_env_steps = 139000, scores = -1.540 ± 0.27 (n=2), actor_loss = -0.193, critic_loss = 0.000, entropy_coef_loss = 0.961, entropy_coef = 0.000, action_stds = 0.264 ± 0.047, action_magnitude = 0.464 ± 0.283, num_gradient_steps = 129000, step_time = 6.83, total_time = 903.36
#
#
# step = 140000, num_env_steps = 140000, scores = -1.684 ± 0.05 (n=2), actor_loss = -0.180, critic_loss = 0.000, entropy_coef_loss = 2.020, entropy_coef = 0.000, action_stds = 0.252 ± 0.037, action_magnitude = 0.478 ± 0.275, num_gradient_steps = 130000, step_time = 6.82, total_time = 910.18
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 141000, num_env_steps = 141000, scores = -2.154 ± 0.06 (n=2), actor_loss = -0.166, critic_loss = 0.000, entropy_coef_loss = -0.304, entropy_coef = 0.000, action_stds = 0.489 ± 0.211, action_magnitude = 0.568 ± 0.312, num_gradient_steps = 131000, step_time = 6.91, total_time = 917.09
#
#
# step = 142000, num_env_steps = 142000, scores = -2.390 ± 0.17 (n=2), actor_loss = -0.166, critic_loss = 0.000, entropy_coef_loss = -1.150, entropy_coef = 0.000, action_stds = 0.307 ± 0.080, action_magnitude = 0.605 ± 0.314, num_gradient_steps = 132000, step_time = 6.77, total_time = 923.87
#
#
# step = 143000, num_env_steps = 143000, scores = -1.427 ± 0.06 (n=2), actor_loss = -0.156, critic_loss = 0.000, entropy_coef_loss = 1.893, entropy_coef = 0.000, action_stds = 0.239 ± 0.047, action_magnitude = 0.437 ± 0.286, num_gradient_steps = 133000, step_time = 6.77, total_time = 930.64
#
#
# step = 144000, num_env_steps = 144000, scores = -1.566 ± 0.21 (n=2), actor_loss = -0.156, critic_loss = 0.000, entropy_coef_loss = -7.333, entropy_coef = 0.000, action_stds = 0.241 ± 0.051, action_magnitude = 0.465 ± 0.286, num_gradient_steps = 134000, step_time = 6.88, total_time = 937.51
#
#
# step = 145000, num_env_steps = 145000, scores = -1.768 ± 0.22 (n=2), actor_loss = -0.143, critic_loss = 0.000, entropy_coef_loss = 7.107, entropy_coef = 0.000, action_stds = 0.212 ± 0.032, action_magnitude = 0.512 ± 0.301, num_gradient_steps = 135000, step_time = 6.75, total_time = 944.26
#
#
# step = 146000, num_env_steps = 146000, scores = -2.004 ± 0.34 (n=2), actor_loss = -0.136, critic_loss = 0.000, entropy_coef_loss = 5.343, entropy_coef = 0.000, action_stds = 0.302 ± 0.092, action_magnitude = 0.553 ± 0.315, num_gradient_steps = 136000, step_time = 6.86, total_time = 951.12
#
#
# step = 147000, num_env_steps = 147000, scores = -1.503 ± 0.19 (n=2), actor_loss = -0.125, critic_loss = 0.000, entropy_coef_loss = 2.061, entropy_coef = 0.000, action_stds = 0.206 ± 0.031, action_magnitude = 0.467 ± 0.275, num_gradient_steps = 137000, step_time = 6.80, total_time = 957.92
#
#
# step = 148000, num_env_steps = 148000, scores = -1.608 ± 0.04 (n=2), actor_loss = -0.113, critic_loss = 0.000, entropy_coef_loss = 3.450, entropy_coef = 0.000, action_stds = 0.203 ± 0.030, action_magnitude = 0.476 ± 0.283, num_gradient_steps = 138000, step_time = 6.90, total_time = 964.82
#
#
# step = 149000, num_env_steps = 149000, scores = -1.670 ± 0.05 (n=2), actor_loss = -0.101, critic_loss = 0.000, entropy_coef_loss = 6.176, entropy_coef = 0.000, action_stds = 0.288 ± 0.067, action_magnitude = 0.551 ± 0.304, num_gradient_steps = 139000, step_time = 6.80, total_time = 971.62
#
#
# step = 150000, num_env_steps = 150000, scores = -2.230 ± 0.15 (n=2), actor_loss = -0.100, critic_loss = 0.000, entropy_coef_loss = 1.403, entropy_coef = 0.000, action_stds = 0.291 ± 0.070, action_magnitude = 0.603 ± 0.304, num_gradient_steps = 140000, step_time = 6.93, total_time = 978.55
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 151000, num_env_steps = 151000, scores = -1.461 ± 0.09 (n=2), actor_loss = -0.092, critic_loss = 0.000, entropy_coef_loss = -3.510, entropy_coef = 0.000, action_stds = 0.227 ± 0.047, action_magnitude = 0.556 ± 0.308, num_gradient_steps = 141000, step_time = 6.96, total_time = 985.51
#
#
# step = 152000, num_env_steps = 152000, scores = -1.264 ± 0.13 (n=2), actor_loss = -0.087, critic_loss = 0.000, entropy_coef_loss = 3.353, entropy_coef = 0.000, action_stds = 0.216 ± 0.068, action_magnitude = 0.500 ± 0.296, num_gradient_steps = 142000, step_time = 6.95, total_time = 992.46
#
#
# step = 153000, num_env_steps = 153000, scores = -1.416 ± 0.02 (n=2), actor_loss = -0.070, critic_loss = 0.000, entropy_coef_loss = 5.160, entropy_coef = 0.000, action_stds = 0.231 ± 0.045, action_magnitude = 0.510 ± 0.297, num_gradient_steps = 143000, step_time = 6.82, total_time = 999.27
#
#
# step = 154000, num_env_steps = 154000, scores = -1.639 ± 0.28 (n=2), actor_loss = -0.068, critic_loss = 0.000, entropy_coef_loss = -6.084, entropy_coef = 0.000, action_stds = 0.205 ± 0.075, action_magnitude = 0.580 ± 0.313, num_gradient_steps = 144000, step_time = 7.96, total_time = 1007.23
#
#
# step = 155000, num_env_steps = 155000, scores = -1.574 ± 0.14 (n=2), actor_loss = -0.053, critic_loss = 0.000, entropy_coef_loss = 0.853, entropy_coef = 0.000, action_stds = 0.234 ± 0.054, action_magnitude = 0.536 ± 0.303, num_gradient_steps = 145000, step_time = 7.52, total_time = 1014.75
#
#
# step = 156000, num_env_steps = 156000, scores = -1.682 ± 0.13 (n=2), actor_loss = -0.040, critic_loss = 0.000, entropy_coef_loss = -0.502, entropy_coef = 0.000, action_stds = 0.227 ± 0.028, action_magnitude = 0.477 ± 0.284, num_gradient_steps = 146000, step_time = 7.57, total_time = 1022.32
#
#
# step = 157000, num_env_steps = 157000, scores = -1.437 ± 0.12 (n=2), actor_loss = -0.037, critic_loss = 0.000, entropy_coef_loss = 0.725, entropy_coef = 0.000, action_stds = 0.238 ± 0.038, action_magnitude = 0.446 ± 0.268, num_gradient_steps = 147000, step_time = 7.43, total_time = 1029.75
#
#
# step = 158000, num_env_steps = 158000, scores = -1.648 ± 0.37 (n=2), actor_loss = -0.029, critic_loss = 0.000, entropy_coef_loss = 5.120, entropy_coef = 0.000, action_stds = 0.298 ± 0.085, action_magnitude = 0.529 ± 0.299, num_gradient_steps = 148000, step_time = 7.11, total_time = 1036.86
#
#
# step = 159000, num_env_steps = 159000, scores = -1.910 ± 0.51 (n=2), actor_loss = -0.025, critic_loss = 0.000, entropy_coef_loss = 1.521, entropy_coef = 0.000, action_stds = 0.270 ± 0.041, action_magnitude = 0.533 ± 0.315, num_gradient_steps = 149000, step_time = 7.49, total_time = 1044.35
#
#
# step = 160000, num_env_steps = 160000, scores = -1.738 ± 0.01 (n=2), actor_loss = -0.022, critic_loss = 0.000, entropy_coef_loss = 2.180, entropy_coef = 0.000, action_stds = 0.210 ± 0.046, action_magnitude = 0.520 ± 0.295, num_gradient_steps = 150000, step_time = 8.33, total_time = 1052.68
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 161000, num_env_steps = 161000, scores = -1.356 ± 0.15 (n=2), actor_loss = -0.009, critic_loss = 0.000, entropy_coef_loss = -1.214, entropy_coef = 0.000, action_stds = 0.292 ± 0.046, action_magnitude = 0.523 ± 0.301, num_gradient_steps = 151000, step_time = 7.96, total_time = 1060.64
#
#
# step = 162000, num_env_steps = 162000, scores = -1.932 ± 0.18 (n=2), actor_loss = -0.010, critic_loss = 0.000, entropy_coef_loss = -1.398, entropy_coef = 0.000, action_stds = 0.319 ± 0.109, action_magnitude = 0.576 ± 0.299, num_gradient_steps = 152000, step_time = 8.46, total_time = 1069.10
#
#
# step = 163000, num_env_steps = 163000, scores = -1.692 ± 0.41 (n=2), actor_loss = -0.004, critic_loss = 0.000, entropy_coef_loss = 1.947, entropy_coef = 0.000, action_stds = 0.433 ± 0.207, action_magnitude = 0.623 ± 0.312, num_gradient_steps = 153000, step_time = 8.14, total_time = 1077.23
#
#
# step = 164000, num_env_steps = 164000, scores = -1.568 ± 0.19 (n=2), actor_loss = 0.002, critic_loss = 0.000, entropy_coef_loss = -6.825, entropy_coef = 0.000, action_stds = 0.325 ± 0.146, action_magnitude = 0.604 ± 0.305, num_gradient_steps = 154000, step_time = 7.58, total_time = 1084.81
#
#
# step = 165000, num_env_steps = 165000, scores = -1.710 ± 0.27 (n=2), actor_loss = 0.004, critic_loss = 0.000, entropy_coef_loss = 0.094, entropy_coef = 0.000, action_stds = 0.329 ± 0.073, action_magnitude = 0.585 ± 0.307, num_gradient_steps = 155000, step_time = 7.80, total_time = 1092.61
#
#
# step = 166000, num_env_steps = 166000, scores = -1.399 ± 0.10 (n=2), actor_loss = 0.008, critic_loss = 0.000, entropy_coef_loss = -2.397, entropy_coef = 0.000, action_stds = 0.253 ± 0.074, action_magnitude = 0.529 ± 0.299, num_gradient_steps = 156000, step_time = 7.58, total_time = 1100.19
#
#
# step = 167000, num_env_steps = 167000, scores = -1.722 ± 0.04 (n=2), actor_loss = 0.013, critic_loss = 0.000, entropy_coef_loss = -5.645, entropy_coef = 0.000, action_stds = 0.264 ± 0.067, action_magnitude = 0.580 ± 0.305, num_gradient_steps = 157000, step_time = 8.06, total_time = 1108.25
#
#
# ...
#
#
# step = 581000, num_env_steps = 581000, scores = 12.305 ± 0.18 (n=2), actor_loss = -0.949, critic_loss = 0.001, entropy_coef_loss = 2.395, entropy_coef = 0.000, action_stds = 0.530 ± 0.068, action_magnitude = 0.773 ± 0.269, num_gradient_steps = 571000, step_time = 6.98, total_time = 4030.17
#
#
# step = 582000, num_env_steps = 582000, scores = 12.103 ± 0.72 (n=2), actor_loss = -0.947, critic_loss = 0.001, entropy_coef_loss = -5.758, entropy_coef = 0.000, action_stds = 0.506 ± 0.049, action_magnitude = 0.773 ± 0.268, num_gradient_steps = 572000, step_time = 6.90, total_time = 4037.08
#
#
# step = 583000, num_env_steps = 583000, scores = 12.515 ± 0.19 (n=2), actor_loss = -1.007, critic_loss = 0.001, entropy_coef_loss = 6.473, entropy_coef = 0.000, action_stds = 0.519 ± 0.034, action_magnitude = 0.770 ± 0.271, num_gradient_steps = 573000, step_time = 6.82, total_time = 4043.90
#
#
# step = 584000, num_env_steps = 584000, scores = 12.400 ± 0.46 (n=2), actor_loss = -0.958, critic_loss = 0.001, entropy_coef_loss = -5.429, entropy_coef = 0.000, action_stds = 0.498 ± 0.083, action_magnitude = 0.769 ± 0.271, num_gradient_steps = 574000, step_time = 7.10, total_time = 4051.00
#
#
# step = 585000, num_env_steps = 585000, scores = 12.702 ± 0.29 (n=2), actor_loss = -0.924, critic_loss = 0.001, entropy_coef_loss = -1.515, entropy_coef = 0.000, action_stds = 0.515 ± 0.090, action_magnitude = 0.767 ± 0.274, num_gradient_steps = 575000, step_time = 6.90, total_time = 4057.91
#
#
# step = 586000, num_env_steps = 586000, scores = 12.633 ± 0.73 (n=2), actor_loss = -0.927, critic_loss = 0.001, entropy_coef_loss = -3.630, entropy_coef = 0.000, action_stds = 0.529 ± 0.089, action_magnitude = 0.770 ± 0.270, num_gradient_steps = 576000, step_time = 6.97, total_time = 4064.87
#
#
# step = 587000, num_env_steps = 587000, scores = 12.466 ± 0.34 (n=2), actor_loss = -0.902, critic_loss = 0.001, entropy_coef_loss = -1.828, entropy_coef = 0.000, action_stds = 0.479 ± 0.046, action_magnitude = 0.773 ± 0.268, num_gradient_steps = 577000, step_time = 6.90, total_time = 4071.77
#
#
# step = 588000, num_env_steps = 588000, scores = 12.073 ± 0.15 (n=2), actor_loss = -0.954, critic_loss = 0.001, entropy_coef_loss = -4.334, entropy_coef = 0.000, action_stds = 0.531 ± 0.062, action_magnitude = 0.770 ± 0.272, num_gradient_steps = 578000, step_time = 6.97, total_time = 4078.74
#
#
# step = 589000, num_env_steps = 589000, scores = 12.610 ± 0.47 (n=2), actor_loss = -0.965, critic_loss = 0.001, entropy_coef_loss = 4.731, entropy_coef = 0.000, action_stds = 0.500 ± 0.038, action_magnitude = 0.770 ± 0.266, num_gradient_steps = 579000, step_time = 6.89, total_time = 4085.63
#
#
# step = 590000, num_env_steps = 590000, scores = 12.538 ± 0.15 (n=2), actor_loss = -0.922, critic_loss = 0.001, entropy_coef_loss = 1.878, entropy_coef = 0.000, action_stds = 0.539 ± 0.027, action_magnitude = 0.770 ± 0.270, num_gradient_steps = 580000, step_time = 6.95, total_time = 4092.58
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 591000, num_env_steps = 591000, scores = 12.689 ± 0.32 (n=2), actor_loss = -1.003, critic_loss = 0.001, entropy_coef_loss = 1.218, entropy_coef = 0.000, action_stds = 0.566 ± 0.053, action_magnitude = 0.771 ± 0.267, num_gradient_steps = 581000, step_time = 6.87, total_time = 4099.46
#
#
# step = 592000, num_env_steps = 592000, scores = 12.887 ± 0.05 (n=2), actor_loss = -0.972, critic_loss = 0.001, entropy_coef_loss = -5.114, entropy_coef = 0.000, action_stds = 0.511 ± 0.055, action_magnitude = 0.764 ± 0.275, num_gradient_steps = 582000, step_time = 7.01, total_time = 4106.47
#
#
# step = 593000, num_env_steps = 593000, scores = 12.122 ± 0.12 (n=2), actor_loss = -0.936, critic_loss = 0.001, entropy_coef_loss = -2.440, entropy_coef = 0.000, action_stds = 0.530 ± 0.060, action_magnitude = 0.768 ± 0.270, num_gradient_steps = 583000, step_time = 6.81, total_time = 4113.28
#
#
# step = 594000, num_env_steps = 594000, scores = 12.570 ± 0.20 (n=2), actor_loss = -0.987, critic_loss = 0.001, entropy_coef_loss = -0.088, entropy_coef = 0.000, action_stds = 0.488 ± 0.052, action_magnitude = 0.769 ± 0.267, num_gradient_steps = 584000, step_time = 6.90, total_time = 4120.18
#
#
# step = 595000, num_env_steps = 595000, scores = 13.015 ± 0.21 (n=2), actor_loss = -0.955, critic_loss = 0.001, entropy_coef_loss = -4.512, entropy_coef = 0.000, action_stds = 0.498 ± 0.055, action_magnitude = 0.770 ± 0.268, num_gradient_steps = 585000, step_time = 6.87, total_time = 4127.05
#
#
# step = 596000, num_env_steps = 596000, scores = 12.562 ± 0.57 (n=2), actor_loss = -1.007, critic_loss = 0.001, entropy_coef_loss = 0.367, entropy_coef = 0.000, action_stds = 0.544 ± 0.040, action_magnitude = 0.768 ± 0.267, num_gradient_steps = 586000, step_time = 6.84, total_time = 4133.89
#
#
# step = 597000, num_env_steps = 597000, scores = 12.776 ± 0.26 (n=2), actor_loss = -0.993, critic_loss = 0.001, entropy_coef_loss = 2.720, entropy_coef = 0.000, action_stds = 0.541 ± 0.037, action_magnitude = 0.771 ± 0.269, num_gradient_steps = 587000, step_time = 7.11, total_time = 4141.00
#
#
# step = 598000, num_env_steps = 598000, scores = 12.902 ± 0.32 (n=2), actor_loss = -0.952, critic_loss = 0.001, entropy_coef_loss = 2.501, entropy_coef = 0.000, action_stds = 0.497 ± 0.044, action_magnitude = 0.768 ± 0.268, num_gradient_steps = 588000, step_time = 6.78, total_time = 4147.78
#
#
# step = 599000, num_env_steps = 599000, scores = 12.807 ± 0.25 (n=2), actor_loss = -0.967, critic_loss = 0.001, entropy_coef_loss = 1.839, entropy_coef = 0.000, action_stds = 0.494 ± 0.043, action_magnitude = 0.768 ± 0.270, num_gradient_steps = 589000, step_time = 7.03, total_time = 4154.82
#
#
# step = 600000, num_env_steps = 600000, scores = 13.125 ± 0.08 (n=2), actor_loss = -0.985, critic_loss = 0.001, entropy_coef_loss = -1.380, entropy_coef = 0.000, action_stds = 0.482 ± 0.036, action_magnitude = 0.767 ± 0.270, num_gradient_steps = 590000, step_time = 6.81, total_time = 4161.62
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 601000, num_env_steps = 601000, scores = 12.862 ± 0.07 (n=2), actor_loss = -1.012, critic_loss = 0.001, entropy_coef_loss = 4.910, entropy_coef = 0.000, action_stds = 0.505 ± 0.036, action_magnitude = 0.769 ± 0.270, num_gradient_steps = 591000, step_time = 7.11, total_time = 4168.73
#
#
# step = 602000, num_env_steps = 602000, scores = 12.447 ± 0.36 (n=2), actor_loss = -1.038, critic_loss = 0.001, entropy_coef_loss = -3.731, entropy_coef = 0.000, action_stds = 0.509 ± 0.047, action_magnitude = 0.765 ± 0.273, num_gradient_steps = 592000, step_time = 6.90, total_time = 4175.63
#
#
# step = 603000, num_env_steps = 603000, scores = 12.639 ± 0.01 (n=2), actor_loss = -1.033, critic_loss = 0.001, entropy_coef_loss = -0.037, entropy_coef = 0.000, action_stds = 0.503 ± 0.054, action_magnitude = 0.771 ± 0.270, num_gradient_steps = 593000, step_time = 7.06, total_time = 4182.69
#
#
# step = 604000, num_env_steps = 604000, scores = 12.378 ± 0.03 (n=2), actor_loss = -1.003, critic_loss = 0.001, entropy_coef_loss = -0.643, entropy_coef = 0.000, action_stds = 0.510 ± 0.047, action_magnitude = 0.770 ± 0.270, num_gradient_steps = 594000, step_time = 6.81, total_time = 4189.50
#
#
# step = 605000, num_env_steps = 605000, scores = 13.099 ± 0.12 (n=2), actor_loss = -1.010, critic_loss = 0.001, entropy_coef_loss = -6.956, entropy_coef = 0.000, action_stds = 0.498 ± 0.042, action_magnitude = 0.767 ± 0.271, num_gradient_steps = 595000, step_time = 7.09, total_time = 4196.60
#
#
# step = 606000, num_env_steps = 606000, scores = 11.210 ± 1.59 (n=2), actor_loss = -1.105, critic_loss = 0.001, entropy_coef_loss = 2.538, entropy_coef = 0.000, action_stds = 0.515 ± 0.048, action_magnitude = 0.762 ± 0.273, num_gradient_steps = 596000, step_time = 6.84, total_time = 4203.44
#
#
# step = 607000, num_env_steps = 607000, scores = 12.893 ± 0.21 (n=2), actor_loss = -1.084, critic_loss = 0.001, entropy_coef_loss = 5.277, entropy_coef = 0.000, action_stds = 0.465 ± 0.042, action_magnitude = 0.776 ± 0.264, num_gradient_steps = 597000, step_time = 6.99, total_time = 4210.43
#
#
# step = 608000, num_env_steps = 608000, scores = 13.023 ± 0.17 (n=2), actor_loss = -0.971, critic_loss = 0.001, entropy_coef_loss = 1.232, entropy_coef = 0.000, action_stds = 0.483 ± 0.058, action_magnitude = 0.777 ± 0.266, num_gradient_steps = 598000, step_time = 6.92, total_time = 4217.35
#
#
# step = 609000, num_env_steps = 609000, scores = 12.489 ± 0.07 (n=2), actor_loss = -0.999, critic_loss = 0.001, entropy_coef_loss = 0.630, entropy_coef = 0.000, action_stds = 0.504 ± 0.027, action_magnitude = 0.767 ± 0.271, num_gradient_steps = 599000, step_time = 6.83, total_time = 4224.19
#
#
# step = 610000, num_env_steps = 610000, scores = 12.758 ± 0.16 (n=2), actor_loss = -1.032, critic_loss = 0.001, entropy_coef_loss = 2.108, entropy_coef = 0.000, action_stds = 0.497 ± 0.044, action_magnitude = 0.768 ± 0.271, num_gradient_steps = 600000, step_time = 6.96, total_time = 4231.15
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 611000, num_env_steps = 611000, scores = 12.264 ± 0.28 (n=2), actor_loss = -1.000, critic_loss = 0.001, entropy_coef_loss = -2.552, entropy_coef = 0.000, action_stds = 0.545 ± 0.048, action_magnitude = 0.766 ± 0.271, num_gradient_steps = 601000, step_time = 6.89, total_time = 4238.04
#
#
# step = 612000, num_env_steps = 612000, scores = 13.226 ± 0.12 (n=2), actor_loss = -1.103, critic_loss = 0.001, entropy_coef_loss = 1.744, entropy_coef = 0.000, action_stds = 0.486 ± 0.077, action_magnitude = 0.768 ± 0.269, num_gradient_steps = 602000, step_time = 7.04, total_time = 4245.08
#
#
# step = 613000, num_env_steps = 613000, scores = 13.505 ± 0.03 (n=2), actor_loss = -1.031, critic_loss = 0.001, entropy_coef_loss = -0.043, entropy_coef = 0.000, action_stds = 0.539 ± 0.049, action_magnitude = 0.769 ± 0.272, num_gradient_steps = 603000, step_time = 6.82, total_time = 4251.90
#
#
# step = 614000, num_env_steps = 614000, scores = 13.112 ± 0.33 (n=2), actor_loss = -1.108, critic_loss = 0.001, entropy_coef_loss = -0.843, entropy_coef = 0.000, action_stds = 0.507 ± 0.065, action_magnitude = 0.770 ± 0.269, num_gradient_steps = 604000, step_time = 6.98, total_time = 4258.88
#
#
# step = 615000, num_env_steps = 615000, scores = 12.692 ± 0.51 (n=2), actor_loss = -1.092, critic_loss = 0.001, entropy_coef_loss = 5.287, entropy_coef = 0.000, action_stds = 0.493 ± 0.045, action_magnitude = 0.770 ± 0.271, num_gradient_steps = 605000, step_time = 6.86, total_time = 4265.74
#
#
# step = 616000, num_env_steps = 616000, scores = 12.995 ± 0.23 (n=2), actor_loss = -1.036, critic_loss = 0.001, entropy_coef_loss = -0.648, entropy_coef = 0.000, action_stds = 0.481 ± 0.035, action_magnitude = 0.772 ± 0.266, num_gradient_steps = 606000, step_time = 7.01, total_time = 4272.75
#
#
# step = 617000, num_env_steps = 617000, scores = 13.275 ± 0.04 (n=2), actor_loss = -1.102, critic_loss = 0.001, entropy_coef_loss = 1.297, entropy_coef = 0.000, action_stds = 0.478 ± 0.038, action_magnitude = 0.771 ± 0.268, num_gradient_steps = 607000, step_time = 6.87, total_time = 4279.63
#
#
# step = 618000, num_env_steps = 618000, scores = 13.239 ± 0.08 (n=2), actor_loss = -0.993, critic_loss = 0.001, entropy_coef_loss = -1.166, entropy_coef = 0.000, action_stds = 0.517 ± 0.051, action_magnitude = 0.770 ± 0.268, num_gradient_steps = 608000, step_time = 7.01, total_time = 4286.64
#
#
# step = 619000, num_env_steps = 619000, scores = 13.429 ± 0.50 (n=2), actor_loss = -1.116, critic_loss = 0.001, entropy_coef_loss = 1.457, entropy_coef = 0.000, action_stds = 0.482 ± 0.062, action_magnitude = 0.769 ± 0.271, num_gradient_steps = 609000, step_time = 6.94, total_time = 4293.58
#
#
# step = 620000, num_env_steps = 620000, scores = 13.177 ± 0.35 (n=2), actor_loss = -1.083, critic_loss = 0.001, entropy_coef_loss = -0.622, entropy_coef = 0.000, action_stds = 0.516 ± 0.044, action_magnitude = 0.768 ± 0.271, num_gradient_steps = 610000, step_time = 6.91, total_time = 4300.49
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 621000, num_env_steps = 621000, scores = 13.114 ± 0.00 (n=2), actor_loss = -1.034, critic_loss = 0.001, entropy_coef_loss = -3.500, entropy_coef = 0.000, action_stds = 0.518 ± 0.070, action_magnitude = 0.770 ± 0.269, num_gradient_steps = 611000, step_time = 6.88, total_time = 4307.37
#
#
# step = 622000, num_env_steps = 622000, scores = 12.796 ± 0.35 (n=2), actor_loss = -1.058, critic_loss = 0.001, entropy_coef_loss = 0.974, entropy_coef = 0.000, action_stds = 0.510 ± 0.049, action_magnitude = 0.768 ± 0.271, num_gradient_steps = 612000, step_time = 7.86, total_time = 4315.23
#
#
# step = 623000, num_env_steps = 623000, scores = 13.065 ± 0.09 (n=2), actor_loss = -1.082, critic_loss = 0.001, entropy_coef_loss = -2.196, entropy_coef = 0.000, action_stds = 0.536 ± 0.064, action_magnitude = 0.764 ± 0.271, num_gradient_steps = 613000, step_time = 7.15, total_time = 4322.38
#
#
# step = 624000, num_env_steps = 624000, scores = 12.525 ± 0.72 (n=2), actor_loss = -1.084, critic_loss = 0.001, entropy_coef_loss = 7.631, entropy_coef = 0.000, action_stds = 0.511 ± 0.067, action_magnitude = 0.765 ± 0.273, num_gradient_steps = 614000, step_time = 7.32, total_time = 4329.70
#
#
# step = 625000, num_env_steps = 625000, scores = 13.013 ± 0.32 (n=2), actor_loss = -1.097, critic_loss = 0.001, entropy_coef_loss = -1.257, entropy_coef = 0.000, action_stds = 0.511 ± 0.070, action_magnitude = 0.767 ± 0.270, num_gradient_steps = 615000, step_time = 7.66, total_time = 4337.36
#
#
# step = 626000, num_env_steps = 626000, scores = 12.768 ± 0.38 (n=2), actor_loss = -1.069, critic_loss = 0.001, entropy_coef_loss = -1.781, entropy_coef = 0.000, action_stds = 0.531 ± 0.062, action_magnitude = 0.769 ± 0.268, num_gradient_steps = 616000, step_time = 7.52, total_time = 4344.88
#
#
# step = 627000, num_env_steps = 627000, scores = 13.399 ± 0.09 (n=2), actor_loss = -1.106, critic_loss = 0.001, entropy_coef_loss = 1.973, entropy_coef = 0.000, action_stds = 0.533 ± 0.071, action_magnitude = 0.771 ± 0.269, num_gradient_steps = 617000, step_time = 7.86, total_time = 4352.73
#
#
# step = 628000, num_env_steps = 628000, scores = 13.090 ± 0.07 (n=2), actor_loss = -1.094, critic_loss = 0.001, entropy_coef_loss = -6.648, entropy_coef = 0.000, action_stds = 0.493 ± 0.078, action_magnitude = 0.772 ± 0.266, num_gradient_steps = 618000, step_time = 7.59, total_time = 4360.33
#
#
# step = 629000, num_env_steps = 629000, scores = 12.740 ± 0.40 (n=2), actor_loss = -1.117, critic_loss = 0.001, entropy_coef_loss = 0.438, entropy_coef = 0.000, action_stds = 0.490 ± 0.030, action_magnitude = 0.771 ± 0.266, num_gradient_steps = 619000, step_time = 7.54, total_time = 4367.86
#
#
# step = 630000, num_env_steps = 630000, scores = 13.755 ± 0.08 (n=2), actor_loss = -1.109, critic_loss = 0.001, entropy_coef_loss = -1.922, entropy_coef = 0.000, action_stds = 0.504 ± 0.071, action_magnitude = 0.772 ± 0.266, num_gradient_steps = 620000, step_time = 7.68, total_time = 4375.54
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
#
#
# step = 631000, num_env_steps = 631000, scores = 13.467 ± 0.02 (n=2), actor_loss = -1.187, critic_loss = 0.001, entropy_coef_loss = 2.376, entropy_coef = 0.000, action_stds = 0.508 ± 0.044, action_magnitude = 0.770 ± 0.268, num_gradient_steps = 621000, step_time = 7.77, total_time = 4383.31
#
#
# step = 632000, num_env_steps = 632000, scores = 13.452 ± 0.12 (n=2), actor_loss = -1.088, critic_loss = 0.001, entropy_coef_loss = -1.503, entropy_coef = 0.000, action_stds = 0.488 ± 0.055, action_magnitude = 0.771 ± 0.269, num_gradient_steps = 622000, step_time = 7.76, total_time = 4391.07
#
#
# saved experiment log 2024-10-24_01-01-51_418731~eisOnc at experiment_logs/2024-10-24_01-01-51_418731~eisOnc.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
