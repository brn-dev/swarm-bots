# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.core.buffers.replay.ring_with_reservoir_replay_buffer import \
    RingWithReservoirReplayBuffer
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.envs.swarm_bot_env__v0_1 import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
            best_iteration_score = iteration_score
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        # if step % 100_000 == 0:
        #     save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=5, 
        hip_range=np.pi / 4,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    latent_action_size = 256
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, latent_action_size),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=latent_action_size,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_type=RingWithReservoirReplayBuffer,
            buffer_step_size=200_000,
            buffer_kwargs={
                'reservoir_total_size': 300_000,
            },
            reward_scale=10,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef_clamp_range=(0.001, 1.5),
            # entropy_coef=0.1,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        # algo.load('saved_models/2024-10-28_11-12-19_363042~VskSv0/', '2024-10-28_11-12-19_363042~VskSv0')
        total_stopwatch.reset()
        with log_experiment(
            logger,
            # experiment_id='2024-10-28_11-12-19_363042~VskSv0_1',
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 259618
# env = <swarmbots.envs.swarm_bot_env__v0_1.SwarmBotEnv object at 0x000001C57B14B590>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# Starting Training
#
# step = 11000, num_env_steps = 11000, scores = -3.099 ± 0.00 (n=2), actor_loss = -47.305, critic_loss = 15.360, entropy_coef_loss = -8.052, entropy_coef = 0.737, action_stds = 0.882 ± 0.053, action_magnitude = 0.519 ± 0.285, num_gradient_steps = 1000, step_time = 18.42, total_time = 17.95
#
# step = 12000, num_env_steps = 12000, scores = -3.527 ± 0.32 (n=2), actor_loss = -71.114, critic_loss = 8.512, entropy_coef_loss = -15.457, entropy_coef = 0.549, action_stds = 0.872 ± 0.021, action_magnitude = 0.543 ± 0.290, num_gradient_steps = 2000, step_time = 11.08, total_time = 29.03
#
# step = 13000, num_env_steps = 13000, scores = -3.208 ± 0.21 (n=2), actor_loss = -85.708, critic_loss = 7.785, entropy_coef_loss = -23.394, entropy_coef = 0.407, action_stds = 0.883 ± 0.029, action_magnitude = 0.539 ± 0.288, num_gradient_steps = 3000, step_time = 11.13, total_time = 40.16
#
# step = 14000, num_env_steps = 14000, scores = -3.014 ± 0.11 (n=2), actor_loss = -91.814, critic_loss = 5.613, entropy_coef_loss = -31.203, entropy_coef = 0.301, action_stds = 0.874 ± 0.032, action_magnitude = 0.538 ± 0.288, num_gradient_steps = 4000, step_time = 11.69, total_time = 51.86
#
# step = 15000, num_env_steps = 15000, scores = -2.603 ± 0.19 (n=2), actor_loss = -95.812, critic_loss = 4.820, entropy_coef_loss = -38.421, entropy_coef = 0.224, action_stds = 0.883 ± 0.024, action_magnitude = 0.545 ± 0.290, num_gradient_steps = 5000, step_time = 11.56, total_time = 63.41
#
# step = 16000, num_env_steps = 16000, scores = -3.041 ± 0.21 (n=2), actor_loss = -94.830, critic_loss = 4.796, entropy_coef_loss = -44.612, entropy_coef = 0.166, action_stds = 0.889 ± 0.042, action_magnitude = 0.555 ± 0.291, num_gradient_steps = 6000, step_time = 11.39, total_time = 74.80
#
# step = 17000, num_env_steps = 17000, scores = -2.975 ± 0.29 (n=2), actor_loss = -94.633, critic_loss = 3.419, entropy_coef_loss = -50.322, entropy_coef = 0.124, action_stds = 0.897 ± 0.046, action_magnitude = 0.568 ± 0.293, num_gradient_steps = 7000, step_time = 11.84, total_time = 86.64
#
# step = 18000, num_env_steps = 18000, scores = -3.863 ± 0.10 (n=2), actor_loss = -93.311, critic_loss = 3.055, entropy_coef_loss = -55.311, entropy_coef = 0.093, action_stds = 0.869 ± 0.045, action_magnitude = 0.579 ± 0.296, num_gradient_steps = 8000, step_time = 11.80, total_time = 98.44
#
# step = 19000, num_env_steps = 19000, scores = -2.928 ± 0.41 (n=2), actor_loss = -91.306, critic_loss = 2.441, entropy_coef_loss = -58.898, entropy_coef = 0.070, action_stds = 0.875 ± 0.047, action_magnitude = 0.596 ± 0.298, num_gradient_steps = 9000, step_time = 12.58, total_time = 111.02
#
# step = 20000, num_env_steps = 20000, scores = -4.234 ± 0.72 (n=2), actor_loss = -86.027, critic_loss = 2.577, entropy_coef_loss = -61.402, entropy_coef = 0.053, action_stds = 0.862 ± 0.034, action_magnitude = 0.613 ± 0.297, num_gradient_steps = 10000, step_time = 12.69, total_time = 123.71
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 21000, num_env_steps = 21000, scores = -3.761 ± 0.25 (n=2), actor_loss = -84.067, critic_loss = 1.874, entropy_coef_loss = -60.365, entropy_coef = 0.040, action_stds = 0.844 ± 0.073, action_magnitude = 0.625 ± 0.297, num_gradient_steps = 11000, step_time = 12.31, total_time = 136.02
#
# step = 22000, num_env_steps = 22000, scores = -4.194 ± 0.40 (n=2), actor_loss = -79.537, critic_loss = 1.902, entropy_coef_loss = -58.061, entropy_coef = 0.030, action_stds = 0.832 ± 0.071, action_magnitude = 0.640 ± 0.299, num_gradient_steps = 12000, step_time = 11.27, total_time = 147.29
#
# step = 23000, num_env_steps = 23000, scores = -4.065 ± 0.85 (n=2), actor_loss = -75.145, critic_loss = 1.435, entropy_coef_loss = -52.874, entropy_coef = 0.023, action_stds = 0.822 ± 0.115, action_magnitude = 0.653 ± 0.299, num_gradient_steps = 13000, step_time = 11.80, total_time = 159.09
#
# step = 24000, num_env_steps = 24000, scores = -4.407 ± 0.65 (n=2), actor_loss = -72.014, critic_loss = 1.433, entropy_coef_loss = -50.588, entropy_coef = 0.018, action_stds = 0.751 ± 0.075, action_magnitude = 0.671 ± 0.299, num_gradient_steps = 14000, step_time = 11.38, total_time = 170.47
#
# step = 25000, num_env_steps = 25000, scores = -3.685 ± 0.74 (n=2), actor_loss = -68.318, critic_loss = 0.938, entropy_coef_loss = -48.567, entropy_coef = 0.014, action_stds = 0.767 ± 0.070, action_magnitude = 0.676 ± 0.299, num_gradient_steps = 15000, step_time = 11.34, total_time = 181.81
#
# step = 26000, num_env_steps = 26000, scores = -4.498 ± 0.10 (n=2), actor_loss = -65.018, critic_loss = 0.841, entropy_coef_loss = -35.474, entropy_coef = 0.011, action_stds = 0.740 ± 0.065, action_magnitude = 0.681 ± 0.299, num_gradient_steps = 16000, step_time = 11.34, total_time = 193.15
#
# step = 27000, num_env_steps = 27000, scores = -4.596 ± 0.52 (n=2), actor_loss = -61.698, critic_loss = 0.715, entropy_coef_loss = -34.514, entropy_coef = 0.009, action_stds = 0.731 ± 0.089, action_magnitude = 0.693 ± 0.298, num_gradient_steps = 17000, step_time = 11.27, total_time = 204.42
#
# step = 28000, num_env_steps = 28000, scores = -4.265 ± 0.38 (n=2), actor_loss = -58.151, critic_loss = 0.581, entropy_coef_loss = -31.261, entropy_coef = 0.007, action_stds = 0.739 ± 0.070, action_magnitude = 0.697 ± 0.296, num_gradient_steps = 18000, step_time = 11.42, total_time = 215.84
#
# step = 29000, num_env_steps = 29000, scores = -4.931 ± 0.21 (n=2), actor_loss = -55.832, critic_loss = 0.523, entropy_coef_loss = -23.362, entropy_coef = 0.006, action_stds = 0.660 ± 0.082, action_magnitude = 0.708 ± 0.296, num_gradient_steps = 19000, step_time = 11.39, total_time = 227.23
#
# step = 30000, num_env_steps = 30000, scores = -5.385 ± 0.38 (n=2), actor_loss = -51.504, critic_loss = 0.604, entropy_coef_loss = -13.124, entropy_coef = 0.005, action_stds = 0.661 ± 0.115, action_magnitude = 0.714 ± 0.296, num_gradient_steps = 20000, step_time = 11.36, total_time = 238.60
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 31000, num_env_steps = 31000, scores = -5.294 ± 0.05 (n=2), actor_loss = -48.838, critic_loss = 0.384, entropy_coef_loss = -9.817, entropy_coef = 0.004, action_stds = 0.625 ± 0.089, action_magnitude = 0.721 ± 0.293, num_gradient_steps = 21000, step_time = 11.36, total_time = 249.96
#
# step = 32000, num_env_steps = 32000, scores = -4.508 ± 0.54 (n=2), actor_loss = -45.860, critic_loss = 0.396, entropy_coef_loss = -9.858, entropy_coef = 0.003, action_stds = 0.671 ± 0.092, action_magnitude = 0.704 ± 0.296, num_gradient_steps = 22000, step_time = 11.30, total_time = 261.27
#
# step = 33000, num_env_steps = 33000, scores = -5.105 ± 0.07 (n=2), actor_loss = -43.063, critic_loss = 0.332, entropy_coef_loss = 2.934, entropy_coef = 0.003, action_stds = 0.666 ± 0.054, action_magnitude = 0.714 ± 0.295, num_gradient_steps = 23000, step_time = 11.46, total_time = 272.73
#
# step = 34000, num_env_steps = 34000, scores = -4.804 ± 0.38 (n=2), actor_loss = -41.151, critic_loss = 0.294, entropy_coef_loss = -0.270, entropy_coef = 0.003, action_stds = 0.610 ± 0.063, action_magnitude = 0.721 ± 0.295, num_gradient_steps = 24000, step_time = 11.38, total_time = 284.12
#
# step = 35000, num_env_steps = 35000, scores = -4.569 ± 0.12 (n=2), actor_loss = -38.389, critic_loss = 0.261, entropy_coef_loss = -16.832, entropy_coef = 0.002, action_stds = 0.603 ± 0.055, action_magnitude = 0.715 ± 0.295, num_gradient_steps = 25000, step_time = 11.34, total_time = 295.45
#
# step = 36000, num_env_steps = 36000, scores = -4.455 ± 0.26 (n=2), actor_loss = -35.658, critic_loss = 0.294, entropy_coef_loss = 2.545, entropy_coef = 0.002, action_stds = 0.606 ± 0.099, action_magnitude = 0.716 ± 0.295, num_gradient_steps = 26000, step_time = 11.32, total_time = 306.77
#
# step = 37000, num_env_steps = 37000, scores = -4.900 ± 0.03 (n=2), actor_loss = -34.076, critic_loss = 0.175, entropy_coef_loss = -0.716, entropy_coef = 0.002, action_stds = 0.597 ± 0.075, action_magnitude = 0.702 ± 0.297, num_gradient_steps = 27000, step_time = 11.38, total_time = 318.15
#
# step = 38000, num_env_steps = 38000, scores = -4.568 ± 0.00 (n=2), actor_loss = -31.355, critic_loss = 0.168, entropy_coef_loss = 6.639, entropy_coef = 0.002, action_stds = 0.641 ± 0.084, action_magnitude = 0.702 ± 0.298, num_gradient_steps = 28000, step_time = 11.26, total_time = 329.41
#
# step = 39000, num_env_steps = 39000, scores = -4.685 ± 0.30 (n=2), actor_loss = -30.222, critic_loss = 0.119, entropy_coef_loss = -11.629, entropy_coef = 0.002, action_stds = 0.573 ± 0.062, action_magnitude = 0.702 ± 0.295, num_gradient_steps = 29000, step_time = 11.31, total_time = 340.72
#
# step = 40000, num_env_steps = 40000, scores = -5.276 ± 0.27 (n=2), actor_loss = -28.098, critic_loss = 0.129, entropy_coef_loss = -0.473, entropy_coef = 0.001, action_stds = 0.612 ± 0.063, action_magnitude = 0.717 ± 0.294, num_gradient_steps = 30000, step_time = 11.34, total_time = 352.06
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 41000, num_env_steps = 41000, scores = -4.680 ± 0.02 (n=2), actor_loss = -26.108, critic_loss = 0.105, entropy_coef_loss = -9.638, entropy_coef = 0.001, action_stds = 0.598 ± 0.081, action_magnitude = 0.705 ± 0.296, num_gradient_steps = 31000, step_time = 11.35, total_time = 363.41
#
# step = 42000, num_env_steps = 42000, scores = -4.475 ± 0.08 (n=2), actor_loss = -24.850, critic_loss = 0.076, entropy_coef_loss = 5.153, entropy_coef = 0.001, action_stds = 0.554 ± 0.072, action_magnitude = 0.698 ± 0.299, num_gradient_steps = 32000, step_time = 11.29, total_time = 374.70
#
# step = 43000, num_env_steps = 43000, scores = -4.787 ± 0.42 (n=2), actor_loss = -23.037, critic_loss = 0.076, entropy_coef_loss = 4.793, entropy_coef = 0.001, action_stds = 0.596 ± 0.083, action_magnitude = 0.691 ± 0.298, num_gradient_steps = 33000, step_time = 11.36, total_time = 386.06
#
# step = 44000, num_env_steps = 44000, scores = -4.801 ± 0.33 (n=2), actor_loss = -21.326, critic_loss = 0.077, entropy_coef_loss = -6.944, entropy_coef = 0.001, action_stds = 0.538 ± 0.071, action_magnitude = 0.697 ± 0.299, num_gradient_steps = 34000, step_time = 11.43, total_time = 397.48
#
# step = 45000, num_env_steps = 45000, scores = -4.643 ± 0.76 (n=2), actor_loss = -20.184, critic_loss = 0.060, entropy_coef_loss = -14.694, entropy_coef = 0.001, action_stds = 0.571 ± 0.058, action_magnitude = 0.695 ± 0.298, num_gradient_steps = 35000, step_time = 11.37, total_time = 408.85
#
# step = 46000, num_env_steps = 46000, scores = -4.031 ± 0.05 (n=2), actor_loss = -18.652, critic_loss = 0.051, entropy_coef_loss = -18.744, entropy_coef = 0.001, action_stds = 0.614 ± 0.042, action_magnitude = 0.679 ± 0.297, num_gradient_steps = 36000, step_time = 11.33, total_time = 420.18
#
# step = 47000, num_env_steps = 47000, scores = -4.446 ± 0.20 (n=2), actor_loss = -17.266, critic_loss = 0.048, entropy_coef_loss = -23.120, entropy_coef = 0.001, action_stds = 0.529 ± 0.058, action_magnitude = 0.669 ± 0.299, num_gradient_steps = 37000, step_time = 11.33, total_time = 431.52
#
# step = 48000, num_env_steps = 48000, scores = -4.008 ± 0.21 (n=2), actor_loss = -16.132, critic_loss = 0.040, entropy_coef_loss = -43.864, entropy_coef = 0.001, action_stds = 0.565 ± 0.033, action_magnitude = 0.651 ± 0.301, num_gradient_steps = 38000, step_time = 11.37, total_time = 442.89
#
# step = 49000, num_env_steps = 49000, scores = -4.030 ± 0.09 (n=2), actor_loss = -14.969, critic_loss = 0.036, entropy_coef_loss = -45.287, entropy_coef = 0.001, action_stds = 0.578 ± 0.065, action_magnitude = 0.655 ± 0.301, num_gradient_steps = 39000, step_time = 11.29, total_time = 454.17
#
# step = 50000, num_env_steps = 50000, scores = -3.625 ± 0.21 (n=2), actor_loss = -13.674, critic_loss = 0.037, entropy_coef_loss = -53.424, entropy_coef = 0.001, action_stds = 0.535 ± 0.051, action_magnitude = 0.637 ± 0.300, num_gradient_steps = 40000, step_time = 11.29, total_time = 465.46
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 51000, num_env_steps = 51000, scores = -3.661 ± 0.27 (n=2), actor_loss = -12.848, critic_loss = 0.030, entropy_coef_loss = -44.788, entropy_coef = 0.001, action_stds = 0.564 ± 0.044, action_magnitude = 0.631 ± 0.300, num_gradient_steps = 41000, step_time = 11.43, total_time = 476.89
#
# step = 52000, num_env_steps = 52000, scores = -3.958 ± 0.01 (n=2), actor_loss = -11.648, critic_loss = 0.029, entropy_coef_loss = -76.744, entropy_coef = 0.001, action_stds = 0.557 ± 0.054, action_magnitude = 0.634 ± 0.299, num_gradient_steps = 42000, step_time = 11.30, total_time = 488.18
#
# step = 53000, num_env_steps = 53000, scores = -3.090 ± 0.15 (n=2), actor_loss = -10.889, critic_loss = 0.029, entropy_coef_loss = -68.942, entropy_coef = 0.001, action_stds = 0.573 ± 0.085, action_magnitude = 0.620 ± 0.300, num_gradient_steps = 43000, step_time = 11.34, total_time = 499.52
#
# step = 54000, num_env_steps = 54000, scores = -3.223 ± 0.23 (n=2), actor_loss = -10.062, critic_loss = 0.022, entropy_coef_loss = -73.682, entropy_coef = 0.001, action_stds = 0.521 ± 0.037, action_magnitude = 0.610 ± 0.297, num_gradient_steps = 44000, step_time = 11.37, total_time = 510.89
#
# step = 55000, num_env_steps = 55000, scores = -3.496 ± 0.25 (n=2), actor_loss = -9.192, critic_loss = 0.023, entropy_coef_loss = -68.699, entropy_coef = 0.001, action_stds = 0.516 ± 0.039, action_magnitude = 0.599 ± 0.297, num_gradient_steps = 45000, step_time = 11.37, total_time = 522.27
#
# step = 56000, num_env_steps = 56000, scores = -3.435 ± 0.05 (n=2), actor_loss = -8.339, critic_loss = 0.023, entropy_coef_loss = -74.030, entropy_coef = 0.001, action_stds = 0.536 ± 0.052, action_magnitude = 0.605 ± 0.300, num_gradient_steps = 46000, step_time = 11.40, total_time = 533.67
#
# step = 57000, num_env_steps = 57000, scores = -3.278 ± 0.10 (n=2), actor_loss = -7.609, critic_loss = 0.023, entropy_coef_loss = -81.738, entropy_coef = 0.001, action_stds = 0.595 ± 0.052, action_magnitude = 0.595 ± 0.300, num_gradient_steps = 47000, step_time = 11.35, total_time = 545.02
#
# step = 58000, num_env_steps = 58000, scores = -3.251 ± 0.26 (n=2), actor_loss = -6.878, critic_loss = 0.018, entropy_coef_loss = -80.330, entropy_coef = 0.001, action_stds = 0.525 ± 0.046, action_magnitude = 0.588 ± 0.299, num_gradient_steps = 48000, step_time = 11.33, total_time = 556.35
#
# step = 59000, num_env_steps = 59000, scores = -2.702 ± 0.25 (n=2), actor_loss = -6.217, critic_loss = 0.017, entropy_coef_loss = -85.851, entropy_coef = 0.001, action_stds = 0.529 ± 0.038, action_magnitude = 0.579 ± 0.295, num_gradient_steps = 49000, step_time = 11.42, total_time = 567.76
#
# step = 60000, num_env_steps = 60000, scores = -3.032 ± 0.04 (n=2), actor_loss = -5.753, critic_loss = 0.016, entropy_coef_loss = -76.034, entropy_coef = 0.001, action_stds = 0.535 ± 0.045, action_magnitude = 0.574 ± 0.296, num_gradient_steps = 50000, step_time = 11.40, total_time = 579.16
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 61000, num_env_steps = 61000, scores = -2.740 ± 0.11 (n=2), actor_loss = -5.117, critic_loss = 0.017, entropy_coef_loss = -78.604, entropy_coef = 0.001, action_stds = 0.498 ± 0.061, action_magnitude = 0.563 ± 0.294, num_gradient_steps = 51000, step_time = 11.42, total_time = 590.57
#
# step = 62000, num_env_steps = 62000, scores = -2.671 ± 0.09 (n=2), actor_loss = -4.521, critic_loss = 0.014, entropy_coef_loss = -86.459, entropy_coef = 0.001, action_stds = 0.463 ± 0.045, action_magnitude = 0.558 ± 0.294, num_gradient_steps = 52000, step_time = 11.40, total_time = 601.98
#
# step = 63000, num_env_steps = 63000, scores = -2.734 ± 0.17 (n=2), actor_loss = -4.088, critic_loss = 0.017, entropy_coef_loss = -87.582, entropy_coef = 0.001, action_stds = 0.521 ± 0.038, action_magnitude = 0.563 ± 0.294, num_gradient_steps = 53000, step_time = 11.36, total_time = 613.34
#
# step = 64000, num_env_steps = 64000, scores = -2.875 ± 0.03 (n=2), actor_loss = -3.599, critic_loss = 0.013, entropy_coef_loss = -86.715, entropy_coef = 0.001, action_stds = 0.465 ± 0.027, action_magnitude = 0.570 ± 0.295, num_gradient_steps = 54000, step_time = 11.40, total_time = 624.74
#
# step = 65000, num_env_steps = 65000, scores = -3.235 ± 0.17 (n=2), actor_loss = -3.146, critic_loss = 0.015, entropy_coef_loss = -91.103, entropy_coef = 0.001, action_stds = 0.482 ± 0.056, action_magnitude = 0.578 ± 0.294, num_gradient_steps = 55000, step_time = 11.37, total_time = 636.11
#
# step = 66000, num_env_steps = 66000, scores = -2.635 ± 0.03 (n=2), actor_loss = -2.779, critic_loss = 0.014, entropy_coef_loss = -91.178, entropy_coef = 0.001, action_stds = 0.471 ± 0.059, action_magnitude = 0.550 ± 0.292, num_gradient_steps = 56000, step_time = 11.34, total_time = 647.45
#
# step = 67000, num_env_steps = 67000, scores = -2.742 ± 0.51 (n=2), actor_loss = -2.398, critic_loss = 0.012, entropy_coef_loss = -91.318, entropy_coef = 0.001, action_stds = 0.459 ± 0.037, action_magnitude = 0.546 ± 0.291, num_gradient_steps = 57000, step_time = 11.39, total_time = 658.84
#
# step = 68000, num_env_steps = 68000, scores = -2.685 ± 0.11 (n=2), actor_loss = -2.020, critic_loss = 0.016, entropy_coef_loss = -95.942, entropy_coef = 0.001, action_stds = 0.446 ± 0.035, action_magnitude = 0.550 ± 0.293, num_gradient_steps = 58000, step_time = 11.42, total_time = 670.26
#
# step = 69000, num_env_steps = 69000, scores = -2.620 ± 0.35 (n=2), actor_loss = -1.693, critic_loss = 0.014, entropy_coef_loss = -86.697, entropy_coef = 0.001, action_stds = 0.471 ± 0.054, action_magnitude = 0.540 ± 0.289, num_gradient_steps = 59000, step_time = 11.29, total_time = 681.55
#
# step = 70000, num_env_steps = 70000, scores = -2.564 ± 0.35 (n=2), actor_loss = -1.389, critic_loss = 0.012, entropy_coef_loss = -90.700, entropy_coef = 0.001, action_stds = 0.462 ± 0.040, action_magnitude = 0.550 ± 0.293, num_gradient_steps = 60000, step_time = 11.38, total_time = 692.92
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 71000, num_env_steps = 71000, scores = -2.468 ± 0.29 (n=2), actor_loss = -1.073, critic_loss = 0.012, entropy_coef_loss = -90.239, entropy_coef = 0.001, action_stds = 0.436 ± 0.040, action_magnitude = 0.545 ± 0.291, num_gradient_steps = 61000, step_time = 11.43, total_time = 704.35
#
# step = 72000, num_env_steps = 72000, scores = -2.340 ± 0.20 (n=2), actor_loss = -0.812, critic_loss = 0.012, entropy_coef_loss = -90.464, entropy_coef = 0.001, action_stds = 0.433 ± 0.046, action_magnitude = 0.537 ± 0.289, num_gradient_steps = 62000, step_time = 11.40, total_time = 715.76
#
# step = 73000, num_env_steps = 73000, scores = -2.603 ± 0.01 (n=2), actor_loss = -0.571, critic_loss = 0.011, entropy_coef_loss = -86.227, entropy_coef = 0.001, action_stds = 0.423 ± 0.037, action_magnitude = 0.526 ± 0.286, num_gradient_steps = 63000, step_time = 11.41, total_time = 727.16
#
# step = 74000, num_env_steps = 74000, scores = -2.396 ± 0.02 (n=2), actor_loss = -0.366, critic_loss = 0.012, entropy_coef_loss = -84.859, entropy_coef = 0.001, action_stds = 0.389 ± 0.045, action_magnitude = 0.548 ± 0.291, num_gradient_steps = 64000, step_time = 11.31, total_time = 738.48
#
# step = 75000, num_env_steps = 75000, scores = -2.545 ± 0.10 (n=2), actor_loss = -0.083, critic_loss = 0.011, entropy_coef_loss = -93.510, entropy_coef = 0.001, action_stds = 0.462 ± 0.049, action_magnitude = 0.543 ± 0.290, num_gradient_steps = 65000, step_time = 11.42, total_time = 749.90
#
# step = 76000, num_env_steps = 76000, scores = -2.228 ± 0.08 (n=2), actor_loss = 0.116, critic_loss = 0.013, entropy_coef_loss = -85.684, entropy_coef = 0.001, action_stds = 0.420 ± 0.037, action_magnitude = 0.532 ± 0.289, num_gradient_steps = 66000, step_time = 11.46, total_time = 761.36
#
# step = 77000, num_env_steps = 77000, scores = -2.247 ± 0.21 (n=2), actor_loss = 0.287, critic_loss = 0.010, entropy_coef_loss = -83.611, entropy_coef = 0.001, action_stds = 0.409 ± 0.047, action_magnitude = 0.538 ± 0.289, num_gradient_steps = 67000, step_time = 11.44, total_time = 772.80
#
# step = 78000, num_env_steps = 78000, scores = -2.137 ± 0.06 (n=2), actor_loss = 0.524, critic_loss = 0.013, entropy_coef_loss = -84.619, entropy_coef = 0.001, action_stds = 0.390 ± 0.041, action_magnitude = 0.531 ± 0.287, num_gradient_steps = 68000, step_time = 11.38, total_time = 784.19
#
# step = 79000, num_env_steps = 79000, scores = -2.221 ± 0.11 (n=2), actor_loss = 0.648, critic_loss = 0.010, entropy_coef_loss = -85.216, entropy_coef = 0.001, action_stds = 0.405 ± 0.052, action_magnitude = 0.536 ± 0.287, num_gradient_steps = 69000, step_time = 11.37, total_time = 795.55
#
# step = 80000, num_env_steps = 80000, scores = -2.357 ± 0.17 (n=2), actor_loss = 0.803, critic_loss = 0.014, entropy_coef_loss = -85.631, entropy_coef = 0.001, action_stds = 0.392 ± 0.066, action_magnitude = 0.527 ± 0.289, num_gradient_steps = 70000, step_time = 11.34, total_time = 806.89
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 81000, num_env_steps = 81000, scores = -2.480 ± 0.47 (n=2), actor_loss = 0.959, critic_loss = 0.012, entropy_coef_loss = -82.711, entropy_coef = 0.001, action_stds = 0.362 ± 0.057, action_magnitude = 0.543 ± 0.290, num_gradient_steps = 71000, step_time = 11.46, total_time = 818.35
#
# step = 82000, num_env_steps = 82000, scores = -2.425 ± 0.33 (n=2), actor_loss = 1.164, critic_loss = 0.013, entropy_coef_loss = -84.585, entropy_coef = 0.001, action_stds = 0.356 ± 0.049, action_magnitude = 0.543 ± 0.289, num_gradient_steps = 72000, step_time = 11.36, total_time = 829.72
#
# step = 83000, num_env_steps = 83000, scores = -2.313 ± 0.12 (n=2), actor_loss = 1.218, critic_loss = 0.012, entropy_coef_loss = -87.268, entropy_coef = 0.001, action_stds = 0.361 ± 0.044, action_magnitude = 0.542 ± 0.289, num_gradient_steps = 73000, step_time = 11.47, total_time = 841.19
#
# step = 84000, num_env_steps = 84000, scores = -2.435 ± 0.06 (n=2), actor_loss = 1.355, critic_loss = 0.013, entropy_coef_loss = -79.972, entropy_coef = 0.001, action_stds = 0.390 ± 0.050, action_magnitude = 0.536 ± 0.292, num_gradient_steps = 74000, step_time = 11.41, total_time = 852.60
#
# step = 85000, num_env_steps = 85000, scores = -2.260 ± 0.29 (n=2), actor_loss = 1.454, critic_loss = 0.014, entropy_coef_loss = -79.488, entropy_coef = 0.001, action_stds = 0.379 ± 0.035, action_magnitude = 0.541 ± 0.292, num_gradient_steps = 75000, step_time = 11.37, total_time = 863.97
#
# step = 86000, num_env_steps = 86000, scores = -2.650 ± 0.31 (n=2), actor_loss = 1.593, critic_loss = 0.011, entropy_coef_loss = -77.913, entropy_coef = 0.001, action_stds = 0.460 ± 0.067, action_magnitude = 0.539 ± 0.291, num_gradient_steps = 76000, step_time = 11.47, total_time = 875.44
#
# step = 87000, num_env_steps = 87000, scores = -2.909 ± 0.32 (n=2), actor_loss = 1.685, critic_loss = 0.011, entropy_coef_loss = -81.106, entropy_coef = 0.001, action_stds = 0.380 ± 0.035, action_magnitude = 0.542 ± 0.291, num_gradient_steps = 77000, step_time = 11.39, total_time = 886.82
#
# step = 88000, num_env_steps = 88000, scores = -2.703 ± 0.09 (n=2), actor_loss = 1.819, critic_loss = 0.011, entropy_coef_loss = -76.913, entropy_coef = 0.001, action_stds = 0.424 ± 0.062, action_magnitude = 0.542 ± 0.293, num_gradient_steps = 78000, step_time = 11.39, total_time = 898.22
#
# step = 89000, num_env_steps = 89000, scores = -2.409 ± 0.18 (n=2), actor_loss = 1.920, critic_loss = 0.013, entropy_coef_loss = -81.706, entropy_coef = 0.001, action_stds = 0.400 ± 0.042, action_magnitude = 0.535 ± 0.289, num_gradient_steps = 79000, step_time = 11.45, total_time = 909.66
#
# step = 90000, num_env_steps = 90000, scores = -2.796 ± 0.64 (n=2), actor_loss = 2.025, critic_loss = 0.010, entropy_coef_loss = -81.976, entropy_coef = 0.001, action_stds = 0.390 ± 0.033, action_magnitude = 0.536 ± 0.288, num_gradient_steps = 80000, step_time = 11.37, total_time = 921.03
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 91000, num_env_steps = 91000, scores = -2.390 ± 0.21 (n=2), actor_loss = 2.082, critic_loss = 0.010, entropy_coef_loss = -82.181, entropy_coef = 0.001, action_stds = 0.378 ± 0.051, action_magnitude = 0.532 ± 0.289, num_gradient_steps = 81000, step_time = 11.41, total_time = 932.44
#
# step = 92000, num_env_steps = 92000, scores = -2.480 ± 0.33 (n=2), actor_loss = 2.192, critic_loss = 0.013, entropy_coef_loss = -85.273, entropy_coef = 0.001, action_stds = 0.409 ± 0.038, action_magnitude = 0.532 ± 0.291, num_gradient_steps = 82000, step_time = 11.48, total_time = 943.91
#
# step = 93000, num_env_steps = 93000, scores = -2.058 ± 0.30 (n=2), actor_loss = 2.357, critic_loss = 0.015, entropy_coef_loss = -83.254, entropy_coef = 0.001, action_stds = 0.398 ± 0.054, action_magnitude = 0.522 ± 0.285, num_gradient_steps = 83000, step_time = 11.43, total_time = 955.34
#
# step = 94000, num_env_steps = 94000, scores = -2.504 ± 0.27 (n=2), actor_loss = 2.397, critic_loss = 0.010, entropy_coef_loss = -79.000, entropy_coef = 0.001, action_stds = 0.362 ± 0.033, action_magnitude = 0.533 ± 0.288, num_gradient_steps = 84000, step_time = 11.49, total_time = 966.83
#
# step = 95000, num_env_steps = 95000, scores = -2.003 ± 0.25 (n=2), actor_loss = 2.479, critic_loss = 0.011, entropy_coef_loss = -80.869, entropy_coef = 0.001, action_stds = 0.387 ± 0.058, action_magnitude = 0.546 ± 0.290, num_gradient_steps = 85000, step_time = 11.35, total_time = 978.18
#
# step = 96000, num_env_steps = 96000, scores = -2.503 ± 0.35 (n=2), actor_loss = 2.536, critic_loss = 0.010, entropy_coef_loss = -82.648, entropy_coef = 0.001, action_stds = 0.386 ± 0.049, action_magnitude = 0.533 ± 0.289, num_gradient_steps = 86000, step_time = 11.41, total_time = 989.59
#
# step = 97000, num_env_steps = 97000, scores = -2.447 ± 0.04 (n=2), actor_loss = 2.650, critic_loss = 0.011, entropy_coef_loss = -84.260, entropy_coef = 0.001, action_stds = 0.385 ± 0.049, action_magnitude = 0.532 ± 0.289, num_gradient_steps = 87000, step_time = 11.47, total_time = 1001.05
#
# step = 98000, num_env_steps = 98000, scores = -2.404 ± 0.28 (n=2), actor_loss = 2.676, critic_loss = 0.011, entropy_coef_loss = -84.511, entropy_coef = 0.001, action_stds = 0.376 ± 0.051, action_magnitude = 0.529 ± 0.290, num_gradient_steps = 88000, step_time = 11.40, total_time = 1012.45
#
# step = 99000, num_env_steps = 99000, scores = -2.206 ± 0.00 (n=2), actor_loss = 2.740, critic_loss = 0.010, entropy_coef_loss = -76.096, entropy_coef = 0.001, action_stds = 0.386 ± 0.056, action_magnitude = 0.536 ± 0.289, num_gradient_steps = 89000, step_time = 11.38, total_time = 1023.83
#
# step = 100000, num_env_steps = 100000, scores = -2.212 ± 0.08 (n=2), actor_loss = 2.878, critic_loss = 0.012, entropy_coef_loss = -79.419, entropy_coef = 0.001, action_stds = 0.405 ± 0.084, action_magnitude = 0.527 ± 0.290, num_gradient_steps = 90000, step_time = 11.46, total_time = 1035.29
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 101000, num_env_steps = 101000, scores = -2.228 ± 0.30 (n=2), actor_loss = 2.959, critic_loss = 0.011, entropy_coef_loss = -76.822, entropy_coef = 0.001, action_stds = 0.350 ± 0.044, action_magnitude = 0.520 ± 0.285, num_gradient_steps = 91000, step_time = 11.49, total_time = 1046.78
#
# step = 102000, num_env_steps = 102000, scores = -2.370 ± 0.23 (n=2), actor_loss = 2.935, critic_loss = 0.012, entropy_coef_loss = -79.371, entropy_coef = 0.001, action_stds = 0.426 ± 0.058, action_magnitude = 0.533 ± 0.291, num_gradient_steps = 92000, step_time = 11.44, total_time = 1058.21
#
# step = 103000, num_env_steps = 103000, scores = -2.411 ± 0.28 (n=2), actor_loss = 3.029, critic_loss = 0.012, entropy_coef_loss = -78.613, entropy_coef = 0.001, action_stds = 0.356 ± 0.041, action_magnitude = 0.521 ± 0.286, num_gradient_steps = 93000, step_time = 11.43, total_time = 1069.65
#
# step = 104000, num_env_steps = 104000, scores = -2.209 ± 0.12 (n=2), actor_loss = 3.046, critic_loss = 0.011, entropy_coef_loss = -78.925, entropy_coef = 0.001, action_stds = 0.435 ± 0.063, action_magnitude = 0.533 ± 0.291, num_gradient_steps = 94000, step_time = 11.48, total_time = 1081.12
#
# step = 105000, num_env_steps = 105000, scores = -2.072 ± 0.13 (n=2), actor_loss = 3.154, critic_loss = 0.011, entropy_coef_loss = -80.637, entropy_coef = 0.001, action_stds = 0.349 ± 0.063, action_magnitude = 0.534 ± 0.289, num_gradient_steps = 95000, step_time = 11.45, total_time = 1092.58
#
# step = 106000, num_env_steps = 106000, scores = -2.133 ± 0.25 (n=2), actor_loss = 3.200, critic_loss = 0.010, entropy_coef_loss = -78.044, entropy_coef = 0.001, action_stds = 0.362 ± 0.052, action_magnitude = 0.528 ± 0.291, num_gradient_steps = 96000, step_time = 11.45, total_time = 1104.02
#
# step = 107000, num_env_steps = 107000, scores = -2.105 ± 0.14 (n=2), actor_loss = 3.275, critic_loss = 0.010, entropy_coef_loss = -80.852, entropy_coef = 0.001, action_stds = 0.401 ± 0.056, action_magnitude = 0.508 ± 0.284, num_gradient_steps = 97000, step_time = 11.41, total_time = 1115.44
#
# step = 108000, num_env_steps = 108000, scores = -2.388 ± 0.16 (n=2), actor_loss = 3.251, critic_loss = 0.012, entropy_coef_loss = -76.704, entropy_coef = 0.001, action_stds = 0.397 ± 0.060, action_magnitude = 0.536 ± 0.290, num_gradient_steps = 98000, step_time = 11.41, total_time = 1126.84
#
# step = 109000, num_env_steps = 109000, scores = -2.184 ± 0.32 (n=2), actor_loss = 3.321, critic_loss = 0.012, entropy_coef_loss = -83.569, entropy_coef = 0.001, action_stds = 0.354 ± 0.043, action_magnitude = 0.523 ± 0.288, num_gradient_steps = 99000, step_time = 11.41, total_time = 1138.26
#
# step = 110000, num_env_steps = 110000, scores = -2.043 ± 0.30 (n=2), actor_loss = 3.389, critic_loss = 0.011, entropy_coef_loss = -82.955, entropy_coef = 0.001, action_stds = 0.405 ± 0.061, action_magnitude = 0.549 ± 0.293, num_gradient_steps = 100000, step_time = 11.42, total_time = 1149.68
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 111000, num_env_steps = 111000, scores = -1.995 ± 0.05 (n=2), actor_loss = 3.479, critic_loss = 0.009, entropy_coef_loss = -86.949, entropy_coef = 0.001, action_stds = 0.388 ± 0.055, action_magnitude = 0.523 ± 0.287, num_gradient_steps = 101000, step_time = 11.52, total_time = 1161.20
#
# step = 112000, num_env_steps = 112000, scores = -2.020 ± 0.17 (n=2), actor_loss = 3.474, critic_loss = 0.009, entropy_coef_loss = -79.264, entropy_coef = 0.001, action_stds = 0.441 ± 0.049, action_magnitude = 0.527 ± 0.289, num_gradient_steps = 102000, step_time = 11.43, total_time = 1172.63
#
# step = 113000, num_env_steps = 113000, scores = -1.906 ± 0.02 (n=2), actor_loss = 3.582, critic_loss = 0.010, entropy_coef_loss = -82.383, entropy_coef = 0.001, action_stds = 0.396 ± 0.068, action_magnitude = 0.523 ± 0.287, num_gradient_steps = 103000, step_time = 11.46, total_time = 1184.09
#
# step = 114000, num_env_steps = 114000, scores = -2.231 ± 0.00 (n=2), actor_loss = 3.573, critic_loss = 0.011, entropy_coef_loss = -80.488, entropy_coef = 0.001, action_stds = 0.370 ± 0.044, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 104000, step_time = 11.45, total_time = 1195.54
#
# step = 115000, num_env_steps = 115000, scores = -2.214 ± 0.10 (n=2), actor_loss = 3.556, critic_loss = 0.012, entropy_coef_loss = -81.389, entropy_coef = 0.001, action_stds = 0.366 ± 0.050, action_magnitude = 0.523 ± 0.288, num_gradient_steps = 105000, step_time = 11.45, total_time = 1206.99
#
# step = 116000, num_env_steps = 116000, scores = -2.256 ± 0.30 (n=2), actor_loss = 3.666, critic_loss = 0.010, entropy_coef_loss = -81.356, entropy_coef = 0.001, action_stds = 0.372 ± 0.046, action_magnitude = 0.534 ± 0.289, num_gradient_steps = 106000, step_time = 11.45, total_time = 1218.45
#
# step = 117000, num_env_steps = 117000, scores = -1.789 ± 0.45 (n=2), actor_loss = 3.672, critic_loss = 0.010, entropy_coef_loss = -83.150, entropy_coef = 0.001, action_stds = 0.421 ± 0.049, action_magnitude = 0.543 ± 0.293, num_gradient_steps = 107000, step_time = 11.40, total_time = 1229.85
#
# step = 118000, num_env_steps = 118000, scores = -1.826 ± 0.13 (n=2), actor_loss = 3.692, critic_loss = 0.010, entropy_coef_loss = -80.798, entropy_coef = 0.001, action_stds = 0.399 ± 0.102, action_magnitude = 0.508 ± 0.284, num_gradient_steps = 108000, step_time = 11.42, total_time = 1241.27
#
# step = 119000, num_env_steps = 119000, scores = -1.766 ± 0.13 (n=2), actor_loss = 3.687, critic_loss = 0.013, entropy_coef_loss = -77.424, entropy_coef = 0.001, action_stds = 0.393 ± 0.038, action_magnitude = 0.519 ± 0.286, num_gradient_steps = 109000, step_time = 11.44, total_time = 1252.71
#
# step = 120000, num_env_steps = 120000, scores = -1.978 ± 0.06 (n=2), actor_loss = 3.763, critic_loss = 0.009, entropy_coef_loss = -85.813, entropy_coef = 0.001, action_stds = 0.424 ± 0.038, action_magnitude = 0.516 ± 0.287, num_gradient_steps = 110000, step_time = 11.40, total_time = 1264.11
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 121000, num_env_steps = 121000, scores = -2.161 ± 0.36 (n=2), actor_loss = 3.698, critic_loss = 0.009, entropy_coef_loss = -76.370, entropy_coef = 0.001, action_stds = 0.410 ± 0.045, action_magnitude = 0.543 ± 0.292, num_gradient_steps = 111000, step_time = 11.40, total_time = 1275.51
#
# step = 122000, num_env_steps = 122000, scores = -1.924 ± 0.12 (n=2), actor_loss = 3.749, critic_loss = 0.009, entropy_coef_loss = -75.619, entropy_coef = 0.001, action_stds = 0.345 ± 0.039, action_magnitude = 0.512 ± 0.286, num_gradient_steps = 112000, step_time = 11.45, total_time = 1286.96
#
# step = 123000, num_env_steps = 123000, scores = -2.054 ± 0.13 (n=2), actor_loss = 3.794, critic_loss = 0.009, entropy_coef_loss = -79.911, entropy_coef = 0.001, action_stds = 0.356 ± 0.044, action_magnitude = 0.510 ± 0.285, num_gradient_steps = 113000, step_time = 11.51, total_time = 1298.47
#
# step = 124000, num_env_steps = 124000, scores = -2.065 ± 0.06 (n=2), actor_loss = 3.877, critic_loss = 0.010, entropy_coef_loss = -85.461, entropy_coef = 0.001, action_stds = 0.370 ± 0.031, action_magnitude = 0.532 ± 0.287, num_gradient_steps = 114000, step_time = 11.40, total_time = 1309.87
#
# step = 125000, num_env_steps = 125000, scores = -2.138 ± 0.31 (n=2), actor_loss = 3.800, critic_loss = 0.010, entropy_coef_loss = -82.093, entropy_coef = 0.001, action_stds = 0.422 ± 0.065, action_magnitude = 0.508 ± 0.286, num_gradient_steps = 115000, step_time = 11.42, total_time = 1321.29
#
# step = 126000, num_env_steps = 126000, scores = -1.795 ± 0.02 (n=2), actor_loss = 3.880, critic_loss = 0.009, entropy_coef_loss = -81.294, entropy_coef = 0.001, action_stds = 0.351 ± 0.045, action_magnitude = 0.487 ± 0.277, num_gradient_steps = 116000, step_time = 11.42, total_time = 1332.71
#
# step = 127000, num_env_steps = 127000, scores = -2.197 ± 0.03 (n=2), actor_loss = 3.936, critic_loss = 0.009, entropy_coef_loss = -80.032, entropy_coef = 0.001, action_stds = 0.364 ± 0.038, action_magnitude = 0.517 ± 0.288, num_gradient_steps = 117000, step_time = 11.45, total_time = 1344.16
#
# step = 128000, num_env_steps = 128000, scores = -2.058 ± 0.07 (n=2), actor_loss = 3.946, critic_loss = 0.009, entropy_coef_loss = -82.726, entropy_coef = 0.001, action_stds = 0.430 ± 0.049, action_magnitude = 0.511 ± 0.285, num_gradient_steps = 118000, step_time = 11.51, total_time = 1355.67
#
# step = 129000, num_env_steps = 129000, scores = -2.079 ± 0.13 (n=2), actor_loss = 3.992, critic_loss = 0.008, entropy_coef_loss = -80.401, entropy_coef = 0.001, action_stds = 0.368 ± 0.047, action_magnitude = 0.517 ± 0.285, num_gradient_steps = 119000, step_time = 11.38, total_time = 1367.04
#
# step = 130000, num_env_steps = 130000, scores = -1.903 ± 0.15 (n=2), actor_loss = 3.887, critic_loss = 0.010, entropy_coef_loss = -84.380, entropy_coef = 0.001, action_stds = 0.371 ± 0.031, action_magnitude = 0.534 ± 0.290, num_gradient_steps = 120000, step_time = 11.50, total_time = 1378.55
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 131000, num_env_steps = 131000, scores = -2.210 ± 0.10 (n=2), actor_loss = 3.955, critic_loss = 0.009, entropy_coef_loss = -78.873, entropy_coef = 0.001, action_stds = 0.400 ± 0.057, action_magnitude = 0.494 ± 0.283, num_gradient_steps = 121000, step_time = 11.40, total_time = 1389.95
#
# step = 132000, num_env_steps = 132000, scores = -2.297 ± 0.16 (n=2), actor_loss = 3.979, critic_loss = 0.008, entropy_coef_loss = -77.364, entropy_coef = 0.001, action_stds = 0.354 ± 0.045, action_magnitude = 0.528 ± 0.286, num_gradient_steps = 122000, step_time = 11.46, total_time = 1401.41
#
# step = 133000, num_env_steps = 133000, scores = -1.911 ± 0.04 (n=2), actor_loss = 3.993, critic_loss = 0.008, entropy_coef_loss = -79.993, entropy_coef = 0.001, action_stds = 0.364 ± 0.042, action_magnitude = 0.511 ± 0.285, num_gradient_steps = 123000, step_time = 11.51, total_time = 1412.92
#
# step = 134000, num_env_steps = 134000, scores = -2.011 ± 0.02 (n=2), actor_loss = 4.032, critic_loss = 0.009, entropy_coef_loss = -85.815, entropy_coef = 0.001, action_stds = 0.370 ± 0.036, action_magnitude = 0.509 ± 0.285, num_gradient_steps = 124000, step_time = 11.44, total_time = 1424.35
#
# step = 135000, num_env_steps = 135000, scores = -2.190 ± 0.08 (n=2), actor_loss = 4.047, critic_loss = 0.008, entropy_coef_loss = -85.765, entropy_coef = 0.001, action_stds = 0.394 ± 0.047, action_magnitude = 0.511 ± 0.284, num_gradient_steps = 125000, step_time = 11.45, total_time = 1435.81
#
# step = 136000, num_env_steps = 136000, scores = -2.076 ± 0.04 (n=2), actor_loss = 4.147, critic_loss = 0.008, entropy_coef_loss = -83.584, entropy_coef = 0.001, action_stds = 0.388 ± 0.045, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 126000, step_time = 11.45, total_time = 1447.26
#
# step = 137000, num_env_steps = 137000, scores = -2.071 ± 0.01 (n=2), actor_loss = 4.159, critic_loss = 0.008, entropy_coef_loss = -85.586, entropy_coef = 0.001, action_stds = 0.379 ± 0.055, action_magnitude = 0.532 ± 0.288, num_gradient_steps = 127000, step_time = 11.42, total_time = 1458.68
#
# step = 138000, num_env_steps = 138000, scores = -2.070 ± 0.28 (n=2), actor_loss = 4.020, critic_loss = 0.008, entropy_coef_loss = -86.851, entropy_coef = 0.001, action_stds = 0.377 ± 0.052, action_magnitude = 0.506 ± 0.283, num_gradient_steps = 128000, step_time = 11.47, total_time = 1470.15
#
# step = 139000, num_env_steps = 139000, scores = -1.902 ± 0.06 (n=2), actor_loss = 4.086, critic_loss = 0.009, entropy_coef_loss = -81.034, entropy_coef = 0.001, action_stds = 0.390 ± 0.041, action_magnitude = 0.497 ± 0.281, num_gradient_steps = 129000, step_time = 11.51, total_time = 1481.66
#
# step = 140000, num_env_steps = 140000, scores = -2.065 ± 0.02 (n=2), actor_loss = 4.017, critic_loss = 0.010, entropy_coef_loss = -79.493, entropy_coef = 0.001, action_stds = 0.410 ± 0.044, action_magnitude = 0.507 ± 0.287, num_gradient_steps = 130000, step_time = 11.45, total_time = 1493.11
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 141000, num_env_steps = 141000, scores = -2.149 ± 0.01 (n=2), actor_loss = 4.066, critic_loss = 0.008, entropy_coef_loss = -82.595, entropy_coef = 0.001, action_stds = 0.412 ± 0.060, action_magnitude = 0.539 ± 0.292, num_gradient_steps = 131000, step_time = 11.46, total_time = 1504.57
#
# step = 142000, num_env_steps = 142000, scores = -2.095 ± 0.19 (n=2), actor_loss = 4.095, critic_loss = 0.009, entropy_coef_loss = -82.668, entropy_coef = 0.001, action_stds = 0.368 ± 0.052, action_magnitude = 0.512 ± 0.282, num_gradient_steps = 132000, step_time = 11.73, total_time = 1516.30
#
# step = 143000, num_env_steps = 143000, scores = -2.262 ± 0.10 (n=2), actor_loss = 4.071, critic_loss = 0.009, entropy_coef_loss = -81.265, entropy_coef = 0.001, action_stds = 0.380 ± 0.049, action_magnitude = 0.514 ± 0.280, num_gradient_steps = 133000, step_time = 11.73, total_time = 1528.03
#
# step = 144000, num_env_steps = 144000, scores = -1.861 ± 0.20 (n=2), actor_loss = 4.135, critic_loss = 0.009, entropy_coef_loss = -85.817, entropy_coef = 0.001, action_stds = 0.428 ± 0.057, action_magnitude = 0.503 ± 0.284, num_gradient_steps = 134000, step_time = 12.04, total_time = 1540.06
#
# step = 145000, num_env_steps = 145000, scores = -1.943 ± 0.01 (n=2), actor_loss = 4.165, critic_loss = 0.008, entropy_coef_loss = -81.214, entropy_coef = 0.001, action_stds = 0.393 ± 0.049, action_magnitude = 0.506 ± 0.282, num_gradient_steps = 135000, step_time = 11.58, total_time = 1551.65
#
# step = 146000, num_env_steps = 146000, scores = -1.936 ± 0.13 (n=2), actor_loss = 4.041, critic_loss = 0.008, entropy_coef_loss = -82.368, entropy_coef = 0.001, action_stds = 0.422 ± 0.054, action_magnitude = 0.499 ± 0.284, num_gradient_steps = 136000, step_time = 11.55, total_time = 1563.20
#
# step = 147000, num_env_steps = 147000, scores = -1.703 ± 0.17 (n=2), actor_loss = 4.196, critic_loss = 0.009, entropy_coef_loss = -85.732, entropy_coef = 0.001, action_stds = 0.408 ± 0.066, action_magnitude = 0.536 ± 0.289, num_gradient_steps = 137000, step_time = 11.62, total_time = 1574.81
#
# step = 148000, num_env_steps = 148000, scores = -1.715 ± 0.03 (n=2), actor_loss = 4.119, critic_loss = 0.009, entropy_coef_loss = -88.462, entropy_coef = 0.001, action_stds = 0.375 ± 0.053, action_magnitude = 0.491 ± 0.280, num_gradient_steps = 138000, step_time = 13.24, total_time = 1588.05
#
# step = 149000, num_env_steps = 149000, scores = -1.662 ± 0.01 (n=2), actor_loss = 4.146, critic_loss = 0.009, entropy_coef_loss = -82.665, entropy_coef = 0.001, action_stds = 0.407 ± 0.061, action_magnitude = 0.489 ± 0.280, num_gradient_steps = 139000, step_time = 12.13, total_time = 1600.19
#
# step = 150000, num_env_steps = 150000, scores = -2.037 ± 0.18 (n=2), actor_loss = 4.181, critic_loss = 0.008, entropy_coef_loss = -79.274, entropy_coef = 0.001, action_stds = 0.402 ± 0.050, action_magnitude = 0.503 ± 0.280, num_gradient_steps = 140000, step_time = 12.71, total_time = 1612.90
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 151000, num_env_steps = 151000, scores = -1.626 ± 0.07 (n=2), actor_loss = 4.189, critic_loss = 0.008, entropy_coef_loss = -84.275, entropy_coef = 0.001, action_stds = 0.379 ± 0.052, action_magnitude = 0.471 ± 0.274, num_gradient_steps = 141000, step_time = 11.31, total_time = 1624.21
#
# step = 152000, num_env_steps = 152000, scores = -1.863 ± 0.07 (n=2), actor_loss = 4.179, critic_loss = 0.008, entropy_coef_loss = -85.743, entropy_coef = 0.001, action_stds = 0.353 ± 0.034, action_magnitude = 0.481 ± 0.279, num_gradient_steps = 142000, step_time = 11.14, total_time = 1635.36
#
# step = 153000, num_env_steps = 153000, scores = -1.818 ± 0.14 (n=2), actor_loss = 4.174, critic_loss = 0.007, entropy_coef_loss = -82.582, entropy_coef = 0.001, action_stds = 0.395 ± 0.049, action_magnitude = 0.485 ± 0.279, num_gradient_steps = 143000, step_time = 11.14, total_time = 1646.50
#
# step = 154000, num_env_steps = 154000, scores = -1.539 ± 0.11 (n=2), actor_loss = 4.174, critic_loss = 0.009, entropy_coef_loss = -79.757, entropy_coef = 0.001, action_stds = 0.405 ± 0.060, action_magnitude = 0.500 ± 0.282, num_gradient_steps = 144000, step_time = 11.18, total_time = 1657.68
#
# step = 155000, num_env_steps = 155000, scores = -1.751 ± 0.05 (n=2), actor_loss = 4.210, critic_loss = 0.009, entropy_coef_loss = -85.020, entropy_coef = 0.001, action_stds = 0.367 ± 0.029, action_magnitude = 0.467 ± 0.274, num_gradient_steps = 145000, step_time = 11.12, total_time = 1668.80
#
# step = 156000, num_env_steps = 156000, scores = -1.635 ± 0.23 (n=2), actor_loss = 4.162, critic_loss = 0.008, entropy_coef_loss = -80.436, entropy_coef = 0.001, action_stds = 0.402 ± 0.066, action_magnitude = 0.507 ± 0.282, num_gradient_steps = 146000, step_time = 11.18, total_time = 1679.98
#
# step = 157000, num_env_steps = 157000, scores = -1.791 ± 0.08 (n=2), actor_loss = 4.229, critic_loss = 0.008, entropy_coef_loss = -82.432, entropy_coef = 0.001, action_stds = 0.366 ± 0.040, action_magnitude = 0.496 ± 0.281, num_gradient_steps = 147000, step_time = 11.18, total_time = 1691.16
#
# step = 158000, num_env_steps = 158000, scores = -1.864 ± 0.22 (n=2), actor_loss = 4.355, critic_loss = 0.008, entropy_coef_loss = -81.454, entropy_coef = 0.001, action_stds = 0.360 ± 0.049, action_magnitude = 0.474 ± 0.278, num_gradient_steps = 148000, step_time = 11.16, total_time = 1702.32
#
# step = 159000, num_env_steps = 159000, scores = -1.888 ± 0.08 (n=2), actor_loss = 4.199, critic_loss = 0.008, entropy_coef_loss = -86.912, entropy_coef = 0.001, action_stds = 0.380 ± 0.032, action_magnitude = 0.487 ± 0.279, num_gradient_steps = 149000, step_time = 11.17, total_time = 1713.49
#
# step = 160000, num_env_steps = 160000, scores = -1.813 ± 0.12 (n=2), actor_loss = 4.235, critic_loss = 0.008, entropy_coef_loss = -82.888, entropy_coef = 0.001, action_stds = 0.380 ± 0.046, action_magnitude = 0.511 ± 0.286, num_gradient_steps = 150000, step_time = 11.18, total_time = 1724.67
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 161000, num_env_steps = 161000, scores = -1.859 ± 0.38 (n=2), actor_loss = 4.186, critic_loss = 0.010, entropy_coef_loss = -85.781, entropy_coef = 0.001, action_stds = 0.370 ± 0.054, action_magnitude = 0.538 ± 0.292, num_gradient_steps = 151000, step_time = 11.15, total_time = 1735.82
#
# step = 162000, num_env_steps = 162000, scores = -1.704 ± 0.16 (n=2), actor_loss = 4.281, critic_loss = 0.009, entropy_coef_loss = -83.908, entropy_coef = 0.001, action_stds = 0.400 ± 0.066, action_magnitude = 0.528 ± 0.293, num_gradient_steps = 152000, step_time = 11.19, total_time = 1747.01
#
# step = 163000, num_env_steps = 163000, scores = -1.534 ± 0.26 (n=2), actor_loss = 4.228, critic_loss = 0.008, entropy_coef_loss = -79.366, entropy_coef = 0.001, action_stds = 0.413 ± 0.047, action_magnitude = 0.476 ± 0.277, num_gradient_steps = 153000, step_time = 11.10, total_time = 1758.12
#
# step = 164000, num_env_steps = 164000, scores = -1.949 ± 0.19 (n=2), actor_loss = 4.191, critic_loss = 0.008, entropy_coef_loss = -83.496, entropy_coef = 0.001, action_stds = 0.359 ± 0.045, action_magnitude = 0.495 ± 0.282, num_gradient_steps = 154000, step_time = 11.12, total_time = 1769.24
#
# step = 165000, num_env_steps = 165000, scores = -1.668 ± 0.33 (n=2), actor_loss = 4.324, critic_loss = 0.008, entropy_coef_loss = -85.626, entropy_coef = 0.001, action_stds = 0.364 ± 0.048, action_magnitude = 0.511 ± 0.285, num_gradient_steps = 155000, step_time = 11.15, total_time = 1780.39
#
# step = 166000, num_env_steps = 166000, scores = -1.979 ± 0.34 (n=2), actor_loss = 4.175, critic_loss = 0.008, entropy_coef_loss = -85.237, entropy_coef = 0.001, action_stds = 0.348 ± 0.032, action_magnitude = 0.490 ± 0.283, num_gradient_steps = 156000, step_time = 11.15, total_time = 1791.54
#
# step = 167000, num_env_steps = 167000, scores = -1.714 ± 0.03 (n=2), actor_loss = 4.230, critic_loss = 0.007, entropy_coef_loss = -87.203, entropy_coef = 0.001, action_stds = 0.369 ± 0.051, action_magnitude = 0.490 ± 0.284, num_gradient_steps = 157000, step_time = 11.10, total_time = 1802.64
#
# ...
#
# step = 2924000, num_env_steps = 2924000, scores = 21.049 ± 0.28 (n=2), actor_loss = -24.273, critic_loss = 0.379, entropy_coef_loss = 2.000, entropy_coef = 0.007, action_stds = 0.540 ± 0.047, action_magnitude = 0.780 ± 0.255, num_gradient_steps = 2914000, step_time = 11.65, total_time = 34482.77
#
# step = 2925000, num_env_steps = 2925000, scores = 21.112 ± 1.05 (n=2), actor_loss = -24.119, critic_loss = 0.571, entropy_coef_loss = -1.962, entropy_coef = 0.007, action_stds = 0.555 ± 0.045, action_magnitude = 0.786 ± 0.249, num_gradient_steps = 2915000, step_time = 11.70, total_time = 34494.47
#
# step = 2926000, num_env_steps = 2926000, scores = 21.170 ± 1.00 (n=2), actor_loss = -24.113, critic_loss = 0.376, entropy_coef_loss = -1.237, entropy_coef = 0.007, action_stds = 0.551 ± 0.045, action_magnitude = 0.780 ± 0.255, num_gradient_steps = 2916000, step_time = 11.61, total_time = 34506.08
#
# step = 2927000, num_env_steps = 2927000, scores = 16.251 ± 3.71 (n=2), actor_loss = -23.609, critic_loss = 0.524, entropy_coef_loss = 1.006, entropy_coef = 0.007, action_stds = 0.562 ± 0.125, action_magnitude = 0.779 ± 0.257, num_gradient_steps = 2917000, step_time = 11.68, total_time = 34517.76
#
# step = 2928000, num_env_steps = 2928000, scores = 19.882 ± 0.27 (n=2), actor_loss = -23.529, critic_loss = 0.657, entropy_coef_loss = 0.248, entropy_coef = 0.007, action_stds = 0.535 ± 0.058, action_magnitude = 0.777 ± 0.256, num_gradient_steps = 2918000, step_time = 11.65, total_time = 34529.41
#
# step = 2929000, num_env_steps = 2929000, scores = 8.050 ± 12.75 (n=2), actor_loss = -23.583, critic_loss = 0.452, entropy_coef_loss = 0.104, entropy_coef = 0.007, action_stds = 0.446 ± 0.155, action_magnitude = 0.819 ± 0.250, num_gradient_steps = 2919000, step_time = 11.65, total_time = 34541.06
#
# step = 2930000, num_env_steps = 2930000, scores = 8.085 ± 11.98 (n=2), actor_loss = -23.849, critic_loss = 0.772, entropy_coef_loss = -2.597, entropy_coef = 0.007, action_stds = 0.537 ± 0.035, action_magnitude = 0.778 ± 0.270, num_gradient_steps = 2920000, step_time = 11.66, total_time = 34552.72
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 2931000, num_env_steps = 2931000, scores = 20.522 ± 0.48 (n=2), actor_loss = -23.526, critic_loss = 0.476, entropy_coef_loss = 0.367, entropy_coef = 0.007, action_stds = 0.542 ± 0.039, action_magnitude = 0.777 ± 0.255, num_gradient_steps = 2921000, step_time = 11.81, total_time = 34564.54
#
# step = 2932000, num_env_steps = 2932000, scores = 19.780 ± 1.28 (n=2), actor_loss = -23.940, critic_loss = 0.488, entropy_coef_loss = -3.672, entropy_coef = 0.007, action_stds = 0.514 ± 0.046, action_magnitude = 0.780 ± 0.254, num_gradient_steps = 2922000, step_time = 11.65, total_time = 34576.19
#
# step = 2933000, num_env_steps = 2933000, scores = 21.972 ± 1.00 (n=2), actor_loss = -24.289, critic_loss = 0.720, entropy_coef_loss = 1.883, entropy_coef = 0.007, action_stds = 0.536 ± 0.049, action_magnitude = 0.778 ± 0.255, num_gradient_steps = 2923000, step_time = 11.74, total_time = 34587.93
#
# step = 2934000, num_env_steps = 2934000, scores = 20.317 ± 1.81 (n=2), actor_loss = -24.606, critic_loss = 0.448, entropy_coef_loss = -5.170, entropy_coef = 0.007, action_stds = 0.505 ± 0.041, action_magnitude = 0.774 ± 0.258, num_gradient_steps = 2924000, step_time = 11.64, total_time = 34599.57
#
# step = 2935000, num_env_steps = 2935000, scores = 8.222 ± 11.44 (n=2), actor_loss = -24.048, critic_loss = 0.444, entropy_coef_loss = -0.944, entropy_coef = 0.007, action_stds = 0.549 ± 0.044, action_magnitude = 0.750 ± 0.274, num_gradient_steps = 2925000, step_time = 11.64, total_time = 34611.21
#
# step = 2936000, num_env_steps = 2936000, scores = 8.164 ± 12.52 (n=2), actor_loss = -24.690, critic_loss = 0.512, entropy_coef_loss = 0.190, entropy_coef = 0.007, action_stds = 0.474 ± 0.110, action_magnitude = 0.787 ± 0.259, num_gradient_steps = 2926000, step_time = 11.73, total_time = 34622.94
#
# step = 2937000, num_env_steps = 2937000, scores = 17.955 ± 1.74 (n=2), actor_loss = -24.854, critic_loss = 0.655, entropy_coef_loss = 1.449, entropy_coef = 0.007, action_stds = 0.520 ± 0.240, action_magnitude = 0.775 ± 0.259, num_gradient_steps = 2927000, step_time = 11.68, total_time = 34634.62
#
# step = 2938000, num_env_steps = 2938000, scores = 18.918 ± 1.92 (n=2), actor_loss = -23.441, critic_loss = 0.435, entropy_coef_loss = 1.400, entropy_coef = 0.007, action_stds = 0.539 ± 0.045, action_magnitude = 0.778 ± 0.255, num_gradient_steps = 2928000, step_time = 11.59, total_time = 34646.21
#
# step = 2939000, num_env_steps = 2939000, scores = 11.649 ± 9.28 (n=2), actor_loss = -23.360, critic_loss = 0.464, entropy_coef_loss = -0.703, entropy_coef = 0.007, action_stds = 0.543 ± 0.026, action_magnitude = 0.756 ± 0.270, num_gradient_steps = 2929000, step_time = 11.61, total_time = 34657.82
#
# step = 2940000, num_env_steps = 2940000, scores = 19.567 ± 1.47 (n=2), actor_loss = -24.416, critic_loss = 0.520, entropy_coef_loss = -1.550, entropy_coef = 0.007, action_stds = 0.526 ± 0.045, action_magnitude = 0.778 ± 0.256, num_gradient_steps = 2930000, step_time = 11.63, total_time = 34669.45
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 2941000, num_env_steps = 2941000, scores = 11.788 ± 8.56 (n=2), actor_loss = -23.987, critic_loss = 0.442, entropy_coef_loss = 2.846, entropy_coef = 0.007, action_stds = 0.547 ± 0.046, action_magnitude = 0.761 ± 0.274, num_gradient_steps = 2931000, step_time = 11.95, total_time = 34681.40
#
# step = 2942000, num_env_steps = 2942000, scores = 21.004 ± 0.93 (n=2), actor_loss = -24.111, critic_loss = 0.404, entropy_coef_loss = 2.130, entropy_coef = 0.007, action_stds = 0.522 ± 0.050, action_magnitude = 0.787 ± 0.249, num_gradient_steps = 2932000, step_time = 11.66, total_time = 34693.06
#
# step = 2943000, num_env_steps = 2943000, scores = 22.203 ± 1.54 (n=2), actor_loss = -23.892, critic_loss = 0.639, entropy_coef_loss = 2.339, entropy_coef = 0.007, action_stds = 0.531 ± 0.028, action_magnitude = 0.782 ± 0.253, num_gradient_steps = 2933000, step_time = 11.73, total_time = 34704.79
#
# step = 2944000, num_env_steps = 2944000, scores = 21.463 ± 0.47 (n=2), actor_loss = -23.849, critic_loss = 0.574, entropy_coef_loss = -1.293, entropy_coef = 0.007, action_stds = 0.534 ± 0.037, action_magnitude = 0.783 ± 0.251, num_gradient_steps = 2934000, step_time = 11.70, total_time = 34716.49
#
# step = 2945000, num_env_steps = 2945000, scores = 11.403 ± 8.21 (n=2), actor_loss = -22.998, critic_loss = 0.448, entropy_coef_loss = -0.407, entropy_coef = 0.007, action_stds = 0.527 ± 0.042, action_magnitude = 0.805 ± 0.248, num_gradient_steps = 2935000, step_time = 11.68, total_time = 34728.17
#
# step = 2946000, num_env_steps = 2946000, scores = 21.119 ± 0.67 (n=2), actor_loss = -23.677, critic_loss = 0.442, entropy_coef_loss = -3.081, entropy_coef = 0.007, action_stds = 0.490 ± 0.037, action_magnitude = 0.784 ± 0.248, num_gradient_steps = 2936000, step_time = 11.73, total_time = 34739.90
#
# step = 2947000, num_env_steps = 2947000, scores = 20.225 ± 1.82 (n=2), actor_loss = -23.965, critic_loss = 0.380, entropy_coef_loss = 4.265, entropy_coef = 0.007, action_stds = 0.529 ± 0.027, action_magnitude = 0.782 ± 0.254, num_gradient_steps = 2937000, step_time = 11.63, total_time = 34751.54
#
# step = 2948000, num_env_steps = 2948000, scores = 8.146 ± 11.58 (n=2), actor_loss = -23.599, critic_loss = 0.518, entropy_coef_loss = 4.684, entropy_coef = 0.007, action_stds = 0.474 ± 0.136, action_magnitude = 0.767 ± 0.274, num_gradient_steps = 2938000, step_time = 11.71, total_time = 34763.25
#
# step = 2949000, num_env_steps = 2949000, scores = 20.932 ± 0.04 (n=2), actor_loss = -24.614, critic_loss = 0.304, entropy_coef_loss = 2.710, entropy_coef = 0.007, action_stds = 0.538 ± 0.037, action_magnitude = 0.780 ± 0.253, num_gradient_steps = 2939000, step_time = 11.62, total_time = 34774.87
#
# step = 2950000, num_env_steps = 2950000, scores = 15.190 ± 5.19 (n=2), actor_loss = -24.457, critic_loss = 1.097, entropy_coef_loss = 2.896, entropy_coef = 0.007, action_stds = 0.486 ± 0.044, action_magnitude = 0.765 ± 0.260, num_gradient_steps = 2940000, step_time = 11.69, total_time = 34786.56
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 2951000, num_env_steps = 2951000, scores = 8.863 ± 12.24 (n=2), actor_loss = -22.671, critic_loss = 0.411, entropy_coef_loss = -2.320, entropy_coef = 0.007, action_stds = 0.459 ± 0.089, action_magnitude = 0.753 ± 0.274, num_gradient_steps = 2941000, step_time = 11.91, total_time = 34798.47
#
# step = 2952000, num_env_steps = 2952000, scores = 21.017 ± 0.03 (n=2), actor_loss = -24.527, critic_loss = 0.394, entropy_coef_loss = 3.677, entropy_coef = 0.007, action_stds = 0.517 ± 0.045, action_magnitude = 0.782 ± 0.252, num_gradient_steps = 2942000, step_time = 11.74, total_time = 34810.20
#
# step = 2953000, num_env_steps = 2953000, scores = 21.843 ± 0.05 (n=2), actor_loss = -23.439, critic_loss = 0.376, entropy_coef_loss = -4.390, entropy_coef = 0.007, action_stds = 0.527 ± 0.026, action_magnitude = 0.785 ± 0.251, num_gradient_steps = 2943000, step_time = 11.67, total_time = 34821.87
#
# step = 2954000, num_env_steps = 2954000, scores = 21.282 ± 0.18 (n=2), actor_loss = -23.444, critic_loss = 0.407, entropy_coef_loss = 0.296, entropy_coef = 0.007, action_stds = 0.529 ± 0.032, action_magnitude = 0.778 ± 0.255, num_gradient_steps = 2944000, step_time = 11.63, total_time = 34833.50
#
# step = 2955000, num_env_steps = 2955000, scores = 20.390 ± 1.02 (n=2), actor_loss = -23.625, critic_loss = 0.495, entropy_coef_loss = 1.479, entropy_coef = 0.007, action_stds = 0.553 ± 0.032, action_magnitude = 0.781 ± 0.256, num_gradient_steps = 2945000, step_time = 11.60, total_time = 34845.10
#
# step = 2956000, num_env_steps = 2956000, scores = 20.916 ± 0.59 (n=2), actor_loss = -23.877, critic_loss = 0.510, entropy_coef_loss = 2.239, entropy_coef = 0.007, action_stds = 0.504 ± 0.040, action_magnitude = 0.782 ± 0.252, num_gradient_steps = 2946000, step_time = 11.63, total_time = 34856.73
#
# step = 2957000, num_env_steps = 2957000, scores = 17.388 ± 4.54 (n=2), actor_loss = -23.601, critic_loss = 0.373, entropy_coef_loss = 1.669, entropy_coef = 0.007, action_stds = 0.534 ± 0.041, action_magnitude = 0.776 ± 0.258, num_gradient_steps = 2947000, step_time = 11.72, total_time = 34868.45
#
# step = 2958000, num_env_steps = 2958000, scores = 6.580 ± 12.30 (n=2), actor_loss = -23.344, critic_loss = 0.390, entropy_coef_loss = -0.329, entropy_coef = 0.007, action_stds = 0.525 ± 0.038, action_magnitude = 0.838 ± 0.225, num_gradient_steps = 2948000, step_time = 11.63, total_time = 34880.08
#
# step = 2959000, num_env_steps = 2959000, scores = 21.055 ± 1.31 (n=2), actor_loss = -23.916, critic_loss = 0.388, entropy_coef_loss = -3.201, entropy_coef = 0.007, action_stds = 0.511 ± 0.052, action_magnitude = 0.785 ± 0.250, num_gradient_steps = 2949000, step_time = 11.47, total_time = 34891.55
#
# step = 2960000, num_env_steps = 2960000, scores = 8.523 ± 12.86 (n=2), actor_loss = -23.587, critic_loss = 0.578, entropy_coef_loss = 3.113, entropy_coef = 0.007, action_stds = 0.543 ± 0.032, action_magnitude = 0.794 ± 0.257, num_gradient_steps = 2950000, step_time = 11.62, total_time = 34903.17
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 2961000, num_env_steps = 2961000, scores = 22.366 ± 1.28 (n=2), actor_loss = -24.064, critic_loss = 0.374, entropy_coef_loss = -2.030, entropy_coef = 0.007, action_stds = 0.523 ± 0.035, action_magnitude = 0.786 ± 0.250, num_gradient_steps = 2951000, step_time = 11.93, total_time = 34915.10
#
# step = 2962000, num_env_steps = 2962000, scores = 21.570 ± 0.16 (n=2), actor_loss = -22.384, critic_loss = 0.396, entropy_coef_loss = 3.556, entropy_coef = 0.007, action_stds = 0.526 ± 0.040, action_magnitude = 0.783 ± 0.253, num_gradient_steps = 2952000, step_time = 11.65, total_time = 34926.76
#
# step = 2963000, num_env_steps = 2963000, scores = 21.270 ± 0.54 (n=2), actor_loss = -24.048, critic_loss = 0.401, entropy_coef_loss = -3.036, entropy_coef = 0.007, action_stds = 0.545 ± 0.027, action_magnitude = 0.783 ± 0.252, num_gradient_steps = 2953000, step_time = 11.56, total_time = 34938.32
#
# step = 2964000, num_env_steps = 2964000, scores = 16.855 ± 3.43 (n=2), actor_loss = -23.474, critic_loss = 0.377, entropy_coef_loss = 1.403, entropy_coef = 0.007, action_stds = 0.562 ± 0.051, action_magnitude = 0.778 ± 0.260, num_gradient_steps = 2954000, step_time = 11.58, total_time = 34949.90
#
# step = 2965000, num_env_steps = 2965000, scores = 17.755 ± 3.95 (n=2), actor_loss = -23.790, critic_loss = 0.406, entropy_coef_loss = 4.065, entropy_coef = 0.007, action_stds = 0.472 ± 0.075, action_magnitude = 0.783 ± 0.254, num_gradient_steps = 2955000, step_time = 11.63, total_time = 34961.53
#
# step = 2966000, num_env_steps = 2966000, scores = 8.501 ± 5.86 (n=2), actor_loss = -23.639, critic_loss = 0.375, entropy_coef_loss = 2.333, entropy_coef = 0.007, action_stds = 0.456 ± 0.129, action_magnitude = 0.785 ± 0.259, num_gradient_steps = 2956000, step_time = 11.60, total_time = 34973.13
#
# step = 2967000, num_env_steps = 2967000, scores = 21.749 ± 0.36 (n=2), actor_loss = -23.805, critic_loss = 0.423, entropy_coef_loss = 0.451, entropy_coef = 0.007, action_stds = 0.514 ± 0.071, action_magnitude = 0.786 ± 0.250, num_gradient_steps = 2957000, step_time = 11.64, total_time = 34984.78
#
# step = 2968000, num_env_steps = 2968000, scores = 21.801 ± 0.21 (n=2), actor_loss = -23.739, critic_loss = 0.434, entropy_coef_loss = 1.934, entropy_coef = 0.007, action_stds = 0.537 ± 0.036, action_magnitude = 0.783 ± 0.251, num_gradient_steps = 2958000, step_time = 11.78, total_time = 34996.55
#
# step = 2969000, num_env_steps = 2969000, scores = 21.644 ± 1.08 (n=2), actor_loss = -23.619, critic_loss = 0.398, entropy_coef_loss = -0.001, entropy_coef = 0.007, action_stds = 0.534 ± 0.033, action_magnitude = 0.782 ± 0.251, num_gradient_steps = 2959000, step_time = 12.04, total_time = 35008.60
#
# step = 2970000, num_env_steps = 2970000, scores = 21.860 ± 0.78 (n=2), actor_loss = -24.601, critic_loss = 0.464, entropy_coef_loss = -1.328, entropy_coef = 0.007, action_stds = 0.540 ± 0.026, action_magnitude = 0.783 ± 0.252, num_gradient_steps = 2960000, step_time = 11.71, total_time = 35020.31
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
#
# step = 2971000, num_env_steps = 2971000, scores = 21.646 ± 0.48 (n=2), actor_loss = -23.819, critic_loss = 0.420, entropy_coef_loss = 6.040, entropy_coef = 0.007, action_stds = 0.517 ± 0.030, action_magnitude = 0.785 ± 0.250, num_gradient_steps = 2961000, step_time = 12.13, total_time = 35032.44
#
# step = 2972000, num_env_steps = 2972000, scores = 21.710 ± 0.59 (n=2), actor_loss = -23.917, critic_loss = 0.493, entropy_coef_loss = 1.532, entropy_coef = 0.007, action_stds = 0.538 ± 0.036, action_magnitude = 0.780 ± 0.254, num_gradient_steps = 2962000, step_time = 12.10, total_time = 35044.54
#
# step = 2973000, num_env_steps = 2973000, scores = 22.168 ± 0.56 (n=2), actor_loss = -23.336, critic_loss = 0.287, entropy_coef_loss = -1.653, entropy_coef = 0.007, action_stds = 0.526 ± 0.028, action_magnitude = 0.786 ± 0.251, num_gradient_steps = 2963000, step_time = 12.13, total_time = 35056.67
#
# step = 2974000, num_env_steps = 2974000, scores = 20.845 ± 0.75 (n=2), actor_loss = -24.072, critic_loss = 0.393, entropy_coef_loss = 0.206, entropy_coef = 0.007, action_stds = 0.527 ± 0.067, action_magnitude = 0.788 ± 0.249, num_gradient_steps = 2964000, step_time = 13.04, total_time = 35069.71
#
# saved experiment log 2024-11-02_17-43-34_835121~N0PEGG at experiment_logs/2024-11-02_17-43-34_835121~N0PEGG.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
def save_training():
    experiment_id = logger.experiment_log['experiment_id']
    algo.save(f'saved_models/{experiment_id}', experiment_id)

save_training()

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
