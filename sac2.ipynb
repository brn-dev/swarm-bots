# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.swarm_bot_env import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        if step % 100_000 == 0:
            save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=4, 
        hip_range=np.pi / 3.5,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, 256),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=256,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 259618
# env = <swarmbots.swarm_bot_env.SwarmBotEnv object at 0x0000021F6538B710>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# Starting Training
#
# step = 11000, num_env_steps = 11000, scores = -2.669 ± 0.18 (n=2), actor_loss = -49.314, critic_loss = 16.485, entropy_coef_loss = -7.883, entropy_coef = 0.738, action_stds = 0.849 ± 0.064, action_magnitude = 0.519 ± 0.287, num_gradient_steps = 1000, step_time = 19.06, total_time = 18.58
#
# step = 12000, num_env_steps = 12000, scores = -3.352 ± 0.75 (n=2), actor_loss = -73.544, critic_loss = 10.298, entropy_coef_loss = -15.545, entropy_coef = 0.550, action_stds = 0.872 ± 0.057, action_magnitude = 0.555 ± 0.294, num_gradient_steps = 2000, step_time = 11.61, total_time = 30.19
#
# step = 13000, num_env_steps = 13000, scores = -2.819 ± 0.03 (n=2), actor_loss = -87.809, critic_loss = 6.928, entropy_coef_loss = -23.192, entropy_coef = 0.407, action_stds = 0.864 ± 0.057, action_magnitude = 0.540 ± 0.289, num_gradient_steps = 3000, step_time = 11.36, total_time = 41.54
#
# step = 14000, num_env_steps = 14000, scores = -3.081 ± 0.19 (n=2), actor_loss = -96.469, critic_loss = 5.917, entropy_coef_loss = -31.095, entropy_coef = 0.301, action_stds = 0.894 ± 0.027, action_magnitude = 0.543 ± 0.290, num_gradient_steps = 4000, step_time = 12.19, total_time = 53.73
#
# step = 15000, num_env_steps = 15000, scores = -3.147 ± 0.59 (n=2), actor_loss = -98.913, critic_loss = 5.105, entropy_coef_loss = -38.636, entropy_coef = 0.224, action_stds = 0.883 ± 0.055, action_magnitude = 0.548 ± 0.290, num_gradient_steps = 5000, step_time = 11.62, total_time = 65.35
#
# step = 16000, num_env_steps = 16000, scores = -3.749 ± 0.12 (n=2), actor_loss = -100.533, critic_loss = 4.248, entropy_coef_loss = -44.912, entropy_coef = 0.166, action_stds = 0.910 ± 0.043, action_magnitude = 0.559 ± 0.291, num_gradient_steps = 6000, step_time = 11.71, total_time = 77.06
#
# step = 17000, num_env_steps = 17000, scores = -2.658 ± 0.21 (n=2), actor_loss = -99.956, critic_loss = 3.709, entropy_coef_loss = -50.491, entropy_coef = 0.124, action_stds = 0.907 ± 0.044, action_magnitude = 0.566 ± 0.293, num_gradient_steps = 7000, step_time = 11.28, total_time = 88.34
#
# step = 18000, num_env_steps = 18000, scores = -3.797 ± 0.04 (n=2), actor_loss = -96.882, critic_loss = 2.587, entropy_coef_loss = -54.884, entropy_coef = 0.093, action_stds = 0.866 ± 0.073, action_magnitude = 0.585 ± 0.298, num_gradient_steps = 8000, step_time = 10.88, total_time = 99.22
#
# step = 19000, num_env_steps = 19000, scores = -3.753 ± 0.22 (n=2), actor_loss = -94.861, critic_loss = 2.384, entropy_coef_loss = -56.329, entropy_coef = 0.070, action_stds = 0.889 ± 0.047, action_magnitude = 0.600 ± 0.298, num_gradient_steps = 9000, step_time = 10.91, total_time = 110.13
#
# step = 20000, num_env_steps = 20000, scores = -3.681 ± 0.11 (n=2), actor_loss = -90.904, critic_loss = 2.161, entropy_coef_loss = -61.412, entropy_coef = 0.053, action_stds = 0.838 ± 0.071, action_magnitude = 0.616 ± 0.298, num_gradient_steps = 10000, step_time = 10.91, total_time = 121.04
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 21000, num_env_steps = 21000, scores = -4.596 ± 0.17 (n=2), actor_loss = -87.948, critic_loss = 1.506, entropy_coef_loss = -60.140, entropy_coef = 0.040, action_stds = 0.858 ± 0.096, action_magnitude = 0.626 ± 0.298, num_gradient_steps = 11000, step_time = 10.89, total_time = 131.93
#
# step = 22000, num_env_steps = 22000, scores = -4.108 ± 0.17 (n=2), actor_loss = -84.027, critic_loss = 1.325, entropy_coef_loss = -57.984, entropy_coef = 0.030, action_stds = 0.837 ± 0.109, action_magnitude = 0.639 ± 0.301, num_gradient_steps = 12000, step_time = 10.94, total_time = 142.87
#
# step = 23000, num_env_steps = 23000, scores = -4.467 ± 0.20 (n=2), actor_loss = -80.755, critic_loss = 1.564, entropy_coef_loss = -60.797, entropy_coef = 0.023, action_stds = 0.830 ± 0.083, action_magnitude = 0.652 ± 0.298, num_gradient_steps = 13000, step_time = 10.89, total_time = 153.76
#
# step = 24000, num_env_steps = 24000, scores = -4.172 ± 0.18 (n=2), actor_loss = -76.958, critic_loss = 1.207, entropy_coef_loss = -50.803, entropy_coef = 0.018, action_stds = 0.772 ± 0.103, action_magnitude = 0.665 ± 0.300, num_gradient_steps = 14000, step_time = 10.91, total_time = 164.67
#
# step = 25000, num_env_steps = 25000, scores = -4.063 ± 0.01 (n=2), actor_loss = -72.886, critic_loss = 0.978, entropy_coef_loss = -51.981, entropy_coef = 0.014, action_stds = 0.787 ± 0.051, action_magnitude = 0.664 ± 0.300, num_gradient_steps = 15000, step_time = 10.90, total_time = 175.56
#
# step = 26000, num_env_steps = 26000, scores = -4.781 ± 0.45 (n=2), actor_loss = -69.779, critic_loss = 0.814, entropy_coef_loss = -41.044, entropy_coef = 0.011, action_stds = 0.720 ± 0.129, action_magnitude = 0.685 ± 0.298, num_gradient_steps = 16000, step_time = 10.90, total_time = 186.46
#
# step = 27000, num_env_steps = 27000, scores = -4.960 ± 0.20 (n=2), actor_loss = -66.120, critic_loss = 0.799, entropy_coef_loss = -25.639, entropy_coef = 0.008, action_stds = 0.711 ± 0.045, action_magnitude = 0.694 ± 0.298, num_gradient_steps = 17000, step_time = 10.97, total_time = 197.43
#
# step = 28000, num_env_steps = 28000, scores = -4.805 ± 0.44 (n=2), actor_loss = -62.696, critic_loss = 0.516, entropy_coef_loss = -36.084, entropy_coef = 0.007, action_stds = 0.753 ± 0.115, action_magnitude = 0.707 ± 0.295, num_gradient_steps = 18000, step_time = 10.93, total_time = 208.36
#
# step = 29000, num_env_steps = 29000, scores = -5.067 ± 0.41 (n=2), actor_loss = -59.997, critic_loss = 0.577, entropy_coef_loss = -8.502, entropy_coef = 0.005, action_stds = 0.739 ± 0.066, action_magnitude = 0.710 ± 0.295, num_gradient_steps = 19000, step_time = 10.90, total_time = 219.25
#
# step = 30000, num_env_steps = 30000, scores = -4.958 ± 0.23 (n=2), actor_loss = -57.428, critic_loss = 0.482, entropy_coef_loss = -15.574, entropy_coef = 0.005, action_stds = 0.728 ± 0.094, action_magnitude = 0.715 ± 0.294, num_gradient_steps = 20000, step_time = 10.92, total_time = 230.18
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 31000, num_env_steps = 31000, scores = -5.326 ± 0.13 (n=2), actor_loss = -54.115, critic_loss = 0.330, entropy_coef_loss = -11.843, entropy_coef = 0.004, action_stds = 0.709 ± 0.059, action_magnitude = 0.718 ± 0.295, num_gradient_steps = 21000, step_time = 10.94, total_time = 241.11
#
# step = 32000, num_env_steps = 32000, scores = -4.446 ± 0.34 (n=2), actor_loss = -51.965, critic_loss = 0.378, entropy_coef_loss = -9.449, entropy_coef = 0.004, action_stds = 0.721 ± 0.105, action_magnitude = 0.722 ± 0.292, num_gradient_steps = 22000, step_time = 10.85, total_time = 251.96
#
# step = 33000, num_env_steps = 33000, scores = -5.024 ± 0.03 (n=2), actor_loss = -48.352, critic_loss = 0.285, entropy_coef_loss = -8.571, entropy_coef = 0.003, action_stds = 0.719 ± 0.146, action_magnitude = 0.728 ± 0.293, num_gradient_steps = 23000, step_time = 10.95, total_time = 262.91
#
# step = 34000, num_env_steps = 34000, scores = -5.291 ± 0.18 (n=2), actor_loss = -46.225, critic_loss = 0.262, entropy_coef_loss = 7.683, entropy_coef = 0.003, action_stds = 0.665 ± 0.083, action_magnitude = 0.718 ± 0.295, num_gradient_steps = 24000, step_time = 10.85, total_time = 273.76
#
# step = 35000, num_env_steps = 35000, scores = -4.973 ± 0.07 (n=2), actor_loss = -43.870, critic_loss = 0.196, entropy_coef_loss = -6.830, entropy_coef = 0.003, action_stds = 0.727 ± 0.067, action_magnitude = 0.721 ± 0.295, num_gradient_steps = 25000, step_time = 10.83, total_time = 284.59
#
# step = 36000, num_env_steps = 36000, scores = -4.862 ± 0.13 (n=2), actor_loss = -42.026, critic_loss = 0.221, entropy_coef_loss = 3.426, entropy_coef = 0.002, action_stds = 0.689 ± 0.076, action_magnitude = 0.720 ± 0.295, num_gradient_steps = 26000, step_time = 10.88, total_time = 295.47
#
# step = 37000, num_env_steps = 37000, scores = -4.778 ± 0.32 (n=2), actor_loss = -39.721, critic_loss = 0.152, entropy_coef_loss = -10.829, entropy_coef = 0.002, action_stds = 0.623 ± 0.061, action_magnitude = 0.729 ± 0.292, num_gradient_steps = 27000, step_time = 10.92, total_time = 306.39
#
# step = 38000, num_env_steps = 38000, scores = -5.245 ± 0.43 (n=2), actor_loss = -37.436, critic_loss = 0.133, entropy_coef_loss = -9.668, entropy_coef = 0.002, action_stds = 0.723 ± 0.070, action_magnitude = 0.722 ± 0.294, num_gradient_steps = 28000, step_time = 10.90, total_time = 317.29
#
# step = 39000, num_env_steps = 39000, scores = -4.592 ± 0.11 (n=2), actor_loss = -35.630, critic_loss = 0.104, entropy_coef_loss = 0.910, entropy_coef = 0.002, action_stds = 0.693 ± 0.090, action_magnitude = 0.704 ± 0.298, num_gradient_steps = 29000, step_time = 11.58, total_time = 328.87
#
# step = 40000, num_env_steps = 40000, scores = -4.209 ± 0.57 (n=2), actor_loss = -33.989, critic_loss = 0.097, entropy_coef_loss = -14.883, entropy_coef = 0.002, action_stds = 0.647 ± 0.071, action_magnitude = 0.705 ± 0.297, num_gradient_steps = 30000, step_time = 11.45, total_time = 340.32
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 41000, num_env_steps = 41000, scores = -4.422 ± 0.16 (n=2), actor_loss = -32.163, critic_loss = 0.097, entropy_coef_loss = -7.502, entropy_coef = 0.001, action_stds = 0.673 ± 0.079, action_magnitude = 0.704 ± 0.298, num_gradient_steps = 31000, step_time = 11.79, total_time = 352.11
#
# step = 42000, num_env_steps = 42000, scores = -4.725 ± 0.07 (n=2), actor_loss = -30.873, critic_loss = 0.067, entropy_coef_loss = 14.763, entropy_coef = 0.001, action_stds = 0.606 ± 0.074, action_magnitude = 0.712 ± 0.295, num_gradient_steps = 32000, step_time = 11.34, total_time = 363.45
#
# step = 43000, num_env_steps = 43000, scores = -4.903 ± 0.32 (n=2), actor_loss = -28.716, critic_loss = 0.079, entropy_coef_loss = -5.548, entropy_coef = 0.001, action_stds = 0.587 ± 0.066, action_magnitude = 0.710 ± 0.297, num_gradient_steps = 33000, step_time = 11.25, total_time = 374.69
#
# step = 44000, num_env_steps = 44000, scores = -5.068 ± 0.19 (n=2), actor_loss = -27.524, critic_loss = 0.048, entropy_coef_loss = -4.208, entropy_coef = 0.001, action_stds = 0.578 ± 0.081, action_magnitude = 0.707 ± 0.296, num_gradient_steps = 34000, step_time = 11.33, total_time = 386.02
#
# step = 45000, num_env_steps = 45000, scores = -4.532 ± 0.31 (n=2), actor_loss = -25.867, critic_loss = 0.048, entropy_coef_loss = -9.691, entropy_coef = 0.001, action_stds = 0.606 ± 0.091, action_magnitude = 0.711 ± 0.294, num_gradient_steps = 35000, step_time = 11.24, total_time = 397.26
#
# step = 46000, num_env_steps = 46000, scores = -4.263 ± 0.23 (n=2), actor_loss = -24.715, critic_loss = 0.039, entropy_coef_loss = 1.986, entropy_coef = 0.001, action_stds = 0.618 ± 0.056, action_magnitude = 0.707 ± 0.297, num_gradient_steps = 36000, step_time = 11.15, total_time = 408.41
#
# step = 47000, num_env_steps = 47000, scores = -4.722 ± 0.25 (n=2), actor_loss = -23.518, critic_loss = 0.052, entropy_coef_loss = -12.092, entropy_coef = 0.001, action_stds = 0.518 ± 0.058, action_magnitude = 0.707 ± 0.298, num_gradient_steps = 37000, step_time = 11.20, total_time = 419.62
#
# step = 48000, num_env_steps = 48000, scores = -4.885 ± 0.53 (n=2), actor_loss = -22.116, critic_loss = 0.036, entropy_coef_loss = -3.672, entropy_coef = 0.001, action_stds = 0.609 ± 0.081, action_magnitude = 0.702 ± 0.297, num_gradient_steps = 38000, step_time = 11.07, total_time = 430.68
#
# step = 49000, num_env_steps = 49000, scores = -4.541 ± 0.05 (n=2), actor_loss = -21.201, critic_loss = 0.029, entropy_coef_loss = -1.318, entropy_coef = 0.001, action_stds = 0.630 ± 0.069, action_magnitude = 0.697 ± 0.296, num_gradient_steps = 39000, step_time = 10.97, total_time = 441.66
#
# step = 50000, num_env_steps = 50000, scores = -4.554 ± 0.12 (n=2), actor_loss = -20.126, critic_loss = 0.026, entropy_coef_loss = -10.049, entropy_coef = 0.001, action_stds = 0.567 ± 0.076, action_magnitude = 0.700 ± 0.299, num_gradient_steps = 40000, step_time = 11.03, total_time = 452.68
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 51000, num_env_steps = 51000, scores = -4.276 ± 0.22 (n=2), actor_loss = -18.880, critic_loss = 0.027, entropy_coef_loss = -12.975, entropy_coef = 0.001, action_stds = 0.574 ± 0.084, action_magnitude = 0.697 ± 0.298, num_gradient_steps = 41000, step_time = 10.98, total_time = 463.66
#
# step = 52000, num_env_steps = 52000, scores = -4.671 ± 0.26 (n=2), actor_loss = -18.064, critic_loss = 0.017, entropy_coef_loss = -10.701, entropy_coef = 0.000, action_stds = 0.508 ± 0.052, action_magnitude = 0.689 ± 0.297, num_gradient_steps = 42000, step_time = 11.44, total_time = 475.10
#
# step = 53000, num_env_steps = 53000, scores = -4.852 ± 0.33 (n=2), actor_loss = -17.302, critic_loss = 0.016, entropy_coef_loss = -8.703, entropy_coef = 0.000, action_stds = 0.522 ± 0.085, action_magnitude = 0.690 ± 0.298, num_gradient_steps = 43000, step_time = 11.04, total_time = 486.14
#
# step = 54000, num_env_steps = 54000, scores = -4.418 ± 0.44 (n=2), actor_loss = -16.323, critic_loss = 0.022, entropy_coef_loss = -5.720, entropy_coef = 0.000, action_stds = 0.550 ± 0.065, action_magnitude = 0.672 ± 0.303, num_gradient_steps = 44000, step_time = 11.04, total_time = 497.17
#
# step = 55000, num_env_steps = 55000, scores = -4.715 ± 0.19 (n=2), actor_loss = -15.437, critic_loss = 0.011, entropy_coef_loss = 3.986, entropy_coef = 0.000, action_stds = 0.472 ± 0.070, action_magnitude = 0.699 ± 0.297, num_gradient_steps = 45000, step_time = 11.02, total_time = 508.19
#
# step = 56000, num_env_steps = 56000, scores = -4.064 ± 0.27 (n=2), actor_loss = -14.815, critic_loss = 0.011, entropy_coef_loss = -1.009, entropy_coef = 0.000, action_stds = 0.495 ± 0.093, action_magnitude = 0.682 ± 0.299, num_gradient_steps = 46000, step_time = 11.04, total_time = 519.23
#
# step = 57000, num_env_steps = 57000, scores = -4.531 ± 0.06 (n=2), actor_loss = -14.006, critic_loss = 0.008, entropy_coef_loss = -7.028, entropy_coef = 0.000, action_stds = 0.541 ± 0.059, action_magnitude = 0.683 ± 0.299, num_gradient_steps = 47000, step_time = 10.99, total_time = 530.22
#
# step = 58000, num_env_steps = 58000, scores = -4.083 ± 0.49 (n=2), actor_loss = -13.235, critic_loss = 0.008, entropy_coef_loss = 1.281, entropy_coef = 0.000, action_stds = 0.510 ± 0.083, action_magnitude = 0.690 ± 0.298, num_gradient_steps = 48000, step_time = 11.07, total_time = 541.29
#
# step = 59000, num_env_steps = 59000, scores = -4.260 ± 0.11 (n=2), actor_loss = -12.579, critic_loss = 0.006, entropy_coef_loss = -9.162, entropy_coef = 0.000, action_stds = 0.513 ± 0.070, action_magnitude = 0.677 ± 0.298, num_gradient_steps = 49000, step_time = 11.01, total_time = 552.30
#
# step = 60000, num_env_steps = 60000, scores = -4.227 ± 0.10 (n=2), actor_loss = -11.979, critic_loss = 0.008, entropy_coef_loss = -13.699, entropy_coef = 0.000, action_stds = 0.530 ± 0.086, action_magnitude = 0.669 ± 0.301, num_gradient_steps = 50000, step_time = 11.03, total_time = 563.33
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 61000, num_env_steps = 61000, scores = -4.080 ± 0.20 (n=2), actor_loss = -11.360, critic_loss = 0.007, entropy_coef_loss = 12.062, entropy_coef = 0.000, action_stds = 0.474 ± 0.079, action_magnitude = 0.671 ± 0.298, num_gradient_steps = 51000, step_time = 11.06, total_time = 574.39
#
# step = 62000, num_env_steps = 62000, scores = -4.316 ± 0.23 (n=2), actor_loss = -10.786, critic_loss = 0.004, entropy_coef_loss = -14.314, entropy_coef = 0.000, action_stds = 0.633 ± 0.181, action_magnitude = 0.678 ± 0.299, num_gradient_steps = 52000, step_time = 11.02, total_time = 585.42
#
# step = 63000, num_env_steps = 63000, scores = -4.397 ± 0.04 (n=2), actor_loss = -10.200, critic_loss = 0.004, entropy_coef_loss = 1.633, entropy_coef = 0.000, action_stds = 0.466 ± 0.053, action_magnitude = 0.669 ± 0.302, num_gradient_steps = 53000, step_time = 11.03, total_time = 596.45
#
# step = 64000, num_env_steps = 64000, scores = -3.780 ± 0.22 (n=2), actor_loss = -9.624, critic_loss = 0.004, entropy_coef_loss = -7.955, entropy_coef = 0.000, action_stds = 0.504 ± 0.061, action_magnitude = 0.657 ± 0.301, num_gradient_steps = 54000, step_time = 11.04, total_time = 607.49
#
# step = 65000, num_env_steps = 65000, scores = -4.304 ± 0.10 (n=2), actor_loss = -9.202, critic_loss = 0.004, entropy_coef_loss = -28.438, entropy_coef = 0.000, action_stds = 0.489 ± 0.063, action_magnitude = 0.666 ± 0.301, num_gradient_steps = 55000, step_time = 11.06, total_time = 618.54
#
# step = 66000, num_env_steps = 66000, scores = -4.323 ± 0.05 (n=2), actor_loss = -8.726, critic_loss = 0.003, entropy_coef_loss = -15.729, entropy_coef = 0.000, action_stds = 0.499 ± 0.064, action_magnitude = 0.665 ± 0.301, num_gradient_steps = 56000, step_time = 11.13, total_time = 629.67
#
# step = 67000, num_env_steps = 67000, scores = -3.910 ± 0.11 (n=2), actor_loss = -8.280, critic_loss = 0.002, entropy_coef_loss = -8.775, entropy_coef = 0.000, action_stds = 0.481 ± 0.070, action_magnitude = 0.654 ± 0.300, num_gradient_steps = 57000, step_time = 11.14, total_time = 640.81
#
# step = 68000, num_env_steps = 68000, scores = -3.862 ± 0.02 (n=2), actor_loss = -7.867, critic_loss = 0.002, entropy_coef_loss = -8.701, entropy_coef = 0.000, action_stds = 0.436 ± 0.055, action_magnitude = 0.649 ± 0.300, num_gradient_steps = 58000, step_time = 11.11, total_time = 651.92
#
# step = 69000, num_env_steps = 69000, scores = -4.061 ± 0.10 (n=2), actor_loss = -7.464, critic_loss = 0.001, entropy_coef_loss = -8.881, entropy_coef = 0.000, action_stds = 0.442 ± 0.081, action_magnitude = 0.648 ± 0.300, num_gradient_steps = 59000, step_time = 11.13, total_time = 663.05
#
# step = 70000, num_env_steps = 70000, scores = -4.053 ± 0.32 (n=2), actor_loss = -7.010, critic_loss = 0.001, entropy_coef_loss = -3.274, entropy_coef = 0.000, action_stds = 0.413 ± 0.070, action_magnitude = 0.656 ± 0.302, num_gradient_steps = 60000, step_time = 11.14, total_time = 674.19
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 71000, num_env_steps = 71000, scores = -4.012 ± 0.04 (n=2), actor_loss = -6.676, critic_loss = 0.001, entropy_coef_loss = -14.214, entropy_coef = 0.000, action_stds = 0.434 ± 0.059, action_magnitude = 0.637 ± 0.302, num_gradient_steps = 61000, step_time = 11.27, total_time = 685.46
#
# step = 72000, num_env_steps = 72000, scores = -3.773 ± 0.43 (n=2), actor_loss = -6.318, critic_loss = 0.001, entropy_coef_loss = -22.522, entropy_coef = 0.000, action_stds = 0.424 ± 0.082, action_magnitude = 0.635 ± 0.301, num_gradient_steps = 62000, step_time = 11.09, total_time = 696.55
#
# step = 73000, num_env_steps = 73000, scores = -4.032 ± 0.13 (n=2), actor_loss = -5.990, critic_loss = 0.001, entropy_coef_loss = -4.409, entropy_coef = 0.000, action_stds = 0.419 ± 0.079, action_magnitude = 0.642 ± 0.301, num_gradient_steps = 63000, step_time = 11.10, total_time = 707.65
#
# step = 74000, num_env_steps = 74000, scores = -3.921 ± 0.06 (n=2), actor_loss = -5.666, critic_loss = 0.001, entropy_coef_loss = -11.759, entropy_coef = 0.000, action_stds = 0.509 ± 0.119, action_magnitude = 0.648 ± 0.303, num_gradient_steps = 64000, step_time = 11.06, total_time = 718.71
#
# step = 75000, num_env_steps = 75000, scores = -3.674 ± 0.10 (n=2), actor_loss = -5.393, critic_loss = 0.001, entropy_coef_loss = 0.899, entropy_coef = 0.000, action_stds = 0.399 ± 0.073, action_magnitude = 0.635 ± 0.298, num_gradient_steps = 65000, step_time = 11.11, total_time = 729.81
#
# step = 76000, num_env_steps = 76000, scores = -3.912 ± 0.12 (n=2), actor_loss = -5.093, critic_loss = 0.001, entropy_coef_loss = -1.736, entropy_coef = 0.000, action_stds = 0.387 ± 0.065, action_magnitude = 0.648 ± 0.301, num_gradient_steps = 66000, step_time = 11.09, total_time = 740.91
#
# step = 77000, num_env_steps = 77000, scores = -3.619 ± 0.40 (n=2), actor_loss = -4.838, critic_loss = 0.000, entropy_coef_loss = -11.690, entropy_coef = 0.000, action_stds = 0.413 ± 0.075, action_magnitude = 0.609 ± 0.302, num_gradient_steps = 67000, step_time = 11.09, total_time = 751.99
#
# step = 78000, num_env_steps = 78000, scores = -3.194 ± 0.13 (n=2), actor_loss = -4.551, critic_loss = 0.001, entropy_coef_loss = 0.072, entropy_coef = 0.000, action_stds = 0.429 ± 0.061, action_magnitude = 0.608 ± 0.302, num_gradient_steps = 68000, step_time = 11.11, total_time = 763.10
#
# step = 79000, num_env_steps = 79000, scores = -3.655 ± 0.19 (n=2), actor_loss = -4.316, critic_loss = 0.000, entropy_coef_loss = 12.073, entropy_coef = 0.000, action_stds = 0.385 ± 0.088, action_magnitude = 0.607 ± 0.301, num_gradient_steps = 69000, step_time = 11.08, total_time = 774.18
#
# step = 80000, num_env_steps = 80000, scores = -3.466 ± 0.23 (n=2), actor_loss = -4.088, critic_loss = 0.000, entropy_coef_loss = -3.166, entropy_coef = 0.000, action_stds = 0.366 ± 0.043, action_magnitude = 0.603 ± 0.297, num_gradient_steps = 70000, step_time = 11.09, total_time = 785.27
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 81000, num_env_steps = 81000, scores = -3.791 ± 0.19 (n=2), actor_loss = -3.863, critic_loss = 0.000, entropy_coef_loss = -15.680, entropy_coef = 0.000, action_stds = 0.338 ± 0.059, action_magnitude = 0.613 ± 0.300, num_gradient_steps = 71000, step_time = 11.19, total_time = 796.46
#
# step = 82000, num_env_steps = 82000, scores = -2.895 ± 0.09 (n=2), actor_loss = -3.650, critic_loss = 0.000, entropy_coef_loss = -10.605, entropy_coef = 0.000, action_stds = 0.358 ± 0.057, action_magnitude = 0.539 ± 0.297, num_gradient_steps = 72000, step_time = 11.09, total_time = 807.55
#
# step = 83000, num_env_steps = 83000, scores = -2.659 ± 0.11 (n=2), actor_loss = -3.436, critic_loss = 0.000, entropy_coef_loss = 13.837, entropy_coef = 0.000, action_stds = 0.302 ± 0.044, action_magnitude = 0.529 ± 0.292, num_gradient_steps = 73000, step_time = 11.08, total_time = 818.64
#
# step = 84000, num_env_steps = 84000, scores = -2.915 ± 0.30 (n=2), actor_loss = -3.275, critic_loss = 0.000, entropy_coef_loss = 1.295, entropy_coef = 0.000, action_stds = 0.431 ± 0.111, action_magnitude = 0.549 ± 0.295, num_gradient_steps = 74000, step_time = 11.14, total_time = 829.77
#
# step = 85000, num_env_steps = 85000, scores = -2.915 ± 0.17 (n=2), actor_loss = -3.080, critic_loss = 0.000, entropy_coef_loss = 0.279, entropy_coef = 0.000, action_stds = 0.381 ± 0.083, action_magnitude = 0.542 ± 0.295, num_gradient_steps = 75000, step_time = 11.07, total_time = 840.84
#
# step = 86000, num_env_steps = 86000, scores = -2.969 ± 0.43 (n=2), actor_loss = -2.931, critic_loss = 0.000, entropy_coef_loss = -15.156, entropy_coef = 0.000, action_stds = 0.365 ± 0.046, action_magnitude = 0.560 ± 0.294, num_gradient_steps = 76000, step_time = 11.18, total_time = 852.03
#
# step = 87000, num_env_steps = 87000, scores = -3.843 ± 0.99 (n=2), actor_loss = -2.760, critic_loss = 0.000, entropy_coef_loss = -13.384, entropy_coef = 0.000, action_stds = 0.409 ± 0.103, action_magnitude = 0.634 ± 0.304, num_gradient_steps = 77000, step_time = 11.07, total_time = 863.10
#
# step = 88000, num_env_steps = 88000, scores = -3.765 ± 0.99 (n=2), actor_loss = -2.626, critic_loss = 0.000, entropy_coef_loss = 22.444, entropy_coef = 0.000, action_stds = 0.409 ± 0.096, action_magnitude = 0.639 ± 0.308, num_gradient_steps = 78000, step_time = 11.10, total_time = 874.20
#
# step = 89000, num_env_steps = 89000, scores = -2.967 ± 0.22 (n=2), actor_loss = -2.465, critic_loss = 0.000, entropy_coef_loss = -19.916, entropy_coef = 0.000, action_stds = 0.356 ± 0.031, action_magnitude = 0.573 ± 0.305, num_gradient_steps = 79000, step_time = 11.14, total_time = 885.34
#
# step = 90000, num_env_steps = 90000, scores = -3.205 ± 0.08 (n=2), actor_loss = -2.329, critic_loss = 0.000, entropy_coef_loss = 0.202, entropy_coef = 0.000, action_stds = 0.332 ± 0.029, action_magnitude = 0.584 ± 0.291, num_gradient_steps = 80000, step_time = 11.09, total_time = 896.43
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 91000, num_env_steps = 91000, scores = -2.873 ± 0.01 (n=2), actor_loss = -2.204, critic_loss = 0.000, entropy_coef_loss = -6.860, entropy_coef = 0.000, action_stds = 0.359 ± 0.056, action_magnitude = 0.551 ± 0.296, num_gradient_steps = 81000, step_time = 11.15, total_time = 907.59
#
# step = 92000, num_env_steps = 92000, scores = -2.881 ± 0.01 (n=2), actor_loss = -2.074, critic_loss = 0.000, entropy_coef_loss = 3.788, entropy_coef = 0.000, action_stds = 0.341 ± 0.040, action_magnitude = 0.539 ± 0.292, num_gradient_steps = 82000, step_time = 11.13, total_time = 918.72
#
# step = 93000, num_env_steps = 93000, scores = -4.293 ± 0.65 (n=2), actor_loss = -1.958, critic_loss = 0.000, entropy_coef_loss = -14.367, entropy_coef = 0.000, action_stds = 0.424 ± 0.230, action_magnitude = 0.676 ± 0.309, num_gradient_steps = 83000, step_time = 11.08, total_time = 929.80
#
# step = 94000, num_env_steps = 94000, scores = -4.140 ± 0.03 (n=2), actor_loss = -1.847, critic_loss = 0.000, entropy_coef_loss = -1.432, entropy_coef = 0.000, action_stds = 0.397 ± 0.074, action_magnitude = 0.671 ± 0.296, num_gradient_steps = 84000, step_time = 11.12, total_time = 940.92
#
# step = 95000, num_env_steps = 95000, scores = -3.897 ± 0.07 (n=2), actor_loss = -1.734, critic_loss = 0.000, entropy_coef_loss = 0.214, entropy_coef = 0.000, action_stds = 0.337 ± 0.075, action_magnitude = 0.656 ± 0.301, num_gradient_steps = 85000, step_time = 11.08, total_time = 952.00
#
# step = 96000, num_env_steps = 96000, scores = -3.576 ± 0.36 (n=2), actor_loss = -1.649, critic_loss = 0.000, entropy_coef_loss = -0.210, entropy_coef = 0.000, action_stds = 0.397 ± 0.073, action_magnitude = 0.622 ± 0.303, num_gradient_steps = 86000, step_time = 11.08, total_time = 963.08
#
# step = 97000, num_env_steps = 97000, scores = -3.381 ± 0.17 (n=2), actor_loss = -1.542, critic_loss = 0.000, entropy_coef_loss = 19.320, entropy_coef = 0.000, action_stds = 0.319 ± 0.089, action_magnitude = 0.611 ± 0.299, num_gradient_steps = 87000, step_time = 11.15, total_time = 974.23
#
# step = 98000, num_env_steps = 98000, scores = -3.534 ± 0.05 (n=2), actor_loss = -1.459, critic_loss = 0.000, entropy_coef_loss = -9.033, entropy_coef = 0.000, action_stds = 0.328 ± 0.056, action_magnitude = 0.604 ± 0.303, num_gradient_steps = 88000, step_time = 11.01, total_time = 985.24
#
# step = 99000, num_env_steps = 99000, scores = -3.694 ± 0.25 (n=2), actor_loss = -1.379, critic_loss = 0.000, entropy_coef_loss = 2.929, entropy_coef = 0.000, action_stds = 0.353 ± 0.069, action_magnitude = 0.621 ± 0.305, num_gradient_steps = 89000, step_time = 11.08, total_time = 996.32
#
# step = 100000, num_env_steps = 100000, scores = -3.144 ± 0.15 (n=2), actor_loss = -1.294, critic_loss = 0.000, entropy_coef_loss = 0.820, entropy_coef = 0.000, action_stds = 0.319 ± 0.059, action_magnitude = 0.579 ± 0.299, num_gradient_steps = 90000, step_time = 11.06, total_time = 1007.38
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 101000, num_env_steps = 101000, scores = -3.742 ± 0.22 (n=2), actor_loss = -1.214, critic_loss = 0.000, entropy_coef_loss = -4.090, entropy_coef = 0.000, action_stds = 0.290 ± 0.059, action_magnitude = 0.630 ± 0.298, num_gradient_steps = 91000, step_time = 11.08, total_time = 1018.46
#
# step = 102000, num_env_steps = 102000, scores = -3.351 ± 0.23 (n=2), actor_loss = -1.146, critic_loss = 0.000, entropy_coef_loss = -7.566, entropy_coef = 0.000, action_stds = 0.308 ± 0.069, action_magnitude = 0.615 ± 0.307, num_gradient_steps = 92000, step_time = 11.11, total_time = 1029.58
#
# step = 103000, num_env_steps = 103000, scores = -3.063 ± 0.20 (n=2), actor_loss = -1.072, critic_loss = 0.000, entropy_coef_loss = -4.969, entropy_coef = 0.000, action_stds = 0.293 ± 0.043, action_magnitude = 0.593 ± 0.300, num_gradient_steps = 93000, step_time = 11.13, total_time = 1040.71
#
# step = 104000, num_env_steps = 104000, scores = -3.149 ± 0.13 (n=2), actor_loss = -1.017, critic_loss = 0.000, entropy_coef_loss = 3.660, entropy_coef = 0.000, action_stds = 0.286 ± 0.048, action_magnitude = 0.566 ± 0.299, num_gradient_steps = 94000, step_time = 11.14, total_time = 1051.85
#
# step = 105000, num_env_steps = 105000, scores = -2.937 ± 0.03 (n=2), actor_loss = -0.953, critic_loss = 0.000, entropy_coef_loss = 6.208, entropy_coef = 0.000, action_stds = 0.294 ± 0.067, action_magnitude = 0.573 ± 0.304, num_gradient_steps = 95000, step_time = 11.08, total_time = 1062.93
#
# step = 106000, num_env_steps = 106000, scores = -2.872 ± 0.16 (n=2), actor_loss = -0.885, critic_loss = 0.000, entropy_coef_loss = -7.655, entropy_coef = 0.000, action_stds = 0.260 ± 0.053, action_magnitude = 0.569 ± 0.301, num_gradient_steps = 96000, step_time = 11.09, total_time = 1074.02
#
# step = 107000, num_env_steps = 107000, scores = -4.124 ± 0.21 (n=2), actor_loss = -0.836, critic_loss = 0.000, entropy_coef_loss = 4.235, entropy_coef = 0.000, action_stds = 0.294 ± 0.090, action_magnitude = 0.666 ± 0.295, num_gradient_steps = 97000, step_time = 11.14, total_time = 1085.17
#
# step = 108000, num_env_steps = 108000, scores = -3.457 ± 0.38 (n=2), actor_loss = -0.778, critic_loss = 0.000, entropy_coef_loss = -0.538, entropy_coef = 0.000, action_stds = 0.310 ± 0.070, action_magnitude = 0.615 ± 0.306, num_gradient_steps = 98000, step_time = 11.10, total_time = 1096.27
#
# step = 109000, num_env_steps = 109000, scores = -3.464 ± 0.44 (n=2), actor_loss = -0.723, critic_loss = 0.000, entropy_coef_loss = 1.647, entropy_coef = 0.000, action_stds = 0.282 ± 0.074, action_magnitude = 0.621 ± 0.292, num_gradient_steps = 99000, step_time = 11.15, total_time = 1107.42
#
# step = 110000, num_env_steps = 110000, scores = -2.796 ± 0.24 (n=2), actor_loss = -0.681, critic_loss = 0.000, entropy_coef_loss = 3.848, entropy_coef = 0.000, action_stds = 0.261 ± 0.076, action_magnitude = 0.596 ± 0.306, num_gradient_steps = 100000, step_time = 11.12, total_time = 1118.54
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 111000, num_env_steps = 111000, scores = -2.672 ± 0.30 (n=2), actor_loss = -0.631, critic_loss = 0.000, entropy_coef_loss = -0.368, entropy_coef = 0.000, action_stds = 0.309 ± 0.071, action_magnitude = 0.568 ± 0.295, num_gradient_steps = 101000, step_time = 11.22, total_time = 1129.76
#
# step = 112000, num_env_steps = 112000, scores = -2.253 ± 0.09 (n=2), actor_loss = -0.590, critic_loss = 0.000, entropy_coef_loss = -1.522, entropy_coef = 0.000, action_stds = 0.235 ± 0.043, action_magnitude = 0.474 ± 0.276, num_gradient_steps = 102000, step_time = 11.53, total_time = 1141.30
#
# step = 113000, num_env_steps = 113000, scores = -2.315 ± 0.41 (n=2), actor_loss = -0.552, critic_loss = 0.000, entropy_coef_loss = -2.787, entropy_coef = 0.000, action_stds = 0.282 ± 0.073, action_magnitude = 0.503 ± 0.288, num_gradient_steps = 103000, step_time = 11.18, total_time = 1152.47
#
# step = 114000, num_env_steps = 114000, scores = -3.409 ± 0.50 (n=2), actor_loss = -0.520, critic_loss = 0.000, entropy_coef_loss = 10.435, entropy_coef = 0.000, action_stds = 0.268 ± 0.026, action_magnitude = 0.587 ± 0.300, num_gradient_steps = 104000, step_time = 11.16, total_time = 1163.63
#
# step = 115000, num_env_steps = 115000, scores = -3.310 ± 0.38 (n=2), actor_loss = -0.472, critic_loss = 0.000, entropy_coef_loss = -2.341, entropy_coef = 0.000, action_stds = 0.295 ± 0.061, action_magnitude = 0.586 ± 0.296, num_gradient_steps = 105000, step_time = 11.10, total_time = 1174.73
#
# step = 116000, num_env_steps = 116000, scores = -2.554 ± 0.02 (n=2), actor_loss = -0.441, critic_loss = 0.000, entropy_coef_loss = -8.566, entropy_coef = 0.000, action_stds = 0.248 ± 0.047, action_magnitude = 0.538 ± 0.304, num_gradient_steps = 106000, step_time = 11.15, total_time = 1185.87
#
# step = 117000, num_env_steps = 117000, scores = -2.667 ± 0.08 (n=2), actor_loss = -0.412, critic_loss = 0.000, entropy_coef_loss = 3.039, entropy_coef = 0.000, action_stds = 0.278 ± 0.079, action_magnitude = 0.525 ± 0.293, num_gradient_steps = 107000, step_time = 11.16, total_time = 1197.04
#
# step = 118000, num_env_steps = 118000, scores = -2.794 ± 0.34 (n=2), actor_loss = -0.375, critic_loss = 0.000, entropy_coef_loss = 3.681, entropy_coef = 0.000, action_stds = 0.290 ± 0.053, action_magnitude = 0.540 ± 0.280, num_gradient_steps = 108000, step_time = 11.14, total_time = 1208.18
#
# step = 119000, num_env_steps = 119000, scores = -2.834 ± 0.39 (n=2), actor_loss = -0.349, critic_loss = 0.000, entropy_coef_loss = -6.038, entropy_coef = 0.000, action_stds = 0.287 ± 0.039, action_magnitude = 0.559 ± 0.301, num_gradient_steps = 109000, step_time = 11.08, total_time = 1219.26
#
# step = 120000, num_env_steps = 120000, scores = -2.741 ± 0.00 (n=2), actor_loss = -0.327, critic_loss = 0.000, entropy_coef_loss = 5.162, entropy_coef = 0.000, action_stds = 0.312 ± 0.050, action_magnitude = 0.549 ± 0.295, num_gradient_steps = 110000, step_time = 11.22, total_time = 1230.48
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 121000, num_env_steps = 121000, scores = -3.335 ± 0.50 (n=2), actor_loss = -0.308, critic_loss = 0.000, entropy_coef_loss = 5.978, entropy_coef = 0.000, action_stds = 0.307 ± 0.063, action_magnitude = 0.595 ± 0.288, num_gradient_steps = 111000, step_time = 11.14, total_time = 1241.62
#
# step = 122000, num_env_steps = 122000, scores = -3.540 ± 0.91 (n=2), actor_loss = -0.278, critic_loss = 0.000, entropy_coef_loss = 2.533, entropy_coef = 0.000, action_stds = 0.323 ± 0.049, action_magnitude = 0.626 ± 0.289, num_gradient_steps = 112000, step_time = 11.20, total_time = 1252.82
#
# step = 123000, num_env_steps = 123000, scores = -2.491 ± 0.04 (n=2), actor_loss = -0.253, critic_loss = 0.000, entropy_coef_loss = -13.471, entropy_coef = 0.000, action_stds = 0.321 ± 0.058, action_magnitude = 0.509 ± 0.288, num_gradient_steps = 113000, step_time = 11.20, total_time = 1264.02
#
# step = 124000, num_env_steps = 124000, scores = -3.370 ± 0.16 (n=2), actor_loss = -0.230, critic_loss = 0.000, entropy_coef_loss = 4.617, entropy_coef = 0.000, action_stds = 0.362 ± 0.070, action_magnitude = 0.619 ± 0.302, num_gradient_steps = 114000, step_time = 11.24, total_time = 1275.25
#
# step = 125000, num_env_steps = 125000, scores = -3.267 ± 0.33 (n=2), actor_loss = -0.213, critic_loss = 0.000, entropy_coef_loss = 0.069, entropy_coef = 0.000, action_stds = 0.365 ± 0.071, action_magnitude = 0.602 ± 0.303, num_gradient_steps = 115000, step_time = 11.16, total_time = 1286.41
#
# step = 126000, num_env_steps = 126000, scores = -2.603 ± 0.22 (n=2), actor_loss = -0.188, critic_loss = 0.000, entropy_coef_loss = 6.147, entropy_coef = 0.000, action_stds = 0.341 ± 0.041, action_magnitude = 0.541 ± 0.296, num_gradient_steps = 116000, step_time = 11.18, total_time = 1297.59
#
# step = 127000, num_env_steps = 127000, scores = -3.625 ± 0.74 (n=2), actor_loss = -0.168, critic_loss = 0.000, entropy_coef_loss = 5.439, entropy_coef = 0.000, action_stds = 0.363 ± 0.086, action_magnitude = 0.625 ± 0.301, num_gradient_steps = 117000, step_time = 11.21, total_time = 1308.80
#
# step = 128000, num_env_steps = 128000, scores = -3.255 ± 0.30 (n=2), actor_loss = -0.167, critic_loss = 0.000, entropy_coef_loss = 4.647, entropy_coef = 0.000, action_stds = 0.347 ± 0.090, action_magnitude = 0.613 ± 0.302, num_gradient_steps = 118000, step_time = 11.20, total_time = 1320.00
#
# step = 129000, num_env_steps = 129000, scores = -3.567 ± 0.02 (n=2), actor_loss = -0.135, critic_loss = 0.000, entropy_coef_loss = -8.217, entropy_coef = 0.000, action_stds = 0.258 ± 0.073, action_magnitude = 0.651 ± 0.308, num_gradient_steps = 119000, step_time = 11.20, total_time = 1331.20
#
# step = 130000, num_env_steps = 130000, scores = -3.185 ± 0.10 (n=2), actor_loss = -0.124, critic_loss = 0.000, entropy_coef_loss = -2.262, entropy_coef = 0.000, action_stds = 0.335 ± 0.066, action_magnitude = 0.620 ± 0.303, num_gradient_steps = 120000, step_time = 11.18, total_time = 1342.38
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 131000, num_env_steps = 131000, scores = -3.418 ± 0.12 (n=2), actor_loss = -0.097, critic_loss = 0.000, entropy_coef_loss = -1.170, entropy_coef = 0.000, action_stds = 0.416 ± 0.181, action_magnitude = 0.643 ± 0.304, num_gradient_steps = 121000, step_time = 11.31, total_time = 1353.69
#
# step = 132000, num_env_steps = 132000, scores = -2.860 ± 0.38 (n=2), actor_loss = -0.085, critic_loss = 0.000, entropy_coef_loss = 11.539, entropy_coef = 0.000, action_stds = 0.277 ± 0.052, action_magnitude = 0.590 ± 0.300, num_gradient_steps = 122000, step_time = 11.18, total_time = 1364.87
#
# step = 133000, num_env_steps = 133000, scores = -3.741 ± 0.10 (n=2), actor_loss = -0.086, critic_loss = 0.000, entropy_coef_loss = 0.507, entropy_coef = 0.000, action_stds = 0.325 ± 0.070, action_magnitude = 0.640 ± 0.300, num_gradient_steps = 123000, step_time = 11.19, total_time = 1376.06
#
# step = 134000, num_env_steps = 134000, scores = -3.736 ± 0.35 (n=2), actor_loss = -0.054, critic_loss = 0.000, entropy_coef_loss = -0.628, entropy_coef = 0.000, action_stds = 0.216 ± 0.037, action_magnitude = 0.645 ± 0.307, num_gradient_steps = 124000, step_time = 11.21, total_time = 1387.27
#
# step = 135000, num_env_steps = 135000, scores = -3.264 ± 0.00 (n=2), actor_loss = -0.036, critic_loss = 0.000, entropy_coef_loss = 1.937, entropy_coef = 0.000, action_stds = 0.424 ± 0.091, action_magnitude = 0.612 ± 0.301, num_gradient_steps = 125000, step_time = 11.17, total_time = 1398.44
#
# step = 136000, num_env_steps = 136000, scores = -3.316 ± 0.07 (n=2), actor_loss = -0.034, critic_loss = 0.000, entropy_coef_loss = 2.123, entropy_coef = 0.000, action_stds = 0.263 ± 0.053, action_magnitude = 0.624 ± 0.304, num_gradient_steps = 126000, step_time = 11.20, total_time = 1409.63
#
# step = 137000, num_env_steps = 137000, scores = -3.351 ± 0.01 (n=2), actor_loss = -0.011, critic_loss = 0.000, entropy_coef_loss = 2.128, entropy_coef = 0.000, action_stds = 0.352 ± 0.050, action_magnitude = 0.627 ± 0.301, num_gradient_steps = 127000, step_time = 11.15, total_time = 1420.78
#
# step = 138000, num_env_steps = 138000, scores = -3.093 ± 0.10 (n=2), actor_loss = 0.019, critic_loss = 0.000, entropy_coef_loss = -5.853, entropy_coef = 0.000, action_stds = 0.201 ± 0.024, action_magnitude = 0.600 ± 0.303, num_gradient_steps = 128000, step_time = 11.11, total_time = 1431.89
#
# step = 139000, num_env_steps = 139000, scores = -4.123 ± 0.32 (n=2), actor_loss = 0.028, critic_loss = 0.000, entropy_coef_loss = 0.237, entropy_coef = 0.000, action_stds = 0.238 ± 0.046, action_magnitude = 0.647 ± 0.309, num_gradient_steps = 129000, step_time = 11.23, total_time = 1443.12
#
# step = 140000, num_env_steps = 140000, scores = -3.093 ± 0.41 (n=2), actor_loss = 0.020, critic_loss = 0.000, entropy_coef_loss = 15.191, entropy_coef = 0.000, action_stds = 0.290 ± 0.041, action_magnitude = 0.598 ± 0.303, num_gradient_steps = 130000, step_time = 11.19, total_time = 1454.30
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 141000, num_env_steps = 141000, scores = -2.801 ± 0.02 (n=2), actor_loss = 0.049, critic_loss = 0.000, entropy_coef_loss = -2.377, entropy_coef = 0.000, action_stds = 0.243 ± 0.054, action_magnitude = 0.562 ± 0.297, num_gradient_steps = 131000, step_time = 11.14, total_time = 1465.45
#
# step = 142000, num_env_steps = 142000, scores = -3.254 ± 0.33 (n=2), actor_loss = 0.049, critic_loss = 0.000, entropy_coef_loss = -3.923, entropy_coef = 0.000, action_stds = 0.253 ± 0.041, action_magnitude = 0.583 ± 0.292, num_gradient_steps = 132000, step_time = 11.17, total_time = 1476.62
#
# step = 143000, num_env_steps = 143000, scores = -2.814 ± 0.40 (n=2), actor_loss = 0.058, critic_loss = 0.000, entropy_coef_loss = -5.356, entropy_coef = 0.000, action_stds = 0.342 ± 0.098, action_magnitude = 0.549 ± 0.295, num_gradient_steps = 133000, step_time = 11.15, total_time = 1487.77
#
# step = 144000, num_env_steps = 144000, scores = -3.252 ± 0.34 (n=2), actor_loss = 0.067, critic_loss = 0.000, entropy_coef_loss = 2.737, entropy_coef = 0.000, action_stds = 0.354 ± 0.089, action_magnitude = 0.618 ± 0.306, num_gradient_steps = 134000, step_time = 11.13, total_time = 1498.90
#
# step = 145000, num_env_steps = 145000, scores = -3.649 ± 0.08 (n=2), actor_loss = 0.069, critic_loss = 0.000, entropy_coef_loss = 4.325, entropy_coef = 0.000, action_stds = 0.417 ± 0.077, action_magnitude = 0.610 ± 0.307, num_gradient_steps = 135000, step_time = 11.18, total_time = 1510.08
#
# step = 146000, num_env_steps = 146000, scores = -3.597 ± 0.07 (n=2), actor_loss = 0.078, critic_loss = 0.000, entropy_coef_loss = 13.480, entropy_coef = 0.000, action_stds = 0.316 ± 0.079, action_magnitude = 0.607 ± 0.301, num_gradient_steps = 136000, step_time = 11.15, total_time = 1521.23
#
# step = 147000, num_env_steps = 147000, scores = -3.182 ± 0.49 (n=2), actor_loss = 0.089, critic_loss = 0.000, entropy_coef_loss = -4.545, entropy_coef = 0.000, action_stds = 0.269 ± 0.054, action_magnitude = 0.590 ± 0.299, num_gradient_steps = 137000, step_time = 11.06, total_time = 1532.29
#
# step = 148000, num_env_steps = 148000, scores = -3.739 ± 0.39 (n=2), actor_loss = 0.076, critic_loss = 0.000, entropy_coef_loss = 11.871, entropy_coef = 0.000, action_stds = 0.436 ± 0.066, action_magnitude = 0.628 ± 0.302, num_gradient_steps = 138000, step_time = 11.07, total_time = 1543.36
#
# step = 149000, num_env_steps = 149000, scores = -3.816 ± 0.07 (n=2), actor_loss = 0.047, critic_loss = 0.001, entropy_coef_loss = 16.417, entropy_coef = 0.000, action_stds = 0.392 ± 0.099, action_magnitude = 0.629 ± 0.302, num_gradient_steps = 139000, step_time = 11.06, total_time = 1554.42
#
# step = 150000, num_env_steps = 150000, scores = -3.355 ± 0.25 (n=2), actor_loss = 0.084, critic_loss = 0.000, entropy_coef_loss = -11.849, entropy_coef = 0.000, action_stds = 0.361 ± 0.057, action_magnitude = 0.595 ± 0.300, num_gradient_steps = 140000, step_time = 11.09, total_time = 1565.51
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 151000, num_env_steps = 151000, scores = -3.784 ± 0.05 (n=2), actor_loss = 0.061, critic_loss = 0.000, entropy_coef_loss = -8.722, entropy_coef = 0.000, action_stds = 0.397 ± 0.108, action_magnitude = 0.653 ± 0.300, num_gradient_steps = 141000, step_time = 11.04, total_time = 1576.55
#
# step = 152000, num_env_steps = 152000, scores = -4.489 ± 0.06 (n=2), actor_loss = 0.057, critic_loss = 0.000, entropy_coef_loss = -11.376, entropy_coef = 0.000, action_stds = 0.356 ± 0.055, action_magnitude = 0.697 ± 0.302, num_gradient_steps = 142000, step_time = 11.06, total_time = 1587.61
#
# step = 153000, num_env_steps = 153000, scores = -3.905 ± 0.37 (n=2), actor_loss = 0.017, critic_loss = 0.001, entropy_coef_loss = 9.903, entropy_coef = 0.000, action_stds = 0.404 ± 0.117, action_magnitude = 0.667 ± 0.300, num_gradient_steps = 143000, step_time = 11.06, total_time = 1598.66
#
# step = 154000, num_env_steps = 154000, scores = -3.559 ± 0.10 (n=2), actor_loss = 0.085, critic_loss = 0.000, entropy_coef_loss = -5.287, entropy_coef = 0.000, action_stds = 0.448 ± 0.069, action_magnitude = 0.624 ± 0.302, num_gradient_steps = 144000, step_time = 11.06, total_time = 1609.72
#
# step = 155000, num_env_steps = 155000, scores = -3.558 ± 0.36 (n=2), actor_loss = 0.027, critic_loss = 0.001, entropy_coef_loss = 1.070, entropy_coef = 0.000, action_stds = 0.403 ± 0.115, action_magnitude = 0.640 ± 0.302, num_gradient_steps = 145000, step_time = 11.06, total_time = 1620.78
#
# step = 156000, num_env_steps = 156000, scores = -3.829 ± 0.15 (n=2), actor_loss = 0.031, critic_loss = 0.001, entropy_coef_loss = -9.101, entropy_coef = 0.000, action_stds = 0.448 ± 0.071, action_magnitude = 0.645 ± 0.299, num_gradient_steps = 146000, step_time = 11.14, total_time = 1631.92
#
# step = 157000, num_env_steps = 157000, scores = -4.355 ± 0.14 (n=2), actor_loss = 0.003, critic_loss = 0.001, entropy_coef_loss = 1.544, entropy_coef = 0.000, action_stds = 0.457 ± 0.065, action_magnitude = 0.676 ± 0.297, num_gradient_steps = 147000, step_time = 11.14, total_time = 1643.06
#
# step = 158000, num_env_steps = 158000, scores = -4.813 ± 0.41 (n=2), actor_loss = 0.054, critic_loss = 0.001, entropy_coef_loss = -2.767, entropy_coef = 0.000, action_stds = 0.356 ± 0.102, action_magnitude = 0.725 ± 0.292, num_gradient_steps = 148000, step_time = 11.12, total_time = 1654.18
#
# step = 159000, num_env_steps = 159000, scores = -4.405 ± 0.24 (n=2), actor_loss = 0.034, critic_loss = 0.001, entropy_coef_loss = 1.081, entropy_coef = 0.000, action_stds = 0.446 ± 0.053, action_magnitude = 0.700 ± 0.292, num_gradient_steps = 149000, step_time = 11.27, total_time = 1665.46
#
# step = 160000, num_env_steps = 160000, scores = -4.969 ± 0.17 (n=2), actor_loss = 0.025, critic_loss = 0.001, entropy_coef_loss = -0.464, entropy_coef = 0.000, action_stds = 0.437 ± 0.039, action_magnitude = 0.733 ± 0.295, num_gradient_steps = 150000, step_time = 11.88, total_time = 1677.34
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 161000, num_env_steps = 161000, scores = -4.792 ± 0.26 (n=2), actor_loss = -0.001, critic_loss = 0.001, entropy_coef_loss = 2.930, entropy_coef = 0.000, action_stds = 0.419 ± 0.107, action_magnitude = 0.735 ± 0.277, num_gradient_steps = 151000, step_time = 11.43, total_time = 1688.77
#
# step = 162000, num_env_steps = 162000, scores = -4.133 ± 0.06 (n=2), actor_loss = -0.047, critic_loss = 0.001, entropy_coef_loss = 6.475, entropy_coef = 0.000, action_stds = 0.359 ± 0.056, action_magnitude = 0.667 ± 0.307, num_gradient_steps = 152000, step_time = 11.15, total_time = 1699.91
#
# step = 163000, num_env_steps = 163000, scores = -4.330 ± 0.06 (n=2), actor_loss = -0.013, critic_loss = 0.001, entropy_coef_loss = 2.838, entropy_coef = 0.000, action_stds = 0.340 ± 0.068, action_magnitude = 0.686 ± 0.298, num_gradient_steps = 153000, step_time = 11.15, total_time = 1711.06
#
# step = 164000, num_env_steps = 164000, scores = -4.469 ± 0.00 (n=2), actor_loss = -0.042, critic_loss = 0.001, entropy_coef_loss = 11.011, entropy_coef = 0.000, action_stds = 0.328 ± 0.079, action_magnitude = 0.706 ± 0.292, num_gradient_steps = 154000, step_time = 11.38, total_time = 1722.44
#
# step = 165000, num_env_steps = 165000, scores = -3.505 ± 0.20 (n=2), actor_loss = -0.066, critic_loss = 0.001, entropy_coef_loss = 9.254, entropy_coef = 0.000, action_stds = 0.353 ± 0.098, action_magnitude = 0.618 ± 0.317, num_gradient_steps = 155000, step_time = 11.84, total_time = 1734.29
#
# step = 166000, num_env_steps = 166000, scores = -4.094 ± 0.19 (n=2), actor_loss = 0.007, critic_loss = 0.001, entropy_coef_loss = 0.314, entropy_coef = 0.000, action_stds = 0.507 ± 0.057, action_magnitude = 0.672 ± 0.303, num_gradient_steps = 156000, step_time = 11.75, total_time = 1746.04
#
# step = 167000, num_env_steps = 167000, scores = -4.491 ± 0.10 (n=2), actor_loss = -0.109, critic_loss = 0.001, entropy_coef_loss = 3.422, entropy_coef = 0.000, action_stds = 0.375 ± 0.076, action_magnitude = 0.706 ± 0.294, num_gradient_steps = 157000, step_time = 11.60, total_time = 1757.63
#
# ...
#
# step = 1217000, num_env_steps = 1217000, scores = -0.782 ± 0.10 (n=2), actor_loss = 0.295, critic_loss = 0.000, entropy_coef_loss = -3.894, entropy_coef = 0.000, action_stds = 0.171 ± 0.049, action_magnitude = 0.304 ± 0.236, num_gradient_steps = 1207000, step_time = 11.33, total_time = 13362.90
#
# step = 1218000, num_env_steps = 1218000, scores = -1.260 ± 0.09 (n=2), actor_loss = 0.284, critic_loss = 0.000, entropy_coef_loss = -2.815, entropy_coef = 0.000, action_stds = 0.192 ± 0.068, action_magnitude = 0.376 ± 0.257, num_gradient_steps = 1208000, step_time = 11.24, total_time = 13374.14
#
# step = 1219000, num_env_steps = 1219000, scores = -0.662 ± 0.12 (n=2), actor_loss = 0.284, critic_loss = 0.000, entropy_coef_loss = -2.487, entropy_coef = 0.000, action_stds = 0.112 ± 0.031, action_magnitude = 0.287 ± 0.216, num_gradient_steps = 1209000, step_time = 11.22, total_time = 13385.35
#
# step = 1220000, num_env_steps = 1220000, scores = -0.880 ± 0.13 (n=2), actor_loss = 0.292, critic_loss = 0.000, entropy_coef_loss = 2.825, entropy_coef = 0.000, action_stds = 0.182 ± 0.055, action_magnitude = 0.323 ± 0.236, num_gradient_steps = 1210000, step_time = 11.25, total_time = 13396.60
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 1221000, num_env_steps = 1221000, scores = -0.785 ± 0.07 (n=2), actor_loss = 0.303, critic_loss = 0.000, entropy_coef_loss = 0.058, entropy_coef = 0.000, action_stds = 0.129 ± 0.037, action_magnitude = 0.317 ± 0.224, num_gradient_steps = 1211000, step_time = 13.07, total_time = 13409.67
#
# step = 1222000, num_env_steps = 1222000, scores = -0.805 ± 0.09 (n=2), actor_loss = 0.293, critic_loss = 0.000, entropy_coef_loss = 0.111, entropy_coef = 0.000, action_stds = 0.136 ± 0.037, action_magnitude = 0.316 ± 0.220, num_gradient_steps = 1212000, step_time = 13.58, total_time = 13423.26
#
# step = 1223000, num_env_steps = 1223000, scores = -0.765 ± 0.19 (n=2), actor_loss = 0.284, critic_loss = 0.000, entropy_coef_loss = -5.904, entropy_coef = 0.000, action_stds = 0.148 ± 0.033, action_magnitude = 0.303 ± 0.227, num_gradient_steps = 1213000, step_time = 11.42, total_time = 13434.68
#
# step = 1224000, num_env_steps = 1224000, scores = -1.001 ± 0.37 (n=2), actor_loss = 0.284, critic_loss = 0.000, entropy_coef_loss = -5.873, entropy_coef = 0.000, action_stds = 0.132 ± 0.030, action_magnitude = 0.336 ± 0.249, num_gradient_steps = 1214000, step_time = 11.29, total_time = 13445.96
#
# step = 1225000, num_env_steps = 1225000, scores = -0.734 ± 0.05 (n=2), actor_loss = 0.290, critic_loss = 0.000, entropy_coef_loss = -2.265, entropy_coef = 0.000, action_stds = 0.116 ± 0.025, action_magnitude = 0.293 ± 0.225, num_gradient_steps = 1215000, step_time = 11.34, total_time = 13457.30
#
# step = 1226000, num_env_steps = 1226000, scores = -0.660 ± 0.15 (n=2), actor_loss = 0.296, critic_loss = 0.000, entropy_coef_loss = 9.960, entropy_coef = 0.000, action_stds = 0.121 ± 0.034, action_magnitude = 0.291 ± 0.215, num_gradient_steps = 1216000, step_time = 11.30, total_time = 13468.60
#
# step = 1227000, num_env_steps = 1227000, scores = -0.673 ± 0.01 (n=2), actor_loss = 0.292, critic_loss = 0.000, entropy_coef_loss = -2.029, entropy_coef = 0.000, action_stds = 0.163 ± 0.051, action_magnitude = 0.292 ± 0.217, num_gradient_steps = 1217000, step_time = 11.62, total_time = 13480.22
#
# step = 1228000, num_env_steps = 1228000, scores = -1.012 ± 0.16 (n=2), actor_loss = 0.292, critic_loss = 0.000, entropy_coef_loss = 15.832, entropy_coef = 0.000, action_stds = 0.211 ± 0.057, action_magnitude = 0.336 ± 0.241, num_gradient_steps = 1218000, step_time = 12.92, total_time = 13493.14
#
# step = 1229000, num_env_steps = 1229000, scores = -0.795 ± 0.03 (n=2), actor_loss = 0.279, critic_loss = 0.000, entropy_coef_loss = -4.653, entropy_coef = 0.000, action_stds = 0.147 ± 0.038, action_magnitude = 0.300 ± 0.235, num_gradient_steps = 1219000, step_time = 12.80, total_time = 13505.94
#
# step = 1230000, num_env_steps = 1230000, scores = -0.574 ± 0.10 (n=2), actor_loss = 0.272, critic_loss = 0.000, entropy_coef_loss = -7.670, entropy_coef = 0.000, action_stds = 0.119 ± 0.029, action_magnitude = 0.271 ± 0.212, num_gradient_steps = 1220000, step_time = 11.49, total_time = 13517.44
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 1231000, num_env_steps = 1231000, scores = -0.625 ± 0.03 (n=2), actor_loss = 0.291, critic_loss = 0.000, entropy_coef_loss = 8.871, entropy_coef = 0.000, action_stds = 0.158 ± 0.033, action_magnitude = 0.274 ± 0.217, num_gradient_steps = 1221000, step_time = 11.45, total_time = 13528.89
#
# step = 1232000, num_env_steps = 1232000, scores = -0.758 ± 0.01 (n=2), actor_loss = 0.293, critic_loss = 0.000, entropy_coef_loss = 5.008, entropy_coef = 0.000, action_stds = 0.170 ± 0.043, action_magnitude = 0.304 ± 0.221, num_gradient_steps = 1222000, step_time = 11.11, total_time = 13540.00
#
# step = 1233000, num_env_steps = 1233000, scores = -0.757 ± 0.09 (n=2), actor_loss = 0.279, critic_loss = 0.000, entropy_coef_loss = -2.452, entropy_coef = 0.000, action_stds = 0.157 ± 0.037, action_magnitude = 0.301 ± 0.224, num_gradient_steps = 1223000, step_time = 11.10, total_time = 13551.10
#
# step = 1234000, num_env_steps = 1234000, scores = -0.628 ± 0.01 (n=2), actor_loss = 0.277, critic_loss = 0.000, entropy_coef_loss = -1.414, entropy_coef = 0.000, action_stds = 0.157 ± 0.038, action_magnitude = 0.269 ± 0.218, num_gradient_steps = 1224000, step_time = 11.07, total_time = 13562.17
#
# step = 1235000, num_env_steps = 1235000, scores = -0.488 ± 0.03 (n=2), actor_loss = 0.303, critic_loss = 0.000, entropy_coef_loss = -3.151, entropy_coef = 0.000, action_stds = 0.126 ± 0.034, action_magnitude = 0.254 ± 0.213, num_gradient_steps = 1225000, step_time = 11.14, total_time = 13573.31
#
# step = 1236000, num_env_steps = 1236000, scores = -0.670 ± 0.18 (n=2), actor_loss = 0.274, critic_loss = 0.000, entropy_coef_loss = -2.505, entropy_coef = 0.000, action_stds = 0.110 ± 0.024, action_magnitude = 0.278 ± 0.222, num_gradient_steps = 1226000, step_time = 11.15, total_time = 13584.45
#
# step = 1237000, num_env_steps = 1237000, scores = -0.420 ± 0.03 (n=2), actor_loss = 0.296, critic_loss = 0.000, entropy_coef_loss = 8.785, entropy_coef = 0.000, action_stds = 0.109 ± 0.033, action_magnitude = 0.237 ± 0.202, num_gradient_steps = 1227000, step_time = 11.07, total_time = 13595.53
#
# step = 1238000, num_env_steps = 1238000, scores = -1.174 ± 0.43 (n=2), actor_loss = 0.289, critic_loss = 0.000, entropy_coef_loss = 1.918, entropy_coef = 0.000, action_stds = 0.105 ± 0.025, action_magnitude = 0.361 ± 0.258, num_gradient_steps = 1228000, step_time = 11.05, total_time = 13606.58
#
# step = 1239000, num_env_steps = 1239000, scores = -0.596 ± 0.05 (n=2), actor_loss = 0.275, critic_loss = 0.000, entropy_coef_loss = 1.313, entropy_coef = 0.000, action_stds = 0.140 ± 0.034, action_magnitude = 0.276 ± 0.215, num_gradient_steps = 1229000, step_time = 11.09, total_time = 13617.67
#
# step = 1240000, num_env_steps = 1240000, scores = -0.504 ± 0.06 (n=2), actor_loss = 0.274, critic_loss = 0.000, entropy_coef_loss = -2.267, entropy_coef = 0.000, action_stds = 0.117 ± 0.034, action_magnitude = 0.259 ± 0.200, num_gradient_steps = 1230000, step_time = 11.08, total_time = 13628.75
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 1241000, num_env_steps = 1241000, scores = -1.035 ± 0.33 (n=2), actor_loss = 0.283, critic_loss = 0.000, entropy_coef_loss = 1.067, entropy_coef = 0.000, action_stds = 0.208 ± 0.060, action_magnitude = 0.343 ± 0.252, num_gradient_steps = 1231000, step_time = 11.19, total_time = 13639.94
#
# step = 1242000, num_env_steps = 1242000, scores = -0.716 ± 0.30 (n=2), actor_loss = 0.272, critic_loss = 0.000, entropy_coef_loss = 1.337, entropy_coef = 0.000, action_stds = 0.126 ± 0.035, action_magnitude = 0.291 ± 0.230, num_gradient_steps = 1232000, step_time = 11.14, total_time = 13651.08
#
# step = 1243000, num_env_steps = 1243000, scores = -0.484 ± 0.09 (n=2), actor_loss = 0.270, critic_loss = 0.000, entropy_coef_loss = 1.698, entropy_coef = 0.000, action_stds = 0.111 ± 0.033, action_magnitude = 0.263 ± 0.197, num_gradient_steps = 1233000, step_time = 11.09, total_time = 13662.16
#
# step = 1244000, num_env_steps = 1244000, scores = -0.682 ± 0.32 (n=2), actor_loss = 0.288, critic_loss = 0.000, entropy_coef_loss = 5.373, entropy_coef = 0.000, action_stds = 0.196 ± 0.061, action_magnitude = 0.278 ± 0.220, num_gradient_steps = 1234000, step_time = 11.09, total_time = 13673.26
#
# step = 1245000, num_env_steps = 1245000, scores = -0.382 ± 0.03 (n=2), actor_loss = 0.272, critic_loss = 0.000, entropy_coef_loss = -3.107, entropy_coef = 0.000, action_stds = 0.110 ± 0.029, action_magnitude = 0.231 ± 0.193, num_gradient_steps = 1235000, step_time = 11.12, total_time = 13684.37
#
# step = 1246000, num_env_steps = 1246000, scores = -0.534 ± 0.02 (n=2), actor_loss = 0.290, critic_loss = 0.000, entropy_coef_loss = 2.312, entropy_coef = 0.000, action_stds = 0.120 ± 0.032, action_magnitude = 0.263 ± 0.203, num_gradient_steps = 1236000, step_time = 11.10, total_time = 13695.47
#
# step = 1247000, num_env_steps = 1247000, scores = -0.539 ± 0.11 (n=2), actor_loss = 0.288, critic_loss = 0.000, entropy_coef_loss = 2.749, entropy_coef = 0.000, action_stds = 0.117 ± 0.028, action_magnitude = 0.266 ± 0.205, num_gradient_steps = 1237000, step_time = 11.11, total_time = 13706.58
#
# step = 1248000, num_env_steps = 1248000, scores = -0.683 ± 0.02 (n=2), actor_loss = 0.281, critic_loss = 0.000, entropy_coef_loss = -1.209, entropy_coef = 0.000, action_stds = 0.173 ± 0.052, action_magnitude = 0.300 ± 0.228, num_gradient_steps = 1238000, step_time = 11.09, total_time = 13717.67
#
# step = 1249000, num_env_steps = 1249000, scores = -1.108 ± 0.41 (n=2), actor_loss = 0.281, critic_loss = 0.000, entropy_coef_loss = 0.131, entropy_coef = 0.000, action_stds = 0.173 ± 0.059, action_magnitude = 0.351 ± 0.249, num_gradient_steps = 1239000, step_time = 11.09, total_time = 13728.76
#
# step = 1250000, num_env_steps = 1250000, scores = -0.494 ± 0.02 (n=2), actor_loss = 0.275, critic_loss = 0.000, entropy_coef_loss = 5.335, entropy_coef = 0.000, action_stds = 0.122 ± 0.028, action_magnitude = 0.254 ± 0.197, num_gradient_steps = 1240000, step_time = 11.12, total_time = 13739.88
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 1251000, num_env_steps = 1251000, scores = -0.711 ± 0.13 (n=2), actor_loss = 0.285, critic_loss = 0.000, entropy_coef_loss = -1.738, entropy_coef = 0.000, action_stds = 0.174 ± 0.054, action_magnitude = 0.300 ± 0.220, num_gradient_steps = 1241000, step_time = 11.65, total_time = 13751.53
#
# step = 1252000, num_env_steps = 1252000, scores = -0.487 ± 0.10 (n=2), actor_loss = 0.278, critic_loss = 0.000, entropy_coef_loss = 0.876, entropy_coef = 0.000, action_stds = 0.159 ± 0.041, action_magnitude = 0.254 ± 0.204, num_gradient_steps = 1242000, step_time = 11.46, total_time = 13762.99
#
# step = 1253000, num_env_steps = 1253000, scores = -0.373 ± 0.02 (n=2), actor_loss = 0.279, critic_loss = 0.000, entropy_coef_loss = -2.343, entropy_coef = 0.000, action_stds = 0.140 ± 0.036, action_magnitude = 0.231 ± 0.189, num_gradient_steps = 1243000, step_time = 11.79, total_time = 13774.78
#
# step = 1254000, num_env_steps = 1254000, scores = -0.876 ± 0.52 (n=2), actor_loss = 0.285, critic_loss = 0.000, entropy_coef_loss = -5.888, entropy_coef = 0.000, action_stds = 0.177 ± 0.053, action_magnitude = 0.307 ± 0.235, num_gradient_steps = 1244000, step_time = 10.67, total_time = 13785.45
#
# step = 1255000, num_env_steps = 1255000, scores = -0.676 ± 0.37 (n=2), actor_loss = 0.279, critic_loss = 0.000, entropy_coef_loss = 1.148, entropy_coef = 0.000, action_stds = 0.117 ± 0.030, action_magnitude = 0.271 ± 0.227, num_gradient_steps = 1245000, step_time = 10.08, total_time = 13795.52
#
# step = 1256000, num_env_steps = 1256000, scores = -0.344 ± 0.01 (n=2), actor_loss = 0.275, critic_loss = 0.000, entropy_coef_loss = 0.901, entropy_coef = 0.000, action_stds = 0.115 ± 0.029, action_magnitude = 0.224 ± 0.191, num_gradient_steps = 1246000, step_time = 9.82, total_time = 13805.34
#
# step = 1257000, num_env_steps = 1257000, scores = -0.401 ± 0.10 (n=2), actor_loss = 0.268, critic_loss = 0.000, entropy_coef_loss = 3.750, entropy_coef = 0.000, action_stds = 0.152 ± 0.045, action_magnitude = 0.234 ± 0.189, num_gradient_steps = 1247000, step_time = 9.74, total_time = 13815.08
#
# step = 1258000, num_env_steps = 1258000, scores = -0.401 ± 0.02 (n=2), actor_loss = 0.293, critic_loss = 0.000, entropy_coef_loss = 3.609, entropy_coef = 0.000, action_stds = 0.111 ± 0.024, action_magnitude = 0.239 ± 0.186, num_gradient_steps = 1248000, step_time = 9.67, total_time = 13824.75
#
# step = 1259000, num_env_steps = 1259000, scores = -0.459 ± 0.00 (n=2), actor_loss = 0.276, critic_loss = 0.000, entropy_coef_loss = -1.273, entropy_coef = 0.000, action_stds = 0.119 ± 0.028, action_magnitude = 0.251 ± 0.196, num_gradient_steps = 1249000, step_time = 9.52, total_time = 13834.28
#
# step = 1260000, num_env_steps = 1260000, scores = -0.519 ± 0.12 (n=2), actor_loss = 0.269, critic_loss = 0.000, entropy_coef_loss = -10.332, entropy_coef = 0.000, action_stds = 0.152 ± 0.039, action_magnitude = 0.271 ± 0.205, num_gradient_steps = 1250000, step_time = 9.50, total_time = 13843.78
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
#
# step = 1261000, num_env_steps = 1261000, scores = -0.307 ± 0.01 (n=2), actor_loss = 0.273, critic_loss = 0.000, entropy_coef_loss = -3.355, entropy_coef = 0.000, action_stds = 0.108 ± 0.027, action_magnitude = 0.216 ± 0.187, num_gradient_steps = 1251000, step_time = 9.81, total_time = 13853.59
#
# step = 1262000, num_env_steps = 1262000, scores = -0.421 ± 0.03 (n=2), actor_loss = 0.272, critic_loss = 0.000, entropy_coef_loss = 5.784, entropy_coef = 0.000, action_stds = 0.113 ± 0.030, action_magnitude = 0.262 ± 0.200, num_gradient_steps = 1252000, step_time = 9.50, total_time = 13863.10
#
# step = 1263000, num_env_steps = 1263000, scores = -0.349 ± 0.01 (n=2), actor_loss = 0.267, critic_loss = 0.000, entropy_coef_loss = 8.979, entropy_coef = 0.000, action_stds = 0.122 ± 0.037, action_magnitude = 0.236 ± 0.195, num_gradient_steps = 1253000, step_time = 9.83, total_time = 13872.92
#
# step = 1264000, num_env_steps = 1264000, scores = -0.384 ± 0.00 (n=2), actor_loss = 0.277, critic_loss = 0.000, entropy_coef_loss = -0.720, entropy_coef = 0.000, action_stds = 0.112 ± 0.030, action_magnitude = 0.234 ± 0.192, num_gradient_steps = 1254000, step_time = 9.62, total_time = 13882.54
#
# step = 1265000, num_env_steps = 1265000, scores = -0.951 ± 0.52 (n=2), actor_loss = 0.266, critic_loss = 0.000, entropy_coef_loss = -5.382, entropy_coef = 0.000, action_stds = 0.199 ± 0.058, action_magnitude = 0.324 ± 0.252, num_gradient_steps = 1255000, step_time = 9.88, total_time = 13892.42
#
# step = 1266000, num_env_steps = 1266000, scores = -0.447 ± 0.05 (n=2), actor_loss = 0.270, critic_loss = 0.000, entropy_coef_loss = 4.144, entropy_coef = 0.000, action_stds = 0.123 ± 0.037, action_magnitude = 0.258 ± 0.203, num_gradient_steps = 1256000, step_time = 9.27, total_time = 13901.69
#
# step = 1267000, num_env_steps = 1267000, scores = -0.443 ± 0.07 (n=2), actor_loss = 0.265, critic_loss = 0.000, entropy_coef_loss = 4.693, entropy_coef = 0.000, action_stds = 0.127 ± 0.036, action_magnitude = 0.267 ± 0.196, num_gradient_steps = 1257000, step_time = 9.92, total_time = 13911.61
#
# saved experiment log 2024-10-25_22-29-16_611278~pNahaS at experiment_logs/2024-10-25_22-29-16_611278~pNahaS.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Program Files\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\Git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
