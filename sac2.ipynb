# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.swarm_bot_env import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
            best_iteration_score = iteration_score
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        if step % 100_000 == 0:
            save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=5, 
        hip_range=np.pi / 4,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    latent_action_size = int(64)
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 64),
        nn.ReLU(),
        nn.Linear(64, 64),
        nn.ReLU(),
        nn.Linear(64, 64),
        nn.ReLU(),
        nn.Linear(64, latent_action_size),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=latent_action_size,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_size=1_000_000,
            reward_scale=10,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef_clamp_range=(0.001, 1.5),
            # entropy_coef=0.1,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        # algo.load('saved_models/2024-10-28_11-12-19_363042~VskSv0/', '2024-10-28_11-12-19_363042~VskSv0')
        total_stopwatch.reset()
        with log_experiment(
            logger,
            # experiment_id='2024-10-28_11-12-19_363042~VskSv0',
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 188834
# env = <swarmbots.swarm_bot_env.SwarmBotEnv object at 0x00000255C6E5E010>, num_envs = 1
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
# Starting Training
#
#
# step = 1396000, num_env_steps = 1396000, scores = 17.593 ± 3.23 (n=2), actor_loss = -13.902, critic_loss = 0.086, entropy_coef_loss = 79.883, entropy_coef = 0.001, action_stds = 0.303 ± 0.057, action_magnitude = 0.823 ± 0.257, num_gradient_steps = 1385998, step_time = 6.32, total_time = 5.98
#
#
# step = 1397000, num_env_steps = 1397000, scores = 11.270 ± 0.53 (n=2), actor_loss = -13.274, critic_loss = 0.066, entropy_coef_loss = 76.635, entropy_coef = 0.001, action_stds = 0.309 ± 0.062, action_magnitude = 0.820 ± 0.257, num_gradient_steps = 1386998, step_time = 10.90, total_time = 16.87
#
#
# step = 1398000, num_env_steps = 1398000, scores = 13.708 ± 0.56 (n=2), actor_loss = -13.778, critic_loss = 0.099, entropy_coef_loss = 81.483, entropy_coef = 0.001, action_stds = 0.371 ± 0.076, action_magnitude = 0.829 ± 0.252, num_gradient_steps = 1387998, step_time = 10.12, total_time = 26.99
#
#
# step = 1399000, num_env_steps = 1399000, scores = 13.682 ± 0.68 (n=2), actor_loss = -13.600, critic_loss = 0.078, entropy_coef_loss = 83.670, entropy_coef = 0.001, action_stds = 0.289 ± 0.051, action_magnitude = 0.828 ± 0.254, num_gradient_steps = 1388998, step_time = 11.03, total_time = 38.02
#
#
# step = 1400000, num_env_steps = 1400000, scores = 13.255 ± 0.77 (n=2), actor_loss = -14.221, critic_loss = 0.059, entropy_coef_loss = 71.387, entropy_coef = 0.001, action_stds = 0.407 ± 0.053, action_magnitude = 0.829 ± 0.251, num_gradient_steps = 1389998, step_time = 11.50, total_time = 49.52
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1401000, num_env_steps = 1401000, scores = 14.184 ± 0.02 (n=2), actor_loss = -14.270, critic_loss = 0.064, entropy_coef_loss = 76.923, entropy_coef = 0.001, action_stds = 0.380 ± 0.088, action_magnitude = 0.834 ± 0.249, num_gradient_steps = 1390998, step_time = 11.56, total_time = 61.08
#
#
# step = 1402000, num_env_steps = 1402000, scores = 13.483 ± 1.36 (n=2), actor_loss = -13.939, critic_loss = 0.102, entropy_coef_loss = 80.277, entropy_coef = 0.001, action_stds = 0.402 ± 0.067, action_magnitude = 0.828 ± 0.254, num_gradient_steps = 1391998, step_time = 11.58, total_time = 72.66
#
#
# step = 1403000, num_env_steps = 1403000, scores = 12.540 ± 0.62 (n=2), actor_loss = -14.306, critic_loss = 0.101, entropy_coef_loss = 90.390, entropy_coef = 0.001, action_stds = 0.366 ± 0.063, action_magnitude = 0.823 ± 0.256, num_gradient_steps = 1392998, step_time = 11.17, total_time = 83.83
#
#
# step = 1404000, num_env_steps = 1404000, scores = 14.176 ± 0.04 (n=2), actor_loss = -13.907, critic_loss = 0.100, entropy_coef_loss = 84.625, entropy_coef = 0.001, action_stds = 0.342 ± 0.053, action_magnitude = 0.829 ± 0.253, num_gradient_steps = 1393998, step_time = 12.14, total_time = 95.97
#
#
# step = 1405000, num_env_steps = 1405000, scores = 13.368 ± 0.43 (n=2), actor_loss = -14.196, critic_loss = 0.069, entropy_coef_loss = 75.702, entropy_coef = 0.001, action_stds = 0.416 ± 0.076, action_magnitude = 0.827 ± 0.253, num_gradient_steps = 1394998, step_time = 11.75, total_time = 107.71
#
#
# step = 1406000, num_env_steps = 1406000, scores = 13.352 ± 0.69 (n=2), actor_loss = -14.123, critic_loss = 0.075, entropy_coef_loss = 87.797, entropy_coef = 0.001, action_stds = 0.378 ± 0.073, action_magnitude = 0.827 ± 0.254, num_gradient_steps = 1395998, step_time = 11.88, total_time = 119.59
#
#
# step = 1407000, num_env_steps = 1407000, scores = 13.581 ± 0.03 (n=2), actor_loss = -14.379, critic_loss = 0.087, entropy_coef_loss = 83.090, entropy_coef = 0.001, action_stds = 0.376 ± 0.063, action_magnitude = 0.832 ± 0.252, num_gradient_steps = 1396998, step_time = 11.62, total_time = 131.22
#
#
# step = 1408000, num_env_steps = 1408000, scores = 13.588 ± 0.35 (n=2), actor_loss = -14.287, critic_loss = 0.071, entropy_coef_loss = 85.968, entropy_coef = 0.001, action_stds = 0.450 ± 0.128, action_magnitude = 0.833 ± 0.252, num_gradient_steps = 1397998, step_time = 11.40, total_time = 142.62
#
#
# step = 1409000, num_env_steps = 1409000, scores = 13.645 ± 0.25 (n=2), actor_loss = -14.630, critic_loss = 0.092, entropy_coef_loss = 84.873, entropy_coef = 0.001, action_stds = 0.310 ± 0.048, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1398998, step_time = 11.34, total_time = 153.96
#
#
# step = 1410000, num_env_steps = 1410000, scores = 13.958 ± 0.71 (n=2), actor_loss = -14.483, critic_loss = 0.076, entropy_coef_loss = 82.197, entropy_coef = 0.001, action_stds = 0.388 ± 0.099, action_magnitude = 0.832 ± 0.251, num_gradient_steps = 1399998, step_time = 11.90, total_time = 165.86
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1411000, num_env_steps = 1411000, scores = 15.068 ± 0.58 (n=2), actor_loss = -14.144, critic_loss = 0.112, entropy_coef_loss = 74.671, entropy_coef = 0.001, action_stds = 0.346 ± 0.048, action_magnitude = 0.834 ± 0.251, num_gradient_steps = 1400998, step_time = 11.91, total_time = 177.77
#
#
# step = 1412000, num_env_steps = 1412000, scores = 13.650 ± 0.12 (n=2), actor_loss = -14.030, critic_loss = 0.083, entropy_coef_loss = 71.583, entropy_coef = 0.001, action_stds = 0.404 ± 0.094, action_magnitude = 0.832 ± 0.252, num_gradient_steps = 1401998, step_time = 11.75, total_time = 189.53
#
#
# step = 1413000, num_env_steps = 1413000, scores = 13.729 ± 0.07 (n=2), actor_loss = -14.695, critic_loss = 0.112, entropy_coef_loss = 79.131, entropy_coef = 0.001, action_stds = 0.335 ± 0.046, action_magnitude = 0.825 ± 0.258, num_gradient_steps = 1402998, step_time = 11.76, total_time = 201.28
#
#
# step = 1414000, num_env_steps = 1414000, scores = 14.242 ± 0.58 (n=2), actor_loss = -14.422, critic_loss = 0.073, entropy_coef_loss = 74.682, entropy_coef = 0.001, action_stds = 0.379 ± 0.052, action_magnitude = 0.831 ± 0.254, num_gradient_steps = 1403998, step_time = 11.57, total_time = 212.85
#
#
# step = 1415000, num_env_steps = 1415000, scores = 13.470 ± 0.67 (n=2), actor_loss = -14.644, critic_loss = 0.078, entropy_coef_loss = 90.233, entropy_coef = 0.001, action_stds = 0.341 ± 0.075, action_magnitude = 0.830 ± 0.253, num_gradient_steps = 1404998, step_time = 11.45, total_time = 224.30
#
#
# step = 1416000, num_env_steps = 1416000, scores = 14.008 ± 0.95 (n=2), actor_loss = -14.489, critic_loss = 0.101, entropy_coef_loss = 92.035, entropy_coef = 0.001, action_stds = 0.365 ± 0.084, action_magnitude = 0.825 ± 0.255, num_gradient_steps = 1405998, step_time = 11.68, total_time = 235.99
#
#
# step = 1417000, num_env_steps = 1417000, scores = 13.927 ± 0.07 (n=2), actor_loss = -14.350, critic_loss = 0.076, entropy_coef_loss = 80.562, entropy_coef = 0.001, action_stds = 0.341 ± 0.074, action_magnitude = 0.828 ± 0.256, num_gradient_steps = 1406998, step_time = 11.73, total_time = 247.72
#
#
# step = 1418000, num_env_steps = 1418000, scores = 13.772 ± 0.19 (n=2), actor_loss = -14.880, critic_loss = 0.088, entropy_coef_loss = 82.934, entropy_coef = 0.001, action_stds = 0.376 ± 0.085, action_magnitude = 0.825 ± 0.257, num_gradient_steps = 1407998, step_time = 11.78, total_time = 259.50
#
#
# step = 1419000, num_env_steps = 1419000, scores = 14.604 ± 0.40 (n=2), actor_loss = -14.728, critic_loss = 0.071, entropy_coef_loss = 83.040, entropy_coef = 0.001, action_stds = 0.408 ± 0.100, action_magnitude = 0.829 ± 0.253, num_gradient_steps = 1408998, step_time = 11.81, total_time = 271.31
#
#
# step = 1420000, num_env_steps = 1420000, scores = 8.239 ± 3.07 (n=2), actor_loss = -14.926, critic_loss = 0.065, entropy_coef_loss = 86.946, entropy_coef = 0.001, action_stds = 0.378 ± 0.113, action_magnitude = 0.828 ± 0.253, num_gradient_steps = 1409998, step_time = 11.51, total_time = 282.82
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1421000, num_env_steps = 1421000, scores = 13.664 ± 0.58 (n=2), actor_loss = -14.641, critic_loss = 0.084, entropy_coef_loss = 82.876, entropy_coef = 0.001, action_stds = 0.414 ± 0.070, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1410998, step_time = 11.53, total_time = 294.35
#
#
# step = 1422000, num_env_steps = 1422000, scores = 13.141 ± 0.39 (n=2), actor_loss = -15.175, critic_loss = 0.088, entropy_coef_loss = 91.372, entropy_coef = 0.001, action_stds = 0.344 ± 0.046, action_magnitude = 0.819 ± 0.261, num_gradient_steps = 1411998, step_time = 11.33, total_time = 305.68
#
#
# step = 1423000, num_env_steps = 1423000, scores = 13.763 ± 0.55 (n=2), actor_loss = -14.471, critic_loss = 0.080, entropy_coef_loss = 89.056, entropy_coef = 0.001, action_stds = 0.331 ± 0.061, action_magnitude = 0.829 ± 0.256, num_gradient_steps = 1412998, step_time = 11.80, total_time = 317.48
#
#
# step = 1424000, num_env_steps = 1424000, scores = 13.546 ± 0.39 (n=2), actor_loss = -14.990, critic_loss = 0.091, entropy_coef_loss = 81.856, entropy_coef = 0.001, action_stds = 0.401 ± 0.076, action_magnitude = 0.828 ± 0.253, num_gradient_steps = 1413998, step_time = 11.78, total_time = 329.26
#
#
# step = 1425000, num_env_steps = 1425000, scores = 12.090 ± 0.22 (n=2), actor_loss = -14.315, critic_loss = 0.090, entropy_coef_loss = 77.157, entropy_coef = 0.001, action_stds = 0.407 ± 0.080, action_magnitude = 0.822 ± 0.258, num_gradient_steps = 1414998, step_time = 12.50, total_time = 341.76
#
#
# step = 1426000, num_env_steps = 1426000, scores = 13.410 ± 0.17 (n=2), actor_loss = -14.970, critic_loss = 0.081, entropy_coef_loss = 89.208, entropy_coef = 0.001, action_stds = 0.385 ± 0.090, action_magnitude = 0.824 ± 0.256, num_gradient_steps = 1415998, step_time = 11.29, total_time = 353.05
#
#
# step = 1427000, num_env_steps = 1427000, scores = 13.954 ± 0.99 (n=2), actor_loss = -15.013, critic_loss = 0.085, entropy_coef_loss = 90.855, entropy_coef = 0.001, action_stds = 0.362 ± 0.082, action_magnitude = 0.833 ± 0.253, num_gradient_steps = 1416998, step_time = 12.11, total_time = 365.16
#
#
# step = 1428000, num_env_steps = 1428000, scores = 13.257 ± 0.33 (n=2), actor_loss = -14.674, critic_loss = 0.092, entropy_coef_loss = 80.561, entropy_coef = 0.001, action_stds = 0.360 ± 0.071, action_magnitude = 0.831 ± 0.252, num_gradient_steps = 1417998, step_time = 9.20, total_time = 374.36
#
#
# step = 1429000, num_env_steps = 1429000, scores = 12.926 ± 0.09 (n=2), actor_loss = -14.640, critic_loss = 0.075, entropy_coef_loss = 85.114, entropy_coef = 0.001, action_stds = 0.354 ± 0.077, action_magnitude = 0.833 ± 0.251, num_gradient_steps = 1418998, step_time = 8.62, total_time = 382.98
#
#
# step = 1430000, num_env_steps = 1430000, scores = 13.876 ± 0.40 (n=2), actor_loss = -14.341, critic_loss = 0.071, entropy_coef_loss = 88.108, entropy_coef = 0.001, action_stds = 0.364 ± 0.071, action_magnitude = 0.837 ± 0.247, num_gradient_steps = 1419998, step_time = 8.96, total_time = 391.94
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1431000, num_env_steps = 1431000, scores = 14.211 ± 0.09 (n=2), actor_loss = -14.948, critic_loss = 0.083, entropy_coef_loss = 94.531, entropy_coef = 0.001, action_stds = 0.353 ± 0.061, action_magnitude = 0.836 ± 0.250, num_gradient_steps = 1420998, step_time = 9.45, total_time = 401.39
#
#
# step = 1432000, num_env_steps = 1432000, scores = 13.689 ± 0.24 (n=2), actor_loss = -15.052, critic_loss = 0.098, entropy_coef_loss = 87.831, entropy_coef = 0.001, action_stds = 0.338 ± 0.048, action_magnitude = 0.836 ± 0.248, num_gradient_steps = 1421998, step_time = 8.47, total_time = 409.86
#
#
# step = 1433000, num_env_steps = 1433000, scores = 13.223 ± 0.94 (n=2), actor_loss = -15.162, critic_loss = 0.098, entropy_coef_loss = 93.483, entropy_coef = 0.001, action_stds = 0.339 ± 0.070, action_magnitude = 0.831 ± 0.254, num_gradient_steps = 1422998, step_time = 8.29, total_time = 418.15
#
#
# step = 1434000, num_env_steps = 1434000, scores = 14.243 ± 0.62 (n=2), actor_loss = -15.676, critic_loss = 0.093, entropy_coef_loss = 94.577, entropy_coef = 0.001, action_stds = 0.364 ± 0.063, action_magnitude = 0.837 ± 0.250, num_gradient_steps = 1423998, step_time = 8.03, total_time = 426.18
#
#
# step = 1435000, num_env_steps = 1435000, scores = 13.683 ± 0.51 (n=2), actor_loss = -15.000, critic_loss = 0.096, entropy_coef_loss = 89.171, entropy_coef = 0.001, action_stds = 0.353 ± 0.067, action_magnitude = 0.832 ± 0.250, num_gradient_steps = 1424998, step_time = 7.99, total_time = 434.18
#
#
# step = 1436000, num_env_steps = 1436000, scores = 13.280 ± 0.07 (n=2), actor_loss = -15.043, critic_loss = 0.090, entropy_coef_loss = 84.044, entropy_coef = 0.001, action_stds = 0.377 ± 0.101, action_magnitude = 0.837 ± 0.251, num_gradient_steps = 1425998, step_time = 8.01, total_time = 442.19
#
#
# step = 1437000, num_env_steps = 1437000, scores = 14.463 ± 0.31 (n=2), actor_loss = -16.179, critic_loss = 0.087, entropy_coef_loss = 89.351, entropy_coef = 0.001, action_stds = 0.364 ± 0.062, action_magnitude = 0.837 ± 0.247, num_gradient_steps = 1426998, step_time = 7.99, total_time = 450.17
#
#
# step = 1438000, num_env_steps = 1438000, scores = 13.751 ± 0.73 (n=2), actor_loss = -14.694, critic_loss = 0.088, entropy_coef_loss = 88.287, entropy_coef = 0.001, action_stds = 0.388 ± 0.074, action_magnitude = 0.831 ± 0.252, num_gradient_steps = 1427998, step_time = 8.27, total_time = 458.44
#
#
# step = 1439000, num_env_steps = 1439000, scores = 13.256 ± 1.07 (n=2), actor_loss = -15.100, critic_loss = 0.080, entropy_coef_loss = 82.653, entropy_coef = 0.001, action_stds = 0.376 ± 0.103, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1428998, step_time = 8.05, total_time = 466.49
#
#
# step = 1440000, num_env_steps = 1440000, scores = 13.756 ± 1.01 (n=2), actor_loss = -15.247, critic_loss = 0.084, entropy_coef_loss = 88.332, entropy_coef = 0.001, action_stds = 0.363 ± 0.073, action_magnitude = 0.829 ± 0.253, num_gradient_steps = 1429998, step_time = 8.05, total_time = 474.53
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1441000, num_env_steps = 1441000, scores = 14.121 ± 0.43 (n=2), actor_loss = -14.910, critic_loss = 0.075, entropy_coef_loss = 87.245, entropy_coef = 0.001, action_stds = 0.415 ± 0.116, action_magnitude = 0.830 ± 0.253, num_gradient_steps = 1430998, step_time = 8.11, total_time = 482.64
#
#
# step = 1442000, num_env_steps = 1442000, scores = 13.193 ± 0.33 (n=2), actor_loss = -15.634, critic_loss = 0.070, entropy_coef_loss = 84.235, entropy_coef = 0.001, action_stds = 0.346 ± 0.067, action_magnitude = 0.826 ± 0.254, num_gradient_steps = 1431998, step_time = 8.03, total_time = 490.68
#
#
# step = 1443000, num_env_steps = 1443000, scores = 13.187 ± 0.04 (n=2), actor_loss = -15.236, critic_loss = 0.076, entropy_coef_loss = 82.945, entropy_coef = 0.001, action_stds = 0.372 ± 0.085, action_magnitude = 0.827 ± 0.253, num_gradient_steps = 1432998, step_time = 8.04, total_time = 498.72
#
#
# step = 1444000, num_env_steps = 1444000, scores = 14.257 ± 0.24 (n=2), actor_loss = -15.582, critic_loss = 0.060, entropy_coef_loss = 93.615, entropy_coef = 0.001, action_stds = 0.360 ± 0.086, action_magnitude = 0.831 ± 0.250, num_gradient_steps = 1433998, step_time = 8.03, total_time = 506.75
#
#
# step = 1445000, num_env_steps = 1445000, scores = 13.477 ± 0.12 (n=2), actor_loss = -15.277, critic_loss = 0.097, entropy_coef_loss = 79.724, entropy_coef = 0.001, action_stds = 0.333 ± 0.071, action_magnitude = 0.831 ± 0.252, num_gradient_steps = 1434998, step_time = 8.01, total_time = 514.76
#
#
# step = 1446000, num_env_steps = 1446000, scores = 12.974 ± 0.35 (n=2), actor_loss = -15.519, critic_loss = 0.102, entropy_coef_loss = 89.044, entropy_coef = 0.001, action_stds = 0.349 ± 0.071, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1435998, step_time = 8.02, total_time = 522.78
#
#
# step = 1447000, num_env_steps = 1447000, scores = 13.686 ± 0.02 (n=2), actor_loss = -15.433, critic_loss = 0.242, entropy_coef_loss = 96.154, entropy_coef = 0.001, action_stds = 0.345 ± 0.069, action_magnitude = 0.833 ± 0.250, num_gradient_steps = 1436998, step_time = 8.03, total_time = 530.81
#
#
# step = 1448000, num_env_steps = 1448000, scores = 14.334 ± 0.37 (n=2), actor_loss = -15.040, critic_loss = 0.089, entropy_coef_loss = 91.075, entropy_coef = 0.001, action_stds = 0.359 ± 0.084, action_magnitude = 0.829 ± 0.254, num_gradient_steps = 1437998, step_time = 7.98, total_time = 538.80
#
#
# step = 1449000, num_env_steps = 1449000, scores = 14.598 ± 0.23 (n=2), actor_loss = -15.945, critic_loss = 0.127, entropy_coef_loss = 101.326, entropy_coef = 0.001, action_stds = 0.366 ± 0.084, action_magnitude = 0.833 ± 0.252, num_gradient_steps = 1438998, step_time = 8.00, total_time = 546.79
#
#
# step = 1450000, num_env_steps = 1450000, scores = 14.886 ± 0.45 (n=2), actor_loss = -15.432, critic_loss = 0.102, entropy_coef_loss = 89.584, entropy_coef = 0.001, action_stds = 0.450 ± 0.103, action_magnitude = 0.835 ± 0.249, num_gradient_steps = 1439998, step_time = 8.01, total_time = 554.81
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1451000, num_env_steps = 1451000, scores = 14.273 ± 0.41 (n=2), actor_loss = -14.837, critic_loss = 0.080, entropy_coef_loss = 75.898, entropy_coef = 0.001, action_stds = 0.358 ± 0.078, action_magnitude = 0.835 ± 0.249, num_gradient_steps = 1440998, step_time = 8.03, total_time = 562.84
#
#
# step = 1452000, num_env_steps = 1452000, scores = 15.155 ± 0.46 (n=2), actor_loss = -15.657, critic_loss = 0.082, entropy_coef_loss = 84.457, entropy_coef = 0.001, action_stds = 0.359 ± 0.119, action_magnitude = 0.842 ± 0.243, num_gradient_steps = 1441998, step_time = 8.03, total_time = 570.87
#
#
# step = 1453000, num_env_steps = 1453000, scores = 14.461 ± 0.25 (n=2), actor_loss = -15.781, critic_loss = 0.081, entropy_coef_loss = 97.885, entropy_coef = 0.001, action_stds = 0.345 ± 0.073, action_magnitude = 0.833 ± 0.250, num_gradient_steps = 1442998, step_time = 8.01, total_time = 578.88
#
#
# step = 1454000, num_env_steps = 1454000, scores = 13.905 ± 0.80 (n=2), actor_loss = -15.756, critic_loss = 0.095, entropy_coef_loss = 88.518, entropy_coef = 0.001, action_stds = 0.342 ± 0.064, action_magnitude = 0.831 ± 0.249, num_gradient_steps = 1443998, step_time = 8.02, total_time = 586.90
#
#
# step = 1455000, num_env_steps = 1455000, scores = 13.185 ± 1.03 (n=2), actor_loss = -15.876, critic_loss = 0.093, entropy_coef_loss = 92.139, entropy_coef = 0.001, action_stds = 0.336 ± 0.072, action_magnitude = 0.832 ± 0.251, num_gradient_steps = 1444998, step_time = 8.00, total_time = 594.90
#
#
# step = 1456000, num_env_steps = 1456000, scores = 13.621 ± 0.31 (n=2), actor_loss = -15.515, critic_loss = 0.084, entropy_coef_loss = 89.610, entropy_coef = 0.001, action_stds = 0.333 ± 0.098, action_magnitude = 0.827 ± 0.256, num_gradient_steps = 1445998, step_time = 8.00, total_time = 602.90
#
#
# step = 1457000, num_env_steps = 1457000, scores = 14.860 ± 0.56 (n=2), actor_loss = -15.893, critic_loss = 0.087, entropy_coef_loss = 94.729, entropy_coef = 0.001, action_stds = 0.319 ± 0.080, action_magnitude = 0.833 ± 0.251, num_gradient_steps = 1446998, step_time = 8.01, total_time = 610.91
#
#
# step = 1458000, num_env_steps = 1458000, scores = 13.477 ± 0.94 (n=2), actor_loss = -15.631, critic_loss = 0.091, entropy_coef_loss = 98.076, entropy_coef = 0.001, action_stds = 0.355 ± 0.106, action_magnitude = 0.829 ± 0.253, num_gradient_steps = 1447998, step_time = 8.00, total_time = 618.91
#
#
# step = 1459000, num_env_steps = 1459000, scores = 13.825 ± 0.91 (n=2), actor_loss = -14.927, critic_loss = 0.070, entropy_coef_loss = 84.546, entropy_coef = 0.001, action_stds = 0.320 ± 0.068, action_magnitude = 0.830 ± 0.251, num_gradient_steps = 1448998, step_time = 8.01, total_time = 626.92
#
#
# step = 1460000, num_env_steps = 1460000, scores = 13.529 ± 0.33 (n=2), actor_loss = -15.634, critic_loss = 0.065, entropy_coef_loss = 96.970, entropy_coef = 0.001, action_stds = 0.322 ± 0.068, action_magnitude = 0.822 ± 0.259, num_gradient_steps = 1449998, step_time = 8.00, total_time = 634.92
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1461000, num_env_steps = 1461000, scores = 13.966 ± 0.01 (n=2), actor_loss = -15.416, critic_loss = 0.069, entropy_coef_loss = 91.862, entropy_coef = 0.001, action_stds = 0.371 ± 0.072, action_magnitude = 0.828 ± 0.254, num_gradient_steps = 1450998, step_time = 8.03, total_time = 642.95
#
#
# step = 1462000, num_env_steps = 1462000, scores = 13.188 ± 0.08 (n=2), actor_loss = -16.021, critic_loss = 0.087, entropy_coef_loss = 94.290, entropy_coef = 0.001, action_stds = 0.369 ± 0.109, action_magnitude = 0.828 ± 0.256, num_gradient_steps = 1451998, step_time = 8.00, total_time = 650.95
#
#
# step = 1463000, num_env_steps = 1463000, scores = 14.559 ± 0.42 (n=2), actor_loss = -15.352, critic_loss = 0.099, entropy_coef_loss = 89.607, entropy_coef = 0.001, action_stds = 0.324 ± 0.061, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1452998, step_time = 7.97, total_time = 658.92
#
#
# step = 1464000, num_env_steps = 1464000, scores = 13.698 ± 1.04 (n=2), actor_loss = -15.668, critic_loss = 0.074, entropy_coef_loss = 88.301, entropy_coef = 0.001, action_stds = 0.374 ± 0.052, action_magnitude = 0.828 ± 0.253, num_gradient_steps = 1453998, step_time = 7.99, total_time = 666.92
#
#
# step = 1465000, num_env_steps = 1465000, scores = 14.821 ± 0.21 (n=2), actor_loss = -15.377, critic_loss = 0.087, entropy_coef_loss = 98.687, entropy_coef = 0.001, action_stds = 0.338 ± 0.055, action_magnitude = 0.837 ± 0.248, num_gradient_steps = 1454998, step_time = 7.97, total_time = 674.89
#
#
# step = 1466000, num_env_steps = 1466000, scores = 14.718 ± 0.01 (n=2), actor_loss = -15.939, critic_loss = 0.076, entropy_coef_loss = 104.254, entropy_coef = 0.001, action_stds = 0.401 ± 0.134, action_magnitude = 0.837 ± 0.249, num_gradient_steps = 1455998, step_time = 8.03, total_time = 682.91
#
#
# step = 1467000, num_env_steps = 1467000, scores = 14.011 ± 0.37 (n=2), actor_loss = -15.833, critic_loss = 0.075, entropy_coef_loss = 85.005, entropy_coef = 0.001, action_stds = 0.359 ± 0.094, action_magnitude = 0.828 ± 0.255, num_gradient_steps = 1456998, step_time = 8.00, total_time = 690.91
#
#
# step = 1468000, num_env_steps = 1468000, scores = 15.444 ± 0.42 (n=2), actor_loss = -15.689, critic_loss = 0.098, entropy_coef_loss = 94.771, entropy_coef = 0.001, action_stds = 0.393 ± 0.110, action_magnitude = 0.842 ± 0.245, num_gradient_steps = 1457998, step_time = 8.01, total_time = 698.92
#
#
# step = 1469000, num_env_steps = 1469000, scores = 12.726 ± 0.36 (n=2), actor_loss = -16.150, critic_loss = 0.096, entropy_coef_loss = 92.743, entropy_coef = 0.001, action_stds = 0.384 ± 0.077, action_magnitude = 0.832 ± 0.251, num_gradient_steps = 1458998, step_time = 7.98, total_time = 706.90
#
#
# step = 1470000, num_env_steps = 1470000, scores = 15.049 ± 0.75 (n=2), actor_loss = -16.076, critic_loss = 0.109, entropy_coef_loss = 87.022, entropy_coef = 0.001, action_stds = 0.346 ± 0.077, action_magnitude = 0.841 ± 0.249, num_gradient_steps = 1459998, step_time = 8.00, total_time = 714.91
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1471000, num_env_steps = 1471000, scores = 14.832 ± 0.16 (n=2), actor_loss = -15.952, critic_loss = 0.121, entropy_coef_loss = 98.082, entropy_coef = 0.001, action_stds = 0.353 ± 0.071, action_magnitude = 0.840 ± 0.246, num_gradient_steps = 1460998, step_time = 8.03, total_time = 722.94
#
#
# step = 1472000, num_env_steps = 1472000, scores = 14.033 ± 0.78 (n=2), actor_loss = -15.949, critic_loss = 0.106, entropy_coef_loss = 94.188, entropy_coef = 0.001, action_stds = 0.366 ± 0.097, action_magnitude = 0.831 ± 0.254, num_gradient_steps = 1461998, step_time = 7.96, total_time = 730.90
#
#
# step = 1473000, num_env_steps = 1473000, scores = 14.483 ± 0.58 (n=2), actor_loss = -15.869, critic_loss = 0.074, entropy_coef_loss = 94.303, entropy_coef = 0.001, action_stds = 0.413 ± 0.081, action_magnitude = 0.836 ± 0.250, num_gradient_steps = 1462998, step_time = 7.97, total_time = 738.87
#
#
# step = 1474000, num_env_steps = 1474000, scores = 14.228 ± 0.47 (n=2), actor_loss = -16.200, critic_loss = 0.075, entropy_coef_loss = 90.732, entropy_coef = 0.001, action_stds = 0.376 ± 0.088, action_magnitude = 0.838 ± 0.247, num_gradient_steps = 1463998, step_time = 8.03, total_time = 746.90
#
#
# step = 1475000, num_env_steps = 1475000, scores = 14.586 ± 0.23 (n=2), actor_loss = -15.712, critic_loss = 0.115, entropy_coef_loss = 98.951, entropy_coef = 0.001, action_stds = 0.368 ± 0.060, action_magnitude = 0.839 ± 0.249, num_gradient_steps = 1464998, step_time = 8.24, total_time = 755.14
#
#
# step = 1476000, num_env_steps = 1476000, scores = 14.463 ± 0.76 (n=2), actor_loss = -15.612, critic_loss = 0.099, entropy_coef_loss = 92.268, entropy_coef = 0.001, action_stds = 0.327 ± 0.080, action_magnitude = 0.832 ± 0.252, num_gradient_steps = 1465998, step_time = 8.25, total_time = 763.38
#
#
# step = 1477000, num_env_steps = 1477000, scores = 14.115 ± 0.47 (n=2), actor_loss = -16.160, critic_loss = 0.092, entropy_coef_loss = 108.687, entropy_coef = 0.001, action_stds = 0.314 ± 0.055, action_magnitude = 0.838 ± 0.248, num_gradient_steps = 1466998, step_time = 8.63, total_time = 772.01
#
#
# step = 1478000, num_env_steps = 1478000, scores = 14.484 ± 0.08 (n=2), actor_loss = -15.882, critic_loss = 0.097, entropy_coef_loss = 94.674, entropy_coef = 0.001, action_stds = 0.378 ± 0.104, action_magnitude = 0.836 ± 0.250, num_gradient_steps = 1467998, step_time = 9.17, total_time = 781.19
#
#
# step = 1479000, num_env_steps = 1479000, scores = 14.913 ± 0.74 (n=2), actor_loss = -16.046, critic_loss = 0.116, entropy_coef_loss = 101.485, entropy_coef = 0.001, action_stds = 0.330 ± 0.084, action_magnitude = 0.838 ± 0.250, num_gradient_steps = 1468998, step_time = 9.79, total_time = 790.98
#
#
# step = 1480000, num_env_steps = 1480000, scores = 13.077 ± 0.33 (n=2), actor_loss = -15.727, critic_loss = 0.108, entropy_coef_loss = 98.045, entropy_coef = 0.001, action_stds = 0.334 ± 0.098, action_magnitude = 0.825 ± 0.258, num_gradient_steps = 1469998, step_time = 10.96, total_time = 801.94
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1481000, num_env_steps = 1481000, scores = 14.320 ± 0.44 (n=2), actor_loss = -15.781, critic_loss = 0.076, entropy_coef_loss = 100.020, entropy_coef = 0.001, action_stds = 0.368 ± 0.089, action_magnitude = 0.837 ± 0.248, num_gradient_steps = 1470998, step_time = 11.87, total_time = 813.81
#
#
# step = 1482000, num_env_steps = 1482000, scores = 14.064 ± 1.64 (n=2), actor_loss = -15.767, critic_loss = 0.102, entropy_coef_loss = 95.305, entropy_coef = 0.001, action_stds = 0.347 ± 0.101, action_magnitude = 0.832 ± 0.250, num_gradient_steps = 1471998, step_time = 11.13, total_time = 824.94
#
#
# step = 1483000, num_env_steps = 1483000, scores = 15.002 ± 0.03 (n=2), actor_loss = -16.072, critic_loss = 0.098, entropy_coef_loss = 95.757, entropy_coef = 0.001, action_stds = 0.305 ± 0.072, action_magnitude = 0.834 ± 0.249, num_gradient_steps = 1472998, step_time = 10.33, total_time = 835.27
#
#
# step = 1484000, num_env_steps = 1484000, scores = 13.497 ± 1.04 (n=2), actor_loss = -16.054, critic_loss = 0.116, entropy_coef_loss = 100.573, entropy_coef = 0.001, action_stds = 0.294 ± 0.074, action_magnitude = 0.827 ± 0.257, num_gradient_steps = 1473998, step_time = 10.23, total_time = 845.49
#
#
# step = 1485000, num_env_steps = 1485000, scores = 14.870 ± 0.06 (n=2), actor_loss = -15.980, critic_loss = 0.078, entropy_coef_loss = 101.940, entropy_coef = 0.001, action_stds = 0.395 ± 0.100, action_magnitude = 0.835 ± 0.250, num_gradient_steps = 1474998, step_time = 10.09, total_time = 855.58
#
#
# step = 1486000, num_env_steps = 1486000, scores = 13.886 ± 0.75 (n=2), actor_loss = -16.221, critic_loss = 0.086, entropy_coef_loss = 99.649, entropy_coef = 0.001, action_stds = 0.344 ± 0.060, action_magnitude = 0.832 ± 0.252, num_gradient_steps = 1475998, step_time = 10.06, total_time = 865.64
#
#
# step = 1487000, num_env_steps = 1487000, scores = 14.701 ± 0.60 (n=2), actor_loss = -16.098, critic_loss = 0.094, entropy_coef_loss = 111.102, entropy_coef = 0.001, action_stds = 0.332 ± 0.089, action_magnitude = 0.840 ± 0.246, num_gradient_steps = 1476998, step_time = 10.24, total_time = 875.88
#
#
# step = 1488000, num_env_steps = 1488000, scores = 14.109 ± 0.03 (n=2), actor_loss = -16.315, critic_loss = 0.087, entropy_coef_loss = 96.901, entropy_coef = 0.001, action_stds = 0.316 ± 0.076, action_magnitude = 0.837 ± 0.248, num_gradient_steps = 1477998, step_time = 10.19, total_time = 886.07
#
#
# step = 1489000, num_env_steps = 1489000, scores = 13.774 ± 0.68 (n=2), actor_loss = -15.876, critic_loss = 0.103, entropy_coef_loss = 106.876, entropy_coef = 0.001, action_stds = 0.338 ± 0.091, action_magnitude = 0.834 ± 0.250, num_gradient_steps = 1478998, step_time = 10.22, total_time = 896.30
#
#
# step = 1490000, num_env_steps = 1490000, scores = 14.631 ± 1.60 (n=2), actor_loss = -15.942, critic_loss = 0.067, entropy_coef_loss = 92.978, entropy_coef = 0.001, action_stds = 0.292 ± 0.049, action_magnitude = 0.833 ± 0.252, num_gradient_steps = 1479998, step_time = 10.02, total_time = 906.32
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1491000, num_env_steps = 1491000, scores = 13.142 ± 1.82 (n=2), actor_loss = -16.137, critic_loss = 0.115, entropy_coef_loss = 108.318, entropy_coef = 0.001, action_stds = 0.369 ± 0.103, action_magnitude = 0.837 ± 0.249, num_gradient_steps = 1480998, step_time = 10.13, total_time = 916.45
#
#
# step = 1492000, num_env_steps = 1492000, scores = 13.914 ± 1.03 (n=2), actor_loss = -16.035, critic_loss = 0.215, entropy_coef_loss = 91.728, entropy_coef = 0.001, action_stds = 0.323 ± 0.088, action_magnitude = 0.834 ± 0.250, num_gradient_steps = 1481998, step_time = 10.08, total_time = 926.53
#
#
# step = 1493000, num_env_steps = 1493000, scores = 13.718 ± 0.08 (n=2), actor_loss = -16.586, critic_loss = 0.098, entropy_coef_loss = 102.493, entropy_coef = 0.001, action_stds = 0.382 ± 0.082, action_magnitude = 0.836 ± 0.248, num_gradient_steps = 1482998, step_time = 10.02, total_time = 936.55
#
#
# step = 1494000, num_env_steps = 1494000, scores = 14.115 ± 0.26 (n=2), actor_loss = -16.880, critic_loss = 0.113, entropy_coef_loss = 100.855, entropy_coef = 0.001, action_stds = 0.373 ± 0.094, action_magnitude = 0.838 ± 0.247, num_gradient_steps = 1483998, step_time = 9.93, total_time = 946.48
#
#
# step = 1495000, num_env_steps = 1495000, scores = 13.958 ± 0.90 (n=2), actor_loss = -16.142, critic_loss = 0.104, entropy_coef_loss = 106.098, entropy_coef = 0.001, action_stds = 0.373 ± 0.123, action_magnitude = 0.830 ± 0.252, num_gradient_steps = 1484998, step_time = 10.03, total_time = 956.51
#
#
# step = 1496000, num_env_steps = 1496000, scores = 13.747 ± 0.28 (n=2), actor_loss = -16.671, critic_loss = 0.110, entropy_coef_loss = 113.452, entropy_coef = 0.001, action_stds = 0.390 ± 0.117, action_magnitude = 0.829 ± 0.254, num_gradient_steps = 1485998, step_time = 10.12, total_time = 966.63
#
#
# step = 1497000, num_env_steps = 1497000, scores = 13.151 ± 0.23 (n=2), actor_loss = -16.523, critic_loss = 0.086, entropy_coef_loss = 101.328, entropy_coef = 0.001, action_stds = 0.360 ± 0.119, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1486998, step_time = 10.40, total_time = 977.03
#
#
# step = 1498000, num_env_steps = 1498000, scores = 14.332 ± 0.14 (n=2), actor_loss = -16.164, critic_loss = 0.131, entropy_coef_loss = 109.040, entropy_coef = 0.001, action_stds = 0.370 ± 0.115, action_magnitude = 0.835 ± 0.250, num_gradient_steps = 1487998, step_time = 9.44, total_time = 986.47
#
#
# step = 1499000, num_env_steps = 1499000, scores = 15.076 ± 0.03 (n=2), actor_loss = -16.407, critic_loss = 0.080, entropy_coef_loss = 108.534, entropy_coef = 0.001, action_stds = 0.336 ± 0.123, action_magnitude = 0.840 ± 0.247, num_gradient_steps = 1488998, step_time = 9.38, total_time = 995.84
#
#
# step = 1500000, num_env_steps = 1500000, scores = 13.516 ± 0.77 (n=2), actor_loss = -16.368, critic_loss = 0.157, entropy_coef_loss = 102.011, entropy_coef = 0.001, action_stds = 0.327 ± 0.092, action_magnitude = 0.838 ± 0.249, num_gradient_steps = 1489998, step_time = 9.29, total_time = 1005.13
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1501000, num_env_steps = 1501000, scores = 15.026 ± 0.50 (n=2), actor_loss = -16.179, critic_loss = 0.104, entropy_coef_loss = 103.287, entropy_coef = 0.001, action_stds = 0.331 ± 0.078, action_magnitude = 0.837 ± 0.250, num_gradient_steps = 1490998, step_time = 9.52, total_time = 1014.65
#
#
# step = 1502000, num_env_steps = 1502000, scores = 4.631 ± 9.88 (n=2), actor_loss = -16.847, critic_loss = 0.109, entropy_coef_loss = 118.427, entropy_coef = 0.001, action_stds = 0.349 ± 0.094, action_magnitude = 0.886 ± 0.216, num_gradient_steps = 1491998, step_time = 9.36, total_time = 1024.01
#
#
# step = 1503000, num_env_steps = 1503000, scores = 13.660 ± 0.51 (n=2), actor_loss = -17.549, critic_loss = 0.114, entropy_coef_loss = 119.233, entropy_coef = 0.001, action_stds = 0.382 ± 0.103, action_magnitude = 0.840 ± 0.249, num_gradient_steps = 1492998, step_time = 9.33, total_time = 1033.34
#
#
# step = 1504000, num_env_steps = 1504000, scores = 1.184 ± 4.88 (n=2), actor_loss = -17.035, critic_loss = 0.097, entropy_coef_loss = 117.178, entropy_coef = 0.001, action_stds = 0.325 ± 0.087, action_magnitude = 0.838 ± 0.246, num_gradient_steps = 1493998, step_time = 9.14, total_time = 1042.48
#
#
# step = 1505000, num_env_steps = 1505000, scores = 11.995 ± 0.56 (n=2), actor_loss = -16.891, critic_loss = 0.144, entropy_coef_loss = 131.274, entropy_coef = 0.001, action_stds = 0.384 ± 0.097, action_magnitude = 0.834 ± 0.251, num_gradient_steps = 1494998, step_time = 9.16, total_time = 1051.64
#
#
# step = 1506000, num_env_steps = 1506000, scores = -4.564 ± 0.24 (n=2), actor_loss = -17.711, critic_loss = 0.136, entropy_coef_loss = 134.226, entropy_coef = 0.001, action_stds = 0.359 ± 0.094, action_magnitude = 0.813 ± 0.272, num_gradient_steps = 1495998, step_time = 9.15, total_time = 1060.79
#
#
# step = 1507000, num_env_steps = 1507000, scores = -4.981 ± 0.04 (n=2), actor_loss = -17.696, critic_loss = 0.161, entropy_coef_loss = 122.675, entropy_coef = 0.001, action_stds = 0.286 ± 0.086, action_magnitude = 0.779 ± 0.280, num_gradient_steps = 1496998, step_time = 9.09, total_time = 1069.89
#
#
# step = 1508000, num_env_steps = 1508000, scores = -5.249 ± 0.31 (n=2), actor_loss = -17.881, critic_loss = 0.227, entropy_coef_loss = 136.287, entropy_coef = 0.001, action_stds = 0.339 ± 0.106, action_magnitude = 0.788 ± 0.290, num_gradient_steps = 1497998, step_time = 9.25, total_time = 1079.14
#
#
# step = 1509000, num_env_steps = 1509000, scores = -5.845 ± 0.22 (n=2), actor_loss = -18.026, critic_loss = 0.229, entropy_coef_loss = 134.300, entropy_coef = 0.001, action_stds = 0.387 ± 0.100, action_magnitude = 0.845 ± 0.254, num_gradient_steps = 1498998, step_time = 9.03, total_time = 1088.17
#
#
# step = 1510000, num_env_steps = 1510000, scores = -5.493 ± 0.29 (n=2), actor_loss = -17.849, critic_loss = 0.118, entropy_coef_loss = 135.238, entropy_coef = 0.001, action_stds = 0.391 ± 0.109, action_magnitude = 0.842 ± 0.250, num_gradient_steps = 1499998, step_time = 9.00, total_time = 1097.17
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1511000, num_env_steps = 1511000, scores = -6.300 ± 0.31 (n=2), actor_loss = -18.388, critic_loss = 0.162, entropy_coef_loss = 132.921, entropy_coef = 0.001, action_stds = 0.382 ± 0.103, action_magnitude = 0.933 ± 0.168, num_gradient_steps = 1500998, step_time = 9.22, total_time = 1106.39
#
#
# step = 1512000, num_env_steps = 1512000, scores = -5.831 ± 0.80 (n=2), actor_loss = -18.224, critic_loss = 0.151, entropy_coef_loss = 118.861, entropy_coef = 0.001, action_stds = 0.367 ± 0.097, action_magnitude = 0.873 ± 0.224, num_gradient_steps = 1501998, step_time = 9.11, total_time = 1115.50
#
#
# step = 1513000, num_env_steps = 1513000, scores = -4.263 ± 0.10 (n=2), actor_loss = -18.591, critic_loss = 0.144, entropy_coef_loss = 120.372, entropy_coef = 0.001, action_stds = 0.339 ± 0.128, action_magnitude = 0.734 ± 0.303, num_gradient_steps = 1502998, step_time = 9.13, total_time = 1124.63
#
#
# step = 1514000, num_env_steps = 1514000, scores = -4.390 ± 0.48 (n=2), actor_loss = -18.253, critic_loss = 0.139, entropy_coef_loss = 113.012, entropy_coef = 0.001, action_stds = 0.318 ± 0.093, action_magnitude = 0.730 ± 0.302, num_gradient_steps = 1503998, step_time = 8.98, total_time = 1133.61
#
#
# step = 1515000, num_env_steps = 1515000, scores = -3.880 ± 0.05 (n=2), actor_loss = -17.918, critic_loss = 0.127, entropy_coef_loss = 115.162, entropy_coef = 0.001, action_stds = 0.387 ± 0.088, action_magnitude = 0.736 ± 0.286, num_gradient_steps = 1504998, step_time = 9.05, total_time = 1142.66
#
#
# step = 1516000, num_env_steps = 1516000, scores = 3.169 ± 8.08 (n=2), actor_loss = -18.272, critic_loss = 0.114, entropy_coef_loss = 114.162, entropy_coef = 0.001, action_stds = 0.343 ± 0.109, action_magnitude = 0.812 ± 0.267, num_gradient_steps = 1505998, step_time = 9.18, total_time = 1151.84
#
#
# step = 1517000, num_env_steps = 1517000, scores = 4.373 ± 8.65 (n=2), actor_loss = -17.804, critic_loss = 0.105, entropy_coef_loss = 110.390, entropy_coef = 0.001, action_stds = 0.354 ± 0.119, action_magnitude = 0.783 ± 0.282, num_gradient_steps = 1506998, step_time = 9.19, total_time = 1161.03
#
#
# step = 1518000, num_env_steps = 1518000, scores = 13.095 ± 0.43 (n=2), actor_loss = -18.098, critic_loss = 0.130, entropy_coef_loss = 120.291, entropy_coef = 0.001, action_stds = 0.395 ± 0.093, action_magnitude = 0.832 ± 0.250, num_gradient_steps = 1507998, step_time = 9.14, total_time = 1170.17
#
#
# step = 1519000, num_env_steps = 1519000, scores = 10.790 ± 0.34 (n=2), actor_loss = -17.572, critic_loss = 0.112, entropy_coef_loss = 122.259, entropy_coef = 0.001, action_stds = 0.321 ± 0.057, action_magnitude = 0.813 ± 0.263, num_gradient_steps = 1508998, step_time = 9.16, total_time = 1179.33
#
#
# step = 1520000, num_env_steps = 1520000, scores = 12.795 ± 0.54 (n=2), actor_loss = -17.639, critic_loss = 0.114, entropy_coef_loss = 108.259, entropy_coef = 0.001, action_stds = 0.347 ± 0.075, action_magnitude = 0.828 ± 0.254, num_gradient_steps = 1509998, step_time = 9.24, total_time = 1188.57
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1521000, num_env_steps = 1521000, scores = 11.282 ± 1.64 (n=2), actor_loss = -17.331, critic_loss = 0.099, entropy_coef_loss = 108.858, entropy_coef = 0.001, action_stds = 0.330 ± 0.076, action_magnitude = 0.818 ± 0.258, num_gradient_steps = 1510998, step_time = 9.25, total_time = 1197.81
#
#
# step = 1522000, num_env_steps = 1522000, scores = 12.538 ± 0.63 (n=2), actor_loss = -17.509, critic_loss = 0.139, entropy_coef_loss = 110.952, entropy_coef = 0.001, action_stds = 0.390 ± 0.080, action_magnitude = 0.826 ± 0.258, num_gradient_steps = 1511998, step_time = 9.17, total_time = 1206.99
#
#
# step = 1523000, num_env_steps = 1523000, scores = 12.767 ± 0.22 (n=2), actor_loss = -17.260, critic_loss = 0.109, entropy_coef_loss = 103.823, entropy_coef = 0.001, action_stds = 0.417 ± 0.099, action_magnitude = 0.831 ± 0.253, num_gradient_steps = 1512998, step_time = 9.05, total_time = 1216.03
#
#
# step = 1524000, num_env_steps = 1524000, scores = 12.340 ± 0.19 (n=2), actor_loss = -17.127, critic_loss = 0.125, entropy_coef_loss = 110.588, entropy_coef = 0.001, action_stds = 0.291 ± 0.041, action_magnitude = 0.828 ± 0.254, num_gradient_steps = 1513998, step_time = 9.14, total_time = 1225.18
#
#
# step = 1525000, num_env_steps = 1525000, scores = 13.329 ± 0.94 (n=2), actor_loss = -17.328, critic_loss = 0.146, entropy_coef_loss = 117.343, entropy_coef = 0.001, action_stds = 0.351 ± 0.073, action_magnitude = 0.838 ± 0.248, num_gradient_steps = 1514998, step_time = 9.12, total_time = 1234.30
#
#
# step = 1526000, num_env_steps = 1526000, scores = 13.626 ± 1.02 (n=2), actor_loss = -17.069, critic_loss = 0.097, entropy_coef_loss = 107.384, entropy_coef = 0.001, action_stds = 0.335 ± 0.064, action_magnitude = 0.837 ± 0.247, num_gradient_steps = 1515998, step_time = 9.17, total_time = 1243.47
#
#
# step = 1527000, num_env_steps = 1527000, scores = 11.545 ± 0.11 (n=2), actor_loss = -17.266, critic_loss = 0.119, entropy_coef_loss = 120.384, entropy_coef = 0.001, action_stds = 0.368 ± 0.078, action_magnitude = 0.828 ± 0.251, num_gradient_steps = 1516998, step_time = 9.25, total_time = 1252.72
#
#
# step = 1528000, num_env_steps = 1528000, scores = 4.799 ± 8.81 (n=2), actor_loss = -16.390, critic_loss = 0.167, entropy_coef_loss = 113.182, entropy_coef = 0.001, action_stds = 0.340 ± 0.054, action_magnitude = 0.819 ± 0.258, num_gradient_steps = 1517998, step_time = 9.12, total_time = 1261.85
#
#
# step = 1529000, num_env_steps = 1529000, scores = 13.833 ± 0.98 (n=2), actor_loss = -16.835, critic_loss = 0.079, entropy_coef_loss = 100.626, entropy_coef = 0.001, action_stds = 0.360 ± 0.103, action_magnitude = 0.835 ± 0.249, num_gradient_steps = 1518998, step_time = 9.14, total_time = 1270.99
#
#
# step = 1530000, num_env_steps = 1530000, scores = 7.069 ± 5.96 (n=2), actor_loss = -16.176, critic_loss = 0.123, entropy_coef_loss = 120.525, entropy_coef = 0.001, action_stds = 0.389 ± 0.118, action_magnitude = 0.809 ± 0.274, num_gradient_steps = 1519998, step_time = 9.13, total_time = 1280.12
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1531000, num_env_steps = 1531000, scores = 13.799 ± 0.29 (n=2), actor_loss = -16.789, critic_loss = 0.094, entropy_coef_loss = 113.093, entropy_coef = 0.001, action_stds = 0.305 ± 0.056, action_magnitude = 0.839 ± 0.248, num_gradient_steps = 1520998, step_time = 9.26, total_time = 1289.38
#
#
# step = 1532000, num_env_steps = 1532000, scores = 12.775 ± 0.00 (n=2), actor_loss = -16.456, critic_loss = 0.188, entropy_coef_loss = 107.315, entropy_coef = 0.001, action_stds = 0.345 ± 0.052, action_magnitude = 0.841 ± 0.246, num_gradient_steps = 1521998, step_time = 9.14, total_time = 1298.52
#
#
# step = 1533000, num_env_steps = 1533000, scores = 14.715 ± 0.65 (n=2), actor_loss = -16.573, critic_loss = 0.147, entropy_coef_loss = 120.965, entropy_coef = 0.001, action_stds = 0.323 ± 0.047, action_magnitude = 0.845 ± 0.245, num_gradient_steps = 1522998, step_time = 9.12, total_time = 1307.64
#
#
# step = 1534000, num_env_steps = 1534000, scores = 13.353 ± 0.80 (n=2), actor_loss = -17.036, critic_loss = 0.107, entropy_coef_loss = 118.039, entropy_coef = 0.001, action_stds = 0.337 ± 0.065, action_magnitude = 0.839 ± 0.247, num_gradient_steps = 1523998, step_time = 9.08, total_time = 1316.72
#
#
# step = 1535000, num_env_steps = 1535000, scores = 13.393 ± 0.55 (n=2), actor_loss = -16.520, critic_loss = 0.120, entropy_coef_loss = 110.030, entropy_coef = 0.001, action_stds = 0.346 ± 0.098, action_magnitude = 0.843 ± 0.245, num_gradient_steps = 1524998, step_time = 9.13, total_time = 1325.85
#
#
# step = 1536000, num_env_steps = 1536000, scores = 13.825 ± 0.84 (n=2), actor_loss = -16.322, critic_loss = 0.121, entropy_coef_loss = 104.962, entropy_coef = 0.001, action_stds = 0.355 ± 0.069, action_magnitude = 0.843 ± 0.245, num_gradient_steps = 1525998, step_time = 9.23, total_time = 1335.07
#
#
# step = 1537000, num_env_steps = 1537000, scores = 5.532 ± 8.89 (n=2), actor_loss = -16.532, critic_loss = 0.187, entropy_coef_loss = 109.055, entropy_coef = 0.001, action_stds = 0.381 ± 0.090, action_magnitude = 0.846 ± 0.239, num_gradient_steps = 1526998, step_time = 9.01, total_time = 1344.09
#
#
# step = 1538000, num_env_steps = 1538000, scores = 14.150 ± 0.01 (n=2), actor_loss = -17.019, critic_loss = 0.089, entropy_coef_loss = 110.797, entropy_coef = 0.001, action_stds = 0.354 ± 0.084, action_magnitude = 0.840 ± 0.248, num_gradient_steps = 1527998, step_time = 9.01, total_time = 1353.10
#
#
# step = 1539000, num_env_steps = 1539000, scores = 14.305 ± 0.40 (n=2), actor_loss = -16.117, critic_loss = 0.221, entropy_coef_loss = 100.445, entropy_coef = 0.001, action_stds = 0.349 ± 0.057, action_magnitude = 0.840 ± 0.247, num_gradient_steps = 1528998, step_time = 9.10, total_time = 1362.20
#
#
# step = 1540000, num_env_steps = 1540000, scores = 8.600 ± 5.18 (n=2), actor_loss = -17.016, critic_loss = 0.115, entropy_coef_loss = 112.732, entropy_coef = 0.001, action_stds = 0.367 ± 0.075, action_magnitude = 0.840 ± 0.248, num_gradient_steps = 1529998, step_time = 9.13, total_time = 1371.33
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 1541000, num_env_steps = 1541000, scores = 13.893 ± 0.45 (n=2), actor_loss = -16.740, critic_loss = 0.103, entropy_coef_loss = 116.775, entropy_coef = 0.001, action_stds = 0.324 ± 0.059, action_magnitude = 0.841 ± 0.245, num_gradient_steps = 1530998, step_time = 9.23, total_time = 1380.56
#
#
# step = 1542000, num_env_steps = 1542000, scores = 14.299 ± 0.13 (n=2), actor_loss = -16.908, critic_loss = 0.399, entropy_coef_loss = 112.732, entropy_coef = 0.001, action_stds = 0.362 ± 0.066, action_magnitude = 0.843 ± 0.245, num_gradient_steps = 1531998, step_time = 9.11, total_time = 1389.67
#
#
# step = 1543000, num_env_steps = 1543000, scores = 14.002 ± 0.13 (n=2), actor_loss = -17.346, critic_loss = 0.107, entropy_coef_loss = 122.277, entropy_coef = 0.001, action_stds = 0.340 ± 0.064, action_magnitude = 0.845 ± 0.241, num_gradient_steps = 1532998, step_time = 9.01, total_time = 1398.69
#
#
# step = 1544000, num_env_steps = 1544000, scores = 14.505 ± 0.49 (n=2), actor_loss = -16.868, critic_loss = 0.122, entropy_coef_loss = 113.157, entropy_coef = 0.001, action_stds = 0.323 ± 0.068, action_magnitude = 0.836 ± 0.248, num_gradient_steps = 1533998, step_time = 9.06, total_time = 1407.75
#
#
# step = 1545000, num_env_steps = 1545000, scores = 13.753 ± 0.65 (n=2), actor_loss = -16.584, critic_loss = 0.111, entropy_coef_loss = 108.159, entropy_coef = 0.001, action_stds = 0.313 ± 0.081, action_magnitude = 0.838 ± 0.247, num_gradient_steps = 1534998, step_time = 9.15, total_time = 1416.90
#
#
# step = 1546000, num_env_steps = 1546000, scores = 14.199 ± 1.15 (n=2), actor_loss = -17.190, critic_loss = 0.144, entropy_coef_loss = 126.806, entropy_coef = 0.001, action_stds = 0.349 ± 0.092, action_magnitude = 0.836 ± 0.250, num_gradient_steps = 1535998, step_time = 9.17, total_time = 1426.08
#
#
# step = 1547000, num_env_steps = 1547000, scores = 14.582 ± 0.01 (n=2), actor_loss = -16.361, critic_loss = 0.172, entropy_coef_loss = 114.585, entropy_coef = 0.001, action_stds = 0.382 ± 0.066, action_magnitude = 0.841 ± 0.248, num_gradient_steps = 1536998, step_time = 9.18, total_time = 1435.25
#
#
# step = 1548000, num_env_steps = 1548000, scores = 13.706 ± 0.83 (n=2), actor_loss = -16.268, critic_loss = 0.155, entropy_coef_loss = 111.276, entropy_coef = 0.001, action_stds = 0.380 ± 0.085, action_magnitude = 0.833 ± 0.251, num_gradient_steps = 1537998, step_time = 9.03, total_time = 1444.28
#
#
# step = 1549000, num_env_steps = 1549000, scores = 13.421 ± 0.13 (n=2), actor_loss = -16.917, critic_loss = 0.115, entropy_coef_loss = 120.981, entropy_coef = 0.001, action_stds = 0.333 ± 0.077, action_magnitude = 0.835 ± 0.250, num_gradient_steps = 1538998, step_time = 9.18, total_time = 1453.47
#
#
# ...
#
#
# step = 2844000, num_env_steps = 2844000, scores = -5.428 ± 0.11 (n=2), actor_loss = -18.493, critic_loss = 0.439, entropy_coef_loss = 277.565, entropy_coef = 0.001, action_stds = 0.412 ± 0.197, action_magnitude = 0.878 ± 0.225, num_gradient_steps = 2833998, step_time = 9.04, total_time = 13188.06
#
#
# step = 2845000, num_env_steps = 2845000, scores = -5.014 ± 0.63 (n=2), actor_loss = -18.807, critic_loss = 0.433, entropy_coef_loss = 286.142, entropy_coef = 0.001, action_stds = 0.324 ± 0.170, action_magnitude = 0.817 ± 0.259, num_gradient_steps = 2834998, step_time = 9.01, total_time = 13197.07
#
#
# step = 2846000, num_env_steps = 2846000, scores = 1.024 ± 6.75 (n=2), actor_loss = -19.630, critic_loss = 0.497, entropy_coef_loss = 276.180, entropy_coef = 0.001, action_stds = 0.343 ± 0.158, action_magnitude = 0.882 ± 0.222, num_gradient_steps = 2835998, step_time = 9.07, total_time = 13206.14
#
#
# step = 2847000, num_env_steps = 2847000, scores = -5.248 ± 0.01 (n=2), actor_loss = -18.595, critic_loss = 0.453, entropy_coef_loss = 278.682, entropy_coef = 0.001, action_stds = 0.412 ± 0.261, action_magnitude = 0.885 ± 0.203, num_gradient_steps = 2836998, step_time = 9.07, total_time = 13215.21
#
#
# step = 2848000, num_env_steps = 2848000, scores = -4.411 ± 0.47 (n=2), actor_loss = -18.272, critic_loss = 0.652, entropy_coef_loss = 304.624, entropy_coef = 0.001, action_stds = 0.468 ± 0.197, action_magnitude = 0.854 ± 0.245, num_gradient_steps = 2837998, step_time = 9.04, total_time = 13224.25
#
#
# step = 2849000, num_env_steps = 2849000, scores = 2.975 ± 7.13 (n=2), actor_loss = -18.586, critic_loss = 0.903, entropy_coef_loss = 293.612, entropy_coef = 0.001, action_stds = 0.453 ± 0.188, action_magnitude = 0.903 ± 0.203, num_gradient_steps = 2838998, step_time = 9.13, total_time = 13233.39
#
#
# step = 2850000, num_env_steps = 2850000, scores = -4.387 ± 0.44 (n=2), actor_loss = -18.134, critic_loss = 1.082, entropy_coef_loss = 281.327, entropy_coef = 0.001, action_stds = 0.434 ± 0.211, action_magnitude = 0.860 ± 0.223, num_gradient_steps = 2839998, step_time = 9.02, total_time = 13242.40
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 2851000, num_env_steps = 2851000, scores = -4.425 ± 0.24 (n=2), actor_loss = -19.546, critic_loss = 0.886, entropy_coef_loss = 282.312, entropy_coef = 0.001, action_stds = 0.436 ± 0.182, action_magnitude = 0.841 ± 0.251, num_gradient_steps = 2840998, step_time = 9.26, total_time = 13251.66
#
#
# step = 2852000, num_env_steps = 2852000, scores = -3.021 ± 0.66 (n=2), actor_loss = -17.714, critic_loss = 0.560, entropy_coef_loss = 289.907, entropy_coef = 0.001, action_stds = 0.517 ± 0.238, action_magnitude = 0.884 ± 0.236, num_gradient_steps = 2841998, step_time = 9.22, total_time = 13260.89
#
#
# step = 2853000, num_env_steps = 2853000, scores = -4.099 ± 1.54 (n=2), actor_loss = -18.652, critic_loss = 0.580, entropy_coef_loss = 284.990, entropy_coef = 0.001, action_stds = 0.373 ± 0.150, action_magnitude = 0.880 ± 0.222, num_gradient_steps = 2842998, step_time = 9.10, total_time = 13269.99
#
#
# step = 2854000, num_env_steps = 2854000, scores = -5.400 ± 0.27 (n=2), actor_loss = -19.668, critic_loss = 0.630, entropy_coef_loss = 288.821, entropy_coef = 0.001, action_stds = 0.199 ± 0.143, action_magnitude = 0.838 ± 0.262, num_gradient_steps = 2843998, step_time = 9.09, total_time = 13279.08
#
#
# step = 2855000, num_env_steps = 2855000, scores = -6.715 ± 0.10 (n=2), actor_loss = -18.662, critic_loss = 0.878, entropy_coef_loss = 307.207, entropy_coef = 0.001, action_stds = 0.263 ± 0.237, action_magnitude = 0.901 ± 0.185, num_gradient_steps = 2844998, step_time = 8.81, total_time = 13287.89
#
#
# step = 2856000, num_env_steps = 2856000, scores = -5.706 ± 0.16 (n=2), actor_loss = -18.994, critic_loss = 0.950, entropy_coef_loss = 310.724, entropy_coef = 0.001, action_stds = 0.294 ± 0.174, action_magnitude = 0.807 ± 0.265, num_gradient_steps = 2845998, step_time = 10.09, total_time = 13297.98
#
#
# step = 2857000, num_env_steps = 2857000, scores = -5.900 ± 0.20 (n=2), actor_loss = -20.352, critic_loss = 1.055, entropy_coef_loss = 314.318, entropy_coef = 0.001, action_stds = 0.318 ± 0.182, action_magnitude = 0.830 ± 0.228, num_gradient_steps = 2846998, step_time = 8.30, total_time = 13306.27
#
#
# step = 2858000, num_env_steps = 2858000, scores = -5.386 ± 0.14 (n=2), actor_loss = -20.519, critic_loss = 1.021, entropy_coef_loss = 321.178, entropy_coef = 0.001, action_stds = 0.233 ± 0.176, action_magnitude = 0.769 ± 0.295, num_gradient_steps = 2847998, step_time = 7.82, total_time = 13314.09
#
#
# step = 2859000, num_env_steps = 2859000, scores = -5.861 ± 0.13 (n=2), actor_loss = -21.958, critic_loss = 1.184, entropy_coef_loss = 323.198, entropy_coef = 0.001, action_stds = 0.229 ± 0.143, action_magnitude = 0.830 ± 0.245, num_gradient_steps = 2848998, step_time = 8.19, total_time = 13322.28
#
#
# step = 2860000, num_env_steps = 2860000, scores = -5.663 ± 0.62 (n=2), actor_loss = -21.250, critic_loss = 0.886, entropy_coef_loss = 319.257, entropy_coef = 0.001, action_stds = 0.425 ± 0.266, action_magnitude = 0.806 ± 0.275, num_gradient_steps = 2849998, step_time = 8.53, total_time = 13330.81
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 2861000, num_env_steps = 2861000, scores = -4.666 ± 1.44 (n=2), actor_loss = -21.004, critic_loss = 1.032, entropy_coef_loss = 335.019, entropy_coef = 0.001, action_stds = 0.391 ± 0.194, action_magnitude = 0.904 ± 0.184, num_gradient_steps = 2850998, step_time = 8.94, total_time = 13339.75
#
#
# step = 2862000, num_env_steps = 2862000, scores = -5.619 ± 0.60 (n=2), actor_loss = -20.514, critic_loss = 0.778, entropy_coef_loss = 343.667, entropy_coef = 0.001, action_stds = 0.365 ± 0.161, action_magnitude = 0.906 ± 0.199, num_gradient_steps = 2851998, step_time = 8.53, total_time = 13348.29
#
#
# step = 2863000, num_env_steps = 2863000, scores = -4.758 ± 0.43 (n=2), actor_loss = -21.414, critic_loss = 0.770, entropy_coef_loss = 318.650, entropy_coef = 0.001, action_stds = 0.399 ± 0.345, action_magnitude = 0.835 ± 0.261, num_gradient_steps = 2852998, step_time = 9.14, total_time = 13357.42
#
#
# step = 2864000, num_env_steps = 2864000, scores = -2.604 ± 2.70 (n=2), actor_loss = -20.251, critic_loss = 0.648, entropy_coef_loss = 303.800, entropy_coef = 0.001, action_stds = 0.501 ± 0.368, action_magnitude = 0.886 ± 0.227, num_gradient_steps = 2853998, step_time = 8.24, total_time = 13365.67
#
#
# step = 2865000, num_env_steps = 2865000, scores = -4.133 ± 0.42 (n=2), actor_loss = -20.120, critic_loss = 0.627, entropy_coef_loss = 305.921, entropy_coef = 0.001, action_stds = 0.400 ± 0.279, action_magnitude = 0.891 ± 0.223, num_gradient_steps = 2854998, step_time = 8.09, total_time = 13373.76
#
#
# step = 2866000, num_env_steps = 2866000, scores = -3.677 ± 1.41 (n=2), actor_loss = -21.825, critic_loss = 0.601, entropy_coef_loss = 299.768, entropy_coef = 0.001, action_stds = 0.508 ± 0.571, action_magnitude = 0.868 ± 0.236, num_gradient_steps = 2855998, step_time = 8.47, total_time = 13382.22
#
#
# step = 2867000, num_env_steps = 2867000, scores = -3.807 ± 0.15 (n=2), actor_loss = -21.807, critic_loss = 0.569, entropy_coef_loss = 290.590, entropy_coef = 0.001, action_stds = 0.398 ± 0.265, action_magnitude = 0.885 ± 0.226, num_gradient_steps = 2856998, step_time = 9.40, total_time = 13391.62
#
#
# step = 2868000, num_env_steps = 2868000, scores = -1.121 ± 3.31 (n=2), actor_loss = -21.331, critic_loss = 0.647, entropy_coef_loss = 289.661, entropy_coef = 0.001, action_stds = 0.380 ± 0.288, action_magnitude = 0.903 ± 0.208, num_gradient_steps = 2857998, step_time = 9.31, total_time = 13400.93
#
#
# step = 2869000, num_env_steps = 2869000, scores = -4.993 ± 1.03 (n=2), actor_loss = -21.015, critic_loss = 0.509, entropy_coef_loss = 285.367, entropy_coef = 0.001, action_stds = 0.439 ± 0.260, action_magnitude = 0.895 ± 0.208, num_gradient_steps = 2858998, step_time = 9.37, total_time = 13410.30
#
#
# step = 2870000, num_env_steps = 2870000, scores = 0.401 ± 0.04 (n=2), actor_loss = -20.913, critic_loss = 0.639, entropy_coef_loss = 292.769, entropy_coef = 0.001, action_stds = 0.376 ± 0.137, action_magnitude = 0.903 ± 0.206, num_gradient_steps = 2859998, step_time = 8.53, total_time = 13418.83
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 2871000, num_env_steps = 2871000, scores = 1.971 ± 2.88 (n=2), actor_loss = -20.421, critic_loss = 0.422, entropy_coef_loss = 275.786, entropy_coef = 0.001, action_stds = 0.413 ± 0.143, action_magnitude = 0.890 ± 0.223, num_gradient_steps = 2860998, step_time = 8.25, total_time = 13427.08
#
#
# step = 2872000, num_env_steps = 2872000, scores = 2.753 ± 2.72 (n=2), actor_loss = -20.058, critic_loss = 0.560, entropy_coef_loss = 282.354, entropy_coef = 0.001, action_stds = 0.457 ± 0.249, action_magnitude = 0.893 ± 0.211, num_gradient_steps = 2861998, step_time = 7.85, total_time = 13434.93
#
#
# step = 2873000, num_env_steps = 2873000, scores = 6.030 ± 5.68 (n=2), actor_loss = -20.258, critic_loss = 0.415, entropy_coef_loss = 276.995, entropy_coef = 0.001, action_stds = 0.397 ± 0.241, action_magnitude = 0.897 ± 0.210, num_gradient_steps = 2862998, step_time = 7.91, total_time = 13442.84
#
#
# step = 2874000, num_env_steps = 2874000, scores = 2.733 ± 2.17 (n=2), actor_loss = -20.014, critic_loss = 0.508, entropy_coef_loss = 284.554, entropy_coef = 0.001, action_stds = 0.346 ± 0.163, action_magnitude = 0.897 ± 0.213, num_gradient_steps = 2863998, step_time = 8.00, total_time = 13450.84
#
#
# step = 2875000, num_env_steps = 2875000, scores = -4.176 ± 1.78 (n=2), actor_loss = -19.582, critic_loss = 0.672, entropy_coef_loss = 260.389, entropy_coef = 0.001, action_stds = 0.288 ± 0.147, action_magnitude = 0.935 ± 0.171, num_gradient_steps = 2864998, step_time = 7.95, total_time = 13458.78
#
#
# step = 2876000, num_env_steps = 2876000, scores = 3.735 ± 5.22 (n=2), actor_loss = -19.088, critic_loss = 0.347, entropy_coef_loss = 270.105, entropy_coef = 0.001, action_stds = 0.459 ± 0.196, action_magnitude = 0.901 ± 0.209, num_gradient_steps = 2865998, step_time = 8.27, total_time = 13467.06
#
#
# step = 2877000, num_env_steps = 2877000, scores = 0.279 ± 3.09 (n=2), actor_loss = -20.765, critic_loss = 0.707, entropy_coef_loss = 283.869, entropy_coef = 0.001, action_stds = 0.427 ± 0.157, action_magnitude = 0.874 ± 0.228, num_gradient_steps = 2866998, step_time = 8.13, total_time = 13475.19
#
#
# step = 2878000, num_env_steps = 2878000, scores = 0.077 ± 0.16 (n=2), actor_loss = -18.936, critic_loss = 0.425, entropy_coef_loss = 278.846, entropy_coef = 0.001, action_stds = 0.445 ± 0.153, action_magnitude = 0.889 ± 0.219, num_gradient_steps = 2867998, step_time = 8.42, total_time = 13483.61
#
#
# step = 2879000, num_env_steps = 2879000, scores = 3.139 ± 8.03 (n=2), actor_loss = -18.908, critic_loss = 0.375, entropy_coef_loss = 264.974, entropy_coef = 0.001, action_stds = 0.358 ± 0.128, action_magnitude = 0.871 ± 0.226, num_gradient_steps = 2868998, step_time = 8.19, total_time = 13491.79
#
#
# step = 2880000, num_env_steps = 2880000, scores = 1.657 ± 6.81 (n=2), actor_loss = -19.097, critic_loss = 0.333, entropy_coef_loss = 251.415, entropy_coef = 0.001, action_stds = 0.381 ± 0.118, action_magnitude = 0.873 ± 0.236, num_gradient_steps = 2869998, step_time = 8.04, total_time = 13499.83
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 2881000, num_env_steps = 2881000, scores = 6.621 ± 7.00 (n=2), actor_loss = -18.356, critic_loss = 0.347, entropy_coef_loss = 265.588, entropy_coef = 0.001, action_stds = 0.372 ± 0.155, action_magnitude = 0.892 ± 0.218, num_gradient_steps = 2870998, step_time = 8.44, total_time = 13508.27
#
#
# step = 2882000, num_env_steps = 2882000, scores = 8.223 ± 5.16 (n=2), actor_loss = -19.155, critic_loss = 0.393, entropy_coef_loss = 276.547, entropy_coef = 0.001, action_stds = 0.335 ± 0.143, action_magnitude = 0.877 ± 0.228, num_gradient_steps = 2871998, step_time = 8.16, total_time = 13516.42
#
#
# step = 2883000, num_env_steps = 2883000, scores = 13.382 ± 1.21 (n=2), actor_loss = -17.988, critic_loss = 0.420, entropy_coef_loss = 261.792, entropy_coef = 0.001, action_stds = 0.528 ± 0.202, action_magnitude = 0.869 ± 0.231, num_gradient_steps = 2872998, step_time = 8.33, total_time = 13524.75
#
#
# step = 2884000, num_env_steps = 2884000, scores = 13.794 ± 0.54 (n=2), actor_loss = -17.555, critic_loss = 0.396, entropy_coef_loss = 264.410, entropy_coef = 0.001, action_stds = 0.377 ± 0.140, action_magnitude = 0.871 ± 0.228, num_gradient_steps = 2873998, step_time = 7.98, total_time = 13532.73
#
#
# step = 2885000, num_env_steps = 2885000, scores = 13.970 ± 0.07 (n=2), actor_loss = -18.570, critic_loss = 0.426, entropy_coef_loss = 265.722, entropy_coef = 0.001, action_stds = 0.411 ± 0.216, action_magnitude = 0.871 ± 0.226, num_gradient_steps = 2874998, step_time = 8.12, total_time = 13540.84
#
#
# step = 2886000, num_env_steps = 2886000, scores = 8.792 ± 7.06 (n=2), actor_loss = -17.830, critic_loss = 0.303, entropy_coef_loss = 236.930, entropy_coef = 0.001, action_stds = 0.488 ± 0.182, action_magnitude = 0.889 ± 0.214, num_gradient_steps = 2875998, step_time = 8.05, total_time = 13548.90
#
#
# step = 2887000, num_env_steps = 2887000, scores = 14.725 ± 0.29 (n=2), actor_loss = -18.187, critic_loss = 0.272, entropy_coef_loss = 248.065, entropy_coef = 0.001, action_stds = 0.425 ± 0.173, action_magnitude = 0.867 ± 0.228, num_gradient_steps = 2876998, step_time = 8.20, total_time = 13557.10
#
#
# step = 2888000, num_env_steps = 2888000, scores = 14.228 ± 0.91 (n=2), actor_loss = -16.953, critic_loss = 0.468, entropy_coef_loss = 254.914, entropy_coef = 0.001, action_stds = 0.405 ± 0.110, action_magnitude = 0.867 ± 0.232, num_gradient_steps = 2877998, step_time = 8.05, total_time = 13565.14
#
#
# step = 2889000, num_env_steps = 2889000, scores = 14.238 ± 0.12 (n=2), actor_loss = -17.141, critic_loss = 0.529, entropy_coef_loss = 252.532, entropy_coef = 0.001, action_stds = 0.400 ± 0.125, action_magnitude = 0.866 ± 0.230, num_gradient_steps = 2878998, step_time = 8.68, total_time = 13573.82
#
#
# step = 2890000, num_env_steps = 2890000, scores = 16.554 ± 0.44 (n=2), actor_loss = -17.040, critic_loss = 0.435, entropy_coef_loss = 253.255, entropy_coef = 0.001, action_stds = 0.419 ± 0.279, action_magnitude = 0.868 ± 0.230, num_gradient_steps = 2879998, step_time = 8.55, total_time = 13582.37
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
#
#
# step = 2891000, num_env_steps = 2891000, scores = 10.434 ± 5.15 (n=2), actor_loss = -16.937, critic_loss = 0.390, entropy_coef_loss = 235.650, entropy_coef = 0.001, action_stds = 0.369 ± 0.127, action_magnitude = 0.863 ± 0.234, num_gradient_steps = 2880998, step_time = 8.65, total_time = 13591.02
#
#
# step = 2892000, num_env_steps = 2892000, scores = 16.297 ± 0.56 (n=2), actor_loss = -17.137, critic_loss = 0.319, entropy_coef_loss = 246.783, entropy_coef = 0.001, action_stds = 0.448 ± 0.166, action_magnitude = 0.868 ± 0.228, num_gradient_steps = 2881998, step_time = 9.88, total_time = 13600.90
#
#
# step = 2893000, num_env_steps = 2893000, scores = 16.121 ± 1.16 (n=2), actor_loss = -16.921, critic_loss = 0.244, entropy_coef_loss = 258.321, entropy_coef = 0.001, action_stds = 0.387 ± 0.191, action_magnitude = 0.868 ± 0.229, num_gradient_steps = 2882998, step_time = 8.14, total_time = 13609.04
#
#
# saved experiment log 2024-10-28_11-12-19_363042~VskSv0 at experiment_logs/2024-10-28_11-12-19_363042~VskSv0.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
def save_training():
    experiment_id = logger.experiment_log['experiment_id']
    algo.save(f'saved_models/{experiment_id}', experiment_id)

save_training()

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
