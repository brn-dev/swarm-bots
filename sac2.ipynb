# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.core.buffers.replay.ring_with_reservoir_replay_buffer import \
    RingWithReservoirReplayBuffer
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.envs.swarm_bot_env__v0_1 import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
            best_iteration_score = iteration_score
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        # if step % 100_000 == 0:
        #     save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=5, 
        hip_range=np.pi / 4,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    latent_action_size = 256
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, latent_action_size),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=latent_action_size,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # buffer_type=RingWithReservoirReplayBuffer,
            buffer_step_size=1_000_000,
            # buffer_kwargs={
            #     'reservoir_total_size': 700_000,
            # },
            reward_scale=10,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef_clamp_range=(0.001, 1.5),
            # entropy_coef=0.1,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        # algo.load('saved_models/2024-10-28_11-12-19_363042~VskSv0/', '2024-10-28_11-12-19_363042~VskSv0')
        total_stopwatch.reset()
        with log_experiment(
            logger,
            # experiment_id='2024-10-28_11-12-19_363042~VskSv0_1',
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 259618
# env = <swarmbots.envs.swarm_bot_env__v0_1.SwarmBotEnv object at 0x0000013E6C87E990>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# Starting Training
#
# step = 11000, num_env_steps = 11000, scores = -2.810 ± 0.02 (n=2), actor_loss = -49.130, critic_loss = 15.443, entropy_coef_loss = -8.005, entropy_coef = 0.738, action_stds = 0.895 ± 0.034, action_magnitude = 0.521 ± 0.285, num_gradient_steps = 1000, step_time = 18.07, total_time = 18.01
#
# step = 12000, num_env_steps = 12000, scores = -3.243 ± 0.61 (n=2), actor_loss = -73.046, critic_loss = 11.767, entropy_coef_loss = -15.518, entropy_coef = 0.549, action_stds = 0.856 ± 0.027, action_magnitude = 0.541 ± 0.292, num_gradient_steps = 2000, step_time = 11.40, total_time = 29.41
#
# step = 13000, num_env_steps = 13000, scores = -2.665 ± 1.02 (n=2), actor_loss = -87.108, critic_loss = 6.953, entropy_coef_loss = -23.338, entropy_coef = 0.407, action_stds = 0.871 ± 0.022, action_magnitude = 0.541 ± 0.292, num_gradient_steps = 3000, step_time = 10.99, total_time = 40.40
#
# step = 14000, num_env_steps = 14000, scores = -4.052 ± 0.45 (n=2), actor_loss = -94.889, critic_loss = 6.019, entropy_coef_loss = -31.055, entropy_coef = 0.302, action_stds = 0.885 ± 0.026, action_magnitude = 0.538 ± 0.289, num_gradient_steps = 4000, step_time = 10.95, total_time = 51.35
#
# step = 15000, num_env_steps = 15000, scores = -3.593 ± 0.15 (n=2), actor_loss = -97.348, critic_loss = 3.837, entropy_coef_loss = -38.542, entropy_coef = 0.224, action_stds = 0.897 ± 0.056, action_magnitude = 0.545 ± 0.291, num_gradient_steps = 5000, step_time = 10.98, total_time = 62.33
#
# step = 16000, num_env_steps = 16000, scores = -2.907 ± 0.82 (n=2), actor_loss = -96.529, critic_loss = 3.913, entropy_coef_loss = -44.170, entropy_coef = 0.166, action_stds = 0.892 ± 0.050, action_magnitude = 0.551 ± 0.291, num_gradient_steps = 6000, step_time = 10.98, total_time = 73.30
#
# step = 17000, num_env_steps = 17000, scores = -3.181 ± 0.57 (n=2), actor_loss = -97.417, critic_loss = 3.090, entropy_coef_loss = -50.786, entropy_coef = 0.124, action_stds = 0.893 ± 0.032, action_magnitude = 0.567 ± 0.294, num_gradient_steps = 7000, step_time = 10.91, total_time = 84.21
#
# step = 18000, num_env_steps = 18000, scores = -3.334 ± 0.14 (n=2), actor_loss = -94.505, critic_loss = 2.570, entropy_coef_loss = -55.780, entropy_coef = 0.093, action_stds = 0.895 ± 0.034, action_magnitude = 0.579 ± 0.295, num_gradient_steps = 8000, step_time = 10.92, total_time = 95.13
#
# step = 19000, num_env_steps = 19000, scores = -4.075 ± 0.48 (n=2), actor_loss = -91.064, critic_loss = 3.150, entropy_coef_loss = -59.746, entropy_coef = 0.070, action_stds = 0.871 ± 0.038, action_magnitude = 0.590 ± 0.297, num_gradient_steps = 9000, step_time = 10.90, total_time = 106.02
#
# step = 20000, num_env_steps = 20000, scores = -3.867 ± 0.12 (n=2), actor_loss = -86.852, critic_loss = 2.099, entropy_coef_loss = -59.539, entropy_coef = 0.052, action_stds = 0.838 ± 0.044, action_magnitude = 0.603 ± 0.297, num_gradient_steps = 10000, step_time = 10.84, total_time = 116.86
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 21000, num_env_steps = 21000, scores = -3.422 ± 0.09 (n=2), actor_loss = -82.517, critic_loss = 2.663, entropy_coef_loss = -61.381, entropy_coef = 0.040, action_stds = 0.836 ± 0.045, action_magnitude = 0.619 ± 0.298, num_gradient_steps = 11000, step_time = 10.93, total_time = 127.79
#
# step = 22000, num_env_steps = 22000, scores = -4.402 ± 0.20 (n=2), actor_loss = -79.099, critic_loss = 1.579, entropy_coef_loss = -59.070, entropy_coef = 0.030, action_stds = 0.822 ± 0.072, action_magnitude = 0.627 ± 0.298, num_gradient_steps = 12000, step_time = 10.98, total_time = 138.77
#
# step = 23000, num_env_steps = 23000, scores = -4.549 ± 0.09 (n=2), actor_loss = -76.492, critic_loss = 1.392, entropy_coef_loss = -54.813, entropy_coef = 0.023, action_stds = 0.817 ± 0.094, action_magnitude = 0.647 ± 0.299, num_gradient_steps = 13000, step_time = 10.86, total_time = 149.63
#
# step = 24000, num_env_steps = 24000, scores = -4.403 ± 0.25 (n=2), actor_loss = -71.791, critic_loss = 1.048, entropy_coef_loss = -56.282, entropy_coef = 0.018, action_stds = 0.804 ± 0.132, action_magnitude = 0.658 ± 0.298, num_gradient_steps = 14000, step_time = 10.94, total_time = 160.57
#
# step = 25000, num_env_steps = 25000, scores = -5.026 ± 1.07 (n=2), actor_loss = -68.821, critic_loss = 1.182, entropy_coef_loss = -48.296, entropy_coef = 0.014, action_stds = 0.747 ± 0.071, action_magnitude = 0.670 ± 0.300, num_gradient_steps = 15000, step_time = 10.87, total_time = 171.44
#
# step = 26000, num_env_steps = 26000, scores = -4.608 ± 0.26 (n=2), actor_loss = -65.461, critic_loss = 0.883, entropy_coef_loss = -46.744, entropy_coef = 0.011, action_stds = 0.772 ± 0.089, action_magnitude = 0.678 ± 0.297, num_gradient_steps = 16000, step_time = 10.92, total_time = 182.36
#
# step = 27000, num_env_steps = 27000, scores = -4.669 ± 0.22 (n=2), actor_loss = -60.451, critic_loss = 0.780, entropy_coef_loss = -31.087, entropy_coef = 0.008, action_stds = 0.708 ± 0.084, action_magnitude = 0.688 ± 0.296, num_gradient_steps = 17000, step_time = 10.95, total_time = 193.31
#
# step = 28000, num_env_steps = 28000, scores = -5.051 ± 0.15 (n=2), actor_loss = -57.776, critic_loss = 0.675, entropy_coef_loss = -38.062, entropy_coef = 0.007, action_stds = 0.719 ± 0.063, action_magnitude = 0.706 ± 0.296, num_gradient_steps = 18000, step_time = 10.88, total_time = 204.19
#
# step = 29000, num_env_steps = 29000, scores = -4.846 ± 0.00 (n=2), actor_loss = -55.200, critic_loss = 0.453, entropy_coef_loss = -17.782, entropy_coef = 0.005, action_stds = 0.715 ± 0.085, action_magnitude = 0.711 ± 0.297, num_gradient_steps = 19000, step_time = 10.95, total_time = 215.14
#
# step = 30000, num_env_steps = 30000, scores = -5.012 ± 0.17 (n=2), actor_loss = -51.421, critic_loss = 0.517, entropy_coef_loss = -19.193, entropy_coef = 0.005, action_stds = 0.684 ± 0.085, action_magnitude = 0.716 ± 0.294, num_gradient_steps = 20000, step_time = 10.96, total_time = 226.10
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 31000, num_env_steps = 31000, scores = -5.556 ± 0.36 (n=2), actor_loss = -48.812, critic_loss = 0.608, entropy_coef_loss = -7.257, entropy_coef = 0.004, action_stds = 0.708 ± 0.151, action_magnitude = 0.724 ± 0.294, num_gradient_steps = 21000, step_time = 10.96, total_time = 237.06
#
# step = 32000, num_env_steps = 32000, scores = -4.660 ± 0.27 (n=2), actor_loss = -46.650, critic_loss = 0.328, entropy_coef_loss = -10.944, entropy_coef = 0.003, action_stds = 0.712 ± 0.103, action_magnitude = 0.713 ± 0.295, num_gradient_steps = 22000, step_time = 10.99, total_time = 248.05
#
# step = 33000, num_env_steps = 33000, scores = -4.666 ± 0.20 (n=2), actor_loss = -43.261, critic_loss = 0.304, entropy_coef_loss = 0.948, entropy_coef = 0.003, action_stds = 0.714 ± 0.118, action_magnitude = 0.706 ± 0.298, num_gradient_steps = 23000, step_time = 11.00, total_time = 259.05
#
# step = 34000, num_env_steps = 34000, scores = -4.920 ± 0.67 (n=2), actor_loss = -41.530, critic_loss = 0.240, entropy_coef_loss = 1.322, entropy_coef = 0.003, action_stds = 0.695 ± 0.063, action_magnitude = 0.707 ± 0.297, num_gradient_steps = 24000, step_time = 10.98, total_time = 270.03
#
# step = 35000, num_env_steps = 35000, scores = -4.959 ± 0.20 (n=2), actor_loss = -38.927, critic_loss = 0.230, entropy_coef_loss = -6.346, entropy_coef = 0.002, action_stds = 0.665 ± 0.085, action_magnitude = 0.716 ± 0.296, num_gradient_steps = 25000, step_time = 10.98, total_time = 281.01
#
# step = 36000, num_env_steps = 36000, scores = -5.592 ± 0.04 (n=2), actor_loss = -36.840, critic_loss = 0.197, entropy_coef_loss = -4.854, entropy_coef = 0.002, action_stds = 0.651 ± 0.136, action_magnitude = 0.726 ± 0.293, num_gradient_steps = 26000, step_time = 10.98, total_time = 291.98
#
# step = 37000, num_env_steps = 37000, scores = -4.700 ± 0.63 (n=2), actor_loss = -33.532, critic_loss = 0.201, entropy_coef_loss = 5.545, entropy_coef = 0.002, action_stds = 0.592 ± 0.074, action_magnitude = 0.720 ± 0.294, num_gradient_steps = 27000, step_time = 10.89, total_time = 302.88
#
# step = 38000, num_env_steps = 38000, scores = -4.786 ± 0.25 (n=2), actor_loss = -32.339, critic_loss = 0.176, entropy_coef_loss = 9.060, entropy_coef = 0.002, action_stds = 0.645 ± 0.069, action_magnitude = 0.712 ± 0.296, num_gradient_steps = 28000, step_time = 11.01, total_time = 313.88
#
# step = 39000, num_env_steps = 39000, scores = -4.847 ± 0.44 (n=2), actor_loss = -29.837, critic_loss = 0.127, entropy_coef_loss = -0.826, entropy_coef = 0.002, action_stds = 0.603 ± 0.052, action_magnitude = 0.707 ± 0.296, num_gradient_steps = 29000, step_time = 10.90, total_time = 324.78
#
# step = 40000, num_env_steps = 40000, scores = -4.832 ± 0.02 (n=2), actor_loss = -27.748, critic_loss = 0.134, entropy_coef_loss = 8.076, entropy_coef = 0.001, action_stds = 0.575 ± 0.060, action_magnitude = 0.710 ± 0.296, num_gradient_steps = 30000, step_time = 10.97, total_time = 335.75
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 41000, num_env_steps = 41000, scores = -4.618 ± 0.09 (n=2), actor_loss = -25.967, critic_loss = 0.106, entropy_coef_loss = -0.430, entropy_coef = 0.001, action_stds = 0.572 ± 0.062, action_magnitude = 0.702 ± 0.299, num_gradient_steps = 31000, step_time = 10.96, total_time = 346.70
#
# step = 42000, num_env_steps = 42000, scores = -4.513 ± 0.17 (n=2), actor_loss = -24.560, critic_loss = 0.083, entropy_coef_loss = -9.951, entropy_coef = 0.001, action_stds = 0.603 ± 0.072, action_magnitude = 0.701 ± 0.297, num_gradient_steps = 32000, step_time = 10.90, total_time = 357.60
#
# step = 43000, num_env_steps = 43000, scores = -4.613 ± 0.07 (n=2), actor_loss = -23.278, critic_loss = 0.076, entropy_coef_loss = 0.259, entropy_coef = 0.001, action_stds = 0.512 ± 0.075, action_magnitude = 0.696 ± 0.298, num_gradient_steps = 33000, step_time = 10.97, total_time = 368.58
#
# step = 44000, num_env_steps = 44000, scores = -4.581 ± 0.03 (n=2), actor_loss = -21.462, critic_loss = 0.069, entropy_coef_loss = -13.538, entropy_coef = 0.001, action_stds = 0.589 ± 0.089, action_magnitude = 0.690 ± 0.300, num_gradient_steps = 34000, step_time = 10.99, total_time = 379.56
#
# step = 45000, num_env_steps = 45000, scores = -4.092 ± 0.13 (n=2), actor_loss = -19.934, critic_loss = 0.065, entropy_coef_loss = -8.386, entropy_coef = 0.001, action_stds = 0.475 ± 0.078, action_magnitude = 0.695 ± 0.297, num_gradient_steps = 35000, step_time = 10.99, total_time = 390.55
#
# step = 46000, num_env_steps = 46000, scores = -4.360 ± 0.15 (n=2), actor_loss = -18.800, critic_loss = 0.063, entropy_coef_loss = -17.020, entropy_coef = 0.001, action_stds = 0.566 ± 0.051, action_magnitude = 0.685 ± 0.299, num_gradient_steps = 36000, step_time = 10.97, total_time = 401.53
#
# step = 47000, num_env_steps = 47000, scores = -4.101 ± 0.18 (n=2), actor_loss = -17.450, critic_loss = 0.066, entropy_coef_loss = -25.275, entropy_coef = 0.001, action_stds = 0.581 ± 0.175, action_magnitude = 0.678 ± 0.300, num_gradient_steps = 37000, step_time = 10.97, total_time = 412.49
#
# step = 48000, num_env_steps = 48000, scores = -4.043 ± 0.28 (n=2), actor_loss = -16.028, critic_loss = 0.058, entropy_coef_loss = -31.741, entropy_coef = 0.001, action_stds = 0.530 ± 0.084, action_magnitude = 0.668 ± 0.302, num_gradient_steps = 38000, step_time = 10.94, total_time = 423.43
#
# step = 49000, num_env_steps = 49000, scores = -3.122 ± 0.39 (n=2), actor_loss = -14.969, critic_loss = 0.052, entropy_coef_loss = -39.638, entropy_coef = 0.001, action_stds = 0.554 ± 0.057, action_magnitude = 0.655 ± 0.300, num_gradient_steps = 39000, step_time = 11.03, total_time = 434.46
#
# step = 50000, num_env_steps = 50000, scores = -4.122 ± 0.06 (n=2), actor_loss = -14.024, critic_loss = 0.041, entropy_coef_loss = -36.452, entropy_coef = 0.001, action_stds = 0.570 ± 0.127, action_magnitude = 0.656 ± 0.300, num_gradient_steps = 40000, step_time = 10.95, total_time = 445.42
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 51000, num_env_steps = 51000, scores = -3.884 ± 0.01 (n=2), actor_loss = -12.731, critic_loss = 0.035, entropy_coef_loss = -52.777, entropy_coef = 0.001, action_stds = 0.535 ± 0.053, action_magnitude = 0.641 ± 0.301, num_gradient_steps = 41000, step_time = 10.98, total_time = 456.40
#
# step = 52000, num_env_steps = 52000, scores = -3.347 ± 0.08 (n=2), actor_loss = -12.132, critic_loss = 0.038, entropy_coef_loss = -50.904, entropy_coef = 0.001, action_stds = 0.516 ± 0.077, action_magnitude = 0.631 ± 0.299, num_gradient_steps = 42000, step_time = 10.93, total_time = 467.33
#
# step = 53000, num_env_steps = 53000, scores = -3.448 ± 0.19 (n=2), actor_loss = -10.982, critic_loss = 0.035, entropy_coef_loss = -51.609, entropy_coef = 0.001, action_stds = 0.496 ± 0.065, action_magnitude = 0.630 ± 0.301, num_gradient_steps = 43000, step_time = 11.03, total_time = 478.36
#
# step = 54000, num_env_steps = 54000, scores = -3.514 ± 0.17 (n=2), actor_loss = -10.109, critic_loss = 0.031, entropy_coef_loss = -58.414, entropy_coef = 0.001, action_stds = 0.527 ± 0.060, action_magnitude = 0.633 ± 0.299, num_gradient_steps = 44000, step_time = 11.00, total_time = 489.36
#
# step = 55000, num_env_steps = 55000, scores = -3.422 ± 0.09 (n=2), actor_loss = -9.382, critic_loss = 0.029, entropy_coef_loss = -65.436, entropy_coef = 0.001, action_stds = 0.542 ± 0.061, action_magnitude = 0.622 ± 0.300, num_gradient_steps = 45000, step_time = 11.02, total_time = 500.39
#
# step = 56000, num_env_steps = 56000, scores = -3.379 ± 0.14 (n=2), actor_loss = -8.606, critic_loss = 0.023, entropy_coef_loss = -66.973, entropy_coef = 0.001, action_stds = 0.526 ± 0.064, action_magnitude = 0.621 ± 0.299, num_gradient_steps = 46000, step_time = 10.96, total_time = 511.35
#
# step = 57000, num_env_steps = 57000, scores = -3.000 ± 0.03 (n=2), actor_loss = -7.889, critic_loss = 0.019, entropy_coef_loss = -71.289, entropy_coef = 0.001, action_stds = 0.474 ± 0.059, action_magnitude = 0.603 ± 0.298, num_gradient_steps = 47000, step_time = 10.96, total_time = 522.31
#
# step = 58000, num_env_steps = 58000, scores = -2.937 ± 0.25 (n=2), actor_loss = -7.169, critic_loss = 0.025, entropy_coef_loss = -74.356, entropy_coef = 0.001, action_stds = 0.556 ± 0.080, action_magnitude = 0.609 ± 0.298, num_gradient_steps = 48000, step_time = 11.04, total_time = 533.35
#
# step = 59000, num_env_steps = 59000, scores = -2.788 ± 0.17 (n=2), actor_loss = -6.590, critic_loss = 0.026, entropy_coef_loss = -77.426, entropy_coef = 0.001, action_stds = 0.501 ± 0.051, action_magnitude = 0.595 ± 0.298, num_gradient_steps = 49000, step_time = 11.02, total_time = 544.37
#
# step = 60000, num_env_steps = 60000, scores = -2.963 ± 0.16 (n=2), actor_loss = -5.999, critic_loss = 0.018, entropy_coef_loss = -85.560, entropy_coef = 0.001, action_stds = 0.503 ± 0.050, action_magnitude = 0.579 ± 0.295, num_gradient_steps = 50000, step_time = 10.95, total_time = 555.32
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 61000, num_env_steps = 61000, scores = -3.122 ± 0.08 (n=2), actor_loss = -5.480, critic_loss = 0.020, entropy_coef_loss = -78.077, entropy_coef = 0.001, action_stds = 0.481 ± 0.033, action_magnitude = 0.583 ± 0.295, num_gradient_steps = 51000, step_time = 10.98, total_time = 566.30
#
# step = 62000, num_env_steps = 62000, scores = -2.951 ± 0.25 (n=2), actor_loss = -4.845, critic_loss = 0.016, entropy_coef_loss = -79.959, entropy_coef = 0.001, action_stds = 0.468 ± 0.056, action_magnitude = 0.573 ± 0.295, num_gradient_steps = 52000, step_time = 11.11, total_time = 577.40
#
# step = 63000, num_env_steps = 63000, scores = -2.615 ± 0.00 (n=2), actor_loss = -4.323, critic_loss = 0.014, entropy_coef_loss = -85.931, entropy_coef = 0.001, action_stds = 0.493 ± 0.047, action_magnitude = 0.577 ± 0.297, num_gradient_steps = 53000, step_time = 11.01, total_time = 588.41
#
# step = 64000, num_env_steps = 64000, scores = -2.802 ± 0.05 (n=2), actor_loss = -3.860, critic_loss = 0.015, entropy_coef_loss = -84.309, entropy_coef = 0.001, action_stds = 0.476 ± 0.076, action_magnitude = 0.566 ± 0.292, num_gradient_steps = 54000, step_time = 11.01, total_time = 599.42
#
# step = 65000, num_env_steps = 65000, scores = -2.934 ± 0.22 (n=2), actor_loss = -3.475, critic_loss = 0.013, entropy_coef_loss = -91.202, entropy_coef = 0.001, action_stds = 0.469 ± 0.054, action_magnitude = 0.567 ± 0.294, num_gradient_steps = 55000, step_time = 10.97, total_time = 610.39
#
# step = 66000, num_env_steps = 66000, scores = -2.206 ± 0.21 (n=2), actor_loss = -3.012, critic_loss = 0.016, entropy_coef_loss = -86.729, entropy_coef = 0.001, action_stds = 0.447 ± 0.036, action_magnitude = 0.562 ± 0.296, num_gradient_steps = 56000, step_time = 10.98, total_time = 621.37
#
# step = 67000, num_env_steps = 67000, scores = -2.364 ± 0.10 (n=2), actor_loss = -2.661, critic_loss = 0.013, entropy_coef_loss = -94.591, entropy_coef = 0.001, action_stds = 0.460 ± 0.041, action_magnitude = 0.541 ± 0.290, num_gradient_steps = 57000, step_time = 11.03, total_time = 632.40
#
# step = 68000, num_env_steps = 68000, scores = -2.850 ± 0.01 (n=2), actor_loss = -2.313, critic_loss = 0.014, entropy_coef_loss = -86.312, entropy_coef = 0.001, action_stds = 0.452 ± 0.055, action_magnitude = 0.562 ± 0.295, num_gradient_steps = 58000, step_time = 10.94, total_time = 643.34
#
# step = 69000, num_env_steps = 69000, scores = -2.655 ± 0.35 (n=2), actor_loss = -1.941, critic_loss = 0.012, entropy_coef_loss = -87.589, entropy_coef = 0.001, action_stds = 0.437 ± 0.057, action_magnitude = 0.543 ± 0.288, num_gradient_steps = 59000, step_time = 10.95, total_time = 654.29
#
# step = 70000, num_env_steps = 70000, scores = -2.456 ± 0.03 (n=2), actor_loss = -1.632, critic_loss = 0.012, entropy_coef_loss = -86.132, entropy_coef = 0.001, action_stds = 0.423 ± 0.036, action_magnitude = 0.546 ± 0.292, num_gradient_steps = 60000, step_time = 11.00, total_time = 665.29
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 71000, num_env_steps = 71000, scores = -2.245 ± 0.10 (n=2), actor_loss = -1.307, critic_loss = 0.014, entropy_coef_loss = -87.849, entropy_coef = 0.001, action_stds = 0.446 ± 0.038, action_magnitude = 0.550 ± 0.292, num_gradient_steps = 61000, step_time = 10.97, total_time = 676.26
#
# step = 72000, num_env_steps = 72000, scores = -2.271 ± 0.39 (n=2), actor_loss = -1.076, critic_loss = 0.014, entropy_coef_loss = -85.441, entropy_coef = 0.001, action_stds = 0.428 ± 0.040, action_magnitude = 0.526 ± 0.287, num_gradient_steps = 62000, step_time = 11.13, total_time = 687.39
#
# step = 73000, num_env_steps = 73000, scores = -2.370 ± 0.17 (n=2), actor_loss = -0.749, critic_loss = 0.014, entropy_coef_loss = -81.509, entropy_coef = 0.001, action_stds = 0.429 ± 0.034, action_magnitude = 0.523 ± 0.287, num_gradient_steps = 63000, step_time = 10.99, total_time = 698.38
#
# step = 74000, num_env_steps = 74000, scores = -2.450 ± 0.35 (n=2), actor_loss = -0.522, critic_loss = 0.011, entropy_coef_loss = -81.701, entropy_coef = 0.001, action_stds = 0.450 ± 0.074, action_magnitude = 0.529 ± 0.288, num_gradient_steps = 64000, step_time = 11.01, total_time = 709.39
#
# step = 75000, num_env_steps = 75000, scores = -2.370 ± 0.06 (n=2), actor_loss = -0.321, critic_loss = 0.013, entropy_coef_loss = -82.674, entropy_coef = 0.001, action_stds = 0.436 ± 0.036, action_magnitude = 0.537 ± 0.289, num_gradient_steps = 65000, step_time = 11.03, total_time = 720.42
#
# step = 76000, num_env_steps = 76000, scores = -2.348 ± 0.06 (n=2), actor_loss = -0.104, critic_loss = 0.012, entropy_coef_loss = -76.344, entropy_coef = 0.001, action_stds = 0.442 ± 0.063, action_magnitude = 0.533 ± 0.290, num_gradient_steps = 66000, step_time = 10.99, total_time = 731.42
#
# step = 77000, num_env_steps = 77000, scores = -2.297 ± 0.22 (n=2), actor_loss = 0.100, critic_loss = 0.014, entropy_coef_loss = -84.139, entropy_coef = 0.001, action_stds = 0.377 ± 0.034, action_magnitude = 0.520 ± 0.288, num_gradient_steps = 67000, step_time = 11.06, total_time = 742.48
#
# step = 78000, num_env_steps = 78000, scores = -2.462 ± 0.26 (n=2), actor_loss = 0.274, critic_loss = 0.011, entropy_coef_loss = -83.334, entropy_coef = 0.001, action_stds = 0.370 ± 0.030, action_magnitude = 0.523 ± 0.290, num_gradient_steps = 68000, step_time = 11.03, total_time = 753.52
#
# step = 79000, num_env_steps = 79000, scores = -2.116 ± 0.36 (n=2), actor_loss = 0.433, critic_loss = 0.011, entropy_coef_loss = -83.742, entropy_coef = 0.001, action_stds = 0.350 ± 0.048, action_magnitude = 0.514 ± 0.287, num_gradient_steps = 69000, step_time = 11.00, total_time = 764.52
#
# step = 80000, num_env_steps = 80000, scores = -2.372 ± 0.21 (n=2), actor_loss = 0.637, critic_loss = 0.012, entropy_coef_loss = -86.083, entropy_coef = 0.001, action_stds = 0.377 ± 0.055, action_magnitude = 0.521 ± 0.285, num_gradient_steps = 70000, step_time = 10.97, total_time = 775.49
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 81000, num_env_steps = 81000, scores = -2.225 ± 0.01 (n=2), actor_loss = 0.691, critic_loss = 0.013, entropy_coef_loss = -81.722, entropy_coef = 0.001, action_stds = 0.369 ± 0.042, action_magnitude = 0.503 ± 0.285, num_gradient_steps = 71000, step_time = 11.00, total_time = 786.49
#
# step = 82000, num_env_steps = 82000, scores = -2.422 ± 0.13 (n=2), actor_loss = 0.942, critic_loss = 0.012, entropy_coef_loss = -79.441, entropy_coef = 0.001, action_stds = 0.396 ± 0.060, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 72000, step_time = 10.99, total_time = 797.48
#
# step = 83000, num_env_steps = 83000, scores = -2.289 ± 0.22 (n=2), actor_loss = 1.045, critic_loss = 0.010, entropy_coef_loss = -81.163, entropy_coef = 0.001, action_stds = 0.421 ± 0.084, action_magnitude = 0.510 ± 0.283, num_gradient_steps = 73000, step_time = 10.99, total_time = 808.46
#
# step = 84000, num_env_steps = 84000, scores = -2.118 ± 0.11 (n=2), actor_loss = 1.224, critic_loss = 0.011, entropy_coef_loss = -82.367, entropy_coef = 0.001, action_stds = 0.412 ± 0.071, action_magnitude = 0.525 ± 0.285, num_gradient_steps = 74000, step_time = 11.00, total_time = 819.46
#
# step = 85000, num_env_steps = 85000, scores = -2.189 ± 0.11 (n=2), actor_loss = 1.385, critic_loss = 0.013, entropy_coef_loss = -77.969, entropy_coef = 0.001, action_stds = 0.382 ± 0.035, action_magnitude = 0.523 ± 0.287, num_gradient_steps = 75000, step_time = 11.01, total_time = 830.47
#
# step = 86000, num_env_steps = 86000, scores = -1.743 ± 0.24 (n=2), actor_loss = 1.367, critic_loss = 0.011, entropy_coef_loss = -78.874, entropy_coef = 0.001, action_stds = 0.380 ± 0.051, action_magnitude = 0.522 ± 0.287, num_gradient_steps = 76000, step_time = 11.10, total_time = 841.58
#
# step = 87000, num_env_steps = 87000, scores = -1.802 ± 0.06 (n=2), actor_loss = 1.599, critic_loss = 0.010, entropy_coef_loss = -80.511, entropy_coef = 0.001, action_stds = 0.433 ± 0.064, action_magnitude = 0.523 ± 0.286, num_gradient_steps = 77000, step_time = 11.10, total_time = 852.68
#
# step = 88000, num_env_steps = 88000, scores = -1.840 ± 0.17 (n=2), actor_loss = 1.670, critic_loss = 0.011, entropy_coef_loss = -79.799, entropy_coef = 0.001, action_stds = 0.356 ± 0.053, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 78000, step_time = 11.02, total_time = 863.69
#
# step = 89000, num_env_steps = 89000, scores = -2.049 ± 0.06 (n=2), actor_loss = 1.750, critic_loss = 0.012, entropy_coef_loss = -77.971, entropy_coef = 0.001, action_stds = 0.370 ± 0.021, action_magnitude = 0.499 ± 0.281, num_gradient_steps = 79000, step_time = 11.05, total_time = 874.74
#
# step = 90000, num_env_steps = 90000, scores = -1.552 ± 0.09 (n=2), actor_loss = 1.880, critic_loss = 0.010, entropy_coef_loss = -79.259, entropy_coef = 0.001, action_stds = 0.371 ± 0.043, action_magnitude = 0.512 ± 0.285, num_gradient_steps = 80000, step_time = 11.01, total_time = 885.75
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 91000, num_env_steps = 91000, scores = -1.879 ± 0.02 (n=2), actor_loss = 2.020, critic_loss = 0.011, entropy_coef_loss = -80.820, entropy_coef = 0.001, action_stds = 0.422 ± 0.051, action_magnitude = 0.517 ± 0.287, num_gradient_steps = 81000, step_time = 11.01, total_time = 896.76
#
# step = 92000, num_env_steps = 92000, scores = -2.246 ± 0.10 (n=2), actor_loss = 2.082, critic_loss = 0.010, entropy_coef_loss = -78.781, entropy_coef = 0.001, action_stds = 0.371 ± 0.039, action_magnitude = 0.536 ± 0.288, num_gradient_steps = 82000, step_time = 11.04, total_time = 907.80
#
# step = 93000, num_env_steps = 93000, scores = -2.058 ± 0.01 (n=2), actor_loss = 2.081, critic_loss = 0.009, entropy_coef_loss = -76.885, entropy_coef = 0.001, action_stds = 0.383 ± 0.047, action_magnitude = 0.515 ± 0.286, num_gradient_steps = 83000, step_time = 11.04, total_time = 918.83
#
# step = 94000, num_env_steps = 94000, scores = -2.030 ± 0.29 (n=2), actor_loss = 2.195, critic_loss = 0.009, entropy_coef_loss = -80.449, entropy_coef = 0.001, action_stds = 0.364 ± 0.032, action_magnitude = 0.519 ± 0.286, num_gradient_steps = 84000, step_time = 11.03, total_time = 929.87
#
# step = 95000, num_env_steps = 95000, scores = -2.109 ± 0.27 (n=2), actor_loss = 2.290, critic_loss = 0.010, entropy_coef_loss = -82.304, entropy_coef = 0.001, action_stds = 0.408 ± 0.062, action_magnitude = 0.503 ± 0.283, num_gradient_steps = 85000, step_time = 11.09, total_time = 940.96
#
# step = 96000, num_env_steps = 96000, scores = -2.207 ± 0.28 (n=2), actor_loss = 2.307, critic_loss = 0.009, entropy_coef_loss = -78.912, entropy_coef = 0.001, action_stds = 0.359 ± 0.030, action_magnitude = 0.527 ± 0.289, num_gradient_steps = 86000, step_time = 11.04, total_time = 951.99
#
# step = 97000, num_env_steps = 97000, scores = -2.242 ± 0.48 (n=2), actor_loss = 2.428, critic_loss = 0.010, entropy_coef_loss = -83.250, entropy_coef = 0.001, action_stds = 0.403 ± 0.056, action_magnitude = 0.518 ± 0.286, num_gradient_steps = 87000, step_time = 11.04, total_time = 963.03
#
# step = 98000, num_env_steps = 98000, scores = -2.092 ± 0.26 (n=2), actor_loss = 2.480, critic_loss = 0.010, entropy_coef_loss = -80.043, entropy_coef = 0.001, action_stds = 0.403 ± 0.045, action_magnitude = 0.516 ± 0.286, num_gradient_steps = 88000, step_time = 11.09, total_time = 974.12
#
# step = 99000, num_env_steps = 99000, scores = -1.650 ± 0.09 (n=2), actor_loss = 2.626, critic_loss = 0.011, entropy_coef_loss = -76.066, entropy_coef = 0.001, action_stds = 0.425 ± 0.042, action_magnitude = 0.495 ± 0.282, num_gradient_steps = 89000, step_time = 10.99, total_time = 985.11
#
# step = 100000, num_env_steps = 100000, scores = -2.126 ± 0.11 (n=2), actor_loss = 2.591, critic_loss = 0.009, entropy_coef_loss = -80.877, entropy_coef = 0.001, action_stds = 0.355 ± 0.037, action_magnitude = 0.498 ± 0.282, num_gradient_steps = 90000, step_time = 11.05, total_time = 996.16
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 101000, num_env_steps = 101000, scores = -1.821 ± 0.06 (n=2), actor_loss = 2.765, critic_loss = 0.010, entropy_coef_loss = -80.819, entropy_coef = 0.001, action_stds = 0.383 ± 0.027, action_magnitude = 0.497 ± 0.283, num_gradient_steps = 91000, step_time = 11.10, total_time = 1007.26
#
# step = 102000, num_env_steps = 102000, scores = -1.787 ± 0.20 (n=2), actor_loss = 2.775, critic_loss = 0.010, entropy_coef_loss = -87.054, entropy_coef = 0.001, action_stds = 0.398 ± 0.043, action_magnitude = 0.489 ± 0.281, num_gradient_steps = 92000, step_time = 11.04, total_time = 1018.31
#
# step = 103000, num_env_steps = 103000, scores = -1.928 ± 0.14 (n=2), actor_loss = 2.957, critic_loss = 0.009, entropy_coef_loss = -84.301, entropy_coef = 0.001, action_stds = 0.369 ± 0.055, action_magnitude = 0.494 ± 0.283, num_gradient_steps = 93000, step_time = 11.00, total_time = 1029.31
#
# step = 104000, num_env_steps = 104000, scores = -1.772 ± 0.20 (n=2), actor_loss = 2.832, critic_loss = 0.008, entropy_coef_loss = -82.013, entropy_coef = 0.001, action_stds = 0.388 ± 0.028, action_magnitude = 0.498 ± 0.285, num_gradient_steps = 94000, step_time = 11.06, total_time = 1040.37
#
# step = 105000, num_env_steps = 105000, scores = -1.628 ± 0.16 (n=2), actor_loss = 2.836, critic_loss = 0.008, entropy_coef_loss = -81.890, entropy_coef = 0.001, action_stds = 0.365 ± 0.045, action_magnitude = 0.497 ± 0.280, num_gradient_steps = 95000, step_time = 11.02, total_time = 1051.39
#
# step = 106000, num_env_steps = 106000, scores = -2.106 ± 0.01 (n=2), actor_loss = 2.929, critic_loss = 0.010, entropy_coef_loss = -78.715, entropy_coef = 0.001, action_stds = 0.374 ± 0.048, action_magnitude = 0.498 ± 0.283, num_gradient_steps = 96000, step_time = 11.06, total_time = 1062.45
#
# step = 107000, num_env_steps = 107000, scores = -2.079 ± 0.18 (n=2), actor_loss = 2.982, critic_loss = 0.010, entropy_coef_loss = -79.182, entropy_coef = 0.001, action_stds = 0.407 ± 0.041, action_magnitude = 0.505 ± 0.283, num_gradient_steps = 97000, step_time = 11.06, total_time = 1073.50
#
# step = 108000, num_env_steps = 108000, scores = -1.726 ± 0.03 (n=2), actor_loss = 2.967, critic_loss = 0.009, entropy_coef_loss = -82.106, entropy_coef = 0.001, action_stds = 0.344 ± 0.036, action_magnitude = 0.485 ± 0.281, num_gradient_steps = 98000, step_time = 11.06, total_time = 1084.56
#
# step = 109000, num_env_steps = 109000, scores = -1.541 ± 0.00 (n=2), actor_loss = 3.022, critic_loss = 0.009, entropy_coef_loss = -79.835, entropy_coef = 0.001, action_stds = 0.371 ± 0.039, action_magnitude = 0.471 ± 0.275, num_gradient_steps = 99000, step_time = 11.13, total_time = 1095.69
#
# step = 110000, num_env_steps = 110000, scores = -1.757 ± 0.16 (n=2), actor_loss = 3.242, critic_loss = 0.008, entropy_coef_loss = -81.644, entropy_coef = 0.001, action_stds = 0.341 ± 0.037, action_magnitude = 0.479 ± 0.278, num_gradient_steps = 100000, step_time = 11.04, total_time = 1106.73
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 111000, num_env_steps = 111000, scores = -1.898 ± 0.08 (n=2), actor_loss = 3.188, critic_loss = 0.010, entropy_coef_loss = -84.557, entropy_coef = 0.001, action_stds = 0.448 ± 0.097, action_magnitude = 0.510 ± 0.286, num_gradient_steps = 101000, step_time = 11.06, total_time = 1117.79
#
# step = 112000, num_env_steps = 112000, scores = -1.559 ± 0.02 (n=2), actor_loss = 3.122, critic_loss = 0.009, entropy_coef_loss = -83.253, entropy_coef = 0.001, action_stds = 0.402 ± 0.059, action_magnitude = 0.488 ± 0.280, num_gradient_steps = 102000, step_time = 11.04, total_time = 1128.82
#
# step = 113000, num_env_steps = 113000, scores = -1.662 ± 0.17 (n=2), actor_loss = 3.228, critic_loss = 0.009, entropy_coef_loss = -85.098, entropy_coef = 0.001, action_stds = 0.383 ± 0.058, action_magnitude = 0.493 ± 0.280, num_gradient_steps = 103000, step_time = 11.07, total_time = 1139.90
#
# step = 114000, num_env_steps = 114000, scores = -1.611 ± 0.18 (n=2), actor_loss = 3.248, critic_loss = 0.010, entropy_coef_loss = -81.027, entropy_coef = 0.001, action_stds = 0.403 ± 0.046, action_magnitude = 0.472 ± 0.276, num_gradient_steps = 104000, step_time = 11.11, total_time = 1151.01
#
# step = 115000, num_env_steps = 115000, scores = -1.703 ± 0.02 (n=2), actor_loss = 3.247, critic_loss = 0.008, entropy_coef_loss = -76.588, entropy_coef = 0.001, action_stds = 0.398 ± 0.058, action_magnitude = 0.502 ± 0.281, num_gradient_steps = 105000, step_time = 11.04, total_time = 1162.05
#
# step = 116000, num_env_steps = 116000, scores = -1.760 ± 0.28 (n=2), actor_loss = 3.287, critic_loss = 0.008, entropy_coef_loss = -82.775, entropy_coef = 0.001, action_stds = 0.459 ± 0.047, action_magnitude = 0.508 ± 0.283, num_gradient_steps = 106000, step_time = 11.02, total_time = 1173.07
#
# step = 117000, num_env_steps = 117000, scores = -1.772 ± 0.11 (n=2), actor_loss = 3.219, critic_loss = 0.010, entropy_coef_loss = -77.362, entropy_coef = 0.001, action_stds = 0.397 ± 0.053, action_magnitude = 0.485 ± 0.283, num_gradient_steps = 107000, step_time = 10.97, total_time = 1184.04
#
# step = 118000, num_env_steps = 118000, scores = -1.964 ± 0.54 (n=2), actor_loss = 3.315, critic_loss = 0.008, entropy_coef_loss = -77.882, entropy_coef = 0.001, action_stds = 0.380 ± 0.058, action_magnitude = 0.495 ± 0.284, num_gradient_steps = 108000, step_time = 11.04, total_time = 1195.08
#
# step = 119000, num_env_steps = 119000, scores = -2.081 ± 0.45 (n=2), actor_loss = 3.427, critic_loss = 0.009, entropy_coef_loss = -86.063, entropy_coef = 0.001, action_stds = 0.368 ± 0.047, action_magnitude = 0.516 ± 0.291, num_gradient_steps = 109000, step_time = 11.05, total_time = 1206.13
#
# step = 120000, num_env_steps = 120000, scores = -2.028 ± 0.23 (n=2), actor_loss = 3.416, critic_loss = 0.010, entropy_coef_loss = -83.029, entropy_coef = 0.001, action_stds = 0.357 ± 0.033, action_magnitude = 0.503 ± 0.285, num_gradient_steps = 110000, step_time = 11.03, total_time = 1217.16
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 121000, num_env_steps = 121000, scores = -2.096 ± 0.14 (n=2), actor_loss = 3.365, critic_loss = 0.008, entropy_coef_loss = -76.235, entropy_coef = 0.001, action_stds = 0.348 ± 0.041, action_magnitude = 0.527 ± 0.288, num_gradient_steps = 111000, step_time = 10.99, total_time = 1228.15
#
# step = 122000, num_env_steps = 122000, scores = -1.631 ± 0.03 (n=2), actor_loss = 3.394, critic_loss = 0.007, entropy_coef_loss = -81.755, entropy_coef = 0.001, action_stds = 0.369 ± 0.059, action_magnitude = 0.499 ± 0.284, num_gradient_steps = 112000, step_time = 11.08, total_time = 1239.23
#
# step = 123000, num_env_steps = 123000, scores = -2.524 ± 0.44 (n=2), actor_loss = 3.296, critic_loss = 0.008, entropy_coef_loss = -79.884, entropy_coef = 0.001, action_stds = 0.407 ± 0.039, action_magnitude = 0.512 ± 0.287, num_gradient_steps = 113000, step_time = 11.02, total_time = 1250.26
#
# step = 124000, num_env_steps = 124000, scores = -1.875 ± 0.09 (n=2), actor_loss = 3.512, critic_loss = 0.009, entropy_coef_loss = -78.527, entropy_coef = 0.001, action_stds = 0.356 ± 0.043, action_magnitude = 0.460 ± 0.269, num_gradient_steps = 114000, step_time = 11.00, total_time = 1261.26
#
# step = 125000, num_env_steps = 125000, scores = -2.094 ± 0.12 (n=2), actor_loss = 3.610, critic_loss = 0.007, entropy_coef_loss = -86.452, entropy_coef = 0.001, action_stds = 0.377 ± 0.063, action_magnitude = 0.504 ± 0.283, num_gradient_steps = 115000, step_time = 11.00, total_time = 1272.26
#
# step = 126000, num_env_steps = 126000, scores = -1.649 ± 0.07 (n=2), actor_loss = 3.649, critic_loss = 0.008, entropy_coef_loss = -80.028, entropy_coef = 0.001, action_stds = 0.355 ± 0.037, action_magnitude = 0.508 ± 0.286, num_gradient_steps = 116000, step_time = 11.02, total_time = 1283.28
#
# step = 127000, num_env_steps = 127000, scores = -1.771 ± 0.09 (n=2), actor_loss = 3.412, critic_loss = 0.008, entropy_coef_loss = -74.899, entropy_coef = 0.001, action_stds = 0.388 ± 0.052, action_magnitude = 0.511 ± 0.284, num_gradient_steps = 117000, step_time = 10.98, total_time = 1294.26
#
# step = 128000, num_env_steps = 128000, scores = -1.942 ± 0.01 (n=2), actor_loss = 3.376, critic_loss = 0.008, entropy_coef_loss = -82.262, entropy_coef = 0.001, action_stds = 0.378 ± 0.031, action_magnitude = 0.495 ± 0.280, num_gradient_steps = 118000, step_time = 10.98, total_time = 1305.24
#
# step = 129000, num_env_steps = 129000, scores = -1.982 ± 0.28 (n=2), actor_loss = 3.655, critic_loss = 0.008, entropy_coef_loss = -81.446, entropy_coef = 0.001, action_stds = 0.384 ± 0.047, action_magnitude = 0.505 ± 0.281, num_gradient_steps = 119000, step_time = 11.06, total_time = 1316.30
#
# step = 130000, num_env_steps = 130000, scores = -1.738 ± 0.15 (n=2), actor_loss = 3.523, critic_loss = 0.008, entropy_coef_loss = -84.707, entropy_coef = 0.001, action_stds = 0.352 ± 0.043, action_magnitude = 0.457 ± 0.273, num_gradient_steps = 120000, step_time = 10.99, total_time = 1327.29
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 131000, num_env_steps = 131000, scores = -1.770 ± 0.05 (n=2), actor_loss = 3.556, critic_loss = 0.009, entropy_coef_loss = -84.861, entropy_coef = 0.001, action_stds = 0.412 ± 0.041, action_magnitude = 0.486 ± 0.278, num_gradient_steps = 121000, step_time = 11.06, total_time = 1338.36
#
# step = 132000, num_env_steps = 132000, scores = -1.727 ± 0.10 (n=2), actor_loss = 3.565, critic_loss = 0.010, entropy_coef_loss = -83.601, entropy_coef = 0.001, action_stds = 0.346 ± 0.043, action_magnitude = 0.456 ± 0.270, num_gradient_steps = 122000, step_time = 10.99, total_time = 1349.34
#
# step = 133000, num_env_steps = 133000, scores = -1.623 ± 0.15 (n=2), actor_loss = 3.743, critic_loss = 0.008, entropy_coef_loss = -87.211, entropy_coef = 0.001, action_stds = 0.377 ± 0.044, action_magnitude = 0.453 ± 0.269, num_gradient_steps = 123000, step_time = 11.02, total_time = 1360.36
#
# step = 134000, num_env_steps = 134000, scores = -1.620 ± 0.19 (n=2), actor_loss = 3.596, critic_loss = 0.008, entropy_coef_loss = -87.777, entropy_coef = 0.001, action_stds = 0.351 ± 0.050, action_magnitude = 0.466 ± 0.273, num_gradient_steps = 124000, step_time = 11.02, total_time = 1371.38
#
# step = 135000, num_env_steps = 135000, scores = -1.892 ± 0.06 (n=2), actor_loss = 3.653, critic_loss = 0.008, entropy_coef_loss = -84.173, entropy_coef = 0.001, action_stds = 0.446 ± 0.061, action_magnitude = 0.494 ± 0.282, num_gradient_steps = 125000, step_time = 11.04, total_time = 1382.42
#
# step = 136000, num_env_steps = 136000, scores = -1.793 ± 0.08 (n=2), actor_loss = 3.517, critic_loss = 0.008, entropy_coef_loss = -81.797, entropy_coef = 0.001, action_stds = 0.358 ± 0.043, action_magnitude = 0.467 ± 0.275, num_gradient_steps = 126000, step_time = 11.02, total_time = 1393.45
#
# step = 137000, num_env_steps = 137000, scores = -1.613 ± 0.01 (n=2), actor_loss = 3.582, critic_loss = 0.008, entropy_coef_loss = -86.568, entropy_coef = 0.001, action_stds = 0.347 ± 0.048, action_magnitude = 0.464 ± 0.274, num_gradient_steps = 127000, step_time = 10.99, total_time = 1404.44
#
# step = 138000, num_env_steps = 138000, scores = -1.816 ± 0.03 (n=2), actor_loss = 3.685, critic_loss = 0.008, entropy_coef_loss = -83.995, entropy_coef = 0.001, action_stds = 0.337 ± 0.021, action_magnitude = 0.453 ± 0.270, num_gradient_steps = 128000, step_time = 11.07, total_time = 1415.51
#
# step = 139000, num_env_steps = 139000, scores = -1.681 ± 0.08 (n=2), actor_loss = 3.686, critic_loss = 0.008, entropy_coef_loss = -81.752, entropy_coef = 0.001, action_stds = 0.382 ± 0.047, action_magnitude = 0.486 ± 0.279, num_gradient_steps = 129000, step_time = 11.05, total_time = 1426.55
#
# step = 140000, num_env_steps = 140000, scores = -1.846 ± 0.12 (n=2), actor_loss = 3.541, critic_loss = 0.009, entropy_coef_loss = -77.873, entropy_coef = 0.001, action_stds = 0.367 ± 0.038, action_magnitude = 0.472 ± 0.276, num_gradient_steps = 130000, step_time = 11.06, total_time = 1437.62
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 141000, num_env_steps = 141000, scores = -1.647 ± 0.05 (n=2), actor_loss = 3.564, critic_loss = 0.008, entropy_coef_loss = -83.899, entropy_coef = 0.001, action_stds = 0.359 ± 0.050, action_magnitude = 0.479 ± 0.276, num_gradient_steps = 131000, step_time = 11.05, total_time = 1448.67
#
# step = 142000, num_env_steps = 142000, scores = -1.854 ± 0.06 (n=2), actor_loss = 3.600, critic_loss = 0.009, entropy_coef_loss = -78.374, entropy_coef = 0.001, action_stds = 0.367 ± 0.050, action_magnitude = 0.465 ± 0.274, num_gradient_steps = 132000, step_time = 11.03, total_time = 1459.70
#
# step = 143000, num_env_steps = 143000, scores = -1.525 ± 0.00 (n=2), actor_loss = 3.693, critic_loss = 0.008, entropy_coef_loss = -83.815, entropy_coef = 0.001, action_stds = 0.340 ± 0.030, action_magnitude = 0.474 ± 0.276, num_gradient_steps = 133000, step_time = 10.99, total_time = 1470.69
#
# step = 144000, num_env_steps = 144000, scores = -1.569 ± 0.02 (n=2), actor_loss = 3.581, critic_loss = 0.009, entropy_coef_loss = -84.469, entropy_coef = 0.001, action_stds = 0.342 ± 0.038, action_magnitude = 0.446 ± 0.266, num_gradient_steps = 134000, step_time = 11.01, total_time = 1481.70
#
# step = 145000, num_env_steps = 145000, scores = -1.401 ± 0.17 (n=2), actor_loss = 3.839, critic_loss = 0.008, entropy_coef_loss = -84.321, entropy_coef = 0.001, action_stds = 0.328 ± 0.039, action_magnitude = 0.435 ± 0.264, num_gradient_steps = 135000, step_time = 10.96, total_time = 1492.66
#
# step = 146000, num_env_steps = 146000, scores = -1.665 ± 0.18 (n=2), actor_loss = 3.537, critic_loss = 0.006, entropy_coef_loss = -85.089, entropy_coef = 0.001, action_stds = 0.423 ± 0.056, action_magnitude = 0.465 ± 0.273, num_gradient_steps = 136000, step_time = 11.04, total_time = 1503.70
#
# step = 147000, num_env_steps = 147000, scores = -1.455 ± 0.06 (n=2), actor_loss = 3.722, critic_loss = 0.009, entropy_coef_loss = -80.042, entropy_coef = 0.001, action_stds = 0.348 ± 0.038, action_magnitude = 0.435 ± 0.264, num_gradient_steps = 137000, step_time = 10.96, total_time = 1514.66
#
# step = 148000, num_env_steps = 148000, scores = -1.816 ± 0.13 (n=2), actor_loss = 3.681, critic_loss = 0.008, entropy_coef_loss = -82.854, entropy_coef = 0.001, action_stds = 0.308 ± 0.038, action_magnitude = 0.453 ± 0.269, num_gradient_steps = 138000, step_time = 11.04, total_time = 1525.70
#
# step = 149000, num_env_steps = 149000, scores = -1.656 ± 0.09 (n=2), actor_loss = 3.717, critic_loss = 0.008, entropy_coef_loss = -84.261, entropy_coef = 0.001, action_stds = 0.368 ± 0.057, action_magnitude = 0.451 ± 0.266, num_gradient_steps = 139000, step_time = 10.96, total_time = 1536.66
#
# step = 150000, num_env_steps = 150000, scores = -2.126 ± 0.65 (n=2), actor_loss = 3.611, critic_loss = 0.008, entropy_coef_loss = -84.557, entropy_coef = 0.001, action_stds = 0.369 ± 0.058, action_magnitude = 0.531 ± 0.296, num_gradient_steps = 140000, step_time = 10.96, total_time = 1547.62
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 151000, num_env_steps = 151000, scores = -1.301 ± 0.11 (n=2), actor_loss = 3.596, critic_loss = 0.007, entropy_coef_loss = -80.602, entropy_coef = 0.001, action_stds = 0.344 ± 0.045, action_magnitude = 0.457 ± 0.269, num_gradient_steps = 141000, step_time = 11.05, total_time = 1558.67
#
# step = 152000, num_env_steps = 152000, scores = -2.291 ± 0.34 (n=2), actor_loss = 3.505, critic_loss = 0.008, entropy_coef_loss = -81.743, entropy_coef = 0.001, action_stds = 0.386 ± 0.061, action_magnitude = 0.547 ± 0.290, num_gradient_steps = 142000, step_time = 11.07, total_time = 1569.74
#
# step = 153000, num_env_steps = 153000, scores = -1.415 ± 0.02 (n=2), actor_loss = 3.517, critic_loss = 0.008, entropy_coef_loss = -83.388, entropy_coef = 0.001, action_stds = 0.344 ± 0.028, action_magnitude = 0.448 ± 0.265, num_gradient_steps = 143000, step_time = 11.02, total_time = 1580.76
#
# step = 154000, num_env_steps = 154000, scores = -1.744 ± 0.11 (n=2), actor_loss = 3.611, critic_loss = 0.008, entropy_coef_loss = -85.382, entropy_coef = 0.001, action_stds = 0.311 ± 0.039, action_magnitude = 0.476 ± 0.276, num_gradient_steps = 144000, step_time = 10.99, total_time = 1591.75
#
# step = 155000, num_env_steps = 155000, scores = -1.652 ± 0.29 (n=2), actor_loss = 3.576, critic_loss = 0.007, entropy_coef_loss = -81.436, entropy_coef = 0.001, action_stds = 0.367 ± 0.040, action_magnitude = 0.471 ± 0.271, num_gradient_steps = 145000, step_time = 11.05, total_time = 1602.80
#
# step = 156000, num_env_steps = 156000, scores = -1.616 ± 0.20 (n=2), actor_loss = 3.533, critic_loss = 0.008, entropy_coef_loss = -83.697, entropy_coef = 0.001, action_stds = 0.377 ± 0.034, action_magnitude = 0.462 ± 0.274, num_gradient_steps = 146000, step_time = 11.05, total_time = 1613.85
#
# step = 157000, num_env_steps = 157000, scores = -1.770 ± 0.06 (n=2), actor_loss = 3.562, critic_loss = 0.009, entropy_coef_loss = -79.252, entropy_coef = 0.001, action_stds = 0.376 ± 0.052, action_magnitude = 0.460 ± 0.269, num_gradient_steps = 147000, step_time = 11.06, total_time = 1624.91
#
# step = 158000, num_env_steps = 158000, scores = -1.686 ± 0.01 (n=2), actor_loss = 3.608, critic_loss = 0.008, entropy_coef_loss = -84.409, entropy_coef = 0.001, action_stds = 0.406 ± 0.048, action_magnitude = 0.475 ± 0.277, num_gradient_steps = 148000, step_time = 11.00, total_time = 1635.90
#
# step = 159000, num_env_steps = 159000, scores = -1.635 ± 0.11 (n=2), actor_loss = 3.621, critic_loss = 0.006, entropy_coef_loss = -84.509, entropy_coef = 0.001, action_stds = 0.339 ± 0.030, action_magnitude = 0.452 ± 0.270, num_gradient_steps = 149000, step_time = 11.04, total_time = 1646.94
#
# step = 160000, num_env_steps = 160000, scores = -1.704 ± 0.36 (n=2), actor_loss = 3.530, critic_loss = 0.007, entropy_coef_loss = -81.504, entropy_coef = 0.001, action_stds = 0.309 ± 0.031, action_magnitude = 0.458 ± 0.273, num_gradient_steps = 150000, step_time = 11.05, total_time = 1657.99
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 161000, num_env_steps = 161000, scores = -2.095 ± 0.16 (n=2), actor_loss = 3.475, critic_loss = 0.008, entropy_coef_loss = -81.596, entropy_coef = 0.001, action_stds = 0.345 ± 0.029, action_magnitude = 0.495 ± 0.272, num_gradient_steps = 151000, step_time = 11.04, total_time = 1669.03
#
# step = 162000, num_env_steps = 162000, scores = -1.331 ± 0.02 (n=2), actor_loss = 3.491, critic_loss = 0.008, entropy_coef_loss = -82.977, entropy_coef = 0.001, action_stds = 0.349 ± 0.038, action_magnitude = 0.441 ± 0.267, num_gradient_steps = 152000, step_time = 10.95, total_time = 1679.98
#
# step = 163000, num_env_steps = 163000, scores = -1.365 ± 0.09 (n=2), actor_loss = 3.595, critic_loss = 0.009, entropy_coef_loss = -85.840, entropy_coef = 0.001, action_stds = 0.367 ± 0.041, action_magnitude = 0.468 ± 0.274, num_gradient_steps = 153000, step_time = 11.08, total_time = 1691.05
#
# step = 164000, num_env_steps = 164000, scores = -1.530 ± 0.11 (n=2), actor_loss = 3.435, critic_loss = 0.009, entropy_coef_loss = -82.319, entropy_coef = 0.001, action_stds = 0.327 ± 0.040, action_magnitude = 0.452 ± 0.270, num_gradient_steps = 154000, step_time = 11.05, total_time = 1702.11
#
# step = 165000, num_env_steps = 165000, scores = -1.721 ± 0.41 (n=2), actor_loss = 3.483, critic_loss = 0.009, entropy_coef_loss = -81.505, entropy_coef = 0.001, action_stds = 0.348 ± 0.053, action_magnitude = 0.486 ± 0.281, num_gradient_steps = 155000, step_time = 11.03, total_time = 1713.13
#
# step = 166000, num_env_steps = 166000, scores = -1.796 ± 0.02 (n=2), actor_loss = 3.410, critic_loss = 0.008, entropy_coef_loss = -82.717, entropy_coef = 0.001, action_stds = 0.349 ± 0.044, action_magnitude = 0.497 ± 0.280, num_gradient_steps = 156000, step_time = 11.05, total_time = 1724.18
#
# step = 167000, num_env_steps = 167000, scores = -1.610 ± 0.23 (n=2), actor_loss = 3.579, critic_loss = 0.007, entropy_coef_loss = -83.729, entropy_coef = 0.001, action_stds = 0.356 ± 0.038, action_magnitude = 0.482 ± 0.280, num_gradient_steps = 157000, step_time = 11.02, total_time = 1735.20
#
# ...
#
# step = 3833000, num_env_steps = 3833000, scores = 10.291 ± 15.61 (n=2), actor_loss = -28.723, critic_loss = 0.733, entropy_coef_loss = -1.545, entropy_coef = 0.008, action_stds = 0.534 ± 0.068, action_magnitude = 0.804 ± 0.245, num_gradient_steps = 3823000, step_time = 10.78, total_time = 41967.56
#
# step = 3834000, num_env_steps = 3834000, scores = 25.075 ± 0.53 (n=2), actor_loss = -29.063, critic_loss = 0.560, entropy_coef_loss = -2.643, entropy_coef = 0.008, action_stds = 0.532 ± 0.037, action_magnitude = 0.764 ± 0.263, num_gradient_steps = 3824000, step_time = 10.79, total_time = 41978.34
#
# step = 3835000, num_env_steps = 3835000, scores = 25.374 ± 0.99 (n=2), actor_loss = -29.429, critic_loss = 0.461, entropy_coef_loss = -0.462, entropy_coef = 0.008, action_stds = 0.548 ± 0.042, action_magnitude = 0.768 ± 0.260, num_gradient_steps = 3825000, step_time = 10.78, total_time = 41989.12
#
# step = 3836000, num_env_steps = 3836000, scores = 25.439 ± 1.13 (n=2), actor_loss = -28.385, critic_loss = 0.414, entropy_coef_loss = -0.252, entropy_coef = 0.008, action_stds = 0.551 ± 0.048, action_magnitude = 0.770 ± 0.258, num_gradient_steps = 3826000, step_time = 10.82, total_time = 41999.94
#
# step = 3837000, num_env_steps = 3837000, scores = -4.276 ± 0.29 (n=2), actor_loss = -28.469, critic_loss = 0.544, entropy_coef_loss = 1.675, entropy_coef = 0.008, action_stds = 0.401 ± 0.086, action_magnitude = 0.753 ± 0.275, num_gradient_steps = 3827000, step_time = 10.65, total_time = 42010.60
#
# step = 3838000, num_env_steps = 3838000, scores = 10.054 ± 14.66 (n=2), actor_loss = -27.178, critic_loss = 0.436, entropy_coef_loss = 0.921, entropy_coef = 0.008, action_stds = 0.564 ± 0.055, action_magnitude = 0.769 ± 0.256, num_gradient_steps = 3828000, step_time = 10.74, total_time = 42021.34
#
# step = 3839000, num_env_steps = 3839000, scores = 24.742 ± 0.37 (n=2), actor_loss = -29.270, critic_loss = 0.523, entropy_coef_loss = 0.861, entropy_coef = 0.008, action_stds = 0.537 ± 0.040, action_magnitude = 0.764 ± 0.264, num_gradient_steps = 3829000, step_time = 10.81, total_time = 42032.15
#
# step = 3840000, num_env_steps = 3840000, scores = 11.227 ± 14.94 (n=2), actor_loss = -28.183, critic_loss = 0.554, entropy_coef_loss = 2.484, entropy_coef = 0.008, action_stds = 0.548 ± 0.039, action_magnitude = 0.745 ± 0.274, num_gradient_steps = 3830000, step_time = 10.77, total_time = 42042.92
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 3841000, num_env_steps = 3841000, scores = -4.573 ± 0.12 (n=2), actor_loss = -28.079, critic_loss = 0.539, entropy_coef_loss = -0.670, entropy_coef = 0.008, action_stds = 0.403 ± 0.090, action_magnitude = 0.778 ± 0.245, num_gradient_steps = 3831000, step_time = 11.01, total_time = 42053.93
#
# step = 3842000, num_env_steps = 3842000, scores = 25.005 ± 0.05 (n=2), actor_loss = -28.154, critic_loss = 0.450, entropy_coef_loss = -4.966, entropy_coef = 0.008, action_stds = 0.558 ± 0.043, action_magnitude = 0.768 ± 0.258, num_gradient_steps = 3832000, step_time = 10.82, total_time = 42064.76
#
# step = 3843000, num_env_steps = 3843000, scores = 21.006 ± 5.14 (n=2), actor_loss = -28.167, critic_loss = 0.546, entropy_coef_loss = -0.167, entropy_coef = 0.008, action_stds = 0.539 ± 0.045, action_magnitude = 0.774 ± 0.262, num_gradient_steps = 3833000, step_time = 10.79, total_time = 42075.55
#
# step = 3844000, num_env_steps = 3844000, scores = 25.938 ± 1.07 (n=2), actor_loss = -28.819, critic_loss = 0.508, entropy_coef_loss = 1.000, entropy_coef = 0.008, action_stds = 0.528 ± 0.056, action_magnitude = 0.774 ± 0.258, num_gradient_steps = 3834000, step_time = 10.83, total_time = 42086.37
#
# step = 3845000, num_env_steps = 3845000, scores = 24.302 ± 0.70 (n=2), actor_loss = -28.091, critic_loss = 0.453, entropy_coef_loss = 2.032, entropy_coef = 0.008, action_stds = 0.545 ± 0.054, action_magnitude = 0.773 ± 0.259, num_gradient_steps = 3835000, step_time = 10.83, total_time = 42097.20
#
# step = 3846000, num_env_steps = 3846000, scores = 19.554 ± 4.86 (n=2), actor_loss = -28.016, critic_loss = 0.510, entropy_coef_loss = 2.370, entropy_coef = 0.008, action_stds = 0.480 ± 0.133, action_magnitude = 0.767 ± 0.265, num_gradient_steps = 3836000, step_time = 10.78, total_time = 42107.98
#
# step = 3847000, num_env_steps = 3847000, scores = 26.721 ± 1.79 (n=2), actor_loss = -28.165, critic_loss = 0.417, entropy_coef_loss = -0.431, entropy_coef = 0.008, action_stds = 0.534 ± 0.039, action_magnitude = 0.767 ± 0.260, num_gradient_steps = 3837000, step_time = 11.13, total_time = 42119.11
#
# step = 3848000, num_env_steps = 3848000, scores = 24.899 ± 1.45 (n=2), actor_loss = -28.016, critic_loss = 0.506, entropy_coef_loss = 0.163, entropy_coef = 0.008, action_stds = 0.563 ± 0.064, action_magnitude = 0.770 ± 0.260, num_gradient_steps = 3838000, step_time = 10.92, total_time = 42130.03
#
# step = 3849000, num_env_steps = 3849000, scores = 26.273 ± 0.08 (n=2), actor_loss = -27.494, critic_loss = 0.472, entropy_coef_loss = 1.067, entropy_coef = 0.008, action_stds = 0.508 ± 0.046, action_magnitude = 0.775 ± 0.256, num_gradient_steps = 3839000, step_time = 10.78, total_time = 42140.81
#
# step = 3850000, num_env_steps = 3850000, scores = 24.443 ± 0.93 (n=2), actor_loss = -29.122, critic_loss = 0.520, entropy_coef_loss = -0.137, entropy_coef = 0.008, action_stds = 0.526 ± 0.042, action_magnitude = 0.776 ± 0.258, num_gradient_steps = 3840000, step_time = 10.83, total_time = 42151.65
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 3851000, num_env_steps = 3851000, scores = 25.294 ± 1.65 (n=2), actor_loss = -28.369, critic_loss = 0.636, entropy_coef_loss = 4.236, entropy_coef = 0.008, action_stds = 0.521 ± 0.040, action_magnitude = 0.771 ± 0.260, num_gradient_steps = 3841000, step_time = 11.12, total_time = 42162.77
#
# step = 3852000, num_env_steps = 3852000, scores = 25.796 ± 0.16 (n=2), actor_loss = -29.121, critic_loss = 0.523, entropy_coef_loss = 0.435, entropy_coef = 0.008, action_stds = 0.542 ± 0.039, action_magnitude = 0.769 ± 0.262, num_gradient_steps = 3842000, step_time = 10.82, total_time = 42173.59
#
# step = 3853000, num_env_steps = 3853000, scores = 26.669 ± 0.77 (n=2), actor_loss = -28.388, critic_loss = 0.679, entropy_coef_loss = 1.595, entropy_coef = 0.008, action_stds = 0.546 ± 0.061, action_magnitude = 0.765 ± 0.263, num_gradient_steps = 3843000, step_time = 10.83, total_time = 42184.41
#
# step = 3854000, num_env_steps = 3854000, scores = 24.074 ± 0.51 (n=2), actor_loss = -28.667, critic_loss = 0.458, entropy_coef_loss = 2.200, entropy_coef = 0.008, action_stds = 0.507 ± 0.066, action_magnitude = 0.774 ± 0.258, num_gradient_steps = 3844000, step_time = 10.88, total_time = 42195.29
#
# step = 3855000, num_env_steps = 3855000, scores = 24.087 ± 1.11 (n=2), actor_loss = -28.989, critic_loss = 0.595, entropy_coef_loss = 0.955, entropy_coef = 0.008, action_stds = 0.526 ± 0.061, action_magnitude = 0.772 ± 0.260, num_gradient_steps = 3845000, step_time = 10.79, total_time = 42206.08
#
# step = 3856000, num_env_steps = 3856000, scores = 25.513 ± 0.42 (n=2), actor_loss = -28.865, critic_loss = 0.683, entropy_coef_loss = -2.444, entropy_coef = 0.008, action_stds = 0.553 ± 0.048, action_magnitude = 0.773 ± 0.259, num_gradient_steps = 3846000, step_time = 10.82, total_time = 42216.90
#
# step = 3857000, num_env_steps = 3857000, scores = 27.079 ± 0.36 (n=2), actor_loss = -29.236, critic_loss = 0.652, entropy_coef_loss = 0.395, entropy_coef = 0.008, action_stds = 0.535 ± 0.039, action_magnitude = 0.770 ± 0.260, num_gradient_steps = 3847000, step_time = 10.82, total_time = 42227.72
#
# step = 3858000, num_env_steps = 3858000, scores = 26.065 ± 0.74 (n=2), actor_loss = -28.652, critic_loss = 0.402, entropy_coef_loss = 4.997, entropy_coef = 0.008, action_stds = 0.520 ± 0.035, action_magnitude = 0.770 ± 0.261, num_gradient_steps = 3848000, step_time = 10.82, total_time = 42238.54
#
# step = 3859000, num_env_steps = 3859000, scores = 23.064 ± 2.53 (n=2), actor_loss = -29.917, critic_loss = 0.538, entropy_coef_loss = 0.555, entropy_coef = 0.008, action_stds = 0.533 ± 0.055, action_magnitude = 0.763 ± 0.264, num_gradient_steps = 3849000, step_time = 10.87, total_time = 42249.41
#
# step = 3860000, num_env_steps = 3860000, scores = 26.020 ± 0.38 (n=2), actor_loss = -28.295, critic_loss = 0.462, entropy_coef_loss = 1.026, entropy_coef = 0.008, action_stds = 0.536 ± 0.036, action_magnitude = 0.774 ± 0.258, num_gradient_steps = 3850000, step_time = 10.85, total_time = 42260.26
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 3861000, num_env_steps = 3861000, scores = 25.423 ± 0.88 (n=2), actor_loss = -27.274, critic_loss = 0.646, entropy_coef_loss = -0.115, entropy_coef = 0.008, action_stds = 0.534 ± 0.039, action_magnitude = 0.775 ± 0.256, num_gradient_steps = 3851000, step_time = 11.16, total_time = 42271.42
#
# step = 3862000, num_env_steps = 3862000, scores = 25.794 ± 0.48 (n=2), actor_loss = -28.757, critic_loss = 0.479, entropy_coef_loss = 3.534, entropy_coef = 0.008, action_stds = 0.532 ± 0.060, action_magnitude = 0.773 ± 0.259, num_gradient_steps = 3852000, step_time = 10.78, total_time = 42282.20
#
# step = 3863000, num_env_steps = 3863000, scores = 26.307 ± 1.72 (n=2), actor_loss = -28.131, critic_loss = 0.502, entropy_coef_loss = -0.678, entropy_coef = 0.008, action_stds = 0.570 ± 0.057, action_magnitude = 0.773 ± 0.256, num_gradient_steps = 3853000, step_time = 10.80, total_time = 42293.00
#
# step = 3864000, num_env_steps = 3864000, scores = 26.168 ± 0.86 (n=2), actor_loss = -28.831, critic_loss = 0.463, entropy_coef_loss = -1.807, entropy_coef = 0.008, action_stds = 0.540 ± 0.032, action_magnitude = 0.768 ± 0.262, num_gradient_steps = 3854000, step_time = 10.78, total_time = 42303.79
#
# step = 3865000, num_env_steps = 3865000, scores = 25.893 ± 1.01 (n=2), actor_loss = -28.726, critic_loss = 0.488, entropy_coef_loss = 0.706, entropy_coef = 0.008, action_stds = 0.530 ± 0.044, action_magnitude = 0.774 ± 0.258, num_gradient_steps = 3855000, step_time = 10.87, total_time = 42314.66
#
# step = 3866000, num_env_steps = 3866000, scores = 25.395 ± 0.65 (n=2), actor_loss = -28.680, critic_loss = 0.578, entropy_coef_loss = 5.019, entropy_coef = 0.008, action_stds = 0.517 ± 0.049, action_magnitude = 0.776 ± 0.257, num_gradient_steps = 3856000, step_time = 10.82, total_time = 42325.47
#
# step = 3867000, num_env_steps = 3867000, scores = 26.473 ± 0.34 (n=2), actor_loss = -29.683, critic_loss = 0.727, entropy_coef_loss = 0.541, entropy_coef = 0.008, action_stds = 0.518 ± 0.034, action_magnitude = 0.771 ± 0.261, num_gradient_steps = 3857000, step_time = 10.74, total_time = 42336.22
#
# step = 3868000, num_env_steps = 3868000, scores = 26.724 ± 0.76 (n=2), actor_loss = -28.708, critic_loss = 0.512, entropy_coef_loss = 2.885, entropy_coef = 0.008, action_stds = 0.529 ± 0.036, action_magnitude = 0.774 ± 0.261, num_gradient_steps = 3858000, step_time = 10.81, total_time = 42347.02
#
# step = 3869000, num_env_steps = 3869000, scores = 26.084 ± 0.83 (n=2), actor_loss = -28.555, critic_loss = 0.557, entropy_coef_loss = -2.797, entropy_coef = 0.008, action_stds = 0.525 ± 0.044, action_magnitude = 0.772 ± 0.260, num_gradient_steps = 3859000, step_time = 10.84, total_time = 42357.86
#
# step = 3870000, num_env_steps = 3870000, scores = 25.411 ± 0.67 (n=2), actor_loss = -27.808, critic_loss = 0.469, entropy_coef_loss = 2.990, entropy_coef = 0.008, action_stds = 0.523 ± 0.033, action_magnitude = 0.773 ± 0.261, num_gradient_steps = 3860000, step_time = 10.80, total_time = 42368.66
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 3871000, num_env_steps = 3871000, scores = 25.304 ± 0.12 (n=2), actor_loss = -29.665, critic_loss = 0.422, entropy_coef_loss = -2.658, entropy_coef = 0.008, action_stds = 0.525 ± 0.051, action_magnitude = 0.777 ± 0.256, num_gradient_steps = 3861000, step_time = 11.14, total_time = 42379.80
#
# step = 3872000, num_env_steps = 3872000, scores = 27.451 ± 0.44 (n=2), actor_loss = -29.388, critic_loss = 0.462, entropy_coef_loss = 1.021, entropy_coef = 0.008, action_stds = 0.529 ± 0.052, action_magnitude = 0.777 ± 0.256, num_gradient_steps = 3862000, step_time = 10.78, total_time = 42390.58
#
# step = 3873000, num_env_steps = 3873000, scores = 25.132 ± 1.06 (n=2), actor_loss = -28.059, critic_loss = 0.589, entropy_coef_loss = -2.952, entropy_coef = 0.008, action_stds = 0.518 ± 0.046, action_magnitude = 0.776 ± 0.257, num_gradient_steps = 3863000, step_time = 10.80, total_time = 42401.38
#
# step = 3874000, num_env_steps = 3874000, scores = 25.854 ± 0.30 (n=2), actor_loss = -28.693, critic_loss = 0.414, entropy_coef_loss = -0.730, entropy_coef = 0.008, action_stds = 0.505 ± 0.056, action_magnitude = 0.774 ± 0.259, num_gradient_steps = 3864000, step_time = 10.86, total_time = 42412.23
#
# step = 3875000, num_env_steps = 3875000, scores = 25.756 ± 1.37 (n=2), actor_loss = -29.305, critic_loss = 0.463, entropy_coef_loss = -3.549, entropy_coef = 0.008, action_stds = 0.558 ± 0.049, action_magnitude = 0.769 ± 0.259, num_gradient_steps = 3865000, step_time = 10.83, total_time = 42423.06
#
# step = 3876000, num_env_steps = 3876000, scores = 26.976 ± 0.91 (n=2), actor_loss = -28.823, critic_loss = 0.654, entropy_coef_loss = -0.144, entropy_coef = 0.008, action_stds = 0.530 ± 0.037, action_magnitude = 0.778 ± 0.255, num_gradient_steps = 3866000, step_time = 10.76, total_time = 42433.82
#
# step = 3877000, num_env_steps = 3877000, scores = 25.121 ± 0.32 (n=2), actor_loss = -28.665, critic_loss = 0.461, entropy_coef_loss = 1.326, entropy_coef = 0.008, action_stds = 0.525 ± 0.045, action_magnitude = 0.776 ± 0.256, num_gradient_steps = 3867000, step_time = 10.80, total_time = 42444.62
#
# step = 3878000, num_env_steps = 3878000, scores = 25.874 ± 1.27 (n=2), actor_loss = -29.618, critic_loss = 0.394, entropy_coef_loss = -2.009, entropy_coef = 0.008, action_stds = 0.530 ± 0.051, action_magnitude = 0.771 ± 0.259, num_gradient_steps = 3868000, step_time = 10.82, total_time = 42455.45
#
# step = 3879000, num_env_steps = 3879000, scores = 27.737 ± 0.35 (n=2), actor_loss = -30.012, critic_loss = 0.449, entropy_coef_loss = 1.791, entropy_coef = 0.008, action_stds = 0.548 ± 0.042, action_magnitude = 0.774 ± 0.259, num_gradient_steps = 3869000, step_time = 10.83, total_time = 42466.27
#
# step = 3880000, num_env_steps = 3880000, scores = 25.690 ± 0.27 (n=2), actor_loss = -28.063, critic_loss = 0.506, entropy_coef_loss = 0.701, entropy_coef = 0.008, action_stds = 0.521 ± 0.045, action_magnitude = 0.770 ± 0.263, num_gradient_steps = 3870000, step_time = 10.79, total_time = 42477.06
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
#
# step = 3881000, num_env_steps = 3881000, scores = 25.208 ± 0.82 (n=2), actor_loss = -29.067, critic_loss = 0.669, entropy_coef_loss = 0.800, entropy_coef = 0.008, action_stds = 0.506 ± 0.038, action_magnitude = 0.779 ± 0.257, num_gradient_steps = 3871000, step_time = 11.10, total_time = 42488.15
#
# step = 3882000, num_env_steps = 3882000, scores = 25.538 ± 0.59 (n=2), actor_loss = -29.490, critic_loss = 0.532, entropy_coef_loss = -4.810, entropy_coef = 0.008, action_stds = 0.525 ± 0.037, action_magnitude = 0.772 ± 0.260, num_gradient_steps = 3872000, step_time = 10.76, total_time = 42498.91
#
# step = 3883000, num_env_steps = 3883000, scores = 26.193 ± 0.12 (n=2), actor_loss = -29.918, critic_loss = 0.671, entropy_coef_loss = -0.008, entropy_coef = 0.008, action_stds = 0.547 ± 0.035, action_magnitude = 0.772 ± 0.262, num_gradient_steps = 3873000, step_time = 10.89, total_time = 42509.80
#
# saved experiment log 2024-11-04_23-58-16_274451~JZgCRn at experiment_logs/2024-11-04_23-58-16_274451~JZgCRn.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
def save_training():
    experiment_id = logger.experiment_log['experiment_id']
    algo.save(f'saved_models/{experiment_id}', experiment_id)

save_training()

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
