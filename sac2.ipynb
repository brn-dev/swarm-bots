# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.envs.swarm_bot_env__v0_1 import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
            best_iteration_score = iteration_score
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        if step % 100_000 == 0:
            save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=5, 
        hip_range=np.pi / 4,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    latent_action_size = 256
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, latent_action_size),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=latent_action_size,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_size=1_000_000,
            reward_scale=100,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef_clamp_range=(0.001, 1.5),
            # entropy_coef=0.1,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        # algo.load('saved_models/2024-10-28_11-12-19_363042~VskSv0/', '2024-10-28_11-12-19_363042~VskSv0')
        total_stopwatch.reset()
        with log_experiment(
            logger,
            # experiment_id='2024-10-28_11-12-19_363042~VskSv0_1',
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 259618
# env = <swarmbots.swarm_bot_env.SwarmBotEnv object at 0x000001BD938B64D0>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# Starting Training
#
# step = 11000, num_env_steps = 11000, scores = -2.941 ± 0.18 (n=2), actor_loss = -45.732, critic_loss = 12.145, entropy_coef_loss = -8.110, entropy_coef = 0.737, action_stds = 0.863 ± 0.046, action_magnitude = 0.519 ± 0.286, num_gradient_steps = 1000, step_time = 19.44, total_time = 18.68
#
# step = 12000, num_env_steps = 12000, scores = -2.352 ± 0.20 (n=2), actor_loss = -66.805, critic_loss = 9.828, entropy_coef_loss = -15.614, entropy_coef = 0.549, action_stds = 0.815 ± 0.045, action_magnitude = 0.540 ± 0.289, num_gradient_steps = 2000, step_time = 10.78, total_time = 29.46
#
# step = 13000, num_env_steps = 13000, scores = -2.575 ± 0.67 (n=2), actor_loss = -79.156, critic_loss = 6.667, entropy_coef_loss = -23.555, entropy_coef = 0.406, action_stds = 0.889 ± 0.016, action_magnitude = 0.537 ± 0.289, num_gradient_steps = 3000, step_time = 10.80, total_time = 40.26
#
# step = 14000, num_env_steps = 14000, scores = -3.392 ± 0.27 (n=2), actor_loss = -85.233, critic_loss = 5.432, entropy_coef_loss = -31.150, entropy_coef = 0.301, action_stds = 0.892 ± 0.012, action_magnitude = 0.534 ± 0.288, num_gradient_steps = 4000, step_time = 11.24, total_time = 51.50
#
# step = 15000, num_env_steps = 15000, scores = -2.587 ± 0.01 (n=2), actor_loss = -86.642, critic_loss = 4.960, entropy_coef_loss = -38.630, entropy_coef = 0.223, action_stds = 0.898 ± 0.028, action_magnitude = 0.543 ± 0.290, num_gradient_steps = 5000, step_time = 10.89, total_time = 62.39
#
# step = 16000, num_env_steps = 16000, scores = -2.731 ± 0.13 (n=2), actor_loss = -85.599, critic_loss = 4.252, entropy_coef_loss = -44.908, entropy_coef = 0.166, action_stds = 0.840 ± 0.071, action_magnitude = 0.548 ± 0.292, num_gradient_steps = 6000, step_time = 11.75, total_time = 74.14
#
# step = 17000, num_env_steps = 17000, scores = -2.972 ± 0.13 (n=2), actor_loss = -81.469, critic_loss = 3.297, entropy_coef_loss = -51.196, entropy_coef = 0.124, action_stds = 0.897 ± 0.020, action_magnitude = 0.567 ± 0.291, num_gradient_steps = 7000, step_time = 11.28, total_time = 85.43
#
# step = 18000, num_env_steps = 18000, scores = -2.586 ± 0.32 (n=2), actor_loss = -78.592, critic_loss = 2.954, entropy_coef_loss = -54.924, entropy_coef = 0.093, action_stds = 0.885 ± 0.036, action_magnitude = 0.570 ± 0.294, num_gradient_steps = 8000, step_time = 11.03, total_time = 96.45
#
# step = 19000, num_env_steps = 19000, scores = -3.306 ± 0.48 (n=2), actor_loss = -74.081, critic_loss = 2.946, entropy_coef_loss = -59.988, entropy_coef = 0.070, action_stds = 0.820 ± 0.058, action_magnitude = 0.587 ± 0.296, num_gradient_steps = 9000, step_time = 10.89, total_time = 107.34
#
# step = 20000, num_env_steps = 20000, scores = -3.801 ± 0.12 (n=2), actor_loss = -68.809, critic_loss = 2.139, entropy_coef_loss = -60.067, entropy_coef = 0.052, action_stds = 0.848 ± 0.042, action_magnitude = 0.597 ± 0.297, num_gradient_steps = 10000, step_time = 10.95, total_time = 118.29
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 21000, num_env_steps = 21000, scores = -3.288 ± 0.00 (n=2), actor_loss = -63.982, critic_loss = 2.094, entropy_coef_loss = -62.642, entropy_coef = 0.039, action_stds = 0.813 ± 0.047, action_magnitude = 0.612 ± 0.299, num_gradient_steps = 11000, step_time = 11.00, total_time = 129.29
#
# step = 22000, num_env_steps = 22000, scores = -3.438 ± 0.06 (n=2), actor_loss = -57.886, critic_loss = 2.483, entropy_coef_loss = -61.393, entropy_coef = 0.030, action_stds = 0.786 ± 0.092, action_magnitude = 0.617 ± 0.299, num_gradient_steps = 12000, step_time = 11.01, total_time = 140.31
#
# step = 23000, num_env_steps = 23000, scores = -3.879 ± 0.10 (n=2), actor_loss = -52.635, critic_loss = 2.081, entropy_coef_loss = -63.704, entropy_coef = 0.023, action_stds = 0.843 ± 0.062, action_magnitude = 0.627 ± 0.298, num_gradient_steps = 13000, step_time = 10.89, total_time = 151.19
#
# step = 24000, num_env_steps = 24000, scores = -3.526 ± 0.25 (n=2), actor_loss = -48.038, critic_loss = 1.660, entropy_coef_loss = -55.140, entropy_coef = 0.017, action_stds = 0.765 ± 0.058, action_magnitude = 0.639 ± 0.300, num_gradient_steps = 14000, step_time = 10.95, total_time = 162.14
#
# step = 25000, num_env_steps = 25000, scores = -3.650 ± 0.49 (n=2), actor_loss = -42.598, critic_loss = 1.543, entropy_coef_loss = -58.506, entropy_coef = 0.013, action_stds = 0.742 ± 0.065, action_magnitude = 0.661 ± 0.299, num_gradient_steps = 15000, step_time = 11.33, total_time = 173.47
#
# step = 26000, num_env_steps = 26000, scores = -4.082 ± 0.17 (n=2), actor_loss = -38.217, critic_loss = 1.404, entropy_coef_loss = -43.284, entropy_coef = 0.010, action_stds = 0.739 ± 0.043, action_magnitude = 0.660 ± 0.300, num_gradient_steps = 16000, step_time = 13.57, total_time = 187.04
#
# step = 27000, num_env_steps = 27000, scores = -4.143 ± 0.31 (n=2), actor_loss = -33.558, critic_loss = 1.542, entropy_coef_loss = -33.541, entropy_coef = 0.008, action_stds = 0.636 ± 0.081, action_magnitude = 0.670 ± 0.301, num_gradient_steps = 17000, step_time = 12.47, total_time = 199.51
#
# step = 28000, num_env_steps = 28000, scores = -3.962 ± 0.09 (n=2), actor_loss = -28.320, critic_loss = 1.598, entropy_coef_loss = -26.105, entropy_coef = 0.007, action_stds = 0.644 ± 0.119, action_magnitude = 0.679 ± 0.299, num_gradient_steps = 18000, step_time = 12.20, total_time = 211.70
#
# step = 29000, num_env_steps = 29000, scores = -4.190 ± 0.16 (n=2), actor_loss = -24.235, critic_loss = 1.549, entropy_coef_loss = -6.287, entropy_coef = 0.006, action_stds = 0.624 ± 0.073, action_magnitude = 0.692 ± 0.297, num_gradient_steps = 19000, step_time = 11.14, total_time = 222.85
#
# step = 30000, num_env_steps = 30000, scores = -4.403 ± 0.05 (n=2), actor_loss = -20.510, critic_loss = 1.172, entropy_coef_loss = -17.887, entropy_coef = 0.005, action_stds = 0.594 ± 0.055, action_magnitude = 0.686 ± 0.300, num_gradient_steps = 20000, step_time = 10.79, total_time = 233.64
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 31000, num_env_steps = 31000, scores = -4.151 ± 0.11 (n=2), actor_loss = -16.768, critic_loss = 1.406, entropy_coef_loss = -7.123, entropy_coef = 0.004, action_stds = 0.536 ± 0.050, action_magnitude = 0.690 ± 0.300, num_gradient_steps = 21000, step_time = 10.77, total_time = 244.41
#
# step = 32000, num_env_steps = 32000, scores = -4.277 ± 0.29 (n=2), actor_loss = -12.985, critic_loss = 1.297, entropy_coef_loss = 2.529, entropy_coef = 0.004, action_stds = 0.593 ± 0.041, action_magnitude = 0.697 ± 0.296, num_gradient_steps = 22000, step_time = 10.90, total_time = 255.31
#
# step = 33000, num_env_steps = 33000, scores = -4.067 ± 0.15 (n=2), actor_loss = -9.776, critic_loss = 1.246, entropy_coef_loss = -2.532, entropy_coef = 0.004, action_stds = 0.546 ± 0.043, action_magnitude = 0.688 ± 0.297, num_gradient_steps = 23000, step_time = 11.48, total_time = 266.79
#
# step = 34000, num_env_steps = 34000, scores = -4.310 ± 0.01 (n=2), actor_loss = -6.456, critic_loss = 1.347, entropy_coef_loss = -4.060, entropy_coef = 0.003, action_stds = 0.402 ± 0.042, action_magnitude = 0.680 ± 0.299, num_gradient_steps = 24000, step_time = 11.10, total_time = 277.89
#
# step = 35000, num_env_steps = 35000, scores = -4.081 ± 0.37 (n=2), actor_loss = -3.303, critic_loss = 1.132, entropy_coef_loss = 0.849, entropy_coef = 0.003, action_stds = 0.470 ± 0.084, action_magnitude = 0.674 ± 0.299, num_gradient_steps = 25000, step_time = 11.02, total_time = 288.91
#
# step = 36000, num_env_steps = 36000, scores = -4.124 ± 0.33 (n=2), actor_loss = -0.216, critic_loss = 1.279, entropy_coef_loss = -5.381, entropy_coef = 0.003, action_stds = 0.492 ± 0.044, action_magnitude = 0.666 ± 0.300, num_gradient_steps = 26000, step_time = 11.11, total_time = 300.02
#
# step = 37000, num_env_steps = 37000, scores = -4.547 ± 0.34 (n=2), actor_loss = 2.142, critic_loss = 1.352, entropy_coef_loss = -5.025, entropy_coef = 0.003, action_stds = 0.465 ± 0.100, action_magnitude = 0.706 ± 0.288, num_gradient_steps = 27000, step_time = 10.94, total_time = 310.96
#
# step = 38000, num_env_steps = 38000, scores = -4.107 ± 0.18 (n=2), actor_loss = 4.018, critic_loss = 1.131, entropy_coef_loss = 1.125, entropy_coef = 0.003, action_stds = 0.478 ± 0.083, action_magnitude = 0.657 ± 0.299, num_gradient_steps = 28000, step_time = 10.84, total_time = 321.80
#
# step = 39000, num_env_steps = 39000, scores = -4.188 ± 0.03 (n=2), actor_loss = 7.407, critic_loss = 1.273, entropy_coef_loss = 3.477, entropy_coef = 0.003, action_stds = 0.409 ± 0.080, action_magnitude = 0.669 ± 0.301, num_gradient_steps = 29000, step_time = 10.86, total_time = 332.66
#
# step = 40000, num_env_steps = 40000, scores = -4.299 ± 0.19 (n=2), actor_loss = 9.524, critic_loss = 1.263, entropy_coef_loss = 1.639, entropy_coef = 0.004, action_stds = 0.340 ± 0.032, action_magnitude = 0.666 ± 0.300, num_gradient_steps = 30000, step_time = 11.04, total_time = 343.70
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 41000, num_env_steps = 41000, scores = -4.259 ± 0.24 (n=2), actor_loss = 11.615, critic_loss = 1.312, entropy_coef_loss = -7.111, entropy_coef = 0.003, action_stds = 0.425 ± 0.055, action_magnitude = 0.680 ± 0.297, num_gradient_steps = 31000, step_time = 10.88, total_time = 354.58
#
# step = 42000, num_env_steps = 42000, scores = -3.736 ± 0.52 (n=2), actor_loss = 14.122, critic_loss = 1.288, entropy_coef_loss = 2.645, entropy_coef = 0.003, action_stds = 0.343 ± 0.040, action_magnitude = 0.678 ± 0.299, num_gradient_steps = 32000, step_time = 10.93, total_time = 365.51
#
# step = 43000, num_env_steps = 43000, scores = -3.951 ± 0.21 (n=2), actor_loss = 15.647, critic_loss = 1.212, entropy_coef_loss = 3.138, entropy_coef = 0.004, action_stds = 0.408 ± 0.067, action_magnitude = 0.665 ± 0.300, num_gradient_steps = 33000, step_time = 10.96, total_time = 376.47
#
# step = 44000, num_env_steps = 44000, scores = -3.685 ± 0.15 (n=2), actor_loss = 18.037, critic_loss = 1.255, entropy_coef_loss = -5.133, entropy_coef = 0.004, action_stds = 0.378 ± 0.055, action_magnitude = 0.665 ± 0.300, num_gradient_steps = 34000, step_time = 10.93, total_time = 387.40
#
# step = 45000, num_env_steps = 45000, scores = -4.351 ± 0.28 (n=2), actor_loss = 20.704, critic_loss = 1.317, entropy_coef_loss = 6.689, entropy_coef = 0.003, action_stds = 0.342 ± 0.081, action_magnitude = 0.661 ± 0.302, num_gradient_steps = 35000, step_time = 10.88, total_time = 398.28
#
# step = 46000, num_env_steps = 46000, scores = -3.842 ± 0.22 (n=2), actor_loss = 21.722, critic_loss = 1.225, entropy_coef_loss = -3.611, entropy_coef = 0.003, action_stds = 0.369 ± 0.052, action_magnitude = 0.651 ± 0.300, num_gradient_steps = 36000, step_time = 10.87, total_time = 409.15
#
# step = 47000, num_env_steps = 47000, scores = -3.183 ± 0.03 (n=2), actor_loss = 24.407, critic_loss = 1.440, entropy_coef_loss = 3.445, entropy_coef = 0.003, action_stds = 0.342 ± 0.027, action_magnitude = 0.642 ± 0.299, num_gradient_steps = 37000, step_time = 10.80, total_time = 419.95
#
# step = 48000, num_env_steps = 48000, scores = -3.729 ± 0.17 (n=2), actor_loss = 25.388, critic_loss = 1.450, entropy_coef_loss = -0.172, entropy_coef = 0.003, action_stds = 0.446 ± 0.074, action_magnitude = 0.642 ± 0.301, num_gradient_steps = 38000, step_time = 10.85, total_time = 430.80
#
# step = 49000, num_env_steps = 49000, scores = -4.104 ± 1.00 (n=2), actor_loss = 27.314, critic_loss = 1.313, entropy_coef_loss = -1.213, entropy_coef = 0.003, action_stds = 0.284 ± 0.059, action_magnitude = 0.664 ± 0.300, num_gradient_steps = 39000, step_time = 10.86, total_time = 441.66
#
# step = 50000, num_env_steps = 50000, scores = -3.722 ± 0.13 (n=2), actor_loss = 28.817, critic_loss = 1.294, entropy_coef_loss = -0.162, entropy_coef = 0.003, action_stds = 0.345 ± 0.031, action_magnitude = 0.634 ± 0.300, num_gradient_steps = 40000, step_time = 10.83, total_time = 452.49
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 51000, num_env_steps = 51000, scores = -4.075 ± 0.58 (n=2), actor_loss = 30.002, critic_loss = 1.222, entropy_coef_loss = -3.788, entropy_coef = 0.003, action_stds = 0.366 ± 0.070, action_magnitude = 0.637 ± 0.303, num_gradient_steps = 41000, step_time = 10.86, total_time = 463.35
#
# step = 52000, num_env_steps = 52000, scores = -3.751 ± 0.31 (n=2), actor_loss = 30.751, critic_loss = 1.411, entropy_coef_loss = 5.905, entropy_coef = 0.003, action_stds = 0.302 ± 0.040, action_magnitude = 0.627 ± 0.302, num_gradient_steps = 42000, step_time = 10.83, total_time = 474.18
#
# step = 53000, num_env_steps = 53000, scores = -3.442 ± 0.05 (n=2), actor_loss = 32.604, critic_loss = 1.209, entropy_coef_loss = -0.728, entropy_coef = 0.003, action_stds = 0.264 ± 0.035, action_magnitude = 0.606 ± 0.299, num_gradient_steps = 43000, step_time = 10.84, total_time = 485.02
#
# step = 54000, num_env_steps = 54000, scores = -3.525 ± 0.16 (n=2), actor_loss = 34.826, critic_loss = 1.380, entropy_coef_loss = 2.603, entropy_coef = 0.003, action_stds = 0.295 ± 0.040, action_magnitude = 0.625 ± 0.299, num_gradient_steps = 44000, step_time = 10.85, total_time = 495.87
#
# step = 55000, num_env_steps = 55000, scores = -3.372 ± 0.35 (n=2), actor_loss = 35.102, critic_loss = 1.328, entropy_coef_loss = -2.880, entropy_coef = 0.003, action_stds = 0.312 ± 0.063, action_magnitude = 0.605 ± 0.301, num_gradient_steps = 45000, step_time = 11.37, total_time = 507.24
#
# step = 56000, num_env_steps = 56000, scores = -3.795 ± 0.28 (n=2), actor_loss = 37.044, critic_loss = 1.457, entropy_coef_loss = -7.940, entropy_coef = 0.003, action_stds = 0.270 ± 0.052, action_magnitude = 0.618 ± 0.301, num_gradient_steps = 46000, step_time = 11.37, total_time = 518.61
#
# step = 57000, num_env_steps = 57000, scores = -3.437 ± 0.20 (n=2), actor_loss = 38.079, critic_loss = 1.282, entropy_coef_loss = 7.423, entropy_coef = 0.003, action_stds = 0.248 ± 0.034, action_magnitude = 0.607 ± 0.300, num_gradient_steps = 47000, step_time = 11.30, total_time = 529.90
#
# step = 58000, num_env_steps = 58000, scores = -3.578 ± 0.13 (n=2), actor_loss = 38.446, critic_loss = 1.494, entropy_coef_loss = -3.410, entropy_coef = 0.003, action_stds = 0.269 ± 0.068, action_magnitude = 0.609 ± 0.300, num_gradient_steps = 48000, step_time = 11.05, total_time = 540.95
#
# step = 59000, num_env_steps = 59000, scores = -3.499 ± 0.43 (n=2), actor_loss = 39.481, critic_loss = 1.300, entropy_coef_loss = -5.922, entropy_coef = 0.003, action_stds = 0.284 ± 0.055, action_magnitude = 0.600 ± 0.302, num_gradient_steps = 49000, step_time = 11.85, total_time = 552.80
#
# step = 60000, num_env_steps = 60000, scores = -2.777 ± 0.24 (n=2), actor_loss = 40.699, critic_loss = 1.265, entropy_coef_loss = 3.967, entropy_coef = 0.003, action_stds = 0.287 ± 0.049, action_magnitude = 0.607 ± 0.303, num_gradient_steps = 50000, step_time = 10.95, total_time = 563.76
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 61000, num_env_steps = 61000, scores = -3.467 ± 0.11 (n=2), actor_loss = 42.299, critic_loss = 0.956, entropy_coef_loss = -3.172, entropy_coef = 0.003, action_stds = 0.271 ± 0.038, action_magnitude = 0.605 ± 0.300, num_gradient_steps = 51000, step_time = 10.90, total_time = 574.66
#
# step = 62000, num_env_steps = 62000, scores = -3.205 ± 0.07 (n=2), actor_loss = 43.500, critic_loss = 1.154, entropy_coef_loss = -0.527, entropy_coef = 0.003, action_stds = 0.276 ± 0.048, action_magnitude = 0.606 ± 0.300, num_gradient_steps = 52000, step_time = 10.92, total_time = 585.57
#
# step = 63000, num_env_steps = 63000, scores = -3.536 ± 0.13 (n=2), actor_loss = 43.258, critic_loss = 1.120, entropy_coef_loss = 2.404, entropy_coef = 0.003, action_stds = 0.319 ± 0.043, action_magnitude = 0.602 ± 0.300, num_gradient_steps = 53000, step_time = 10.94, total_time = 596.51
#
# step = 64000, num_env_steps = 64000, scores = -3.556 ± 0.62 (n=2), actor_loss = 44.427, critic_loss = 1.315, entropy_coef_loss = 4.586, entropy_coef = 0.003, action_stds = 0.241 ± 0.026, action_magnitude = 0.601 ± 0.299, num_gradient_steps = 54000, step_time = 10.93, total_time = 607.44
#
# step = 65000, num_env_steps = 65000, scores = -2.956 ± 0.14 (n=2), actor_loss = 45.405, critic_loss = 1.674, entropy_coef_loss = 0.740, entropy_coef = 0.003, action_stds = 0.218 ± 0.037, action_magnitude = 0.605 ± 0.300, num_gradient_steps = 55000, step_time = 10.93, total_time = 618.37
#
# step = 66000, num_env_steps = 66000, scores = -3.163 ± 0.09 (n=2), actor_loss = 46.108, critic_loss = 1.544, entropy_coef_loss = 0.376, entropy_coef = 0.003, action_stds = 0.292 ± 0.074, action_magnitude = 0.608 ± 0.300, num_gradient_steps = 56000, step_time = 10.99, total_time = 629.36
#
# step = 67000, num_env_steps = 67000, scores = -3.464 ± 0.22 (n=2), actor_loss = 46.934, critic_loss = 1.413, entropy_coef_loss = 6.445, entropy_coef = 0.003, action_stds = 0.281 ± 0.035, action_magnitude = 0.600 ± 0.300, num_gradient_steps = 57000, step_time = 10.93, total_time = 640.29
#
# step = 68000, num_env_steps = 68000, scores = -2.914 ± 0.10 (n=2), actor_loss = 47.177, critic_loss = 1.317, entropy_coef_loss = 8.877, entropy_coef = 0.003, action_stds = 0.236 ± 0.039, action_magnitude = 0.579 ± 0.297, num_gradient_steps = 58000, step_time = 11.01, total_time = 651.30
#
# step = 69000, num_env_steps = 69000, scores = -3.262 ± 0.14 (n=2), actor_loss = 47.969, critic_loss = 1.317, entropy_coef_loss = -1.879, entropy_coef = 0.003, action_stds = 0.283 ± 0.093, action_magnitude = 0.597 ± 0.298, num_gradient_steps = 59000, step_time = 10.93, total_time = 662.23
#
# step = 70000, num_env_steps = 70000, scores = -3.104 ± 0.22 (n=2), actor_loss = 48.590, critic_loss = 1.356, entropy_coef_loss = -4.682, entropy_coef = 0.003, action_stds = 0.211 ± 0.027, action_magnitude = 0.582 ± 0.298, num_gradient_steps = 60000, step_time = 10.96, total_time = 673.19
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 71000, num_env_steps = 71000, scores = -2.884 ± 0.27 (n=2), actor_loss = 49.447, critic_loss = 1.267, entropy_coef_loss = 3.996, entropy_coef = 0.003, action_stds = 0.322 ± 0.049, action_magnitude = 0.589 ± 0.296, num_gradient_steps = 61000, step_time = 11.01, total_time = 684.20
#
# step = 72000, num_env_steps = 72000, scores = -3.044 ± 0.07 (n=2), actor_loss = 50.371, critic_loss = 1.258, entropy_coef_loss = 4.013, entropy_coef = 0.003, action_stds = 0.345 ± 0.103, action_magnitude = 0.579 ± 0.298, num_gradient_steps = 62000, step_time = 10.95, total_time = 695.15
#
# step = 73000, num_env_steps = 73000, scores = -3.489 ± 0.60 (n=2), actor_loss = 50.672, critic_loss = 1.158, entropy_coef_loss = -0.429, entropy_coef = 0.003, action_stds = 0.179 ± 0.034, action_magnitude = 0.614 ± 0.300, num_gradient_steps = 63000, step_time = 10.98, total_time = 706.13
#
# step = 74000, num_env_steps = 74000, scores = -2.941 ± 0.23 (n=2), actor_loss = 50.136, critic_loss = 1.381, entropy_coef_loss = 0.264, entropy_coef = 0.003, action_stds = 0.219 ± 0.036, action_magnitude = 0.568 ± 0.296, num_gradient_steps = 64000, step_time = 10.96, total_time = 717.09
#
# step = 75000, num_env_steps = 75000, scores = -3.156 ± 0.04 (n=2), actor_loss = 51.579, critic_loss = 1.442, entropy_coef_loss = 1.331, entropy_coef = 0.003, action_stds = 0.257 ± 0.062, action_magnitude = 0.582 ± 0.297, num_gradient_steps = 65000, step_time = 11.34, total_time = 728.43
#
# step = 76000, num_env_steps = 76000, scores = -2.901 ± 0.14 (n=2), actor_loss = 52.136, critic_loss = 1.308, entropy_coef_loss = 3.254, entropy_coef = 0.003, action_stds = 0.229 ± 0.022, action_magnitude = 0.557 ± 0.294, num_gradient_steps = 66000, step_time = 11.67, total_time = 740.10
#
# step = 77000, num_env_steps = 77000, scores = -3.078 ± 0.11 (n=2), actor_loss = 51.666, critic_loss = 1.354, entropy_coef_loss = 2.871, entropy_coef = 0.003, action_stds = 0.226 ± 0.017, action_magnitude = 0.567 ± 0.296, num_gradient_steps = 67000, step_time = 11.50, total_time = 751.60
#
# step = 78000, num_env_steps = 78000, scores = -3.673 ± 0.46 (n=2), actor_loss = 52.309, critic_loss = 1.212, entropy_coef_loss = 5.984, entropy_coef = 0.003, action_stds = 0.250 ± 0.039, action_magnitude = 0.619 ± 0.300, num_gradient_steps = 68000, step_time = 11.41, total_time = 763.01
#
# step = 79000, num_env_steps = 79000, scores = -2.975 ± 0.19 (n=2), actor_loss = 52.216, critic_loss = 1.272, entropy_coef_loss = 3.294, entropy_coef = 0.003, action_stds = 0.285 ± 0.034, action_magnitude = 0.578 ± 0.299, num_gradient_steps = 69000, step_time = 11.55, total_time = 774.57
#
# step = 80000, num_env_steps = 80000, scores = -2.902 ± 0.23 (n=2), actor_loss = 53.545, critic_loss = 1.160, entropy_coef_loss = 3.196, entropy_coef = 0.003, action_stds = 0.192 ± 0.040, action_magnitude = 0.581 ± 0.297, num_gradient_steps = 70000, step_time = 11.49, total_time = 786.05
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 81000, num_env_steps = 81000, scores = -3.043 ± 0.18 (n=2), actor_loss = 54.127, critic_loss = 1.101, entropy_coef_loss = -1.935, entropy_coef = 0.003, action_stds = 0.283 ± 0.049, action_magnitude = 0.593 ± 0.300, num_gradient_steps = 71000, step_time = 11.89, total_time = 797.94
#
# step = 82000, num_env_steps = 82000, scores = -3.166 ± 0.36 (n=2), actor_loss = 54.336, critic_loss = 1.430, entropy_coef_loss = 1.791, entropy_coef = 0.003, action_stds = 0.197 ± 0.023, action_magnitude = 0.601 ± 0.299, num_gradient_steps = 72000, step_time = 13.02, total_time = 810.96
#
# step = 83000, num_env_steps = 83000, scores = -2.946 ± 0.15 (n=2), actor_loss = 54.545, critic_loss = 1.335, entropy_coef_loss = -3.829, entropy_coef = 0.003, action_stds = 0.162 ± 0.034, action_magnitude = 0.571 ± 0.298, num_gradient_steps = 73000, step_time = 12.80, total_time = 823.76
#
# step = 84000, num_env_steps = 84000, scores = -3.158 ± 0.31 (n=2), actor_loss = 54.586, critic_loss = 1.274, entropy_coef_loss = -5.911, entropy_coef = 0.003, action_stds = 0.307 ± 0.059, action_magnitude = 0.577 ± 0.298, num_gradient_steps = 74000, step_time = 12.36, total_time = 836.12
#
# step = 85000, num_env_steps = 85000, scores = -3.326 ± 0.10 (n=2), actor_loss = 55.892, critic_loss = 1.543, entropy_coef_loss = -5.921, entropy_coef = 0.003, action_stds = 0.312 ± 0.066, action_magnitude = 0.575 ± 0.297, num_gradient_steps = 75000, step_time = 11.15, total_time = 847.27
#
# step = 86000, num_env_steps = 86000, scores = -2.749 ± 0.17 (n=2), actor_loss = 55.679, critic_loss = 1.344, entropy_coef_loss = 6.669, entropy_coef = 0.003, action_stds = 0.266 ± 0.068, action_magnitude = 0.552 ± 0.292, num_gradient_steps = 76000, step_time = 11.69, total_time = 858.96
#
# step = 87000, num_env_steps = 87000, scores = -2.807 ± 0.03 (n=2), actor_loss = 56.206, critic_loss = 1.446, entropy_coef_loss = 2.028, entropy_coef = 0.003, action_stds = 0.223 ± 0.039, action_magnitude = 0.562 ± 0.294, num_gradient_steps = 77000, step_time = 11.66, total_time = 870.62
#
# step = 88000, num_env_steps = 88000, scores = -2.466 ± 0.06 (n=2), actor_loss = 56.383, critic_loss = 1.067, entropy_coef_loss = -1.647, entropy_coef = 0.003, action_stds = 0.230 ± 0.038, action_magnitude = 0.543 ± 0.292, num_gradient_steps = 78000, step_time = 11.80, total_time = 882.42
#
# step = 89000, num_env_steps = 89000, scores = -2.694 ± 0.14 (n=2), actor_loss = 56.215, critic_loss = 1.232, entropy_coef_loss = 5.727, entropy_coef = 0.003, action_stds = 0.308 ± 0.074, action_magnitude = 0.558 ± 0.295, num_gradient_steps = 79000, step_time = 12.47, total_time = 894.88
#
# step = 90000, num_env_steps = 90000, scores = -2.938 ± 0.02 (n=2), actor_loss = 57.454, critic_loss = 1.085, entropy_coef_loss = -2.864, entropy_coef = 0.003, action_stds = 0.233 ± 0.034, action_magnitude = 0.555 ± 0.295, num_gradient_steps = 80000, step_time = 11.45, total_time = 906.33
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 91000, num_env_steps = 91000, scores = -2.644 ± 0.21 (n=2), actor_loss = 56.615, critic_loss = 1.027, entropy_coef_loss = -6.150, entropy_coef = 0.003, action_stds = 0.215 ± 0.023, action_magnitude = 0.527 ± 0.292, num_gradient_steps = 81000, step_time = 11.21, total_time = 917.54
#
# step = 92000, num_env_steps = 92000, scores = -3.754 ± 0.56 (n=2), actor_loss = 56.693, critic_loss = 0.965, entropy_coef_loss = -7.953, entropy_coef = 0.003, action_stds = 0.326 ± 0.089, action_magnitude = 0.597 ± 0.302, num_gradient_steps = 82000, step_time = 11.77, total_time = 929.31
#
# step = 93000, num_env_steps = 93000, scores = -2.440 ± 0.15 (n=2), actor_loss = 57.180, critic_loss = 1.137, entropy_coef_loss = -2.213, entropy_coef = 0.003, action_stds = 0.160 ± 0.032, action_magnitude = 0.526 ± 0.287, num_gradient_steps = 83000, step_time = 11.21, total_time = 940.52
#
# step = 94000, num_env_steps = 94000, scores = -2.521 ± 0.10 (n=2), actor_loss = 56.257, critic_loss = 0.994, entropy_coef_loss = -4.105, entropy_coef = 0.003, action_stds = 0.230 ± 0.039, action_magnitude = 0.538 ± 0.294, num_gradient_steps = 84000, step_time = 11.28, total_time = 951.80
# step = 95000, num_env_steps = 95000, scores = -2.847 ± 0.01 (n=2), actor_loss = 57.656, critic_loss = 0.987, entropy_coef_loss = 3.215, entropy_coef = 0.003, action_stds = 0.259 ± 0.044, action_magnitude = 0.559 ± 0.293, num_gradient_steps = 85000, step_time = 11.74, total_time = 963.54
#
# step = 96000, num_env_steps = 96000, scores = -2.440 ± 0.00 (n=2), actor_loss = 57.664, critic_loss = 1.171, entropy_coef_loss = 2.576, entropy_coef = 0.003, action_stds = 0.282 ± 0.062, action_magnitude = 0.543 ± 0.295, num_gradient_steps = 86000, step_time = 11.89, total_time = 975.43
#
# step = 97000, num_env_steps = 97000, scores = -2.843 ± 0.41 (n=2), actor_loss = 57.046, critic_loss = 1.042, entropy_coef_loss = -2.041, entropy_coef = 0.003, action_stds = 0.323 ± 0.067, action_magnitude = 0.525 ± 0.292, num_gradient_steps = 87000, step_time = 12.15, total_time = 987.58
#
# step = 98000, num_env_steps = 98000, scores = -2.611 ± 0.06 (n=2), actor_loss = 57.023, critic_loss = 1.104, entropy_coef_loss = -0.100, entropy_coef = 0.003, action_stds = 0.259 ± 0.036, action_magnitude = 0.528 ± 0.290, num_gradient_steps = 88000, step_time = 11.68, total_time = 999.26
#
# step = 99000, num_env_steps = 99000, scores = -2.677 ± 0.63 (n=2), actor_loss = 57.265, critic_loss = 1.115, entropy_coef_loss = -6.589, entropy_coef = 0.003, action_stds = 0.162 ± 0.018, action_magnitude = 0.504 ± 0.288, num_gradient_steps = 89000, step_time = 11.41, total_time = 1010.67
#
# step = 100000, num_env_steps = 100000, scores = -2.721 ± 0.02 (n=2), actor_loss = 57.121, critic_loss = 0.926, entropy_coef_loss = -1.196, entropy_coef = 0.003, action_stds = 0.238 ± 0.047, action_magnitude = 0.560 ± 0.299, num_gradient_steps = 90000, step_time = 11.82, total_time = 1022.49
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 101000, num_env_steps = 101000, scores = -2.450 ± 0.07 (n=2), actor_loss = 57.427, critic_loss = 1.020, entropy_coef_loss = -1.692, entropy_coef = 0.003, action_stds = 0.198 ± 0.037, action_magnitude = 0.495 ± 0.284, num_gradient_steps = 91000, step_time = 11.61, total_time = 1034.10
#
# step = 102000, num_env_steps = 102000, scores = -2.545 ± 0.11 (n=2), actor_loss = 57.286, critic_loss = 1.365, entropy_coef_loss = -1.019, entropy_coef = 0.003, action_stds = 0.153 ± 0.028, action_magnitude = 0.521 ± 0.282, num_gradient_steps = 92000, step_time = 11.08, total_time = 1045.17
#
# step = 103000, num_env_steps = 103000, scores = -2.289 ± 0.01 (n=2), actor_loss = 58.298, critic_loss = 1.044, entropy_coef_loss = 1.819, entropy_coef = 0.003, action_stds = 0.155 ± 0.031, action_magnitude = 0.483 ± 0.265, num_gradient_steps = 93000, step_time = 11.39, total_time = 1056.56
#
# step = 104000, num_env_steps = 104000, scores = -2.316 ± 0.19 (n=2), actor_loss = 57.828, critic_loss = 0.977, entropy_coef_loss = 2.119, entropy_coef = 0.003, action_stds = 0.159 ± 0.020, action_magnitude = 0.479 ± 0.268, num_gradient_steps = 94000, step_time = 10.96, total_time = 1067.52
#
# step = 105000, num_env_steps = 105000, scores = -2.296 ± 0.21 (n=2), actor_loss = 57.499, critic_loss = 1.125, entropy_coef_loss = -2.071, entropy_coef = 0.003, action_stds = 0.360 ± 0.096, action_magnitude = 0.510 ± 0.285, num_gradient_steps = 95000, step_time = 11.59, total_time = 1079.11
#
# step = 106000, num_env_steps = 106000, scores = -2.367 ± 0.12 (n=2), actor_loss = 57.978, critic_loss = 1.172, entropy_coef_loss = 0.366, entropy_coef = 0.003, action_stds = 0.154 ± 0.020, action_magnitude = 0.484 ± 0.277, num_gradient_steps = 96000, step_time = 11.21, total_time = 1090.32
#
# step = 107000, num_env_steps = 107000, scores = -2.382 ± 0.26 (n=2), actor_loss = 57.525, critic_loss = 1.125, entropy_coef_loss = -0.589, entropy_coef = 0.003, action_stds = 0.274 ± 0.065, action_magnitude = 0.516 ± 0.288, num_gradient_steps = 97000, step_time = 11.61, total_time = 1101.93
#
# step = 108000, num_env_steps = 108000, scores = -2.379 ± 0.14 (n=2), actor_loss = 57.501, critic_loss = 0.958, entropy_coef_loss = -4.519, entropy_coef = 0.003, action_stds = 0.239 ± 0.027, action_magnitude = 0.503 ± 0.288, num_gradient_steps = 98000, step_time = 11.40, total_time = 1113.32
#
# step = 109000, num_env_steps = 109000, scores = -2.132 ± 0.10 (n=2), actor_loss = 56.862, critic_loss = 0.884, entropy_coef_loss = -5.012, entropy_coef = 0.003, action_stds = 0.138 ± 0.027, action_magnitude = 0.479 ± 0.277, num_gradient_steps = 99000, step_time = 11.74, total_time = 1125.06
#
# step = 110000, num_env_steps = 110000, scores = -2.072 ± 0.01 (n=2), actor_loss = 56.723, critic_loss = 1.189, entropy_coef_loss = -0.956, entropy_coef = 0.003, action_stds = 0.138 ± 0.023, action_magnitude = 0.454 ± 0.275, num_gradient_steps = 100000, step_time = 11.77, total_time = 1136.83
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 111000, num_env_steps = 111000, scores = -2.047 ± 0.06 (n=2), actor_loss = 57.191, critic_loss = 0.886, entropy_coef_loss = 1.580, entropy_coef = 0.003, action_stds = 0.214 ± 0.018, action_magnitude = 0.457 ± 0.280, num_gradient_steps = 101000, step_time = 11.84, total_time = 1148.67
#
# step = 112000, num_env_steps = 112000, scores = -1.834 ± 0.24 (n=2), actor_loss = 56.458, critic_loss = 0.890, entropy_coef_loss = 3.087, entropy_coef = 0.003, action_stds = 0.226 ± 0.042, action_magnitude = 0.421 ± 0.271, num_gradient_steps = 102000, step_time = 11.30, total_time = 1159.97
#
# step = 113000, num_env_steps = 113000, scores = -2.613 ± 0.47 (n=2), actor_loss = 56.580, critic_loss = 1.127, entropy_coef_loss = 0.548, entropy_coef = 0.003, action_stds = 0.144 ± 0.027, action_magnitude = 0.513 ± 0.289, num_gradient_steps = 103000, step_time = 11.78, total_time = 1171.75
#
# step = 114000, num_env_steps = 114000, scores = -2.415 ± 0.27 (n=2), actor_loss = 56.108, critic_loss = 0.945, entropy_coef_loss = 5.695, entropy_coef = 0.003, action_stds = 0.137 ± 0.026, action_magnitude = 0.481 ± 0.278, num_gradient_steps = 104000, step_time = 11.58, total_time = 1183.33
#
# step = 115000, num_env_steps = 115000, scores = -2.081 ± 0.25 (n=2), actor_loss = 55.304, critic_loss = 1.008, entropy_coef_loss = -0.335, entropy_coef = 0.003, action_stds = 0.153 ± 0.025, action_magnitude = 0.449 ± 0.261, num_gradient_steps = 105000, step_time = 11.53, total_time = 1194.86
#
# step = 116000, num_env_steps = 116000, scores = -2.222 ± 0.03 (n=2), actor_loss = 55.281, critic_loss = 0.814, entropy_coef_loss = -4.205, entropy_coef = 0.003, action_stds = 0.138 ± 0.024, action_magnitude = 0.470 ± 0.251, num_gradient_steps = 106000, step_time = 11.61, total_time = 1206.47
#
# step = 117000, num_env_steps = 117000, scores = -2.116 ± 0.41 (n=2), actor_loss = 55.159, critic_loss = 0.943, entropy_coef_loss = 0.243, entropy_coef = 0.003, action_stds = 0.142 ± 0.032, action_magnitude = 0.469 ± 0.283, num_gradient_steps = 107000, step_time = 11.54, total_time = 1218.01
#
# step = 118000, num_env_steps = 118000, scores = -1.959 ± 0.21 (n=2), actor_loss = 55.462, critic_loss = 0.927, entropy_coef_loss = -2.816, entropy_coef = 0.003, action_stds = 0.162 ± 0.017, action_magnitude = 0.437 ± 0.280, num_gradient_steps = 108000, step_time = 11.78, total_time = 1229.79
#
# step = 119000, num_env_steps = 119000, scores = -2.865 ± 0.24 (n=2), actor_loss = 55.347, critic_loss = 1.287, entropy_coef_loss = 3.810, entropy_coef = 0.003, action_stds = 0.151 ± 0.030, action_magnitude = 0.532 ± 0.269, num_gradient_steps = 109000, step_time = 11.61, total_time = 1241.40
#
# step = 120000, num_env_steps = 120000, scores = -1.976 ± 0.09 (n=2), actor_loss = 54.988, critic_loss = 1.025, entropy_coef_loss = -0.938, entropy_coef = 0.003, action_stds = 0.133 ± 0.021, action_magnitude = 0.443 ± 0.254, num_gradient_steps = 110000, step_time = 11.67, total_time = 1253.07
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 121000, num_env_steps = 121000, scores = -2.051 ± 0.28 (n=2), actor_loss = 54.757, critic_loss = 0.832, entropy_coef_loss = -0.853, entropy_coef = 0.003, action_stds = 0.137 ± 0.020, action_magnitude = 0.444 ± 0.271, num_gradient_steps = 111000, step_time = 11.90, total_time = 1264.97
#
# step = 122000, num_env_steps = 122000, scores = -1.762 ± 0.03 (n=2), actor_loss = 54.248, critic_loss = 0.786, entropy_coef_loss = -0.928, entropy_coef = 0.003, action_stds = 0.133 ± 0.024, action_magnitude = 0.414 ± 0.255, num_gradient_steps = 112000, step_time = 11.44, total_time = 1276.41
#
# step = 123000, num_env_steps = 123000, scores = -2.256 ± 0.10 (n=2), actor_loss = 53.943, critic_loss = 1.074, entropy_coef_loss = -4.138, entropy_coef = 0.003, action_stds = 0.126 ± 0.020, action_magnitude = 0.470 ± 0.273, num_gradient_steps = 113000, step_time = 11.27, total_time = 1287.69
#
# step = 124000, num_env_steps = 124000, scores = -2.097 ± 0.26 (n=2), actor_loss = 53.577, critic_loss = 0.822, entropy_coef_loss = -1.979, entropy_coef = 0.003, action_stds = 0.153 ± 0.024, action_magnitude = 0.436 ± 0.275, num_gradient_steps = 114000, step_time = 11.22, total_time = 1298.91
#
# step = 125000, num_env_steps = 125000, scores = -2.695 ± 0.85 (n=2), actor_loss = 53.366, critic_loss = 0.811, entropy_coef_loss = 1.049, entropy_coef = 0.003, action_stds = 0.114 ± 0.025, action_magnitude = 0.501 ± 0.308, num_gradient_steps = 115000, step_time = 11.35, total_time = 1310.26
#
# step = 126000, num_env_steps = 126000, scores = -1.844 ± 0.08 (n=2), actor_loss = 53.116, critic_loss = 0.902, entropy_coef_loss = -4.474, entropy_coef = 0.003, action_stds = 0.198 ± 0.038, action_magnitude = 0.410 ± 0.271, num_gradient_steps = 116000, step_time = 11.52, total_time = 1321.78
#
# step = 127000, num_env_steps = 127000, scores = -2.155 ± 0.12 (n=2), actor_loss = 52.641, critic_loss = 0.836, entropy_coef_loss = 1.238, entropy_coef = 0.003, action_stds = 0.125 ± 0.024, action_magnitude = 0.466 ± 0.265, num_gradient_steps = 117000, step_time = 11.76, total_time = 1333.54
#
# step = 128000, num_env_steps = 128000, scores = -1.838 ± 0.12 (n=2), actor_loss = 52.783, critic_loss = 0.827, entropy_coef_loss = -1.701, entropy_coef = 0.003, action_stds = 0.126 ± 0.038, action_magnitude = 0.403 ± 0.284, num_gradient_steps = 118000, step_time = 11.54, total_time = 1345.08
#
# step = 129000, num_env_steps = 129000, scores = -2.139 ± 0.30 (n=2), actor_loss = 52.117, critic_loss = 0.980, entropy_coef_loss = 0.838, entropy_coef = 0.003, action_stds = 0.141 ± 0.021, action_magnitude = 0.450 ± 0.283, num_gradient_steps = 119000, step_time = 11.53, total_time = 1356.61
#
# step = 130000, num_env_steps = 130000, scores = -2.193 ± 0.24 (n=2), actor_loss = 51.895, critic_loss = 0.656, entropy_coef_loss = -1.854, entropy_coef = 0.003, action_stds = 0.112 ± 0.020, action_magnitude = 0.468 ± 0.267, num_gradient_steps = 120000, step_time = 11.76, total_time = 1368.37
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 131000, num_env_steps = 131000, scores = -1.879 ± 0.17 (n=2), actor_loss = 51.998, critic_loss = 0.926, entropy_coef_loss = -2.732, entropy_coef = 0.003, action_stds = 0.235 ± 0.033, action_magnitude = 0.428 ± 0.253, num_gradient_steps = 121000, step_time = 11.35, total_time = 1379.72
#
# step = 132000, num_env_steps = 132000, scores = -1.917 ± 0.06 (n=2), actor_loss = 51.912, critic_loss = 0.783, entropy_coef_loss = -3.495, entropy_coef = 0.003, action_stds = 0.274 ± 0.063, action_magnitude = 0.428 ± 0.258, num_gradient_steps = 122000, step_time = 11.25, total_time = 1390.97
#
# step = 133000, num_env_steps = 133000, scores = -1.683 ± 0.06 (n=2), actor_loss = 51.575, critic_loss = 0.857, entropy_coef_loss = -5.248, entropy_coef = 0.003, action_stds = 0.125 ± 0.028, action_magnitude = 0.396 ± 0.255, num_gradient_steps = 123000, step_time = 11.07, total_time = 1402.05
#
# step = 134000, num_env_steps = 134000, scores = -2.110 ± 0.18 (n=2), actor_loss = 50.571, critic_loss = 0.860, entropy_coef_loss = -0.335, entropy_coef = 0.003, action_stds = 0.139 ± 0.033, action_magnitude = 0.453 ± 0.283, num_gradient_steps = 124000, step_time = 11.62, total_time = 1413.66
#
# step = 135000, num_env_steps = 135000, scores = -1.733 ± 0.02 (n=2), actor_loss = 50.286, critic_loss = 0.817, entropy_coef_loss = -4.320, entropy_coef = 0.003, action_stds = 0.190 ± 0.035, action_magnitude = 0.410 ± 0.267, num_gradient_steps = 125000, step_time = 11.27, total_time = 1424.94
#
# step = 136000, num_env_steps = 136000, scores = -1.925 ± 0.04 (n=2), actor_loss = 50.445, critic_loss = 0.771, entropy_coef_loss = -0.787, entropy_coef = 0.003, action_stds = 0.109 ± 0.028, action_magnitude = 0.432 ± 0.270, num_gradient_steps = 126000, step_time = 11.09, total_time = 1436.03
#
# step = 137000, num_env_steps = 137000, scores = -1.763 ± 0.07 (n=2), actor_loss = 49.970, critic_loss = 0.778, entropy_coef_loss = -1.317, entropy_coef = 0.003, action_stds = 0.142 ± 0.026, action_magnitude = 0.417 ± 0.257, num_gradient_steps = 127000, step_time = 11.55, total_time = 1447.58
#
# step = 138000, num_env_steps = 138000, scores = -1.770 ± 0.02 (n=2), actor_loss = 49.879, critic_loss = 0.772, entropy_coef_loss = 2.120, entropy_coef = 0.003, action_stds = 0.131 ± 0.027, action_magnitude = 0.403 ± 0.275, num_gradient_steps = 128000, step_time = 11.43, total_time = 1459.01
#
# step = 139000, num_env_steps = 139000, scores = -1.611 ± 0.05 (n=2), actor_loss = 49.086, critic_loss = 0.861, entropy_coef_loss = 2.121, entropy_coef = 0.003, action_stds = 0.112 ± 0.028, action_magnitude = 0.388 ± 0.263, num_gradient_steps = 129000, step_time = 11.20, total_time = 1470.21
#
# step = 140000, num_env_steps = 140000, scores = -1.843 ± 0.06 (n=2), actor_loss = 49.792, critic_loss = 0.832, entropy_coef_loss = 0.669, entropy_coef = 0.003, action_stds = 0.121 ± 0.018, action_magnitude = 0.418 ± 0.272, num_gradient_steps = 130000, step_time = 11.63, total_time = 1481.84
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 141000, num_env_steps = 141000, scores = -2.469 ± 0.23 (n=2), actor_loss = 48.451, critic_loss = 0.895, entropy_coef_loss = -2.386, entropy_coef = 0.004, action_stds = 0.162 ± 0.026, action_magnitude = 0.493 ± 0.254, num_gradient_steps = 131000, step_time = 11.78, total_time = 1493.62
#
# step = 142000, num_env_steps = 142000, scores = -1.873 ± 0.18 (n=2), actor_loss = 48.109, critic_loss = 0.741, entropy_coef_loss = -1.146, entropy_coef = 0.004, action_stds = 0.112 ± 0.016, action_magnitude = 0.422 ± 0.252, num_gradient_steps = 132000, step_time = 11.75, total_time = 1505.38
#
# step = 143000, num_env_steps = 143000, scores = -1.760 ± 0.01 (n=2), actor_loss = 48.195, critic_loss = 0.687, entropy_coef_loss = -2.673, entropy_coef = 0.003, action_stds = 0.117 ± 0.015, action_magnitude = 0.413 ± 0.244, num_gradient_steps = 133000, step_time = 11.59, total_time = 1516.97
#
# step = 144000, num_env_steps = 144000, scores = -1.706 ± 0.02 (n=2), actor_loss = 47.865, critic_loss = 0.758, entropy_coef_loss = -1.332, entropy_coef = 0.004, action_stds = 0.114 ± 0.016, action_magnitude = 0.405 ± 0.261, num_gradient_steps = 134000, step_time = 11.88, total_time = 1528.84
#
# step = 145000, num_env_steps = 145000, scores = -1.654 ± 0.07 (n=2), actor_loss = 47.421, critic_loss = 0.795, entropy_coef_loss = -5.362, entropy_coef = 0.004, action_stds = 0.147 ± 0.025, action_magnitude = 0.412 ± 0.226, num_gradient_steps = 135000, step_time = 11.63, total_time = 1540.47
#
# step = 146000, num_env_steps = 146000, scores = -1.583 ± 0.03 (n=2), actor_loss = 47.437, critic_loss = 0.913, entropy_coef_loss = 3.094, entropy_coef = 0.004, action_stds = 0.112 ± 0.018, action_magnitude = 0.386 ± 0.272, num_gradient_steps = 136000, step_time = 11.14, total_time = 1551.62
#
# step = 147000, num_env_steps = 147000, scores = -1.580 ± 0.15 (n=2), actor_loss = 46.415, critic_loss = 0.872, entropy_coef_loss = 2.623, entropy_coef = 0.004, action_stds = 0.123 ± 0.024, action_magnitude = 0.396 ± 0.255, num_gradient_steps = 137000, step_time = 11.29, total_time = 1562.91
#
# step = 148000, num_env_steps = 148000, scores = -1.728 ± 0.07 (n=2), actor_loss = 47.013, critic_loss = 0.670, entropy_coef_loss = 0.429, entropy_coef = 0.004, action_stds = 0.145 ± 0.020, action_magnitude = 0.421 ± 0.243, num_gradient_steps = 138000, step_time = 11.22, total_time = 1574.13
#
# step = 149000, num_env_steps = 149000, scores = -2.088 ± 0.63 (n=2), actor_loss = 46.798, critic_loss = 0.901, entropy_coef_loss = 0.266, entropy_coef = 0.004, action_stds = 0.121 ± 0.026, action_magnitude = 0.445 ± 0.290, num_gradient_steps = 139000, step_time = 11.35, total_time = 1585.48
#
# step = 150000, num_env_steps = 150000, scores = -1.826 ± 0.18 (n=2), actor_loss = 45.900, critic_loss = 0.748, entropy_coef_loss = 0.602, entropy_coef = 0.004, action_stds = 0.139 ± 0.022, action_magnitude = 0.415 ± 0.265, num_gradient_steps = 140000, step_time = 11.68, total_time = 1597.16
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 151000, num_env_steps = 151000, scores = -1.617 ± 0.00 (n=2), actor_loss = 45.638, critic_loss = 0.717, entropy_coef_loss = 0.209, entropy_coef = 0.004, action_stds = 0.144 ± 0.019, action_magnitude = 0.402 ± 0.265, num_gradient_steps = 141000, step_time = 11.27, total_time = 1608.44
#
# step = 152000, num_env_steps = 152000, scores = -1.702 ± 0.01 (n=2), actor_loss = 45.555, critic_loss = 0.752, entropy_coef_loss = 5.246, entropy_coef = 0.004, action_stds = 0.129 ± 0.021, action_magnitude = 0.397 ± 0.270, num_gradient_steps = 142000, step_time = 11.54, total_time = 1619.98
#
# step = 153000, num_env_steps = 153000, scores = -1.704 ± 0.06 (n=2), actor_loss = 45.593, critic_loss = 0.626, entropy_coef_loss = -4.256, entropy_coef = 0.004, action_stds = 0.119 ± 0.018, action_magnitude = 0.408 ± 0.250, num_gradient_steps = 143000, step_time = 11.51, total_time = 1631.48
#
# step = 154000, num_env_steps = 154000, scores = -1.491 ± 0.03 (n=2), actor_loss = 44.963, critic_loss = 0.711, entropy_coef_loss = -0.460, entropy_coef = 0.004, action_stds = 0.143 ± 0.018, action_magnitude = 0.389 ± 0.252, num_gradient_steps = 144000, step_time = 11.40, total_time = 1642.89
#
# step = 155000, num_env_steps = 155000, scores = -1.793 ± 0.32 (n=2), actor_loss = 44.604, critic_loss = 0.654, entropy_coef_loss = -0.211, entropy_coef = 0.004, action_stds = 0.151 ± 0.024, action_magnitude = 0.419 ± 0.247, num_gradient_steps = 145000, step_time = 11.67, total_time = 1654.56
#
# step = 156000, num_env_steps = 156000, scores = -1.690 ± 0.07 (n=2), actor_loss = 44.955, critic_loss = 0.628, entropy_coef_loss = 4.284, entropy_coef = 0.004, action_stds = 0.157 ± 0.025, action_magnitude = 0.412 ± 0.248, num_gradient_steps = 146000, step_time = 11.57, total_time = 1666.13
#
# step = 157000, num_env_steps = 157000, scores = -1.673 ± 0.45 (n=2), actor_loss = 44.408, critic_loss = 0.857, entropy_coef_loss = -2.467, entropy_coef = 0.004, action_stds = 0.161 ± 0.028, action_magnitude = 0.406 ± 0.236, num_gradient_steps = 147000, step_time = 11.93, total_time = 1678.06
#
# step = 158000, num_env_steps = 158000, scores = -2.034 ± 0.71 (n=2), actor_loss = 44.717, critic_loss = 0.730, entropy_coef_loss = 0.890, entropy_coef = 0.004, action_stds = 0.143 ± 0.024, action_magnitude = 0.430 ± 0.276, num_gradient_steps = 148000, step_time = 11.19, total_time = 1689.25
#
# step = 159000, num_env_steps = 159000, scores = -1.743 ± 0.33 (n=2), actor_loss = 43.420, critic_loss = 0.660, entropy_coef_loss = 3.504, entropy_coef = 0.004, action_stds = 0.123 ± 0.023, action_magnitude = 0.412 ± 0.244, num_gradient_steps = 149000, step_time = 11.92, total_time = 1701.17
#
# step = 160000, num_env_steps = 160000, scores = -1.445 ± 0.07 (n=2), actor_loss = 43.399, critic_loss = 0.838, entropy_coef_loss = 3.883, entropy_coef = 0.004, action_stds = 0.123 ± 0.032, action_magnitude = 0.368 ± 0.249, num_gradient_steps = 150000, step_time = 11.26, total_time = 1712.42
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 161000, num_env_steps = 161000, scores = -1.722 ± 0.13 (n=2), actor_loss = 43.712, critic_loss = 0.686, entropy_coef_loss = -1.588, entropy_coef = 0.004, action_stds = 0.231 ± 0.046, action_magnitude = 0.417 ± 0.259, num_gradient_steps = 151000, step_time = 11.62, total_time = 1724.05
#
# step = 162000, num_env_steps = 162000, scores = -1.214 ± 0.04 (n=2), actor_loss = 42.882, critic_loss = 0.543, entropy_coef_loss = 0.068, entropy_coef = 0.004, action_stds = 0.121 ± 0.029, action_magnitude = 0.346 ± 0.216, num_gradient_steps = 152000, step_time = 11.58, total_time = 1735.62
#
# step = 163000, num_env_steps = 163000, scores = -1.574 ± 0.25 (n=2), actor_loss = 43.247, critic_loss = 0.851, entropy_coef_loss = 2.172, entropy_coef = 0.004, action_stds = 0.110 ± 0.014, action_magnitude = 0.385 ± 0.246, num_gradient_steps = 153000, step_time = 11.86, total_time = 1747.48
#
# step = 164000, num_env_steps = 164000, scores = -1.325 ± 0.32 (n=2), actor_loss = 42.396, critic_loss = 0.656, entropy_coef_loss = -1.563, entropy_coef = 0.004, action_stds = 0.109 ± 0.015, action_magnitude = 0.359 ± 0.226, num_gradient_steps = 154000, step_time = 11.16, total_time = 1758.64
#
# step = 165000, num_env_steps = 165000, scores = -2.223 ± 0.99 (n=2), actor_loss = 42.669, critic_loss = 0.724, entropy_coef_loss = -0.844, entropy_coef = 0.004, action_stds = 0.115 ± 0.016, action_magnitude = 0.453 ± 0.302, num_gradient_steps = 155000, step_time = 11.65, total_time = 1770.29
#
# step = 166000, num_env_steps = 166000, scores = -1.007 ± 0.09 (n=2), actor_loss = 42.700, critic_loss = 0.866, entropy_coef_loss = 0.883, entropy_coef = 0.004, action_stds = 0.118 ± 0.017, action_magnitude = 0.317 ± 0.202, num_gradient_steps = 156000, step_time = 11.14, total_time = 1781.43
#
# step = 167000, num_env_steps = 167000, scores = -1.458 ± 0.10 (n=2), actor_loss = 42.436, critic_loss = 0.607, entropy_coef_loss = 0.950, entropy_coef = 0.004, action_stds = 0.105 ± 0.016, action_magnitude = 0.384 ± 0.234, num_gradient_steps = 157000, step_time = 11.03, total_time = 1792.46
#
# ...
#
# step = 3645000, num_env_steps = 3645000, scores = 17.207 ± 0.49 (n=2), actor_loss = -161.646, critic_loss = 8.125, entropy_coef_loss = -0.653, entropy_coef = 0.044, action_stds = 0.498 ± 0.066, action_magnitude = 0.780 ± 0.260, num_gradient_steps = 3635000, step_time = 11.10, total_time = 40400.85
#
# step = 3646000, num_env_steps = 3646000, scores = 16.920 ± 0.21 (n=2), actor_loss = -163.703, critic_loss = 11.043, entropy_coef_loss = 0.083, entropy_coef = 0.043, action_stds = 0.472 ± 0.081, action_magnitude = 0.773 ± 0.263, num_gradient_steps = 3636000, step_time = 11.02, total_time = 40411.87
#
# step = 3647000, num_env_steps = 3647000, scores = 17.207 ± 0.32 (n=2), actor_loss = -151.266, critic_loss = 9.424, entropy_coef_loss = -2.098, entropy_coef = 0.044, action_stds = 0.494 ± 0.074, action_magnitude = 0.777 ± 0.260, num_gradient_steps = 3637000, step_time = 11.07, total_time = 40422.94
#
# step = 3648000, num_env_steps = 3648000, scores = 17.170 ± 0.69 (n=2), actor_loss = -154.470, critic_loss = 11.684, entropy_coef_loss = -2.345, entropy_coef = 0.043, action_stds = 0.478 ± 0.053, action_magnitude = 0.777 ± 0.260, num_gradient_steps = 3638000, step_time = 10.96, total_time = 40433.90
#
# step = 3649000, num_env_steps = 3649000, scores = 17.330 ± 0.12 (n=2), actor_loss = -158.659, critic_loss = 8.959, entropy_coef_loss = 0.765, entropy_coef = 0.044, action_stds = 0.468 ± 0.069, action_magnitude = 0.771 ± 0.265, num_gradient_steps = 3639000, step_time = 11.04, total_time = 40444.95
#
# step = 3650000, num_env_steps = 3650000, scores = 17.334 ± 0.10 (n=2), actor_loss = -160.107, critic_loss = 6.954, entropy_coef_loss = -1.536, entropy_coef = 0.044, action_stds = 0.460 ± 0.064, action_magnitude = 0.773 ± 0.262, num_gradient_steps = 3640000, step_time = 11.06, total_time = 40456.01
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 3651000, num_env_steps = 3651000, scores = 16.960 ± 0.24 (n=2), actor_loss = -162.186, critic_loss = 10.871, entropy_coef_loss = 1.297, entropy_coef = 0.043, action_stds = 0.481 ± 0.058, action_magnitude = 0.772 ± 0.263, num_gradient_steps = 3641000, step_time = 11.39, total_time = 40467.39
#
# step = 3652000, num_env_steps = 3652000, scores = 17.102 ± 0.35 (n=2), actor_loss = -147.616, critic_loss = 12.129, entropy_coef_loss = -1.632, entropy_coef = 0.044, action_stds = 0.511 ± 0.056, action_magnitude = 0.777 ± 0.261, num_gradient_steps = 3642000, step_time = 11.06, total_time = 40478.46
#
# step = 3653000, num_env_steps = 3653000, scores = 17.454 ± 0.70 (n=2), actor_loss = -156.319, critic_loss = 8.264, entropy_coef_loss = -2.257, entropy_coef = 0.044, action_stds = 0.484 ± 0.084, action_magnitude = 0.772 ± 0.263, num_gradient_steps = 3643000, step_time = 11.05, total_time = 40489.50
#
# step = 3654000, num_env_steps = 3654000, scores = 17.484 ± 0.18 (n=2), actor_loss = -163.247, critic_loss = 11.109, entropy_coef_loss = -2.146, entropy_coef = 0.045, action_stds = 0.487 ± 0.088, action_magnitude = 0.775 ± 0.261, num_gradient_steps = 3644000, step_time = 11.04, total_time = 40500.55
#
# step = 3655000, num_env_steps = 3655000, scores = 17.232 ± 0.27 (n=2), actor_loss = -156.087, critic_loss = 9.956, entropy_coef_loss = 1.829, entropy_coef = 0.045, action_stds = 0.490 ± 0.071, action_magnitude = 0.776 ± 0.260, num_gradient_steps = 3645000, step_time = 11.05, total_time = 40511.60
#
# step = 3656000, num_env_steps = 3656000, scores = 17.626 ± 0.07 (n=2), actor_loss = -156.232, critic_loss = 8.398, entropy_coef_loss = 0.318, entropy_coef = 0.044, action_stds = 0.491 ± 0.079, action_magnitude = 0.777 ± 0.260, num_gradient_steps = 3646000, step_time = 11.01, total_time = 40522.61
#
# step = 3657000, num_env_steps = 3657000, scores = 17.666 ± 0.05 (n=2), actor_loss = -153.150, critic_loss = 7.702, entropy_coef_loss = -1.159, entropy_coef = 0.044, action_stds = 0.474 ± 0.080, action_magnitude = 0.772 ± 0.264, num_gradient_steps = 3647000, step_time = 11.04, total_time = 40533.66
#
# step = 3658000, num_env_steps = 3658000, scores = 17.600 ± 0.33 (n=2), actor_loss = -159.021, critic_loss = 27.206, entropy_coef_loss = -0.055, entropy_coef = 0.046, action_stds = 0.484 ± 0.062, action_magnitude = 0.777 ± 0.260, num_gradient_steps = 3648000, step_time = 11.10, total_time = 40544.76
#
# step = 3659000, num_env_steps = 3659000, scores = 17.807 ± 0.29 (n=2), actor_loss = -156.755, critic_loss = 9.752, entropy_coef_loss = -1.938, entropy_coef = 0.045, action_stds = 0.506 ± 0.064, action_magnitude = 0.776 ± 0.260, num_gradient_steps = 3649000, step_time = 11.07, total_time = 40555.83
#
# step = 3660000, num_env_steps = 3660000, scores = 17.105 ± 0.41 (n=2), actor_loss = -159.251, critic_loss = 6.766, entropy_coef_loss = -3.236, entropy_coef = 0.044, action_stds = 0.472 ± 0.075, action_magnitude = 0.774 ± 0.263, num_gradient_steps = 3650000, step_time = 11.01, total_time = 40566.84
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 3661000, num_env_steps = 3661000, scores = 17.884 ± 0.09 (n=2), actor_loss = -151.858, critic_loss = 8.864, entropy_coef_loss = -2.868, entropy_coef = 0.045, action_stds = 0.509 ± 0.060, action_magnitude = 0.770 ± 0.264, num_gradient_steps = 3651000, step_time = 11.42, total_time = 40578.25
#
# step = 3662000, num_env_steps = 3662000, scores = 17.546 ± 0.15 (n=2), actor_loss = -160.736, critic_loss = 9.240, entropy_coef_loss = 0.531, entropy_coef = 0.046, action_stds = 0.493 ± 0.066, action_magnitude = 0.774 ± 0.263, num_gradient_steps = 3652000, step_time = 11.06, total_time = 40589.31
#
# step = 3663000, num_env_steps = 3663000, scores = 17.640 ± 0.04 (n=2), actor_loss = -165.526, critic_loss = 11.918, entropy_coef_loss = -1.156, entropy_coef = 0.045, action_stds = 0.464 ± 0.087, action_magnitude = 0.776 ± 0.260, num_gradient_steps = 3653000, step_time = 11.15, total_time = 40600.47
#
# step = 3664000, num_env_steps = 3664000, scores = 17.457 ± 0.03 (n=2), actor_loss = -157.301, critic_loss = 16.257, entropy_coef_loss = 1.568, entropy_coef = 0.045, action_stds = 0.494 ± 0.074, action_magnitude = 0.772 ± 0.263, num_gradient_steps = 3654000, step_time = 11.14, total_time = 40611.60
#
# step = 3665000, num_env_steps = 3665000, scores = 17.859 ± 0.39 (n=2), actor_loss = -159.922, critic_loss = 8.609, entropy_coef_loss = -2.569, entropy_coef = 0.045, action_stds = 0.503 ± 0.078, action_magnitude = 0.768 ± 0.266, num_gradient_steps = 3655000, step_time = 11.10, total_time = 40622.70
#
# step = 3666000, num_env_steps = 3666000, scores = 17.357 ± 0.15 (n=2), actor_loss = -157.680, critic_loss = 11.296, entropy_coef_loss = 2.311, entropy_coef = 0.045, action_stds = 0.489 ± 0.075, action_magnitude = 0.772 ± 0.262, num_gradient_steps = 3656000, step_time = 11.16, total_time = 40633.86
#
# step = 3667000, num_env_steps = 3667000, scores = 17.313 ± 0.52 (n=2), actor_loss = -171.578, critic_loss = 11.883, entropy_coef_loss = 3.642, entropy_coef = 0.045, action_stds = 0.474 ± 0.071, action_magnitude = 0.767 ± 0.268, num_gradient_steps = 3657000, step_time = 11.15, total_time = 40645.02
#
# step = 3668000, num_env_steps = 3668000, scores = 17.787 ± 0.38 (n=2), actor_loss = -159.065, critic_loss = 13.978, entropy_coef_loss = 1.247, entropy_coef = 0.045, action_stds = 0.502 ± 0.081, action_magnitude = 0.773 ± 0.262, num_gradient_steps = 3658000, step_time = 11.10, total_time = 40656.12
#
# step = 3669000, num_env_steps = 3669000, scores = 17.068 ± 0.33 (n=2), actor_loss = -159.295, critic_loss = 10.930, entropy_coef_loss = 0.338, entropy_coef = 0.046, action_stds = 0.500 ± 0.055, action_magnitude = 0.776 ± 0.261, num_gradient_steps = 3659000, step_time = 11.16, total_time = 40667.28
#
# step = 3670000, num_env_steps = 3670000, scores = 18.036 ± 0.11 (n=2), actor_loss = -162.523, critic_loss = 11.126, entropy_coef_loss = -1.516, entropy_coef = 0.045, action_stds = 0.488 ± 0.073, action_magnitude = 0.769 ± 0.263, num_gradient_steps = 3660000, step_time = 11.10, total_time = 40678.38
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 3671000, num_env_steps = 3671000, scores = 17.012 ± 0.59 (n=2), actor_loss = -149.114, critic_loss = 10.093, entropy_coef_loss = -0.623, entropy_coef = 0.046, action_stds = 0.475 ± 0.072, action_magnitude = 0.769 ± 0.264, num_gradient_steps = 3661000, step_time = 11.38, total_time = 40689.76
#
# step = 3672000, num_env_steps = 3672000, scores = 17.827 ± 0.20 (n=2), actor_loss = -151.366, critic_loss = 10.857, entropy_coef_loss = -1.420, entropy_coef = 0.047, action_stds = 0.497 ± 0.063, action_magnitude = 0.769 ± 0.263, num_gradient_steps = 3662000, step_time = 11.08, total_time = 40700.84
#
# step = 3673000, num_env_steps = 3673000, scores = 17.428 ± 0.18 (n=2), actor_loss = -162.598, critic_loss = 10.392, entropy_coef_loss = 0.451, entropy_coef = 0.045, action_stds = 0.506 ± 0.113, action_magnitude = 0.765 ± 0.266, num_gradient_steps = 3663000, step_time = 11.04, total_time = 40711.88
#
# step = 3674000, num_env_steps = 3674000, scores = 17.968 ± 0.18 (n=2), actor_loss = -165.683, critic_loss = 12.392, entropy_coef_loss = 1.462, entropy_coef = 0.046, action_stds = 0.483 ± 0.073, action_magnitude = 0.767 ± 0.264, num_gradient_steps = 3664000, step_time = 11.02, total_time = 40722.89
#
# step = 3675000, num_env_steps = 3675000, scores = 17.271 ± 0.04 (n=2), actor_loss = -170.815, critic_loss = 13.500, entropy_coef_loss = -2.139, entropy_coef = 0.045, action_stds = 0.502 ± 0.055, action_magnitude = 0.770 ± 0.264, num_gradient_steps = 3665000, step_time = 11.03, total_time = 40733.93
#
# step = 3676000, num_env_steps = 3676000, scores = 18.048 ± 0.11 (n=2), actor_loss = -158.975, critic_loss = 11.523, entropy_coef_loss = 1.870, entropy_coef = 0.046, action_stds = 0.492 ± 0.044, action_magnitude = 0.765 ± 0.268, num_gradient_steps = 3666000, step_time = 11.07, total_time = 40745.00
#
# step = 3677000, num_env_steps = 3677000, scores = 17.964 ± 0.31 (n=2), actor_loss = -167.891, critic_loss = 6.399, entropy_coef_loss = -2.302, entropy_coef = 0.046, action_stds = 0.483 ± 0.096, action_magnitude = 0.768 ± 0.263, num_gradient_steps = 3667000, step_time = 11.07, total_time = 40756.07
#
# step = 3678000, num_env_steps = 3678000, scores = 17.968 ± 0.33 (n=2), actor_loss = -173.973, critic_loss = 7.700, entropy_coef_loss = 4.085, entropy_coef = 0.046, action_stds = 0.476 ± 0.057, action_magnitude = 0.769 ± 0.266, num_gradient_steps = 3668000, step_time = 11.08, total_time = 40767.15
#
# step = 3679000, num_env_steps = 3679000, scores = 16.918 ± 0.29 (n=2), actor_loss = -170.612, critic_loss = 9.239, entropy_coef_loss = 2.336, entropy_coef = 0.045, action_stds = 0.471 ± 0.095, action_magnitude = 0.770 ± 0.265, num_gradient_steps = 3669000, step_time = 11.03, total_time = 40778.19
#
# step = 3680000, num_env_steps = 3680000, scores = 18.241 ± 0.07 (n=2), actor_loss = -165.137, critic_loss = 10.468, entropy_coef_loss = -1.583, entropy_coef = 0.046, action_stds = 0.494 ± 0.089, action_magnitude = 0.765 ± 0.268, num_gradient_steps = 3670000, step_time = 11.05, total_time = 40789.24
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 3681000, num_env_steps = 3681000, scores = 18.446 ± 0.27 (n=2), actor_loss = -160.252, critic_loss = 10.062, entropy_coef_loss = -2.717, entropy_coef = 0.046, action_stds = 0.476 ± 0.072, action_magnitude = 0.770 ± 0.264, num_gradient_steps = 3671000, step_time = 11.52, total_time = 40800.75
#
# step = 3682000, num_env_steps = 3682000, scores = 17.982 ± 0.24 (n=2), actor_loss = -171.463, critic_loss = 10.984, entropy_coef_loss = 2.568, entropy_coef = 0.046, action_stds = 0.465 ± 0.076, action_magnitude = 0.768 ± 0.264, num_gradient_steps = 3672000, step_time = 11.06, total_time = 40811.82
#
# step = 3683000, num_env_steps = 3683000, scores = 17.811 ± 0.01 (n=2), actor_loss = -169.898, critic_loss = 12.235, entropy_coef_loss = -0.601, entropy_coef = 0.046, action_stds = 0.500 ± 0.037, action_magnitude = 0.771 ± 0.265, num_gradient_steps = 3673000, step_time = 11.14, total_time = 40822.95
#
# step = 3684000, num_env_steps = 3684000, scores = 17.304 ± 0.75 (n=2), actor_loss = -173.993, critic_loss = 8.432, entropy_coef_loss = -0.103, entropy_coef = 0.046, action_stds = 0.496 ± 0.079, action_magnitude = 0.770 ± 0.266, num_gradient_steps = 3674000, step_time = 11.16, total_time = 40834.12
#
# step = 3685000, num_env_steps = 3685000, scores = 17.802 ± 0.10 (n=2), actor_loss = -162.659, critic_loss = 11.354, entropy_coef_loss = -2.549, entropy_coef = 0.046, action_stds = 0.476 ± 0.077, action_magnitude = 0.767 ± 0.266, num_gradient_steps = 3675000, step_time = 11.05, total_time = 40845.17
#
# step = 3686000, num_env_steps = 3686000, scores = 17.334 ± 0.22 (n=2), actor_loss = -179.081, critic_loss = 9.752, entropy_coef_loss = 2.737, entropy_coef = 0.046, action_stds = 0.512 ± 0.063, action_magnitude = 0.770 ± 0.266, num_gradient_steps = 3676000, step_time = 11.13, total_time = 40856.30
#
# step = 3687000, num_env_steps = 3687000, scores = 17.772 ± 0.88 (n=2), actor_loss = -165.940, critic_loss = 7.257, entropy_coef_loss = -2.983, entropy_coef = 0.046, action_stds = 0.522 ± 0.082, action_magnitude = 0.766 ± 0.266, num_gradient_steps = 3677000, step_time = 11.09, total_time = 40867.39
#
# step = 3688000, num_env_steps = 3688000, scores = 17.260 ± 0.17 (n=2), actor_loss = -178.511, critic_loss = 14.893, entropy_coef_loss = 1.490, entropy_coef = 0.047, action_stds = 0.466 ± 0.063, action_magnitude = 0.769 ± 0.267, num_gradient_steps = 3678000, step_time = 11.12, total_time = 40878.51
#
# step = 3689000, num_env_steps = 3689000, scores = 17.632 ± 0.60 (n=2), actor_loss = -169.350, critic_loss = 10.814, entropy_coef_loss = 0.648, entropy_coef = 0.047, action_stds = 0.479 ± 0.084, action_magnitude = 0.766 ± 0.266, num_gradient_steps = 3679000, step_time = 11.11, total_time = 40889.61
#
# step = 3690000, num_env_steps = 3690000, scores = 17.080 ± 0.03 (n=2), actor_loss = -178.231, critic_loss = 9.287, entropy_coef_loss = 0.223, entropy_coef = 0.046, action_stds = 0.496 ± 0.083, action_magnitude = 0.767 ± 0.266, num_gradient_steps = 3680000, step_time = 11.13, total_time = 40900.74
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
#
# step = 3691000, num_env_steps = 3691000, scores = 17.872 ± 0.46 (n=2), actor_loss = -168.994, critic_loss = 9.428, entropy_coef_loss = -0.561, entropy_coef = 0.046, action_stds = 0.476 ± 0.080, action_magnitude = 0.768 ± 0.266, num_gradient_steps = 3681000, step_time = 11.75, total_time = 40912.49
#
# step = 3692000, num_env_steps = 3692000, scores = 16.731 ± 1.14 (n=2), actor_loss = -169.556, critic_loss = 9.237, entropy_coef_loss = -2.724, entropy_coef = 0.046, action_stds = 0.498 ± 0.077, action_magnitude = 0.767 ± 0.266, num_gradient_steps = 3682000, step_time = 11.17, total_time = 40923.66
#
# step = 3693000, num_env_steps = 3693000, scores = 13.168 ± 4.19 (n=2), actor_loss = -163.426, critic_loss = 10.931, entropy_coef_loss = -2.000, entropy_coef = 0.047, action_stds = 0.482 ± 0.071, action_magnitude = 0.764 ± 0.270, num_gradient_steps = 3683000, step_time = 11.53, total_time = 40935.19
#
# step = 3694000, num_env_steps = 3694000, scores = 17.996 ± 0.64 (n=2), actor_loss = -170.380, critic_loss = 7.722, entropy_coef_loss = -0.317, entropy_coef = 0.047, action_stds = 0.477 ± 0.075, action_magnitude = 0.775 ± 0.261, num_gradient_steps = 3684000, step_time = 12.58, total_time = 40947.76
#
# saved experiment log 2024-10-30_13-36-09_498268~vdvgY8 at experiment_logs/2024-10-30_13-36-09_498268~vdvgY8.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
def save_training():
    experiment_id = logger.experiment_log['experiment_id']
    algo.save(f'saved_models/{experiment_id}', experiment_id)

save_training()

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
