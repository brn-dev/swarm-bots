# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics
from swarmbots.swarm_bot_env import SwarmBotEnv

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

save_best = True

def save_policy(suffix: str, score: float, steps_performed: int, gradient_steps_performed: int):
    experiment_id = logger.experiment_log["experiment_id"]
    policy.save(
        f'saved_models/{experiment_id}_{suffix}.pth', 
        score=score, 
        steps_performed=steps_performed,
        gradient_steps_performed=gradient_steps_performed
    )

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(2, consider_truncated_as_done=True)
    
    if save_best and len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            save_policy('best', iteration_score, step, rl.gradient_steps_performed)
            best_iteration_score = iteration_score
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(
        log_item, 
        mean_format='5.3f', 
        std_format='5.3f', 
        step_time='.2f', 
        total_time='.2f',
        scores={
            'mean_format': '5.3f',
            'n_format': 'd',
        }
    ), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        if step % 100_000 == 0:
            save_policy('latest', episode_scores.mean(), step, rl.gradient_steps_performed)
            
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: SwarmBotEnv(
        physics_steps_per_step=10, 
        action_scale=5, 
        hip_range=np.pi / 4,
        ctrl_cost_weight=0.001,
    )
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = int(np.prod(env.observation_space.shape))
    action_size = int(np.prod(env.action_space.shape))
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, 256),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=256,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef_clamp_range=(0.1, 1.5),
            # entropy_coef=0.01,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    # raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 259618
# env = <swarmbots.swarm_bot_env.SwarmBotEnv object at 0x00000205A8836490>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# Starting Training
# step = 11000, num_env_steps = 11000, scores = -2.869 ± 0.50 (n=2), actor_loss = -0.391, critic_loss = 0.005, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.861 ± 0.047, action_magnitude = 0.549 ± 0.291, num_gradient_steps = 1000, step_time = 18.85, total_time = 18.71
#
# step = 12000, num_env_steps = 12000, scores = -3.039 ± 0.33 (n=2), actor_loss = -0.810, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.035, action_magnitude = 0.522 ± 0.287, num_gradient_steps = 2000, step_time = 10.93, total_time = 29.64
#
# step = 13000, num_env_steps = 13000, scores = -2.917 ± 0.22 (n=2), actor_loss = -1.157, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.879 ± 0.017, action_magnitude = 0.519 ± 0.286, num_gradient_steps = 3000, step_time = 11.05, total_time = 40.69
#
# step = 14000, num_env_steps = 14000, scores = -3.103 ± 0.07 (n=2), actor_loss = -1.505, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.861 ± 0.027, action_magnitude = 0.521 ± 0.286, num_gradient_steps = 4000, step_time = 10.79, total_time = 51.48
#
# step = 15000, num_env_steps = 15000, scores = -3.208 ± 0.25 (n=2), actor_loss = -1.834, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.017, action_magnitude = 0.520 ± 0.287, num_gradient_steps = 5000, step_time = 10.88, total_time = 62.35
#
# step = 16000, num_env_steps = 16000, scores = -2.281 ± 0.13 (n=2), actor_loss = -2.152, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.850 ± 0.026, action_magnitude = 0.521 ± 0.284, num_gradient_steps = 6000, step_time = 10.77, total_time = 73.13
#
# step = 17000, num_env_steps = 17000, scores = -2.714 ± 0.09 (n=2), actor_loss = -2.444, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.866 ± 0.021, action_magnitude = 0.525 ± 0.286, num_gradient_steps = 7000, step_time = 10.71, total_time = 83.84
#
# step = 18000, num_env_steps = 18000, scores = -2.210 ± 0.08 (n=2), actor_loss = -2.696, critic_loss = 0.004, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.013, action_magnitude = 0.521 ± 0.286, num_gradient_steps = 8000, step_time = 10.70, total_time = 94.54
#
# step = 19000, num_env_steps = 19000, scores = -3.183 ± 0.02 (n=2), actor_loss = -2.973, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.010, action_magnitude = 0.527 ± 0.287, num_gradient_steps = 9000, step_time = 10.75, total_time = 105.29
#
# step = 20000, num_env_steps = 20000, scores = -2.863 ± 0.05 (n=2), actor_loss = -3.192, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.009, action_magnitude = 0.523 ± 0.288, num_gradient_steps = 10000, step_time = 10.78, total_time = 116.07
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 21000, num_env_steps = 21000, scores = -3.380 ± 0.21 (n=2), actor_loss = -3.463, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.027, action_magnitude = 0.526 ± 0.285, num_gradient_steps = 11000, step_time = 10.74, total_time = 126.81
#
# step = 22000, num_env_steps = 22000, scores = -2.541 ± 0.01 (n=2), actor_loss = -3.660, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.017, action_magnitude = 0.522 ± 0.286, num_gradient_steps = 12000, step_time = 10.61, total_time = 137.42
#
# step = 23000, num_env_steps = 23000, scores = -3.072 ± 0.44 (n=2), actor_loss = -3.887, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.026, action_magnitude = 0.522 ± 0.286, num_gradient_steps = 13000, step_time = 10.70, total_time = 148.12
#
# step = 24000, num_env_steps = 24000, scores = -3.003 ± 0.17 (n=2), actor_loss = -4.102, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.018, action_magnitude = 0.524 ± 0.286, num_gradient_steps = 14000, step_time = 10.56, total_time = 158.68
#
# step = 25000, num_env_steps = 25000, scores = -3.041 ± 0.23 (n=2), actor_loss = -4.303, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.862 ± 0.025, action_magnitude = 0.522 ± 0.287, num_gradient_steps = 15000, step_time = 10.68, total_time = 169.35
#
# step = 26000, num_env_steps = 26000, scores = -3.096 ± 0.13 (n=2), actor_loss = -4.451, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.016, action_magnitude = 0.523 ± 0.286, num_gradient_steps = 16000, step_time = 10.68, total_time = 180.03
#
# step = 27000, num_env_steps = 27000, scores = -2.894 ± 0.10 (n=2), actor_loss = -4.638, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.862 ± 0.016, action_magnitude = 0.527 ± 0.287, num_gradient_steps = 17000, step_time = 10.74, total_time = 190.77
#
# step = 28000, num_env_steps = 28000, scores = -2.733 ± 0.45 (n=2), actor_loss = -4.771, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.020, action_magnitude = 0.519 ± 0.284, num_gradient_steps = 18000, step_time = 10.73, total_time = 201.49
#
# step = 29000, num_env_steps = 29000, scores = -2.485 ± 0.32 (n=2), actor_loss = -4.916, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.012, action_magnitude = 0.522 ± 0.285, num_gradient_steps = 19000, step_time = 10.79, total_time = 212.28
#
# step = 30000, num_env_steps = 30000, scores = -2.811 ± 0.00 (n=2), actor_loss = -5.082, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.016, action_magnitude = 0.524 ± 0.286, num_gradient_steps = 20000, step_time = 10.70, total_time = 222.98
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 31000, num_env_steps = 31000, scores = -2.710 ± 0.22 (n=2), actor_loss = -5.209, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.862 ± 0.018, action_magnitude = 0.527 ± 0.285, num_gradient_steps = 21000, step_time = 10.72, total_time = 233.69
#
# step = 32000, num_env_steps = 32000, scores = -2.785 ± 0.11 (n=2), actor_loss = -5.371, critic_loss = 0.003, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.016, action_magnitude = 0.526 ± 0.285, num_gradient_steps = 22000, step_time = 10.78, total_time = 244.47
#
# step = 33000, num_env_steps = 33000, scores = -2.653 ± 0.42 (n=2), actor_loss = -5.530, critic_loss = 0.004, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.015, action_magnitude = 0.526 ± 0.286, num_gradient_steps = 23000, step_time = 10.74, total_time = 255.21
#
# step = 34000, num_env_steps = 34000, scores = -2.907 ± 0.39 (n=2), actor_loss = -5.618, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.014, action_magnitude = 0.522 ± 0.286, num_gradient_steps = 24000, step_time = 10.78, total_time = 265.99
#
# step = 35000, num_env_steps = 35000, scores = -2.646 ± 0.09 (n=2), actor_loss = -5.748, critic_loss = 0.006, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.015, action_magnitude = 0.519 ± 0.285, num_gradient_steps = 25000, step_time = 10.71, total_time = 276.70
#
# step = 36000, num_env_steps = 36000, scores = -2.741 ± 0.14 (n=2), actor_loss = -5.855, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.015, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 26000, step_time = 10.73, total_time = 287.43
#
# step = 37000, num_env_steps = 37000, scores = -2.826 ± 0.14 (n=2), actor_loss = -5.978, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.014, action_magnitude = 0.520 ± 0.286, num_gradient_steps = 27000, step_time = 10.70, total_time = 298.13
#
# step = 38000, num_env_steps = 38000, scores = -2.748 ± 0.05 (n=2), actor_loss = -6.088, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.863 ± 0.021, action_magnitude = 0.524 ± 0.284, num_gradient_steps = 28000, step_time = 10.81, total_time = 308.94
#
# step = 39000, num_env_steps = 39000, scores = -3.056 ± 0.13 (n=2), actor_loss = -6.161, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.843 ± 0.041, action_magnitude = 0.520 ± 0.285, num_gradient_steps = 29000, step_time = 10.66, total_time = 319.60
#
# step = 40000, num_env_steps = 40000, scores = -2.755 ± 0.06 (n=2), actor_loss = -6.369, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.864 ± 0.021, action_magnitude = 0.520 ± 0.285, num_gradient_steps = 30000, step_time = 10.76, total_time = 330.36
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 41000, num_env_steps = 41000, scores = -2.717 ± 0.48 (n=2), actor_loss = -6.469, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.877 ± 0.026, action_magnitude = 0.520 ± 0.284, num_gradient_steps = 31000, step_time = 10.79, total_time = 341.15
#
# step = 42000, num_env_steps = 42000, scores = -2.846 ± 0.06 (n=2), actor_loss = -6.548, critic_loss = 0.002, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.020, action_magnitude = 0.519 ± 0.285, num_gradient_steps = 32000, step_time = 10.79, total_time = 351.95
#
# step = 43000, num_env_steps = 43000, scores = -2.737 ± 0.24 (n=2), actor_loss = -6.621, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.009, action_magnitude = 0.517 ± 0.284, num_gradient_steps = 33000, step_time = 10.86, total_time = 362.81
#
# step = 44000, num_env_steps = 44000, scores = -2.691 ± 0.27 (n=2), actor_loss = -6.761, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.015, action_magnitude = 0.514 ± 0.287, num_gradient_steps = 34000, step_time = 10.64, total_time = 373.45
#
# step = 45000, num_env_steps = 45000, scores = -2.895 ± 0.15 (n=2), actor_loss = -6.862, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.021, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 35000, step_time = 10.65, total_time = 384.10
#
# step = 46000, num_env_steps = 46000, scores = -2.680 ± 0.06 (n=2), actor_loss = -6.973, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.016, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 36000, step_time = 10.67, total_time = 394.76
#
# step = 47000, num_env_steps = 47000, scores = -2.699 ± 0.37 (n=2), actor_loss = -7.071, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.018, action_magnitude = 0.521 ± 0.283, num_gradient_steps = 37000, step_time = 10.59, total_time = 405.36
#
# step = 48000, num_env_steps = 48000, scores = -2.783 ± 0.07 (n=2), actor_loss = -7.173, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.861 ± 0.012, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 38000, step_time = 10.71, total_time = 416.07
#
# step = 49000, num_env_steps = 49000, scores = -2.676 ± 0.16 (n=2), actor_loss = -7.264, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.013, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 39000, step_time = 10.70, total_time = 426.77
#
# step = 50000, num_env_steps = 50000, scores = -2.706 ± 0.01 (n=2), actor_loss = -7.384, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.011, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 40000, step_time = 10.68, total_time = 437.45
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 51000, num_env_steps = 51000, scores = -2.796 ± 0.29 (n=2), actor_loss = -7.499, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.865 ± 0.008, action_magnitude = 0.509 ± 0.285, num_gradient_steps = 41000, step_time = 10.67, total_time = 448.12
#
# step = 52000, num_env_steps = 52000, scores = -2.686 ± 0.09 (n=2), actor_loss = -7.577, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.013, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 42000, step_time = 10.67, total_time = 458.79
#
# step = 53000, num_env_steps = 53000, scores = -2.441 ± 0.18 (n=2), actor_loss = -7.689, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.865 ± 0.005, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 43000, step_time = 10.66, total_time = 469.45
#
# step = 54000, num_env_steps = 54000, scores = -2.700 ± 0.16 (n=2), actor_loss = -7.797, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.012, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 44000, step_time = 10.72, total_time = 480.17
#
# step = 55000, num_env_steps = 55000, scores = -2.857 ± 0.11 (n=2), actor_loss = -7.908, critic_loss = 0.001, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.866 ± 0.009, action_magnitude = 0.506 ± 0.283, num_gradient_steps = 45000, step_time = 10.72, total_time = 490.89
#
# step = 56000, num_env_steps = 56000, scores = -2.700 ± 0.17 (n=2), actor_loss = -8.016, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.012, action_magnitude = 0.513 ± 0.282, num_gradient_steps = 46000, step_time = 10.69, total_time = 501.59
#
# step = 57000, num_env_steps = 57000, scores = -2.500 ± 0.12 (n=2), actor_loss = -8.103, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.866 ± 0.004, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 47000, step_time = 10.72, total_time = 512.30
#
# step = 58000, num_env_steps = 58000, scores = -2.594 ± 0.06 (n=2), actor_loss = -8.199, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.010, action_magnitude = 0.510 ± 0.283, num_gradient_steps = 48000, step_time = 10.72, total_time = 523.03
#
# step = 59000, num_env_steps = 59000, scores = -2.783 ± 0.35 (n=2), actor_loss = -8.310, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.006, action_magnitude = 0.514 ± 0.286, num_gradient_steps = 49000, step_time = 10.75, total_time = 533.77
#
# step = 60000, num_env_steps = 60000, scores = -2.579 ± 0.17 (n=2), actor_loss = -8.402, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.004, action_magnitude = 0.510 ± 0.282, num_gradient_steps = 50000, step_time = 10.73, total_time = 544.51
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 61000, num_env_steps = 61000, scores = -2.898 ± 0.03 (n=2), actor_loss = -8.476, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.006, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 51000, step_time = 10.80, total_time = 555.30
#
# step = 62000, num_env_steps = 62000, scores = -2.843 ± 0.39 (n=2), actor_loss = -8.548, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.012, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 52000, step_time = 10.77, total_time = 566.08
#
# step = 63000, num_env_steps = 63000, scores = -2.774 ± 0.25 (n=2), actor_loss = -8.665, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.002, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 53000, step_time = 10.84, total_time = 576.91
#
# step = 64000, num_env_steps = 64000, scores = -2.386 ± 0.16 (n=2), actor_loss = -8.711, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.861 ± 0.011, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 54000, step_time = 10.68, total_time = 587.60
#
# step = 65000, num_env_steps = 65000, scores = -2.526 ± 0.32 (n=2), actor_loss = -8.804, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.003, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 55000, step_time = 10.74, total_time = 598.34
#
# step = 66000, num_env_steps = 66000, scores = -2.756 ± 0.05 (n=2), actor_loss = -8.864, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 56000, step_time = 11.39, total_time = 609.73
#
# step = 67000, num_env_steps = 67000, scores = -2.678 ± 0.17 (n=2), actor_loss = -8.896, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.004, action_magnitude = 0.512 ± 0.285, num_gradient_steps = 57000, step_time = 11.10, total_time = 620.83
#
# step = 68000, num_env_steps = 68000, scores = -2.652 ± 0.01 (n=2), actor_loss = -8.972, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.004, action_magnitude = 0.517 ± 0.283, num_gradient_steps = 58000, step_time = 10.86, total_time = 631.69
#
# step = 69000, num_env_steps = 69000, scores = -2.597 ± 0.02 (n=2), actor_loss = -9.054, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 59000, step_time = 10.80, total_time = 642.49
#
# step = 70000, num_env_steps = 70000, scores = -2.482 ± 0.10 (n=2), actor_loss = -9.109, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.006, action_magnitude = 0.511 ± 0.283, num_gradient_steps = 60000, step_time = 10.69, total_time = 653.18
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 71000, num_env_steps = 71000, scores = -2.853 ± 0.10 (n=2), actor_loss = -9.161, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 61000, step_time = 10.74, total_time = 663.92
#
# step = 72000, num_env_steps = 72000, scores = -2.675 ± 0.29 (n=2), actor_loss = -9.197, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.512 ± 0.282, num_gradient_steps = 62000, step_time = 10.72, total_time = 674.63
#
# step = 73000, num_env_steps = 73000, scores = -2.663 ± 0.02 (n=2), actor_loss = -9.254, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.003, action_magnitude = 0.514 ± 0.282, num_gradient_steps = 63000, step_time = 10.68, total_time = 685.31
#
# step = 74000, num_env_steps = 74000, scores = -2.926 ± 0.26 (n=2), actor_loss = -9.298, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 64000, step_time = 10.73, total_time = 696.04
#
# step = 75000, num_env_steps = 75000, scores = -2.991 ± 0.10 (n=2), actor_loss = -9.350, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.006, action_magnitude = 0.511 ± 0.285, num_gradient_steps = 65000, step_time = 10.72, total_time = 706.76
#
# step = 76000, num_env_steps = 76000, scores = -2.655 ± 0.10 (n=2), actor_loss = -9.390, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.006, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 66000, step_time = 10.71, total_time = 717.47
#
# step = 77000, num_env_steps = 77000, scores = -2.801 ± 0.01 (n=2), actor_loss = -9.426, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.006, action_magnitude = 0.513 ± 0.283, num_gradient_steps = 67000, step_time = 10.69, total_time = 728.15
#
# step = 78000, num_env_steps = 78000, scores = -2.948 ± 0.01 (n=2), actor_loss = -9.466, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.004, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 68000, step_time = 10.71, total_time = 738.87
#
# step = 79000, num_env_steps = 79000, scores = -2.616 ± 0.18 (n=2), actor_loss = -9.509, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.005, action_magnitude = 0.514 ± 0.282, num_gradient_steps = 69000, step_time = 10.73, total_time = 749.60
#
# step = 80000, num_env_steps = 80000, scores = -2.820 ± 0.01 (n=2), actor_loss = -9.531, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 70000, step_time = 10.64, total_time = 760.24
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 81000, num_env_steps = 81000, scores = -2.410 ± 0.52 (n=2), actor_loss = -9.567, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.010, action_magnitude = 0.509 ± 0.286, num_gradient_steps = 71000, step_time = 10.70, total_time = 770.94
#
# step = 82000, num_env_steps = 82000, scores = -2.808 ± 0.08 (n=2), actor_loss = -9.595, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 72000, step_time = 10.69, total_time = 781.63
#
# step = 83000, num_env_steps = 83000, scores = -2.576 ± 0.00 (n=2), actor_loss = -9.626, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.004, action_magnitude = 0.521 ± 0.283, num_gradient_steps = 73000, step_time = 10.65, total_time = 792.27
#
# step = 84000, num_env_steps = 84000, scores = -2.761 ± 0.09 (n=2), actor_loss = -9.655, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.007, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 74000, step_time = 10.68, total_time = 802.96
#
# step = 85000, num_env_steps = 85000, scores = -2.846 ± 0.32 (n=2), actor_loss = -9.674, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.005, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 75000, step_time = 10.62, total_time = 813.58
#
# step = 86000, num_env_steps = 86000, scores = -2.558 ± 0.03 (n=2), actor_loss = -9.723, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 76000, step_time = 10.61, total_time = 824.19
#
# step = 87000, num_env_steps = 87000, scores = -2.917 ± 0.03 (n=2), actor_loss = -9.739, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.006, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 77000, step_time = 10.72, total_time = 834.92
#
# step = 88000, num_env_steps = 88000, scores = -2.699 ± 0.10 (n=2), actor_loss = -9.758, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.003, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 78000, step_time = 10.69, total_time = 845.60
#
# step = 89000, num_env_steps = 89000, scores = -2.588 ± 0.08 (n=2), actor_loss = -9.778, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.008, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 79000, step_time = 10.71, total_time = 856.31
#
# step = 90000, num_env_steps = 90000, scores = -2.706 ± 0.02 (n=2), actor_loss = -9.802, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.002, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 80000, step_time = 10.73, total_time = 867.04
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 91000, num_env_steps = 91000, scores = -2.542 ± 0.19 (n=2), actor_loss = -9.819, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.007, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 81000, step_time = 10.75, total_time = 877.79
#
# step = 92000, num_env_steps = 92000, scores = -2.889 ± 0.33 (n=2), actor_loss = -9.846, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.003, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 82000, step_time = 10.69, total_time = 888.49
#
# step = 93000, num_env_steps = 93000, scores = -2.382 ± 0.18 (n=2), actor_loss = -9.845, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.004, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 83000, step_time = 10.68, total_time = 899.17
#
# step = 94000, num_env_steps = 94000, scores = -3.096 ± 0.13 (n=2), actor_loss = -9.876, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.004, action_magnitude = 0.511 ± 0.284, num_gradient_steps = 84000, step_time = 10.71, total_time = 909.88
#
# step = 95000, num_env_steps = 95000, scores = -2.275 ± 0.09 (n=2), actor_loss = -9.882, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.004, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 85000, step_time = 10.76, total_time = 920.64
#
# step = 96000, num_env_steps = 96000, scores = -2.751 ± 0.01 (n=2), actor_loss = -9.896, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.010, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 86000, step_time = 10.71, total_time = 931.35
#
# step = 97000, num_env_steps = 97000, scores = -2.576 ± 0.10 (n=2), actor_loss = -9.915, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 87000, step_time = 10.64, total_time = 942.00
#
# step = 98000, num_env_steps = 98000, scores = -2.429 ± 0.06 (n=2), actor_loss = -9.935, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.002, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 88000, step_time = 10.67, total_time = 952.67
#
# step = 99000, num_env_steps = 99000, scores = -2.777 ± 0.07 (n=2), actor_loss = -9.937, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.003, action_magnitude = 0.510 ± 0.284, num_gradient_steps = 89000, step_time = 10.72, total_time = 963.39
#
# step = 100000, num_env_steps = 100000, scores = -2.766 ± 0.08 (n=2), actor_loss = -9.949, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.003, action_magnitude = 0.520 ± 0.284, num_gradient_steps = 90000, step_time = 10.63, total_time = 974.02
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 101000, num_env_steps = 101000, scores = -2.564 ± 0.00 (n=2), actor_loss = -9.977, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.004, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 91000, step_time = 10.74, total_time = 984.76
#
# step = 102000, num_env_steps = 102000, scores = -2.906 ± 0.11 (n=2), actor_loss = -9.982, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.860 ± 0.013, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 92000, step_time = 10.71, total_time = 995.47
#
# step = 103000, num_env_steps = 103000, scores = -2.420 ± 0.03 (n=2), actor_loss = -9.990, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.003, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 93000, step_time = 10.72, total_time = 1006.18
#
# step = 104000, num_env_steps = 104000, scores = -2.967 ± 0.10 (n=2), actor_loss = -10.002, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.006, action_magnitude = 0.520 ± 0.283, num_gradient_steps = 94000, step_time = 10.72, total_time = 1016.90
#
# step = 105000, num_env_steps = 105000, scores = -2.589 ± 0.48 (n=2), actor_loss = -10.016, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.002, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 95000, step_time = 10.70, total_time = 1027.61
#
# step = 106000, num_env_steps = 106000, scores = -2.433 ± 0.01 (n=2), actor_loss = -10.019, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.513 ± 0.283, num_gradient_steps = 96000, step_time = 10.68, total_time = 1038.28
#
# step = 107000, num_env_steps = 107000, scores = -2.781 ± 0.48 (n=2), actor_loss = -10.025, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.010, action_magnitude = 0.514 ± 0.282, num_gradient_steps = 97000, step_time = 10.81, total_time = 1049.09
#
# step = 108000, num_env_steps = 108000, scores = -2.776 ± 0.05 (n=2), actor_loss = -10.037, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 98000, step_time = 10.68, total_time = 1059.77
#
# step = 109000, num_env_steps = 109000, scores = -2.551 ± 0.21 (n=2), actor_loss = -10.041, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.002, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 99000, step_time = 10.68, total_time = 1070.45
#
# step = 110000, num_env_steps = 110000, scores = -2.365 ± 0.38 (n=2), actor_loss = -10.056, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.011, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 100000, step_time = 10.71, total_time = 1081.16
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 111000, num_env_steps = 111000, scores = -2.324 ± 0.07 (n=2), actor_loss = -10.065, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.005, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 101000, step_time = 10.76, total_time = 1091.92
#
# step = 112000, num_env_steps = 112000, scores = -2.693 ± 0.17 (n=2), actor_loss = -10.077, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.004, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 102000, step_time = 10.77, total_time = 1102.69
#
# step = 113000, num_env_steps = 113000, scores = -2.627 ± 0.30 (n=2), actor_loss = -10.073, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 103000, step_time = 10.70, total_time = 1113.39
#
# step = 114000, num_env_steps = 114000, scores = -2.446 ± 0.06 (n=2), actor_loss = -10.089, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 104000, step_time = 10.71, total_time = 1124.10
#
# step = 115000, num_env_steps = 115000, scores = -2.531 ± 0.25 (n=2), actor_loss = -10.093, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 105000, step_time = 10.75, total_time = 1134.84
#
# step = 116000, num_env_steps = 116000, scores = -2.288 ± 0.17 (n=2), actor_loss = -10.089, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.002, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 106000, step_time = 10.79, total_time = 1145.63
#
# step = 117000, num_env_steps = 117000, scores = -2.845 ± 0.27 (n=2), actor_loss = -10.096, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.002, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 107000, step_time = 10.72, total_time = 1156.35
#
# step = 118000, num_env_steps = 118000, scores = -2.571 ± 0.26 (n=2), actor_loss = -10.111, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.003, action_magnitude = 0.511 ± 0.283, num_gradient_steps = 108000, step_time = 10.69, total_time = 1167.04
#
# step = 119000, num_env_steps = 119000, scores = -2.319 ± 0.03 (n=2), actor_loss = -10.113, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.006, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 109000, step_time = 11.06, total_time = 1178.11
#
# step = 120000, num_env_steps = 120000, scores = -2.769 ± 0.12 (n=2), actor_loss = -10.111, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 110000, step_time = 10.84, total_time = 1188.94
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 121000, num_env_steps = 121000, scores = -2.769 ± 0.15 (n=2), actor_loss = -10.132, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.516 ± 0.285, num_gradient_steps = 111000, step_time = 10.80, total_time = 1199.74
#
# step = 122000, num_env_steps = 122000, scores = -2.290 ± 0.52 (n=2), actor_loss = -10.126, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.003, action_magnitude = 0.511 ± 0.283, num_gradient_steps = 112000, step_time = 10.83, total_time = 1210.57
#
# step = 123000, num_env_steps = 123000, scores = -2.604 ± 0.07 (n=2), actor_loss = -10.142, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.009, action_magnitude = 0.515 ± 0.282, num_gradient_steps = 113000, step_time = 10.75, total_time = 1221.32
#
# step = 124000, num_env_steps = 124000, scores = -2.661 ± 0.18 (n=2), actor_loss = -10.147, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 114000, step_time = 10.74, total_time = 1232.06
#
# step = 125000, num_env_steps = 125000, scores = -2.754 ± 0.34 (n=2), actor_loss = -10.148, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.009, action_magnitude = 0.517 ± 0.283, num_gradient_steps = 115000, step_time = 10.81, total_time = 1242.87
#
# step = 126000, num_env_steps = 126000, scores = -2.330 ± 0.04 (n=2), actor_loss = -10.146, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.005, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 116000, step_time = 10.78, total_time = 1253.65
#
# step = 127000, num_env_steps = 127000, scores = -3.063 ± 0.16 (n=2), actor_loss = -10.142, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.006, action_magnitude = 0.515 ± 0.282, num_gradient_steps = 117000, step_time = 11.03, total_time = 1264.69
#
# step = 128000, num_env_steps = 128000, scores = -3.047 ± 0.01 (n=2), actor_loss = -10.155, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.002, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 118000, step_time = 10.74, total_time = 1275.43
#
# step = 129000, num_env_steps = 129000, scores = -2.568 ± 0.01 (n=2), actor_loss = -10.151, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.007, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 119000, step_time = 10.78, total_time = 1286.21
#
# step = 130000, num_env_steps = 130000, scores = -2.967 ± 0.08 (n=2), actor_loss = -10.148, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.008, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 120000, step_time = 10.86, total_time = 1297.07
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 131000, num_env_steps = 131000, scores = -2.494 ± 0.37 (n=2), actor_loss = -10.146, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.005, action_magnitude = 0.519 ± 0.283, num_gradient_steps = 121000, step_time = 10.80, total_time = 1307.87
#
# step = 132000, num_env_steps = 132000, scores = -2.907 ± 0.23 (n=2), actor_loss = -10.162, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.007, action_magnitude = 0.517 ± 0.285, num_gradient_steps = 122000, step_time = 10.93, total_time = 1318.80
#
# step = 133000, num_env_steps = 133000, scores = -3.077 ± 0.16 (n=2), actor_loss = -10.175, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.005, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 123000, step_time = 10.75, total_time = 1329.55
#
# step = 134000, num_env_steps = 134000, scores = -2.576 ± 0.08 (n=2), actor_loss = -10.162, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.007, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 124000, step_time = 10.78, total_time = 1340.33
#
# step = 135000, num_env_steps = 135000, scores = -2.759 ± 0.26 (n=2), actor_loss = -10.164, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.006, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 125000, step_time = 10.82, total_time = 1351.14
#
# step = 136000, num_env_steps = 136000, scores = -2.794 ± 0.00 (n=2), actor_loss = -10.160, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.002, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 126000, step_time = 10.81, total_time = 1361.96
#
# step = 137000, num_env_steps = 137000, scores = -2.559 ± 0.16 (n=2), actor_loss = -10.178, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.003, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 127000, step_time = 10.85, total_time = 1372.80
#
# step = 138000, num_env_steps = 138000, scores = -2.915 ± 0.30 (n=2), actor_loss = -10.160, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.004, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 128000, step_time = 10.88, total_time = 1383.69
#
# step = 139000, num_env_steps = 139000, scores = -2.856 ± 0.14 (n=2), actor_loss = -10.192, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.002, action_magnitude = 0.517 ± 0.284, num_gradient_steps = 129000, step_time = 10.78, total_time = 1394.46
#
# step = 140000, num_env_steps = 140000, scores = -2.809 ± 0.12 (n=2), actor_loss = -10.179, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.007, action_magnitude = 0.510 ± 0.286, num_gradient_steps = 130000, step_time = 10.90, total_time = 1405.37
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 141000, num_env_steps = 141000, scores = -2.655 ± 0.19 (n=2), actor_loss = -10.185, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.008, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 131000, step_time = 10.87, total_time = 1416.23
#
# step = 142000, num_env_steps = 142000, scores = -2.804 ± 0.37 (n=2), actor_loss = -10.173, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.009, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 132000, step_time = 10.90, total_time = 1427.13
#
# step = 143000, num_env_steps = 143000, scores = -2.558 ± 0.37 (n=2), actor_loss = -10.181, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.510 ± 0.283, num_gradient_steps = 133000, step_time = 10.92, total_time = 1438.05
#
# step = 144000, num_env_steps = 144000, scores = -2.684 ± 0.03 (n=2), actor_loss = -10.184, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.003, action_magnitude = 0.512 ± 0.285, num_gradient_steps = 134000, step_time = 10.72, total_time = 1448.78
#
# step = 145000, num_env_steps = 145000, scores = -2.722 ± 0.34 (n=2), actor_loss = -10.179, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.011, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 135000, step_time = 10.76, total_time = 1459.54
#
# step = 146000, num_env_steps = 146000, scores = -2.709 ± 0.13 (n=2), actor_loss = -10.172, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 136000, step_time = 10.85, total_time = 1470.39
#
# step = 147000, num_env_steps = 147000, scores = -2.468 ± 0.19 (n=2), actor_loss = -10.186, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.007, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 137000, step_time = 10.78, total_time = 1481.17
#
# step = 148000, num_env_steps = 148000, scores = -2.660 ± 0.09 (n=2), actor_loss = -10.190, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.006, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 138000, step_time = 10.85, total_time = 1492.02
#
# step = 149000, num_env_steps = 149000, scores = -2.345 ± 0.26 (n=2), actor_loss = -10.178, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.010, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 139000, step_time = 10.74, total_time = 1502.75
#
# step = 150000, num_env_steps = 150000, scores = -2.599 ± 0.12 (n=2), actor_loss = -10.192, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.869 ± 0.009, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 140000, step_time = 10.81, total_time = 1513.56
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 151000, num_env_steps = 151000, scores = -2.655 ± 0.21 (n=2), actor_loss = -10.194, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.003, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 141000, step_time = 10.81, total_time = 1524.38
#
# step = 152000, num_env_steps = 152000, scores = -2.655 ± 0.01 (n=2), actor_loss = -10.188, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.004, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 142000, step_time = 10.82, total_time = 1535.20
#
# step = 153000, num_env_steps = 153000, scores = -2.611 ± 0.07 (n=2), actor_loss = -10.195, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.513 ± 0.286, num_gradient_steps = 143000, step_time = 10.84, total_time = 1546.04
#
# step = 154000, num_env_steps = 154000, scores = -2.378 ± 0.63 (n=2), actor_loss = -10.191, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.010, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 144000, step_time = 10.84, total_time = 1556.88
#
# step = 155000, num_env_steps = 155000, scores = -2.933 ± 0.22 (n=2), actor_loss = -10.197, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.003, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 145000, step_time = 10.77, total_time = 1567.64
#
# step = 156000, num_env_steps = 156000, scores = -2.743 ± 0.16 (n=2), actor_loss = -10.198, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 146000, step_time = 10.78, total_time = 1578.42
#
# step = 157000, num_env_steps = 157000, scores = -2.915 ± 0.15 (n=2), actor_loss = -10.184, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.004, action_magnitude = 0.517 ± 0.283, num_gradient_steps = 147000, step_time = 10.74, total_time = 1589.16
#
# step = 158000, num_env_steps = 158000, scores = -2.466 ± 0.11 (n=2), actor_loss = -10.202, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.867 ± 0.009, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 148000, step_time = 10.76, total_time = 1599.92
#
# step = 159000, num_env_steps = 159000, scores = -2.887 ± 0.05 (n=2), actor_loss = -10.187, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.004, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 149000, step_time = 10.86, total_time = 1610.78
#
# step = 160000, num_env_steps = 160000, scores = -2.706 ± 0.09 (n=2), actor_loss = -10.197, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.009, action_magnitude = 0.514 ± 0.286, num_gradient_steps = 150000, step_time = 10.73, total_time = 1621.51
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 161000, num_env_steps = 161000, scores = -2.542 ± 0.05 (n=2), actor_loss = -10.201, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.512 ± 0.285, num_gradient_steps = 151000, step_time = 10.77, total_time = 1632.28
#
# step = 162000, num_env_steps = 162000, scores = -2.406 ± 0.46 (n=2), actor_loss = -10.193, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.006, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 152000, step_time = 10.73, total_time = 1643.01
#
# step = 163000, num_env_steps = 163000, scores = -3.025 ± 0.12 (n=2), actor_loss = -10.203, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.003, action_magnitude = 0.516 ± 0.286, num_gradient_steps = 153000, step_time = 10.70, total_time = 1653.71
#
# step = 164000, num_env_steps = 164000, scores = -2.434 ± 0.14 (n=2), actor_loss = -10.189, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.868 ± 0.008, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 154000, step_time = 10.65, total_time = 1664.36
#
# step = 165000, num_env_steps = 165000, scores = -2.768 ± 0.23 (n=2), actor_loss = -10.190, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.006, action_magnitude = 0.513 ± 0.282, num_gradient_steps = 155000, step_time = 10.76, total_time = 1675.12
#
# step = 166000, num_env_steps = 166000, scores = -2.881 ± 0.15 (n=2), actor_loss = -10.197, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 156000, step_time = 10.73, total_time = 1685.85
#
# step = 167000, num_env_steps = 167000, scores = -2.315 ± 0.01 (n=2), actor_loss = -10.198, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.008, action_magnitude = 0.511 ± 0.284, num_gradient_steps = 157000, step_time = 10.67, total_time = 1696.52
#
# step = 168000, num_env_steps = 168000, scores = -2.645 ± 0.08 (n=2), actor_loss = -10.194, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.002, action_magnitude = 0.514 ± 0.286, num_gradient_steps = 158000, step_time = 10.71, total_time = 1707.23
#
# ...
#
# step = 652000, num_env_steps = 652000, scores = -2.519 ± 0.10 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.005, action_magnitude = 0.513 ± 0.284, num_gradient_steps = 642000, step_time = 10.59, total_time = 6901.65
#
# step = 653000, num_env_steps = 653000, scores = -2.864 ± 0.03 (n=2), actor_loss = -10.212, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.006, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 643000, step_time = 10.61, total_time = 6912.25
#
# step = 654000, num_env_steps = 654000, scores = -2.524 ± 0.22 (n=2), actor_loss = -10.216, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 644000, step_time = 10.63, total_time = 6922.88
#
# step = 655000, num_env_steps = 655000, scores = -2.752 ± 0.00 (n=2), actor_loss = -10.214, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.521 ± 0.283, num_gradient_steps = 645000, step_time = 10.66, total_time = 6933.54
#
# step = 656000, num_env_steps = 656000, scores = -2.456 ± 0.43 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 646000, step_time = 10.59, total_time = 6944.13
#
# step = 657000, num_env_steps = 657000, scores = -2.811 ± 0.22 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.008, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 647000, step_time = 10.68, total_time = 6954.82
#
# step = 658000, num_env_steps = 658000, scores = -2.372 ± 0.15 (n=2), actor_loss = -10.211, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.010, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 648000, step_time = 10.66, total_time = 6965.47
#
# step = 659000, num_env_steps = 659000, scores = -2.467 ± 0.01 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.511 ± 0.285, num_gradient_steps = 649000, step_time = 10.61, total_time = 6976.09
#
# step = 660000, num_env_steps = 660000, scores = -2.564 ± 0.11 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.002, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 650000, step_time = 10.63, total_time = 6986.72
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 661000, num_env_steps = 661000, scores = -2.422 ± 0.19 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.006, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 651000, step_time = 10.67, total_time = 6997.38
#
# step = 662000, num_env_steps = 662000, scores = -2.535 ± 0.15 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 652000, step_time = 10.61, total_time = 7008.00
#
# step = 663000, num_env_steps = 663000, scores = -2.817 ± 0.08 (n=2), actor_loss = -10.203, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.006, action_magnitude = 0.515 ± 0.283, num_gradient_steps = 653000, step_time = 10.64, total_time = 7018.64
#
# step = 664000, num_env_steps = 664000, scores = -2.853 ± 0.09 (n=2), actor_loss = -10.215, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 654000, step_time = 10.61, total_time = 7029.24
#
# step = 665000, num_env_steps = 665000, scores = -2.927 ± 0.16 (n=2), actor_loss = -10.210, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.010, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 655000, step_time = 10.62, total_time = 7039.86
#
# step = 666000, num_env_steps = 666000, scores = -2.911 ± 0.23 (n=2), actor_loss = -10.220, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 656000, step_time = 10.71, total_time = 7050.57
#
# step = 667000, num_env_steps = 667000, scores = -2.832 ± 0.02 (n=2), actor_loss = -10.217, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 657000, step_time = 10.64, total_time = 7061.21
#
# step = 668000, num_env_steps = 668000, scores = -2.660 ± 0.08 (n=2), actor_loss = -10.214, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 658000, step_time = 10.62, total_time = 7071.83
#
# step = 669000, num_env_steps = 669000, scores = -2.729 ± 0.11 (n=2), actor_loss = -10.208, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.516 ± 0.282, num_gradient_steps = 659000, step_time = 10.70, total_time = 7082.53
#
# step = 670000, num_env_steps = 670000, scores = -2.457 ± 0.07 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.004, action_magnitude = 0.513 ± 0.283, num_gradient_steps = 660000, step_time = 10.86, total_time = 7093.38
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 671000, num_env_steps = 671000, scores = -2.553 ± 0.10 (n=2), actor_loss = -10.215, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.004, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 661000, step_time = 10.72, total_time = 7104.11
#
# step = 672000, num_env_steps = 672000, scores = -3.004 ± 0.28 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 662000, step_time = 10.69, total_time = 7114.79
#
# step = 673000, num_env_steps = 673000, scores = -2.410 ± 0.06 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.006, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 663000, step_time = 10.64, total_time = 7125.43
#
# step = 674000, num_env_steps = 674000, scores = -3.016 ± 0.24 (n=2), actor_loss = -10.211, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.518 ± 0.284, num_gradient_steps = 664000, step_time = 10.64, total_time = 7136.07
#
# step = 675000, num_env_steps = 675000, scores = -2.450 ± 0.25 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.005, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 665000, step_time = 10.60, total_time = 7146.67
#
# step = 676000, num_env_steps = 676000, scores = -2.392 ± 0.34 (n=2), actor_loss = -10.214, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 666000, step_time = 10.63, total_time = 7157.29
#
# step = 677000, num_env_steps = 677000, scores = -2.624 ± 0.26 (n=2), actor_loss = -10.204, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 667000, step_time = 10.63, total_time = 7167.92
#
# step = 678000, num_env_steps = 678000, scores = -2.790 ± 0.38 (n=2), actor_loss = -10.217, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.006, action_magnitude = 0.521 ± 0.283, num_gradient_steps = 668000, step_time = 10.71, total_time = 7178.64
#
# step = 679000, num_env_steps = 679000, scores = -2.654 ± 0.07 (n=2), actor_loss = -10.221, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.870 ± 0.005, action_magnitude = 0.516 ± 0.284, num_gradient_steps = 669000, step_time = 10.60, total_time = 7189.24
#
# step = 680000, num_env_steps = 680000, scores = -2.829 ± 0.19 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.878 ± 0.011, action_magnitude = 0.518 ± 0.283, num_gradient_steps = 670000, step_time = 10.69, total_time = 7199.93
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 681000, num_env_steps = 681000, scores = -2.848 ± 0.16 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.002, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 671000, step_time = 10.69, total_time = 7210.62
#
# step = 682000, num_env_steps = 682000, scores = -2.852 ± 0.01 (n=2), actor_loss = -10.207, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.003, action_magnitude = 0.515 ± 0.285, num_gradient_steps = 672000, step_time = 10.70, total_time = 7221.32
#
# step = 683000, num_env_steps = 683000, scores = -2.825 ± 0.12 (n=2), actor_loss = -10.211, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 673000, step_time = 10.70, total_time = 7232.02
#
# step = 684000, num_env_steps = 684000, scores = -2.628 ± 0.09 (n=2), actor_loss = -10.224, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 674000, step_time = 10.64, total_time = 7242.66
#
# step = 685000, num_env_steps = 685000, scores = -2.423 ± 0.37 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.004, action_magnitude = 0.518 ± 0.285, num_gradient_steps = 675000, step_time = 10.62, total_time = 7253.28
#
# step = 686000, num_env_steps = 686000, scores = -2.909 ± 0.16 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.522 ± 0.283, num_gradient_steps = 676000, step_time = 10.62, total_time = 7263.89
#
# step = 687000, num_env_steps = 687000, scores = -2.819 ± 0.06 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.002, action_magnitude = 0.513 ± 0.285, num_gradient_steps = 677000, step_time = 10.62, total_time = 7274.52
#
# step = 688000, num_env_steps = 688000, scores = -2.325 ± 0.39 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.005, action_magnitude = 0.517 ± 0.283, num_gradient_steps = 678000, step_time = 10.64, total_time = 7285.15
#
# step = 689000, num_env_steps = 689000, scores = -2.517 ± 0.01 (n=2), actor_loss = -10.217, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.514 ± 0.284, num_gradient_steps = 679000, step_time = 10.65, total_time = 7295.80
#
# step = 690000, num_env_steps = 690000, scores = -2.461 ± 0.12 (n=2), actor_loss = -10.220, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.005, action_magnitude = 0.514 ± 0.285, num_gradient_steps = 680000, step_time = 10.63, total_time = 7306.43
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 691000, num_env_steps = 691000, scores = -2.893 ± 0.32 (n=2), actor_loss = -10.215, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.006, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 681000, step_time = 10.73, total_time = 7317.15
#
# step = 692000, num_env_steps = 692000, scores = -2.867 ± 0.17 (n=2), actor_loss = -10.218, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.875 ± 0.003, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 682000, step_time = 10.62, total_time = 7327.77
#
# step = 693000, num_env_steps = 693000, scores = -2.905 ± 0.02 (n=2), actor_loss = -10.225, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.010, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 683000, step_time = 10.65, total_time = 7338.43
#
# step = 694000, num_env_steps = 694000, scores = -2.637 ± 0.31 (n=2), actor_loss = -10.220, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.003, action_magnitude = 0.515 ± 0.284, num_gradient_steps = 684000, step_time = 10.65, total_time = 7349.07
#
# step = 695000, num_env_steps = 695000, scores = -2.873 ± 0.04 (n=2), actor_loss = -10.213, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.876 ± 0.007, action_magnitude = 0.516 ± 0.283, num_gradient_steps = 685000, step_time = 10.68, total_time = 7359.76
#
# step = 696000, num_env_steps = 696000, scores = -2.723 ± 0.11 (n=2), actor_loss = -10.215, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.005, action_magnitude = 0.514 ± 0.286, num_gradient_steps = 686000, step_time = 10.64, total_time = 7370.40
#
# step = 697000, num_env_steps = 697000, scores = -3.044 ± 0.16 (n=2), actor_loss = -10.219, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.002, action_magnitude = 0.519 ± 0.283, num_gradient_steps = 687000, step_time = 11.36, total_time = 7381.76
#
# step = 698000, num_env_steps = 698000, scores = -2.905 ± 0.05 (n=2), actor_loss = -10.221, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.874 ± 0.003, action_magnitude = 0.514 ± 0.286, num_gradient_steps = 688000, step_time = 11.13, total_time = 7392.89
#
# step = 699000, num_env_steps = 699000, scores = -2.602 ± 0.14 (n=2), actor_loss = -10.221, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.005, action_magnitude = 0.512 ± 0.284, num_gradient_steps = 689000, step_time = 9.85, total_time = 7402.74
#
# step = 700000, num_env_steps = 700000, scores = -2.587 ± 0.41 (n=2), actor_loss = -10.214, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.872 ± 0.007, action_magnitude = 0.511 ± 0.283, num_gradient_steps = 690000, step_time = 9.26, total_time = 7412.00
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
#
# step = 701000, num_env_steps = 701000, scores = -2.747 ± 0.28 (n=2), actor_loss = -10.220, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.004, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 691000, step_time = 9.28, total_time = 7421.28
#
# step = 702000, num_env_steps = 702000, scores = -2.814 ± 0.10 (n=2), actor_loss = -10.216, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.873 ± 0.003, action_magnitude = 0.514 ± 0.283, num_gradient_steps = 692000, step_time = 9.40, total_time = 7430.68
#
# step = 703000, num_env_steps = 703000, scores = -2.485 ± 0.22 (n=2), actor_loss = -10.215, critic_loss = 0.000, entropy_coef_loss = None, entropy_coef = 0.010, action_stds = 0.871 ± 0.007, action_magnitude = 0.512 ± 0.283, num_gradient_steps = 693000, step_time = 9.79, total_time = 7440.47
#
# saved experiment log 2024-10-27_00-07-37_446622~uzg2aU at experiment_logs/2024-10-27_00-07-37_446622~uzg2aU.json
# keyboard interrupt
# closing envs
# envs closed
# done

# %%
from src.reinforcement_learning.core.policy_evaluation import record_policy

env.render_mode = 'rgb_array'
record_policy(
    env=env,
    policy=policy,
    video_folder='videos',
    deterministic_actions=False,
    num_steps=999,
    torch_device=device,
)
# Out:
# C:\Program Files\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at C:\Users\domin\Git\swarm-bots\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-0.mp4
# closing record env
# Moviepy - Building video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\domin\Git\swarm-bots\videos\rl-video-episode-1.mp4
# record env closed

# %%
env.physics.data.xpos
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.55573153, -0.4078065 ,  0.14921404],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.48739983, -0.43612304,  0.21651153],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.64728733, -0.4268981 ,  0.18461243],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.54656564, -0.30979478,  0.13161603],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.02058614, -0.30683126,  0.33239675],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.11026708, -0.30289121,  0.37646266],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [10.00786531, -0.22566631,  0.27538418],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167],
#        [ 9.94918638, -0.30995894,  0.40234167]])

# %%
import PIL.Image

PIL.Image.fromarray(create_env(None).render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
# ----> 3 PIL.Image.fromarray(create_env(None).render())
#
# NameError: name 'create_env' is not defined
