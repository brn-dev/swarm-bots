# %%
# %load_ext autoreload
# %autoreload 2

import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, DummyVecEnv
from stable_baselines3.common.monitor import Monitor
import imageio

from swarmbots import SimpleSwarmTetrahedronZX
from swarmbots import SwarmBotsEnv
from swarmbots import ObstacleStreetScenario

# %%
class NoConnectionActionWrapper(gym.Wrapper):
    """
    Wraps a SwarmBotsEnv to flatten the observation space and
    convert the hybrid Dict action space into a single flat Box space.
    """
    def __init__(self, env: SwarmBotsEnv):
        super().__init__(env)
        self.env = env

        # --- 1. Flatten Observation Space ---
        # Original obs is (n_agents, obs_per_agent) or similar
        # We flatten it to (n_agents * obs_per_agent,)
        self.obs_shape = env.observation_space.shape
        self.obs_dim_flat = np.prod(self.obs_shape)
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(self.obs_dim_flat,),
            dtype=np.float32
        )

        # --- 2. Flatten Action Space (Hybrid -> Box) ---
        # The mj_env action space is a Dict with 'actuators' (Box) and 'connectors' (MultiBinary)
        self.original_action_space = env.action_space

        # Get shapes
        self.act_space = self.original_action_space['actuators']

        self.act_shape = self.act_space.shape

        self.act_dim_flat = np.prod(self.act_shape)

        # Create a single continuous action space for ppo
        # We use [-1, 1] range. For binary actions, >0 will be treated as 1.
        self.action_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(self.act_dim_flat,),
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        obs, info = self.env.reset(seed=seed, options=options)
        return obs.flatten(), info

    def step(self, action):
        # 'action' is a flat float array from ppo

        # 1. Split into actuator and connector parts
        act_part_flat = action[:self.act_dim_flat]

        # 2. Reshape actuators (Continuous)
        # ppo outputs in [-1, 1] which matches the actuator space usually
        actuators = act_part_flat.reshape(self.act_shape)

        # 4. Construct Dictionary Action
        dict_action = {
            'actuators': actuators,
            'connectors': self.env.swarm_connections.get_is_active_mask()
        }

        obs, reward, terminated, truncated, info = self.env.step(dict_action)

        return obs.flatten(), reward, terminated, truncated, info

def make_env():
    rng = np.random.default_rng(42)
    swarm = SimpleSwarmTetrahedronZX(connection_torquescale=10.0)
    scenario = ObstacleStreetScenario(swarm=swarm, payload_type=None, seed=rng.integers(0, 10000000))
    env = SwarmBotsEnv(scenario=scenario, render_mode=None)
    # Use the new wrapper
    env = NoConnectionActionWrapper(env)
    env = Monitor(env)
    print(f'{env.observation_space = }')
    print(f'{env.action_space = }')
    return env

def record(model_path="ppo_no_con_swarm_bots", vecnorm_path="vecnormalize_swarm_bots.pkl"):
    def make_eval_env():
        swarm = SimpleSwarmTetrahedronZX(connection_torquescale=10.0)
        scenario = ObstacleStreetScenario(swarm=swarm, payload_type=None, seed=42)
        env = SwarmBotsEnv(scenario=scenario, render_mode="rgb_array", width=640, height=480)
        env = NoConnectionActionWrapper(env)
        return env

    model = PPO.load(model_path)
    eval_env = DummyVecEnv([make_eval_env])
    eval_env = VecNormalize.load(vecnorm_path, eval_env)
    eval_env.training = False
    eval_env.norm_reward = False

    obs = eval_env.reset()
    images = []
    print("Recording rollout...")

    for _ in range(500):
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = eval_env.step(action)
        img = eval_env.envs[0].render()
        if img is not None:
            images.append(img)
        if dones[0]:
            break

    eval_env.close()

    if images:
        imageio.mimsave("swarm_bots_rollout_ppo_no_con.gif", images, fps=30)
        print("Saved swarm_bots_rollout_ppo_no_con.gif")
    else:
        print("No images captured.")

vec_env = SubprocVecEnv([make_env] * 4)
print(vec_env.action_space)
print(vec_env.observation_space)
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=True)

policy_kwargs = dict(net_arch=dict(pi=[256, 256], vf=[256, 256]))
model = PPO(
    "MlpPolicy",
    vec_env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    n_steps=512,
    device="cpu",
    learning_rate=2e-5,
    target_kl=0.05
)

print("Starting training...")
model.learn(total_timesteps=10_000_000)
print("Training finished.")

model.save("ppo_no_con_swarm_bots")
vec_env.save("vecnormalize_swarm_bots.pkl")

record()
# Out:
# Box(-1.0, 1.0, (16,), float32)
# Box(-inf, inf, (82,), float32)
# Using cpu device
# Starting training...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -0.261   |
# | time/              |          |
# |    fps             | 3245     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.238       |
# | time/                   |              |
# |    fps                  | 2247         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0059620203 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.196        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0214      |
# |    std                  | 1            |
# |    value_loss           | 0.405        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.248      |
# | time/                   |             |
# |    fps                  | 2024        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007218059 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.0246      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 1           |
# |    value_loss           | 0.214       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.236       |
# | time/                   |              |
# |    fps                  | 1910         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073123164 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0102       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0262      |
# |    std                  | 0.999        |
# |    value_loss           | 0.284        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.245       |
# | time/                   |              |
# |    fps                  | 1868         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073382333 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0146       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0243      |
# |    std                  | 0.999        |
# |    value_loss           | 0.0977       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.29        |
# | time/                   |              |
# |    fps                  | 1850         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0055123847 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0096       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0238      |
# |    std                  | 0.999        |
# |    value_loss           | 0.292        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.291       |
# | time/                   |              |
# |    fps                  | 1823         |
# |    iterations           | 7            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063707675 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0284       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0236      |
# |    std                  | 0.999        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.286       |
# | time/                   |              |
# |    fps                  | 1812         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0076815723 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0141       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0258      |
# |    std                  | 0.999        |
# |    value_loss           | 0.114        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.3         |
# | time/                   |              |
# |    fps                  | 1807         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0069660908 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0127      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0257      |
# |    std                  | 0.999        |
# |    value_loss           | 0.0762       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.28        |
# | time/                   |              |
# |    fps                  | 1804         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0068147862 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0124      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0267      |
# |    std                  | 0.999        |
# |    value_loss           | 0.108        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.262       |
# | time/                   |              |
# |    fps                  | 1798         |
# |    iterations           | 11           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0066819545 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0234      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0248      |
# |    std                  | 0.999        |
# |    value_loss           | 0.0736       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.259       |
# | time/                   |              |
# |    fps                  | 1789         |
# |    iterations           | 12           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0063781356 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0137      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0255      |
# |    std                  | 0.999        |
# |    value_loss           | 0.0866       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.261       |
# | time/                   |              |
# |    fps                  | 1783         |
# |    iterations           | 13           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0077390326 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.502        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.029       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0231      |
# |    std                  | 0.998        |
# |    value_loss           | 0.0553       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.247       |
# | time/                   |              |
# |    fps                  | 1773         |
# |    iterations           | 14           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0071065193 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.00824     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0272      |
# |    std                  | 0.998        |
# |    value_loss           | 0.087        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.251       |
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 15           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0076286173 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.00558     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0262      |
# |    std                  | 0.998        |
# |    value_loss           | 0.086        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.242      |
# | time/                   |             |
# |    fps                  | 1720        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007068675 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0133     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.998       |
# |    value_loss           | 0.0755      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.226       |
# | time/                   |              |
# |    fps                  | 1703         |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0076245284 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.00852     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0268      |
# |    std                  | 0.998        |
# |    value_loss           | 0.082        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.227      |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006748524 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.00168    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.998       |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.222      |
# | time/                   |             |
# |    fps                  | 1657        |
# |    iterations           | 19          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007248429 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.00223    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.997       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.219      |
# | time/                   |             |
# |    fps                  | 1641        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006554583 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.019      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.997       |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.208      |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 21          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007862191 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0143     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.997       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.201       |
# | time/                   |              |
# |    fps                  | 1617         |
# |    iterations           | 22           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0073558916 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0213       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0277      |
# |    std                  | 0.996        |
# |    value_loss           | 0.124        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.193      |
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 23          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007935423 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0143     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.996       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.187       |
# | time/                   |              |
# |    fps                  | 1537         |
# |    iterations           | 24           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0076441555 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.00258      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0261      |
# |    std                  | 0.996        |
# |    value_loss           | 0.0898       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.19       |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 25          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008084509 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.00587     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.996       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.193      |
# | time/                   |             |
# |    fps                  | 1508        |
# |    iterations           | 26          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008707922 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.015      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.996       |
# |    value_loss           | 0.0957      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.193      |
# | time/                   |             |
# |    fps                  | 1510        |
# |    iterations           | 27          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007859521 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.0153      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.996       |
# |    value_loss           | 0.0944      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.188      |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 28          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008208225 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0301     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0776      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 1487        |
# |    iterations           | 29          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008425506 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.0144      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0304     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0895      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.164      |
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 30          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007492366 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0201     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.027      |
# |    std                  | 0.994       |
# |    value_loss           | 0.0671      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.147      |
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 31          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007259352 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.0177      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.994       |
# |    value_loss           | 0.109       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.151       |
# | time/                   |              |
# |    fps                  | 1480         |
# |    iterations           | 32           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0074012466 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.0075       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0259      |
# |    std                  | 0.994        |
# |    value_loss           | 0.0903       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.156      |
# | time/                   |             |
# |    fps                  | 1476        |
# |    iterations           | 33          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008219011 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.0146      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0963      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.139      |
# | time/                   |             |
# |    fps                  | 1473        |
# |    iterations           | 34          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007612982 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 0.000436    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0277     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0976      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.137       |
# | time/                   |              |
# |    fps                  | 1469         |
# |    iterations           | 35           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0075877984 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.00189     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0286      |
# |    std                  | 0.993        |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.137       |
# | time/                   |              |
# |    fps                  | 1465         |
# |    iterations           | 36           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0079151895 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.6        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0172      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0285      |
# |    std                  | 0.992        |
# |    value_loss           | 0.0772       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.123      |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 37          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007400301 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0132     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0665      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.122      |
# | time/                   |             |
# |    fps                  | 1456        |
# |    iterations           | 38          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008349279 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0171     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0852      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.127      |
# | time/                   |             |
# |    fps                  | 1456        |
# |    iterations           | 39          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008168029 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0154     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0654      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.121      |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 40          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007295674 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.015      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 0.992       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.12       |
# | time/                   |             |
# |    fps                  | 1452        |
# |    iterations           | 41          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008279632 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0359     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.991       |
# |    value_loss           | 0.0599      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.111      |
# | time/                   |             |
# |    fps                  | 1445        |
# |    iterations           | 42          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008959712 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0189     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.99        |
# |    value_loss           | 0.0854      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.108       |
# | time/                   |              |
# |    fps                  | 1440         |
# |    iterations           | 43           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0070729246 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.5        |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.000253     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0239      |
# |    std                  | 0.99         |
# |    value_loss           | 0.0748       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.105      |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 44          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008197878 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0283     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.99        |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.105      |
# | time/                   |             |
# |    fps                  | 1443        |
# |    iterations           | 45          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007605428 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.00353    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0843      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.111      |
# | time/                   |             |
# |    fps                  | 1443        |
# |    iterations           | 46          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008026525 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0025     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0937      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.114      |
# | time/                   |             |
# |    fps                  | 1445        |
# |    iterations           | 47          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008633828 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0429     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0316     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0697      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.12        |
# | time/                   |              |
# |    fps                  | 1443         |
# |    iterations           | 48           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0073072533 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.5        |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 0.00345      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0277      |
# |    std                  | 0.99         |
# |    value_loss           | 0.136        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -0.104       |
# | time/                   |              |
# |    fps                  | 1440         |
# |    iterations           | 49           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0072764596 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.5        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 2e-05        |
# |    loss                 | -0.0079      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0264      |
# |    std                  | 0.99         |
# |    value_loss           | 0.0956       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.0883     |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 50          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008134469 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0139     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.989       |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.0813     |
# | time/                   |             |
# |    fps                  | 1440        |
# |    iterations           | 51          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008694098 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.00969    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.989       |
# |    value_loss           | 0.0675      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -0.0949     |
# | time/                   |             |
# |    fps                  | 1439        |
# |    iterations           | 52          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008377051 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0277     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.989       |
# ...
# | train/                  |             |
# |    approx_kl            | 0.035603143 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.111      |
# |    n_updates            | 48658       |
# |    policy_gradient_loss | -0.0798     |
# |    std                  | 0.338       |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4868        |
# |    time_elapsed         | 6861        |
# |    total_timesteps      | 9969664     |
# | train/                  |             |
# |    approx_kl            | 0.037441995 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.108      |
# |    n_updates            | 48668       |
# |    policy_gradient_loss | -0.0812     |
# |    std                  | 0.338       |
# |    value_loss           | 0.0235      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2           |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4869        |
# |    time_elapsed         | 6862        |
# |    total_timesteps      | 9971712     |
# | train/                  |             |
# |    approx_kl            | 0.036457147 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.1        |
# |    n_updates            | 48678       |
# |    policy_gradient_loss | -0.0808     |
# |    std                  | 0.338       |
# |    value_loss           | 0.025       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 1.9        |
# | time/                   |            |
# |    fps                  | 1453       |
# |    iterations           | 4870       |
# |    time_elapsed         | 6863       |
# |    total_timesteps      | 9973760    |
# | train/                  |            |
# |    approx_kl            | 0.03563343 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.98      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 2e-05      |
# |    loss                 | -0.109     |
# |    n_updates            | 48688      |
# |    policy_gradient_loss | -0.0831    |
# |    std                  | 0.338      |
# |    value_loss           | 0.0132     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4871        |
# |    time_elapsed         | 6865        |
# |    total_timesteps      | 9975808     |
# | train/                  |             |
# |    approx_kl            | 0.036964856 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.118      |
# |    n_updates            | 48698       |
# |    policy_gradient_loss | -0.0814     |
# |    std                  | 0.338       |
# |    value_loss           | 0.0209      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4872        |
# |    time_elapsed         | 6866        |
# |    total_timesteps      | 9977856     |
# | train/                  |             |
# |    approx_kl            | 0.037519224 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0892     |
# |    n_updates            | 48708       |
# |    policy_gradient_loss | -0.08       |
# |    std                  | 0.338       |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 1.89       |
# | time/                   |            |
# |    fps                  | 1453       |
# |    iterations           | 4873       |
# |    time_elapsed         | 6867       |
# |    total_timesteps      | 9979904    |
# | train/                  |            |
# |    approx_kl            | 0.03913979 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 2e-05      |
# |    loss                 | -0.0922    |
# |    n_updates            | 48718      |
# |    policy_gradient_loss | -0.0827    |
# |    std                  | 0.338      |
# |    value_loss           | 0.0224     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 1.93       |
# | time/                   |            |
# |    fps                  | 1453       |
# |    iterations           | 4874       |
# |    time_elapsed         | 6868       |
# |    total_timesteps      | 9981952    |
# | train/                  |            |
# |    approx_kl            | 0.03730254 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.95      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 2e-05      |
# |    loss                 | -0.105     |
# |    n_updates            | 48728      |
# |    policy_gradient_loss | -0.0819    |
# |    std                  | 0.338      |
# |    value_loss           | 0.0227     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4875        |
# |    time_elapsed         | 6870        |
# |    total_timesteps      | 9984000     |
# | train/                  |             |
# |    approx_kl            | 0.041363765 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.112      |
# |    n_updates            | 48738       |
# |    policy_gradient_loss | -0.0847     |
# |    std                  | 0.338       |
# |    value_loss           | 0.0249      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4876        |
# |    time_elapsed         | 6871        |
# |    total_timesteps      | 9986048     |
# | train/                  |             |
# |    approx_kl            | 0.034997355 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.117      |
# |    n_updates            | 48748       |
# |    policy_gradient_loss | -0.0791     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4877        |
# |    time_elapsed         | 6872        |
# |    total_timesteps      | 9988096     |
# | train/                  |             |
# |    approx_kl            | 0.038599044 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.111      |
# |    n_updates            | 48758       |
# |    policy_gradient_loss | -0.0793     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0235      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.94        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4878        |
# |    time_elapsed         | 6873        |
# |    total_timesteps      | 9990144     |
# | train/                  |             |
# |    approx_kl            | 0.037770487 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0841     |
# |    n_updates            | 48768       |
# |    policy_gradient_loss | -0.0782     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0251      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.97        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4879        |
# |    time_elapsed         | 6875        |
# |    total_timesteps      | 9992192     |
# | train/                  |             |
# |    approx_kl            | 0.040614456 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.0953     |
# |    n_updates            | 48778       |
# |    policy_gradient_loss | -0.0804     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2.05        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4880        |
# |    time_elapsed         | 6876        |
# |    total_timesteps      | 9994240     |
# | train/                  |             |
# |    approx_kl            | 0.035377413 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.109      |
# |    n_updates            | 48788       |
# |    policy_gradient_loss | -0.0821     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2.06        |
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 4881        |
# |    time_elapsed         | 6877        |
# |    total_timesteps      | 9996288     |
# | train/                  |             |
# |    approx_kl            | 0.040933907 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 2e-05       |
# |    loss                 | -0.119      |
# |    n_updates            | 48798       |
# |    policy_gradient_loss | -0.0796     |
# |    std                  | 0.337       |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 1.97       |
# | time/                   |            |
# |    fps                  | 1453       |
# |    iterations           | 4882       |
# |    time_elapsed         | 6878       |
# |    total_timesteps      | 9998336    |
# | train/                  |            |
# |    approx_kl            | 0.03545767 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.93      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 2e-05      |
# |    loss                 | -0.0998    |
# |    n_updates            | 48808      |
# |    policy_gradient_loss | -0.0806    |
# |    std                  | 0.337      |
# |    value_loss           | 0.0316     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 1.91       |
# | time/                   |            |
# |    fps                  | 1453       |
# |    iterations           | 4883       |
# |    time_elapsed         | 6880       |
# |    total_timesteps      | 10000384   |
# | train/                  |            |
# |    approx_kl            | 0.03772781 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.93      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 2e-05      |
# |    loss                 | -0.0664    |
# |    n_updates            | 48818      |
# |    policy_gradient_loss | -0.0726    |
# |    std                  | 0.337      |
# |    value_loss           | 0.0191     |
# ----------------------------------------
# Training finished.
# Recording rollout...
# C:\Users\Brn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Saved swarm_bots_rollout_ppo_no_con.gif

# %%
record()
# Out:
# Recording rollout...
# Saved swarm_bots_rollout_ppo_no_con.gif
